# %%
# 导入必要的包
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import copy
import time
import pandas as pd

# %%
'''
产生初始解和初始目标函数X0和f0，初始化最优值记录器X*和f*

既然序列对可以表达模块的位置信息以及整体的最大长度和宽度
那么我们对模块进行乱序，随机生成一个序列对，一个正序列和一个负序列
目标函数就是该序列形成的矩形面积除以总面积，这样子就可以用求目标函数的最小值的方法求解该问题

while(不满足回火终止条件)
    t=t0
        while t>1e-3
            for i=0 i<L i++
                从四种新解中任选一种产生新解Xnew
                计算评价新解的目标函数fnew
                计算评价目标函数差df=fnew-f
                
                if df<0 or exp(-df/t)>random(0,1)
                    接受新解X=Xnew f=fnew
                    与最优值记录器比较，记录最优值
                else
                    还原原来的解
            下降温度 t=a*t
        以记录器的最优解作为下一个循环的初始解
    达不到要求，产生回火温度

'''

# %%
class module():
    def __init__(self, name='', typ='', w=0., h=0., pos=[], s=0.):
        self.name = name  #模块名称
        self.typ = typ    #模块类型
        self.w = w        #模块宽度
        self.h = h        #模块高度
        self.pos = pos    #模块位置:右下角、右上角、左上角、左下角(左下角一般为(0,0))
        self.s = s        #模块面积

# %%
def rdfile(filename,n):
    #filename是要读取的文件名，n为其中所包含的模块数
    
    #用于存储所有模块对象的列表
    modules = np.zeros(n-1,dtype=type(module('a','b',0.,0.,[],0.))) 
    t = 0
    s_total = 0.
    b1,b2 = 0,0

    #通过文件名打开数据流，按照行的顺序有规律地依次将模块名...读出，顺便创建模块对象放入数组中方便调用
    with open(filename,'r') as f:
        for line in f:
            line = line.split(' ')
            if 'MODULE' in line:
                #print(line[1].split(';')[0])
                name = line[1].split(';')[0]

            if 'TYPE' in line:
                typ = line[2]

            if 'DIMENSIONS' in line:
                #print(line[2:])
                w = 0.
                h = 0.
                pos = np.zeros(8)
                for i in range(10)[2:]:
                    if i != 9:
                        pos[i-2] = int(line[i])
                    else:
                        pos[i-2] = int(line[i].split(";")[0])
                # 用两个坐标值相减即可得到模块的宽高
                h = pos[3]-pos[1]
                w = pos[2]-pos[4]
                s = h*w
                if t == 33:
                    # 这里的s是parent模块的面积，其实实际上并没有使用到
                    s_total = s
                if t<n-1:
                    modules[t] = module(name,typ,w,h,pos,s)
                    t = t+1
                
    return modules,s_total

# %%
# 读取ami33和ami49并计算出它们模块的总面积（不包括parent）
modules,st = rdfile('ami33.yal',34)
modules1,st1 = rdfile('ami49.yal',50)
s = 0.
for i in range(33):
    s = s + modules[i].s
s1 = 0.
for i in range(49):
    s1 = s1 + modules1[i].s
print(s,s1)
# Out:
# 1156449.0 35445424.0

# %%
# m类，用于存储一组模块的布局
# x为正向序列，y为负向序列，modules则存储着从文件读取出来的各个模块的信息，比如宽w和高h
# m类中还存储着这组模块布局所代表的信息比如面积利用率use、总面积s_cur...其中的iuse是用于模拟退火算法，它是面积利用率的倒数
class m():
    def __init__(self, modules,s_total):
        self.modules = modules
        self.s_total = s_total
        self.l = len(modules)
        self.s_cur,self.iuse,self.use = 0.,0.,0.
        
        # 产生一个比较优的解，在此基础上进行模拟退火，这里随机产生可能没有对模块进行旋转
        # 可能在一定程度上会导致我们的初始解较差
        self.x,self.y,self.modules = self.xyInit()
        self.w,self.h = m.whSort(self.l, self.x, self.y, self.modules)
        self.s_cur,self.iuse,self.use = m.calSC(self.l, self.x, self.y, self.w, self.h, self.s_total) 
        
    # 计算当前模块布局的信息：总面积s_cur、面积利用率及其倒数
    def calSC(l,x,y,w,h,s_total):
        Lw,Pw,Lh,Ph = m.lcs_xy(l,x,y,w,h)
        s_cur = Lw*Lh
        iuse = s_cur/s_total
        use = s_total/s_cur
            
        return s_cur,iuse,use
    
    # 根据x和y序列还有模块序列（包含旋转信息），来生成新的模块宽高序列，用于LCS算法
    def whSort(l,x,y,modules):
        w = np.zeros(l)
        h = np.zeros(l)
        for i in range(l):
            w[i] = modules[i].w
            h[i] = modules[i].h
        return w,h
    
    # 初始化生成一组正向和反向序列--生成一个0到（总模块个数-1）长度的顺序序列，然后用shuffle打乱
    def xyInit(self):
        l = self.l
        tmp = np.zeros(l,dtype='int')
        for i in range(l):
            tmp[i] = i
            
        np.random.shuffle(tmp)
        x = copy.deepcopy(tmp)
        np.random.shuffle(tmp)
        y = copy.deepcopy(tmp)
        
        # 模块随机翻转
        md = copy.deepcopy(self.modules)
        for i in range(l):
            yes = random.randint(0,1)
            if yes:
                md[i].w,md[i].h = md[i].h,md[i].w 
            
        return x,y,md
    
    # lcs快速算法
    def lcs_xy(n,x,y,w,h):
        xr = x[::-1]
        Lw,Pw = m.lcs(n,x,y,w)
        Lh,Ph = m.lcs(n,xr,y,h)
        return Lw,Pw,Lh,Ph
    
    # lcs快速算法核心
    def lcs(n,x,y,w):
        # n个模块，x为正序列，y为负序列，w为每个模块的宽度/高度 
        class mdd():
            def __init__(self,x,y):
                self.x = x
                self.y = y

        match = np.zeros(n,dtype=type(mdd(3,4)))
        for i in range(len(x)):
            for j in range(len(y)):
                if x[i]==y[j]:
                    match[int(x[i]-1)] = mdd(i,j)
                    break
                    
        # 模块的位置P，总长度L
        P = np.zeros(n)
        L = np.zeros(n)

        for i in range(n):
            b = int(x[i]-1)
            p = int(match[b].y)
            P[b] = L[p]
            t = P[b] + w[b]
            for j in range(n)[p:n]:
                if t > L[j]:
                    L[j] = t
                else:
                    break

        return L[n-1],P
    
    def refresh(self):
        # 由于x,y,modules的改变，需要更新数据
        self.w,self.h = m.whSort(self.l, self.x, self.y, self.modules)
        self.s_cur,self.iuse,self.use = m.calSC(self.l, self.x, self.y, self.w, self.h, self.s_total) 
    
    def exchangeX(self,pos1,pos2):
        # 第1个随机模块与第2个随机模块交换正序列中的位置
        id1 = np.array(np.where(self.x==pos1))[0][0]
        id2 = np.array(np.where(self.x==pos2))[0][0] 
        x1 = copy.deepcopy(self.x)
        x1[id1],x1[id2] = x1[id2],x1[id1]
        self.x = x1
        return
    
    def exchangeY(self,pos1,pos2):
        # 第1个随机模块与第2个随机模块交换负序列中的位置
        id1 = np.array(np.where(self.y==pos1))[0][0]
        id2 = np.array(np.where(self.y==pos2))[0][0]
        y1 = copy.deepcopy(self.y)
        y1[id1],y1[id2] = y1[id2],y1[id1]
        self.y = y1
        return
    
    def exchangeXY(self,pos1,pos2):
        # 第1个随机模块与第2个随机模块交换正负序列中的位置
        self.exchangeX(pos1,pos2)
        self.exchangeY(pos1,pos2)
        return
    
    def exchangeWH(self,pos):
        # 旋转模块
        md = copy.deepcopy(self.modules)
        md[pos].w,md[pos].h = md[pos].h,md[pos].w 
        self.modules = md
        return

# %%
# SA类 进行模拟退火算法的框架
# 包含3个主要的方法：产生新解、Metropolis准则、运行
class SA:
    def __init__(self, m1, m2, m3, s_total, iter=4000, T0=400, Tf=0.01, alpha=0.95):
        self.iter = iter         #内循环迭代次数,即为L =100
        self.alpha = alpha       #降温系数，alpha=0.95
        self.T0 = T0             #初始温度T0为400
        self.Tf = Tf             #温度终值Tf为0.01
        self.T = T0              #当前温度
        
        # 生成初始解
        self.m1 = m1
        # 用于保存局部最优解&全局最优解
        self.m2 = m2
        self.m3 = m3
        
        # 模块的一些相关信息，模块个数&模块总面积
        self.l = self.m1.l
        self.s_total = self.m1.s_total
        
        # 存放解的序列对
        self.xi = np.zeros((self.iter,self.l),dtype='int')
        self.yi = np.zeros((self.iter,self.l),dtype='int')
        self.modulesi = np.zeros((self.iter,self.l),dtype=type(module()))
                                 
        # 存放f的历史，用于生成图像
        self.history = {'f': [], 'T': []}

    def generate_new(self):   #扰动产生新解的过程
        rand,rand1,rand2 = 0,0,0
        # 选择产生新解的方式
        rand = random.randint(1,4)
        
        while rand1 == rand2:
            rand1 = random.randint(0,self.l-1)
            rand2 = random.randint(0,self.l-1)
            
        if rand == 1:
            #正向序列中交换两个模块的顺序
            self.m1.exchangeX(rand1,rand2)
        elif rand == 2:
            #负向序列中交换两个模块的顺序
            self.m1.exchangeY(rand1,rand2)
        elif rand == 3:
            #正向序列和负向序列中同时交换两个模块的顺序
            self.m1.exchangeXY(rand1,rand2)
        else:
            #将某个模块旋转，即将模块中的宽和高对调
            self.m1.exchangeWH(rand1)
            
        self.m1.refresh()
            
        return 

    def Metrospolis(self, f, f_new):   #Metropolis准则
        if f_new <= f:
            if self.m1.iuse < self.m3.iuse:
                self.m3.x,self.m3.y,self.m3.modules = copy.deepcopy(self.m1.x),copy.deepcopy(self.m1.y),copy.deepcopy(self.m1.modules)
                self.m3.refresh()
            return 1
        else:
            p = math.exp((f - f_new) / self.T)
            if np.random.rand() < p:
                return 1
            else:
                return 0

    
    def run(self):
        count = 0   #迭代计数器
        count1 = 0  #回火计数器
        
        #外循环迭代，当前温度小于终止温度的阈值
        while self.T > self.Tf:  
            #用于存放一次迭代的中间结果
            t= []   
            #内循环迭代
            for i in range(self.iter): 
                #f为迭代一次后的值
                f = self.m2.iuse
                #产生新解
                self.generate_new()
                x_new,y_new,modules_new = copy.deepcopy(self.m1.x),copy.deepcopy(self.m1.y),copy.deepcopy(self.m1.modules)
                #产生新值
                f_new = self.m1.iuse
                #判断是否接受新值
                if self.Metrospolis(f, f_new):
                    self.xi[i] = x_new
                    self.yi[i] = y_new
                    self.modulesi[i] = modules_new
                    t.append(f_new)
                else:
                    t.append(self.m1.iuse)
                    if i>= 1:
                        self.m1.x = copy.deepcopy(self.xi[i-1])
                        self.m1.y = copy.deepcopy(self.yi[i-1])
                        self.m1.modules = copy.deepcopy(self.modulesi[i-1])
                        self.m1.refresh()
            
                    
            f_best = min(t)
            idx = t.index(f_best)
            
            # 将当前局部最优解作为下一次迭代的初始解
            self.m1.x = copy.deepcopy(self.m3.x)
            self.m1.y = copy.deepcopy(self.m3.y)
            self.m1.modules = copy.deepcopy(self.m3.modules)
            self.m1.refresh()
            
            # 保存局部最优解，但是好像没用
            self.m2.x = copy.deepcopy(self.xi[idx])
            self.m2.y = copy.deepcopy(self.yi[idx])
            self.m2.modules = copy.deepcopy(self.modulesi[idx])
            self.m2.refresh()
            
            # 迭代L次记录在该温度下最优解
            self.history['f'].append(f_best)
            self.history['T'].append(self.T)
            
            #温度按照一定的比例下降（冷却）+回火
            self.T = self.T * self.alpha  
            
            if self.T <= self.Tf:
                count1 += 1
                if self.m3.use < 0.9 and count1 == 1:
                    self.T = self.T0
                    #print("现在的结果好像不是很好，我的建议是回火！这是第" + str(count1) + "次回火")
                    
            
            print("第"+str(count)+"次迭代，局部最优结果为："+str(1/f_best))
            self.m3.refresh()
            print("当前最优结果:"+str(self.m3.use))
            
            
        return

# %%
mmm = []
TTT = []
fff = []
sss = []
for i in range(30):
    t1 = time.time()
    m1 = m(modules,s)
    m2 = m(modules,s)
    m3 = m(modules,s)
    sa = SA(m1,m2,m3,s)
    sa.run()
    t2 = time.time()
    t = t2-t1
    mmm.append(sa.m3)
    TTT.append(sa.history['T'])
    fff.append(sa.history['f'])
    sss.append(t)
    print("本次退火用时："+str(t))
# Out:
# 第0次迭代，局部最优结果为：0.5649956908934214
# 当前最优结果:0.5649956908934214
# 第0次迭代，局部最优结果为：0.5473330241187384
# 当前最优结果:0.5649956908934214
# 第0次迭代，局部最优结果为：0.5041548287868755
# 当前最优结果:0.5649956908934214
# 第0次迭代，局部最优结果为：0.5347820175836128
# 当前最优结果:0.5649956908934214
# 第0次迭代，局部最优结果为：0.59847850893876
# 当前最优结果:0.59847850893876
# 第0次迭代，局部最优结果为：0.5659847957984604
# 当前最优结果:0.59847850893876
# 第0次迭代，局部最优结果为：0.5741078595927899
# 当前最优结果:0.59847850893876
# 第0次迭代，局部最优结果为：0.5172481809415271
# 当前最优结果:0.59847850893876
# 第0次迭代，局部最优结果为：0.59847850893876
# 当前最优结果:0.59847850893876
# 第0次迭代，局部最优结果为：0.5789667353547248
# 当前最优结果:0.59847850893876
# 第0次迭代，局部最优结果为：0.5604340805471124
# 当前最优结果:0.59847850893876
# 第0次迭代，局部最优结果为：0.59847850893876
# 当前最优结果:0.59847850893876
# 第0次迭代，局部最优结果为：0.5722703135229504
# 当前最优结果:0.59847850893876
# 第0次迭代，局部最优结果为：0.5041655985644706
# 当前最优结果:0.59847850893876
# 第0次迭代，局部最优结果为：0.613889972688256
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.5821370430664496
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.5445798144815174
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.5785125992744387
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.5276796494209185
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.5560503251342945
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.5935118823085628
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.613889972688256
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.5434262030854248
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.5793078055964654
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.5148560209424083
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.613889972688256
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.575746487119438
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.613889972688256
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.6054798737781882
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.5658762318076103
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.5227937267410951
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.5790945896209054
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.5195482763175274
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.613889972688256
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.553546298902336
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.6252583055158163
# 当前最优结果:0.6252583055158163
# 第0次迭代，局部最优结果为：0.5382825863838522
# 当前最优结果:0.6252583055158163
# 第0次迭代，局部最优结果为：0.6252583055158163
# 当前最优结果:0.6252583055158163
# 第0次迭代，局部最优结果为：0.57552184939524
# 当前最优结果:0.6252583055158163
# 第0次迭代，局部最优结果为：0.613889972688256
# 当前最优结果:0.6252583055158163
# 第0次迭代，局部最优结果为：0.5995275110501448
# 当前最优结果:0.6252583055158163
# 第0次迭代，局部最优结果为：0.5534684114253553
# 当前最优结果:0.6252583055158163
# 第0次迭代，局部最优结果为：0.5923499736465627
# 当前最优结果:0.6252583055158163
# 第0次迭代，局部最优结果为：0.6256892895015908
# 当前最优结果:0.6256892895015906
# 第0次迭代，局部最优结果为：0.6542747837658017
# 当前最优结果:0.6542747837658017
# 第0次迭代，局部最优结果为：0.6036678944137508
# 当前最优结果:0.6542747837658017
# 第0次迭代，局部最优结果为：0.596587462082912
# 当前最优结果:0.6542747837658017
# 第0次迭代，局部最优结果为：0.6542747837658017
# 当前最优结果:0.6542747837658017
# 第0次迭代，局部最优结果为：0.5888473053892216
# 当前最优结果:0.6542747837658017
# 第0次迭代，局部最优结果为：0.5926921145153189
# 当前最优结果:0.6542747837658017
# 第0次迭代，局部最优结果为：0.6786576949620428
# 当前最优结果:0.6786576949620428
# 第0次迭代，局部最优结果为：0.5110432636091984
# 当前最优结果:0.6786576949620428
# 第0次迭代，局部最优结果为：0.6462486308871851
# 当前最优结果:0.6786576949620428
# 第0次迭代，局部最优结果为：0.6786576949620428
# 当前最优结果:0.6786576949620428
# 第0次迭代，局部最优结果为：0.5938254830917874
# 当前最优结果:0.6786576949620428
# 第0次迭代，局部最优结果为：0.5850810650007436
# 当前最优结果:0.6786576949620428
# 第0次迭代，局部最优结果为：0.5840964213235659
# 当前最优结果:0.6786576949620428
# 第0次迭代，局部最优结果为：0.5750730994152047
# 当前最优结果:0.6786576949620428
# 第0次迭代，局部最优结果为：0.6786576949620428
# 当前最优结果:0.6786576949620428
# 第0次迭代，局部最优结果为：0.642938868911409
# 当前最优结果:0.6786576949620428
# 第0次迭代，局部最优结果为：0.6057440583132283
# 当前最优结果:0.6786576949620428
# 第0次迭代，局部最优结果为：0.6104127870887647
# 当前最优结果:0.6786576949620428
# 第0次迭代，局部最优结果为：0.6786576949620428
# 当前最优结果:0.6786576949620428
# 第0次迭代，局部最优结果为：0.6107919254658385
# 当前最优结果:0.6786576949620428
# 第0次迭代，局部最优结果为：0.6914625571311379
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6587306017639835
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6871942697414396
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.67243147757707
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.5573766620220579
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6914625571311379
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6150578546857083
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.5888913840856351
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.5679871005005777
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.5703893467385263
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.5635252262362408
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6914625571311379
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.5573766620220579
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6871942697414396
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.5629338103756709
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6871942697414396
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.5302999662959218
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6871942697414396
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6914625571311379
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6544199201419698
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6914625571311379
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6472233648704236
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6746998284734134
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6914625571311379
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6139698231009365
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.611678415923699
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6534053156146179
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.5985240413877054
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.5601148661477122
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.5811908983451537
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6914625571311379
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.5873525459160818
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6007942366927169
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6343331720690212
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6914625571311379
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.681814242380471
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6376752857258653
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.5991926475068549
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.592394578313253
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6237050739957717
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.5644281819486296
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6914625571311379
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6434998364052786
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6161175794914635
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6706353716753808
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6914625571311379
# 当前最优结果:0.6914625571311379
# 第0次迭代，局部最优结果为：0.6980479148181011
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.590025
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6811255411255411
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6457711987304019
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6044718778813646
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6236721103535754
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6470104449379062
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6385551948051948
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6980479148181011
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6340264345583494
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6937389770723104
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6864147980106449
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.627102431247509
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6644425675675675
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6786576949620428
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.681814242380471
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6850002902420619
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6214223649911793
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6882162540460153
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6980479148181011
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6766341743119266
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6521775174090858
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6336689488521949
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6555833333333334
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6980479148181011
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6546740638002775
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6980479148181011
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6980479148181011
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6980479148181011
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6867143854748603
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6486285934150497
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6937389770723104
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6767311827956989
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6648918187964841
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6465495986631236
# 当前最优结果:0.6980479148181011
# 第0次迭代，局部最优结果为：0.6984610831606984
# 当前最优结果:0.6984610831606984
# 第0次迭代，局部最优结果为：0.6766341743119266
# 当前最优结果:0.6984610831606984
# 第0次迭代，局部最优结果为：0.6860755813953489
# 当前最优结果:0.6984610831606984
# 第0次迭代，局部最优结果为：0.7009712198164484
# 当前最优结果:0.7009712198164484
# 第0次迭代，局部最优结果为：0.6954151688372915
# 当前最优结果:0.7009712198164484
# 第0次迭代，局部最优结果为：0.6748155772859838
# 当前最优结果:0.7009712198164484
# 第0次迭代，局部最优结果为：0.6961536192555012
# 当前最优结果:0.7009712198164484
# 第0次迭代，局部最优结果为：0.6730451149261393
# 当前最优结果:0.7009712198164484
# 第0次迭代，局部最优结果为：0.6811255411255411
# 当前最优结果:0.7009712198164484
# 第0次迭代，局部最优结果为：0.6811255411255411
# 当前最优结果:0.7009712198164484
# 第0次迭代，局部最优结果为：0.6703306066803
# 当前最优结果:0.7009712198164484
# 第0次迭代，局部最优结果为：0.6767311827956989
# 当前最优结果:0.7009712198164484
# 第0次迭代，局部最优结果为：0.7009712198164484
# 当前最优结果:0.7009712198164484
# 第0次迭代，局部最优结果为：0.7009712198164484
# 当前最优结果:0.7009712198164484
# 第0次迭代，局部最优结果为：0.7292361883574341
# 当前最优结果:0.7292361883574342
# 第0次迭代，局部最优结果为：0.6734484234555572
# 当前最优结果:0.7292361883574342
# 第0次迭代，局部最优结果为：0.7239570552147239
# 当前最优结果:0.7292361883574342
# 第0次迭代，局部最优结果为：0.7120101366639515
# 当前最优结果:0.7292361883574342
# 第0次迭代，局部最优结果为：0.7120101366639515
# 当前最优结果:0.7292361883574342
# 第0次迭代，局部最优结果为：0.7230698529411764
# 当前最优结果:0.7292361883574342
# 第0次迭代，局部最优结果为：0.7312697527421455
# 当前最优结果:0.7312697527421453
# 第0次迭代，局部最优结果为：0.7312697527421455
# 当前最优结果:0.7312697527421453
# 第0次迭代，局部最优结果为：0.7416101055806938
# 当前最优结果:0.7416101055806938
# 第0次迭代，局部最优结果为：0.7312697527421455
# 当前最优结果:0.7416101055806938
# 第0次迭代，局部最优结果为：0.7312697527421455
# 当前最优结果:0.7416101055806938
# 第0次迭代，局部最优结果为：0.7561514801999231
# 当前最优结果:0.7561514801999231
# 第0次迭代，局部最优结果为：0.7380617318697814
# 当前最优结果:0.7561514801999231
# 第0次迭代，局部最优结果为：0.724534905139068
# 当前最优结果:0.7561514801999231
# 第0次迭代，局部最优结果为：0.7561514801999231
# 当前最优结果:0.7561514801999231
# 第0次迭代，局部最优结果为：0.7512414056531704
# 当前最优结果:0.7561514801999231
# 第0次迭代，局部最优结果为：0.7512414056531704
# 当前最优结果:0.7561514801999231
# 第0次迭代，局部最优结果为：0.7561514801999231
# 当前最优结果:0.7561514801999231
# 第0次迭代，局部最优结果为：0.7561514801999231
# 当前最优结果:0.7561514801999231
# 第0次迭代，局部最优结果为：0.7764508487958942
# 当前最优结果:0.7764508487958942
# 第0次迭代，局部最优结果为：0.7764508487958942
# 当前最优结果:0.7764508487958942
# 第0次迭代，局部最优结果为：0.7764508487958942
# 当前最优结果:0.7764508487958942
# 第0次迭代，局部最优结果为：0.7764508487958942
# 当前最优结果:0.7764508487958942
# 第0次迭代，局部最优结果为：0.7764508487958942
# 当前最优结果:0.7764508487958942
# 第0次迭代，局部最优结果为：0.766664501039501
# 当前最优结果:0.7764508487958942
# 第0次迭代，局部最优结果为：0.7764508487958942
# 当前最优结果:0.7764508487958942
# 第0次迭代，局部最优结果为：0.7802499338799259
# 当前最优结果:0.7802499338799259
# 第0次迭代，局部最优结果为：0.7764508487958942
# 当前最优结果:0.7802499338799259
# 第0次迭代，局部最优结果为：0.7764508487958942
# 当前最优结果:0.7802499338799259
# 第0次迭代，局部最优结果为：0.7802499338799259
# 当前最优结果:0.7802499338799259
# 第0次迭代，局部最优结果为：0.7802499338799259
# 当前最优结果:0.7802499338799259
# 第0次迭代，局部最优结果为：0.7802499338799259
# 当前最优结果:0.7802499338799259
# 第0次迭代，局部最优结果为：0.7802499338799259
# 当前最优结果:0.7802499338799259
# 第0次迭代，局部最优结果为：0.7841905901116427
# 当前最优结果:0.7841905901116427
# 第0次迭代，局部最优结果为：0.7764508487958942
# 当前最优结果:0.7841905901116427
# 第0次迭代，局部最优结果为：0.7841905901116427
# 当前最优结果:0.7841905901116427
# 第0次迭代，局部最优结果为：0.7778839815425181
# 当前最优结果:0.7841905901116427
# 第0次迭代，局部最优结果为：0.7578754696380977
# 当前最优结果:0.7841905901116427
# 第0次迭代，局部最优结果为：0.7870148059223689
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7686620635747786
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7764508487958942
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7841905901116427
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7544112006137322
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7870148059223689
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7870148059223689
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7841905901116427
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7841905901116427
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7841905901116427
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7870148059223689
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7870148059223689
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7645286686103012
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7512414056531704
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7870148059223689
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7199816961561928
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.5996189024390244
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.6970583023214603
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.6536224659355268
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7097618188379646
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.603343814709717
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.5389832830912579
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.6391777705557361
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.587264855180651
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7870148059223689
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7870148059223689
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.6713984979517524
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.6492888387575999
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.6389701104613386
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.6553102873802582
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7645286686103012
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7870148059223689
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7097618188379646
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7870148059223689
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7208172988821696
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7054340028694405
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7712745098039215
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7105310693641618
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.743291761148904
# 当前最优结果:0.7870148059223689
# 第0次迭代，局部最优结果为：0.7999796623957699
# 当前最优结果:0.7999796623957698
# 第0次迭代，局部最优结果为：0.7401680988521607
# 当前最优结果:0.7999796623957698
# 第0次迭代，局部最优结果为：0.7999796623957699
# 当前最优结果:0.7999796623957698
# 第0次迭代，局部最优结果为：0.7999796623957699
# 当前最优结果:0.7999796623957698
# 第0次迭代，局部最优结果为：0.7318139534883721
# 当前最优结果:0.7999796623957698
# 第0次迭代，局部最优结果为：0.5757605327998829
# 当前最优结果:0.7999796623957698
# 第0次迭代，局部最优结果为：0.7924053182917001
# 当前最优结果:0.7999796623957698
# 第0次迭代，局部最优结果为：0.8067890472772022
# 当前最优结果:0.8067890472772024
# 第0次迭代，局部最优结果为：0.7645286686103012
# 当前最优结果:0.8067890472772024
# 第0次迭代，局部最优结果为：0.8067890472772022
# 当前最优结果:0.8067890472772024
# 第0次迭代，局部最优结果为：0.8067890472772022
# 当前最优结果:0.8067890472772024
# 第0次迭代，局部最优结果为：0.6245137731205843
# 当前最优结果:0.8067890472772024
# 第0次迭代，局部最优结果为：0.5819934898402052
# 当前最优结果:0.8067890472772024
# 第0次迭代，局部最优结果为：0.7662662337662338
# 当前最优结果:0.8067890472772024
# 第0次迭代，局部最优结果为：0.6689625850340135
# 当前最优结果:0.8067890472772024
# 第0次迭代，局部最优结果为：0.733109682229056
# 当前最优结果:0.8067890472772024
# 第0次迭代，局部最优结果为：0.7793738854765208
# 当前最优结果:0.8067890472772024
# 第0次迭代，局部最优结果为：0.7999796623957699
# 当前最优结果:0.8067890472772024
# 第0次迭代，局部最优结果为：0.6020202535520242
# 当前最优结果:0.8067890472772024
# 第0次迭代，局部最优结果为：0.630671797338464
# 当前最优结果:0.8067890472772024
# 第0次迭代，局部最优结果为：0.5902611044417767
# 当前最优结果:0.8067890472772024
# 第0次迭代，局部最优结果为：0.6855375141603974
# 当前最优结果:0.8067890472772024
# 第0次迭代，局部最优结果为：0.810863739435168
# 当前最优结果:0.810863739435168
# 第0次迭代，局部最优结果为：0.6186369593709043
# 当前最优结果:0.810863739435168
# 第0次迭代，局部最优结果为：0.5975239252620386
# 当前最优结果:0.810863739435168
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6679780369070532
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7082070517629407
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.5164784663865546
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7771667544783983
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7963087927660435
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7381309814224056
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6622053872053872
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.5471807474728739
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6622053872053872
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7146620639534883
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6050607598830948
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6411921321451858
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.669645897173987
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7999796623957699
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.5950231948366277
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7999796623957699
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.759876364338839
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7449340319424279
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7403538490495012
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6585467939059099
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7150734737161036
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7589234034343044
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6795370130431027
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7963087927660435
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6389701104613386
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6772555096418732
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.5566011037215226
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.5899365095235715
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6549284049284049
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.766116990196715
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7180540343190945
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7281562384302109
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.687935406768298
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.5938254830917874
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.5673317307692308
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7312697527421455
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7841905901116427
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6144173695720088
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6455945509751894
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6455945509751894
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7314510630384925
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6223071852340145
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7999796623957699
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6549284049284049
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6279533844189017
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7924053182917001
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7740062967335695
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.633074034334764
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6119004407570651
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7740062967335695
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7439477997730425
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6734292073275124
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7841905901116427
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.748382800608828
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7224058769513315
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6930056377730797
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6521054376657826
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7625032308089946
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.766116990196715
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6930056377730797
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7125045284385944
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7011586452762923
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7449810606060606
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7403538490495012
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7500715080247895
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.766116990196715
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.73986645349384
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7284259259259259
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6519613259668509
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7841905901116427
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7841905901116427
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7502384131222581
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7081008100810081
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.6811255411255411
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7146620639534883
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7105310693641618
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7314510630384925
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7403538490495012
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7449340319424279
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.789383905277945
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.733109682229056
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.733109682229056
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7184474885844749
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7592163674966224
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7640831390831392
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7357837635615413
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7640831390831392
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7640831390831392
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7640831390831392
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7452633573323229
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7640831390831392
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7640831390831392
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7640831390831392
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7575349061145883
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7592163674966224
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7640831390831392
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7506201895553718
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7640831390831392
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7855478631340701
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7855478631340701
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7855478631340701
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7855478631340701
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.816417600664176
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7855478631340701
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7855478631340701
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7963087927660435
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.8002509155025092
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.7894367139416645
# 当前最优结果:0.816417600664176
# 第0次迭代，局部最优结果为：0.827756734006734
# 当前最优结果:0.827756734006734
# 第0次迭代，局部最优结果为：0.827756734006734
# 当前最优结果:0.827756734006734
# 第0次迭代，局部最优结果为：0.827756734006734
# 当前最优结果:0.827756734006734
# 第0次迭代，局部最优结果为：0.827756734006734
# 当前最优结果:0.827756734006734
# 第0次迭代，局部最优结果为：0.8113655115511551
# 当前最优结果:0.827756734006734
# 第0次迭代，局部最优结果为：0.8042322633408301
# 当前最优结果:0.827756734006734
# 第0次迭代，局部最优结果为：0.8018005775437405
# 当前最优结果:0.827756734006734
# 第0次迭代，局部最优结果为：0.7724862529457973
# 当前最优结果:0.827756734006734
# 第0次迭代，局部最优结果为：0.8053849303849303
# 当前最优结果:0.827756734006734
# 第0次迭代，局部最优结果为：0.789383905277945
# 当前最优结果:0.827756734006734
# 第0次迭代，局部最优结果为：0.827756734006734
# 当前最优结果:0.827756734006734
# 第0次迭代，局部最优结果为：0.8018005775437405
# 当前最优结果:0.827756734006734
# 第0次迭代，局部最优结果为：0.7587770061728395
# 当前最优结果:0.827756734006734
# 第0次迭代，局部最优结果为：0.827756734006734
# 当前最优结果:0.827756734006734
# 第0次迭代，局部最优结果为：0.827756734006734
# 当前最优结果:0.827756734006734
# 第0次迭代，局部最优结果为：0.8154021558872305
# 当前最优结果:0.827756734006734
# 第0次迭代，局部最优结果为：0.6379855648365906
# 当前最优结果:0.827756734006734
# 第0次迭代，局部最优结果为：0.7137543095626928
# 当前最优结果:0.827756734006734
# 第0次迭代，局部最优结果为：0.6889998248379752
# 当前最优结果:0.827756734006734
# 第0次迭代，局部最优结果为：0.810863739435168
# 当前最优结果:0.827756734006734
# 第0次迭代，局部最优结果为：0.827756734006734
# 当前最优结果:0.827756734006734
# 本次退火用时：5212.610944271088
# 第0次迭代，局部最优结果为：0.48657842652152405
# 当前最优结果:0.486578426521524
# 第0次迭代，局部最优结果为：0.5224812379624095
# 当前最优结果:0.5224812379624095
# 第0次迭代，局部最优结果为：0.5756060679966831
# 当前最优结果:0.5756060679966831
# 第0次迭代，局部最优结果为：0.48483914704794767
# 当前最优结果:0.5756060679966831
# 第0次迭代，局部最优结果为：0.5407120601173021
# 当前最优结果:0.5756060679966831
# 第0次迭代，局部最优结果为：0.5328862697283749
# 当前最优结果:0.5756060679966831
# 第0次迭代，局部最优结果为：0.5556314153875129
# 当前最优结果:0.5756060679966831
# 第0次迭代，局部最优结果为：0.5587754812131543
# 当前最优结果:0.5756060679966831
# 第0次迭代，局部最优结果为：0.5756060679966831
# 当前最优结果:0.5756060679966831
# 第0次迭代，局部最优结果为：0.5768300134425027
# 当前最优结果:0.5768300134425027
# 第0次迭代，局部最优结果为：0.5768300134425027
# 当前最优结果:0.5768300134425027
# 第0次迭代，局部最优结果为：0.5139031028851389
# 当前最优结果:0.5768300134425027
# 第0次迭代，局部最优结果为：0.531554054054054
# 当前最优结果:0.5768300134425027
# 第0次迭代，局部最优结果为：0.5047262617621899
# 当前最优结果:0.5768300134425027
# 第0次迭代，局部最优结果为：0.5472061210294459
# 当前最优结果:0.5768300134425027
# 第0次迭代，局部最优结果为：0.5542092286016203
# 当前最优结果:0.5768300134425027
# 第0次迭代，局部最优结果为：0.5394021118069205
# 当前最优结果:0.5768300134425027
# 第0次迭代，局部最优结果为：0.590025
# 当前最优结果:0.590025
# 第0次迭代，局部最优结果为：0.5807332677165354
# 当前最优结果:0.590025
# 第0次迭代，局部最优结果为：0.5245016334422294
# 当前最优结果:0.590025
# 第0次迭代，局部最优结果为：0.5353157321720196
# 当前最优结果:0.590025
# 第0次迭代，局部最优结果为：0.5266434596331504
# 当前最优结果:0.590025
# 第0次迭代，局部最优结果为：0.5971912955465587
# 当前最优结果:0.5971912955465587
# 第0次迭代，局部最优结果为：0.5971912955465587
# 当前最优结果:0.5971912955465587
# 第0次迭代，局部最优结果为：0.5827119648412424
# 当前最优结果:0.5971912955465587
# 第0次迭代，局部最优结果为：0.5889207735495945
# 当前最优结果:0.5971912955465587
# 第0次迭代，局部最优结果为：0.5971912955465587
# 当前最优结果:0.5971912955465587
# 第0次迭代，局部最优结果为：0.4888460821475175
# 当前最优结果:0.5971912955465587
# 第0次迭代，局部最优结果为：0.5088176957571576
# 当前最优结果:0.5971912955465587
# 第0次迭代，局部最优结果为：0.5756060679966831
# 当前最优结果:0.5971912955465587
# 第0次迭代，局部最优结果为：0.613889972688256
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.588142942583732
# 当前最优结果:0.613889972688256
# 第0次迭代，局部最优结果为：0.6541115822732185
# 当前最优结果:0.6541115822732186
# 第0次迭代，局部最优结果为：0.5326337169939065
# 当前最优结果:0.6541115822732186
# 第0次迭代，局部最优结果为：0.6112190195012043
# 当前最优结果:0.6541115822732186
# 第0次迭代，局部最优结果为：0.6541115822732185
# 当前最优结果:0.6541115822732186
# 第0次迭代，局部最优结果为：0.594903206291591
# 当前最优结果:0.6541115822732186
# 第0次迭代，局部最优结果为：0.6798893786189613
# 当前最优结果:0.6798893786189611
# 第0次迭代，局部最优结果为：0.6798893786189613
# 当前最优结果:0.6798893786189611
# 第0次迭代，局部最优结果为：0.5650497988891017
# 当前最优结果:0.6798893786189611
# 第0次迭代，局部最优结果为：0.5931687946114407
# 当前最优结果:0.6798893786189611
# 第0次迭代，局部最优结果为：0.6920302603800141
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.6119004407570651
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.5221460176991151
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.6173101067168864
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.6353064685455867
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.6920302603800141
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.6427287581699347
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.6166649247491639
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.6356658047834518
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.5871771906254665
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.5927516576250753
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.5367767467248908
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.629914324605653
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.668167147953117
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.6495032611387842
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.6527366761622923
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.6605743394536499
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.6735445205479451
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.6081948202551217
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.6920302603800141
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.6060862865947612
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.6357171717171717
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.5687536148062464
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.6217006480164375
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.6086967735279706
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.5562731279609683
# 当前最优结果:0.692030260380014
# 第0次迭代，局部最优结果为：0.6961741541547447
# 当前最优结果:0.6961741541547447
# 第0次迭代，局部最优结果为：0.657317922294945
# 当前最优结果:0.6961741541547447
# 第0次迭代，局部最优结果为：0.6704829545454546
# 当前最优结果:0.6961741541547447
# 第0次迭代，局部最优结果为：0.699620560858481
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.6954561527581329
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.5988277681924287
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.6761882932699196
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.6144493621452747
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.6020663265306123
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.561287100456621
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.6346914078257362
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.6423788786064235
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.699620560858481
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.6714749061113008
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.6029276517473942
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.5595305832147938
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.699620560858481
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.6225698382969743
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.6453121154950374
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.684563174382179
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.613459139114161
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.575549919523972
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.6225698382969743
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.6214714556562039
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.699620560858481
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.557468820861678
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.6487355689939527
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.5455743313530133
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.699620560858481
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.6039459542453555
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.5520443488023952
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.5642797369994023
# 当前最优结果:0.699620560858481
# 第0次迭代，局部最优结果为：0.7024107142857142
# 当前最优结果:0.7024107142857143
# 第0次迭代，局部最优结果为：0.6100341191066998
# 当前最优结果:0.7024107142857143
# 第0次迭代，局部最优结果为：0.6299647661755285
# 当前最优结果:0.7024107142857143
# 第0次迭代，局部最优结果为：0.7024107142857142
# 当前最优结果:0.7024107142857143
# 第0次迭代，局部最优结果为：0.633158953722334
# 当前最优结果:0.7024107142857143
# 第0次迭代，局部最优结果为：0.6107919254658385
# 当前最优结果:0.7024107142857143
# 第0次迭代，局部最优结果为：0.6704829545454546
# 当前最优结果:0.7024107142857143
# 第0次迭代，局部最优结果为：0.5975239252620386
# 当前最优结果:0.7024107142857143
# 第0次迭代，局部最优结果为：0.6178272251308901
# 当前最优结果:0.7024107142857143
# 第0次迭代，局部最优结果为：0.6982544378698224
# 当前最优结果:0.7024107142857143
# 第0次迭代，局部最优结果为：0.6299647661755285
# 当前最优结果:0.7024107142857143
# 第0次迭代，局部最优结果为：0.650380291005291
# 当前最优结果:0.7024107142857143
# 第0次迭代，局部最优结果为：0.7024107142857142
# 当前最优结果:0.7024107142857143
# 第0次迭代，局部最优结果为：0.7024107142857142
# 当前最优结果:0.7024107142857143
# 第0次迭代，局部最优结果为：0.6188640654499685
# 当前最优结果:0.7024107142857143
# 第0次迭代，局部最优结果为：0.6322769041176628
# 当前最优结果:0.7024107142857143
# 第0次迭代，局部最优结果为：0.6318537159991433
# 当前最优结果:0.7024107142857143
# 第0次迭代，局部最优结果为：0.6299647661755285
# 当前最优结果:0.7024107142857143
# 第0次迭代，局部最优结果为：0.709505772005772
# 当前最优结果:0.709505772005772
# 第0次迭代，局部最优结果为：0.7059404163675521
# 当前最优结果:0.709505772005772
# 第0次迭代，局部最优结果为：0.6819521497919556
# 当前最优结果:0.709505772005772
# 第0次迭代，局部最优结果为：0.6819521497919556
# 当前最优结果:0.709505772005772
# 第0次迭代，局部最优结果为：0.7137543095626928
# 当前最优结果:0.7137543095626928
# 第0次迭代，局部最优结果为：0.709505772005772
# 当前最优结果:0.7137543095626928
# 第0次迭代，局部最优结果为：0.644413499344692
# 当前最优结果:0.7137543095626928
# 第0次迭代，局部最优结果为：0.709505772005772
# 当前最优结果:0.7137543095626928
# 第0次迭代，局部最优结果为：0.6850400557297109
# 当前最优结果:0.7137543095626928
# 第0次迭代，局部最优结果为：0.6704829545454546
# 当前最优结果:0.7137543095626928
# 第0次迭代，局部最优结果为：0.7047178262167811
# 当前最优结果:0.7137543095626928
# 第0次迭代，局部最优结果为：0.630671797338464
# 当前最优结果:0.7137543095626928
# 第0次迭代，局部最优结果为：0.6605743394536499
# 当前最优结果:0.7137543095626928
# 第0次迭代，局部最优结果为：0.6954561527581329
# 当前最优结果:0.7137543095626928
# 第0次迭代，局部最优结果为：0.6635458839406208
# 当前最优结果:0.7137543095626928
# 第0次迭代，局部最优结果为：0.709505772005772
# 当前最优结果:0.7137543095626928
# 第0次迭代，局部最优结果为：0.6941470588235295
# 当前最优结果:0.7137543095626928
# 第0次迭代，局部最优结果为：0.6746998284734134
# 当前最优结果:0.7137543095626928
# 第0次迭代，局部最优结果为：0.699620560858481
# 当前最优结果:0.7137543095626928
# 第0次迭代，局部最优结果为：0.669988076988588
# 当前最优结果:0.7137543095626928
# 第0次迭代，局部最优结果为：0.67770279971285
# 当前最优结果:0.7137543095626928
# 第0次迭代，局部最优结果为：0.6927615357520254
# 当前最优结果:0.7137543095626928
# 第0次迭代，局部最优结果为：0.7173774278853461
# 当前最优结果:0.7173774278853461
# 第0次迭代，局部最优结果为：0.7173774278853461
# 当前最优结果:0.7173774278853461
# 第0次迭代，局部最优结果为：0.7173774278853461
# 当前最优结果:0.7173774278853461
# 第0次迭代，局部最优结果为：0.7216989786557396
# 当前最优结果:0.7216989786557397
# 第0次迭代，局部最优结果为：0.6893822111873814
# 当前最优结果:0.7216989786557397
# 第0次迭代，局部最优结果为：0.6791263812154695
# 当前最优结果:0.7216989786557397
# 第0次迭代，局部最优结果为：0.6772166427546628
# 当前最优结果:0.7216989786557397
# 第0次迭代，局部最优结果为：0.6937389770723104
# 当前最优结果:0.7216989786557397
# 第0次迭代，局部最优结果为：0.7131073241479333
# 当前最优结果:0.7216989786557397
# 第0次迭代，局部最优结果为：0.7131073241479333
# 当前最优结果:0.7216989786557397
# 第0次迭代，局部最优结果为：0.7131073241479333
# 当前最优结果:0.7216989786557397
# 第0次迭代，局部最优结果为：0.7260729118597139
# 当前最优结果:0.7260729118597139
# 第0次迭代，局部最优结果为：0.7260729118597139
# 当前最优结果:0.7260729118597139
# 第0次迭代，局部最优结果为：0.7173774278853461
# 当前最优结果:0.7260729118597139
# 第0次迭代，局部最优结果为：0.6972848406062575
# 当前最优结果:0.7260729118597139
# 第0次迭代，局部最优结果为：0.6905723314606741
# 当前最优结果:0.7260729118597139
# 第0次迭代，局部最优结果为：0.7260729118597139
# 当前最优结果:0.7260729118597139
# 第0次迭代，局部最优结果为：0.7187756966651438
# 当前最优结果:0.7260729118597139
# 第0次迭代，局部最优结果为：0.7105310693641618
# 当前最优结果:0.7260729118597139
# 第0次迭代，局部最优结果为：0.7260729118597139
# 当前最优结果:0.7260729118597139
# 第0次迭代，局部最优结果为：0.7151818181818183
# 当前最优结果:0.7260729118597139
# 第0次迭代，局部最优结果为：0.7260729118597139
# 当前最优结果:0.7260729118597139
# 第0次迭代，局部最优结果为：0.7224058769513315
# 当前最优结果:0.7260729118597139
# 第0次迭代，局部最优结果为：0.7260729118597139
# 当前最优结果:0.7260729118597139
# 第0次迭代，局部最优结果为：0.7373008434864105
# 当前最优结果:0.7373008434864105
# 第0次迭代，局部最优结果为：0.7297322367200544
# 当前最优结果:0.7373008434864105
# 第0次迭代，局部最优结果为：0.7297773654916512
# 当前最优结果:0.7373008434864105
# 第0次迭代，局部最优结果为：0.7405164569671489
# 当前最优结果:0.7405164569671489
# 第0次迭代，局部最优结果为：0.7405164569671489
# 当前最优结果:0.7405164569671489
# 第0次迭代，局部最优结果为：0.7297322367200544
# 当前最优结果:0.7405164569671489
# 第0次迭代，局部最优结果为：0.7405164569671489
# 当前最优结果:0.7405164569671489
# 第0次迭代，局部最优结果为：0.7405164569671489
# 当前最优结果:0.7405164569671489
# 第0次迭代，局部最优结果为：0.7180103437785215
# 当前最优结果:0.7405164569671489
# 第0次迭代，局部最优结果为：0.7230698529411764
# 当前最优结果:0.7405164569671489
# 第0次迭代，局部最优结果为：0.7192576113125896
# 当前最优结果:0.7405164569671489
# 第0次迭代，局部最优结果为：0.7211917494270436
# 当前最优结果:0.7405164569671489
# 第0次迭代，局部最优结果为：0.7405164569671489
# 当前最优结果:0.7405164569671489
# 第0次迭代，局部最优结果为：0.7230698529411764
# 当前最优结果:0.7405164569671489
# 第0次迭代，局部最优结果为：0.7405164569671489
# 当前最优结果:0.7405164569671489
# 第0次迭代，局部最优结果为：0.7192576113125896
# 当前最优结果:0.7405164569671489
# 第0次迭代，局部最优结果为：0.7238682370261317
# 当前最优结果:0.7405164569671489
# 第0次迭代，局部最优结果为：0.7192576113125896
# 当前最优结果:0.7405164569671489
# 第0次迭代，局部最优结果为：0.7405164569671489
# 当前最优结果:0.7405164569671489
# 第0次迭代，局部最优结果为：0.7192576113125896
# 当前最优结果:0.7405164569671489
# 第0次迭代，局部最优结果为：0.7405164569671489
# 当前最优结果:0.7405164569671489
# 第0次迭代，局部最优结果为：0.7297322367200544
# 当前最优结果:0.7405164569671489
# 第0次迭代，局部最优结果为：0.7602435253189023
# 当前最优结果:0.7602435253189022
# 第0次迭代，局部最优结果为：0.7482878883956879
# 当前最优结果:0.7602435253189022
# 第0次迭代，局部最优结果为：0.7602435253189023
# 当前最优结果:0.7602435253189022
# 第0次迭代，局部最优结果为：0.7344100074682599
# 当前最优结果:0.7602435253189022
# 第0次迭代，局部最优结果为：0.7602435253189023
# 当前最优结果:0.7602435253189022
# 第0次迭代，局部最优结果为：0.7562483978467059
# 当前最优结果:0.7602435253189022
# 第0次迭代，局部最优结果为：0.7506201895553718
# 当前最优结果:0.7602435253189022
# 第0次迭代，局部最优结果为：0.7516242038216561
# 当前最优结果:0.7602435253189022
# 第0次迭代，局部最优结果为：0.7526789131266742
# 当前最优结果:0.7602435253189022
# 第0次迭代，局部最优结果为：0.7478847799220458
# 当前最优结果:0.7602435253189022
# 第0次迭代，局部最优结果为：0.7708210856359005
# 当前最优结果:0.7708210856359005
# 第0次迭代，局部最优结果为：0.7516242038216561
# 当前最优结果:0.7708210856359005
# 第0次迭代，局部最优结果为：0.748952779893374
# 当前最优结果:0.7708210856359005
# 第0次迭代，局部最优结果为：0.7708210856359005
# 当前最优结果:0.7708210856359005
# 第0次迭代，局部最优结果为：0.7643801010493587
# 当前最优结果:0.7708210856359005
# 第0次迭代，局部最优结果为：0.7468670886075949
# 当前最优结果:0.7708210856359005
# 第0次迭代，局部最优结果为：0.7708210856359005
# 当前最优结果:0.7708210856359005
# 第0次迭代，局部最优结果为：0.7627496606554198
# 当前最优结果:0.7708210856359005
# 第0次迭代，局部最优结果为：0.7708210856359005
# 当前最优结果:0.7708210856359005
# 第0次迭代，局部最优结果为：0.7756087942423346
# 当前最优结果:0.7756087942423346
# 第0次迭代，局部最优结果为：0.7756087942423346
# 当前最优结果:0.7756087942423346
# 第0次迭代，局部最优结果为：0.7708210856359005
# 当前最优结果:0.7756087942423346
# 第0次迭代，局部最优结果为：0.5784133519594148
# 当前最优结果:0.7756087942423346
# 第0次迭代，局部最优结果为：0.8004680504680505
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.674989274989275
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7230698529411764
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7135600907029478
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6889998248379752
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.8004680504680505
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6427287581699347
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7297773654916512
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.5759713002733308
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6083359109186514
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7853648797045023
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7256933767910952
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6704829545454546
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.8004680504680505
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.8004680504680505
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6027582684203806
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.5243734447209385
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7708210856359005
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7574133504492939
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6212587854378899
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6100341191066998
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7756087942423346
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6912195407685099
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.5610602638773327
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.8004680504680505
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.64738314680711
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7069554277498203
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7072096368212873
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7564423076923077
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7421698113207548
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6948009891662741
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7506201895553718
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7756087942423346
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6966056670602125
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.8004680504680505
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7749211977935382
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7477426100180592
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6061796887039606
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.8004680504680505
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7660921219203428
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.8004680504680505
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7920861860652437
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7238682370261317
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7614208284939993
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.559822572228284
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.674989274989275
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6437806873977087
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7953695278536043
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6342138499986564
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7564423076923077
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7953695278536043
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7170069267225665
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.748952779893374
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.8004680504680505
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.5614473308592635
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6504519898577885
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7011586452762923
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.758240699094005
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6175039246467818
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6966056670602125
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.8004680504680505
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7167456268221574
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6859160660311555
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7273483727810651
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7953695278536043
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.710274467316721
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.8004680504680505
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7069554277498203
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6786576949620428
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7238682370261317
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6009778207837845
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.5685070096834802
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.634589013471001
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.5673044565165136
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6537854234189313
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7758382642998028
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7756087942423346
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6403744403744404
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.8004680504680505
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.5646172248803828
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.5535073524238373
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7758382642998028
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6954561527581329
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.8004680504680505
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.669645897173987
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7069554277498203
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6713603003925585
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.7549421022327426
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6256892895015908
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.6064600678384212
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.665229156096736
# 当前最优结果:0.8004680504680505
# 第0次迭代，局部最优结果为：0.8065960355434039
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.6572263993316625
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.762060058120762
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.5808047249907715
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.7075912933980931
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.6667514196118315
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.6105707041962022
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.7586794393725087
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.7332691232212764
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.8065960355434039
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.5671272377748408
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.668167147953117
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.6564038381309971
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.785914085914086
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.8004680504680505
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.699786514855008
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.5994665989331979
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.6245137731205843
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.6161497493734336
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.6161497493734336
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.7128057988523104
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.701533797039415
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.650380291005291
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.8065960355434039
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.7194988110481069
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.693453605218311
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.7332691232212764
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.7332691232212764
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.7451927630955764
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.659706498951782
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.8065960355434039
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.674989274989275
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.6650042265426881
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.697985981723006
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.6825438139857714
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.6787748058671269
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.6398015614834093
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.621930009486666
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.6966056670602125
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.6772555096418732
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.6855773420479303
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.6758591065292097
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.6400618338621756
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.7549421022327426
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.7057715311004785
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.7981939935064936
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.7451927630955764
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.7194988110481069
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.7024107142857142
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.6796348557276969
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.8023730196505066
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.6616113478358376
# 当前最优结果:0.806596035543404
# 第0次迭代，局部最优结果为：0.8118679050567594
# 当前最优结果:0.8118679050567595
# 第0次迭代，局部最优结果为：0.7636381285187342
# 当前最优结果:0.8118679050567595
# 第0次迭代，局部最优结果为：0.6610924369747899
# 当前最优结果:0.8118679050567595
# 第0次迭代，局部最优结果为：0.7737525408169955
# 当前最优结果:0.8118679050567595
# 第0次迭代，局部最优结果为：0.7751502611094688
# 当前最优结果:0.8118679050567595
# 第0次迭代，局部最优结果为：0.7667641325536062
# 当前最优结果:0.8118679050567595
# 第0次迭代，局部最优结果为：0.7667641325536062
# 当前最优结果:0.8118679050567595
# 第0次迭代，局部最优结果为：0.7212137880454712
# 当前最优结果:0.8118679050567595
# 第0次迭代，局部最优结果为：0.743291761148904
# 当前最优结果:0.8118679050567595
# 第0次迭代，局部最优结果为：0.7174646602827178
# 当前最优结果:0.8118679050567595
# 第0次迭代，局部最优结果为：0.8065960355434039
# 当前最优结果:0.8118679050567595
# 第0次迭代，局部最优结果为：0.7737525408169955
# 当前最优结果:0.8118679050567595
# 第0次迭代，局部最优结果为：0.7812313803376365
# 当前最优结果:0.8118679050567595
# 第0次迭代，局部最优结果为：0.8226211223422796
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7911833724438484
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.8183142054713776
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.8226211223422796
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7306811145510835
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7737525408169955
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.6802617167233527
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7124184979473557
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7624293329026005
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7737525408169955
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7401680988521607
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7974388430869036
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7974388430869036
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7729163255280825
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7974388430869036
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7933909301778331
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7974388430869036
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.8177754677754677
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.785417151985091
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7974388430869036
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7974388430869036
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7933909301778331
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7974388430869036
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.8015282730514518
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7933909301778331
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.759876364338839
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7115164305094965
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.8226211223422796
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.8226211223422796
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.8183142054713776
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.8226211223422796
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.8140521523178809
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.789383905277945
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7911833724438484
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7661667315932996
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7740062967335695
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7740062967335695
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7974388430869036
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7974388430869036
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7974388430869036
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.8015282730514518
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7974388430869036
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.7974388430869036
# 当前最优结果:0.8226211223422796
# 第0次迭代，局部最优结果为：0.8015282730514518
# ...
# 第0次迭代，局部最优结果为：0.7073368099262722
# 当前最优结果:0.7073368099262722
# 第0次迭代，局部最优结果为：0.6822084116201763
# 当前最优结果:0.7073368099262722
# 第0次迭代，局部最优结果为：0.7053075129998206
# 当前最优结果:0.7073368099262722
# 第0次迭代，局部最优结果为：0.6721633629528366
# 当前最优结果:0.7073368099262722
# 第0次迭代，局部最优结果为：0.7073368099262722
# 当前最优结果:0.7073368099262722
# 第0次迭代，局部最优结果为：0.7053075129998206
# 当前最优结果:0.7073368099262722
# 第0次迭代，局部最优结果为：0.7053075129998206
# 当前最优结果:0.7073368099262722
# 第0次迭代，局部最优结果为：0.7073368099262722
# 当前最优结果:0.7073368099262722
# 第0次迭代，局部最优结果为：0.7098045112781954
# 当前最优结果:0.7098045112781954
# 第0次迭代，局部最优结果为：0.7522470835723848
# 当前最优结果:0.7522470835723848
# 第0次迭代，局部最优结果为：0.7053075129998206
# 当前最优结果:0.7522470835723848
# 第0次迭代，局部最优结果为：0.7037511927480916
# 当前最优结果:0.7522470835723848
# 第0次迭代，局部最优结果为：0.6931684680451128
# 当前最优结果:0.7522470835723848
# 第0次迭代，局部最优结果为：0.7108734939759036
# 当前最优结果:0.7522470835723848
# 第0次迭代，局部最优结果为：0.6992888888888888
# 当前最优结果:0.7522470835723848
# 第0次迭代，局部最优结果为：0.762060058120762
# 当前最优结果:0.762060058120762
# 第0次迭代，局部最优结果为：0.743291761148904
# 当前最优结果:0.762060058120762
# 第0次迭代，局部最优结果为：0.7512414056531704
# 当前最优结果:0.762060058120762
# 第0次迭代，局部最优结果为：0.7512414056531704
# 当前最优结果:0.762060058120762
# 第0次迭代，局部最优结果为：0.7552803379416283
# 当前最优结果:0.762060058120762
# 第0次迭代，局部最优结果为：0.743291761148904
# 当前最优结果:0.762060058120762
# 第0次迭代，局部最优结果为：0.7552803379416283
# 当前最优结果:0.762060058120762
# 第0次迭代，局部最优结果为：0.743291761148904
# 当前最优结果:0.762060058120762
# 第0次迭代，局部最优结果为：0.7642810880829015
# 当前最优结果:0.7642810880829015
# 第0次迭代，局部最优结果为：0.7593629343629344
# 当前最优结果:0.7642810880829015
# 第0次迭代，局部最优结果为：0.7335198135198134
# 当前最优结果:0.7642810880829015
# 第0次迭代，局部最优结果为：0.7593629343629344
# 当前最优结果:0.7642810880829015
# 第0次迭代，局部最优结果为：0.7393796992481203
# 当前最优结果:0.7642810880829015
# 第0次迭代，局部最优结果为：0.7388935850474313
# 当前最优结果:0.7642810880829015
# 第0次迭代，局部最优结果为：0.743291761148904
# 当前最优结果:0.7642810880829015
# 第0次迭代，局部最优结果为：0.7593629343629344
# 当前最优结果:0.7642810880829015
# 第0次迭代，局部最优结果为：0.7564423076923077
# 当前最优结果:0.7642810880829015
# 第0次迭代，局部最优结果为：0.7593629343629344
# 当前最优结果:0.7642810880829015
# 第0次迭代，局部最优结果为：0.7502145649893511
# 当前最优结果:0.7642810880829015
# 第0次迭代，局部最优结果为：0.7593629343629344
# 当前最优结果:0.7642810880829015
# 第0次迭代，局部最优结果为：0.7593629343629344
# 当前最优结果:0.7642810880829015
# 第0次迭代，局部最优结果为：0.7642810880829015
# 当前最优结果:0.7642810880829015
# 第0次迭代，局部最优结果为：0.762060058120762
# 当前最优结果:0.7642810880829015
# 第0次迭代，局部最优结果为：0.7593629343629344
# 当前最优结果:0.7642810880829015
# 第0次迭代，局部最优结果为：0.7593629343629344
# 当前最优结果:0.7642810880829015
# 第0次迭代，局部最优结果为：0.7564423076923077
# 当前最优结果:0.7642810880829015
# 第0次迭代，局部最优结果为：0.7642810880829015
# 当前最优结果:0.7642810880829015
# 第0次迭代，局部最优结果为：0.7642810880829015
# 当前最优结果:0.7642810880829015
# 第0次迭代，局部最优结果为：0.7642810880829015
# 当前最优结果:0.7642810880829015
# 第0次迭代，局部最优结果为：0.7642810880829015
# 当前最优结果:0.7642810880829015
# 第0次迭代，局部最优结果为：0.7690127077223851
# 当前最优结果:0.7690127077223852
# 第0次迭代，局部最优结果为：0.7676619828259174
# 当前最优结果:0.7690127077223852
# 第0次迭代，局部最优结果为：0.7708966193042627
# 当前最优结果:0.7708966193042626
# 第0次迭代，局部最优结果为：0.7756087942423346
# 当前最优结果:0.7756087942423346
# 第0次迭代，局部最优结果为：0.7756087942423346
# 当前最优结果:0.7756087942423346
# 第0次迭代，局部最优结果为：0.7874874874874874
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7667641325536062
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7379924953095685
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7552803379416283
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7334514264404252
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7200695630949475
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7648755509463314
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7731695331695332
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7874874874874874
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7874874874874874
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7790651614181026
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7874874874874874
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7874874874874874
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7756087942423346
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.6916043956043956
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.6483791208791209
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7471035137701804
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.6935554967821563
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7874874874874874
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.6458949096880131
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7874874874874874
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.6121226268285092
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.6552557054805931
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7874874874874874
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.593362664990572
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7467961902351042
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.6103969998706841
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.6811255411255411
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.5644281819486296
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7874874874874874
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.6572263993316625
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.6389701104613386
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.6655668358714044
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7874874874874874
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.6971818504076569
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7195426829268293
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7126981730333686
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.6336689488521949
# 当前最优结果:0.7874874874874875
# 第0次迭代，局部最优结果为：0.7917673107890499
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.6313804173354735
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7004095441595442
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.6478096179183136
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7917673107890499
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.6145773657621999
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7790651614181026
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7917673107890499
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7587770061728395
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.6896037868162692
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7917673107890499
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7037931651458221
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7680617026815934
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.5460034702139965
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.645153354108578
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7086110610700774
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7667641325536062
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.5302999662959218
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.5603276353276353
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.6970583023214603
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7329503105590062
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7917673107890499
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7917673107890499
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7874874874874874
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.6613703236654056
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7917673107890499
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7917673107890499
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7708210856359005
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7037931651458221
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7874874874874874
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7047599139990445
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.5660662461324443
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7471035137701804
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.6112665112665112
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.599070971672251
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.5700724637681159
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7371626686656672
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7917673107890499
# 当前最优结果:0.7917673107890499
# 第0次迭代，局部最优结果为：0.7960939081157661
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7188413742690059
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7011586452762923
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.5934372642695499
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.5991622239146991
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7960939081157661
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.717661010764459
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.5239310926608356
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.5690827546296297
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7960939081157661
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.5712591373384325
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.53483049311095
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.6513495611856267
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7863854458216714
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.743291761148904
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7329503105590062
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.6054798737781882
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.6175039246467818
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7086110610700774
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7086110610700774
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.5809333924088023
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7960939081157661
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7627989657401423
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7495712380105444
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7960939081157661
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.5712591373384325
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.6273524720893141
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7960939081157661
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7205972154372252
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7960939081157661
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.6439212048455746
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7135600907029478
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7960939081157661
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.6896037868162692
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7960939081157661
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7960939081157661
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7790651614181026
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.6301161393672406
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7253365295961645
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.5415806140713204
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.6559659801550904
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7667641325536062
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7960939081157661
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.6937389770723104
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.5820796132787451
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7874874874874874
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7631196042293141
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7960939081157661
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7011586452762923
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.696523432888679
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.668280665987088
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.6592089827383945
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7212137880454712
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.6786576949620428
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.6544199201419698
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.7011586452762923
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.72180934030645
# 当前最优结果:0.7960939081157661
# 第0次迭代，局部最优结果为：0.8093621399176955
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7073368099262722
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.6622053872053872
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.8004680504680505
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.6264532568880395
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.5967081310679612
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.5710794395915503
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7960939081157661
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7011586452762923
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7141430646332607
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.6896642412553695
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.6789310166273518
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.6839680055642496
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.8093621399176955
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7832536837913182
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7253365295961645
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.6904511146217307
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.785129740518962
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.785129740518962
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.8093621399176955
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.785129740518962
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7848164405426975
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7491429659725749
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7807920071459292
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7680617026815934
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.753544061302682
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7708210856359005
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7708210856359005
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7708210856359005
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.8093621399176955
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7639100178022334
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7667641325536062
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7587770061728395
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7477426100180592
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7722587611661923
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7230698529411764
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.724401473296501
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7230698529411764
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7881186135043078
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7756087942423346
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7449810606060606
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7477426100180592
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.6981098589049606
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7384543178973717
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7230698529411764
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7586306653809064
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7749211977935382
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7360591317365269
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7667641325536062
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7667641325536062
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7676619828259174
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7327682563338301
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7586306653809064
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7488814850071395
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.8093621399176955
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.8093621399176955
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.8093621399176955
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.8093621399176955
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.8093621399176955
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7758382642998028
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.8093621399176955
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.8048905258850011
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.8093621399176955
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.8093621399176955
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.785129740518962
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7960939081157661
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.8093621399176955
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7917673107890499
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.8093621399176955
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7946464646464647
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7869098426247
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7708210856359005
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.8093621399176955
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7946464646464647
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7598029746957697
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7960939081157661
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.8004680504680505
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7816194734227521
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.785129740518962
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.785129740518962
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7500953470633105
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.8093621399176955
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7990858303707465
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.8093621399176955
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.8093621399176955
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.8043967280163599
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.8093621399176955
# 当前最优结果:0.8093621399176955
# 第0次迭代，局部最优结果为：0.7667641325536062
# 当前最优结果:0.8093621399176955
# 本次退火用时：5239.0041127204895

# %%
def draw(history):
    plt.plot(history['T'], history['f'])
    plt.title('SA')
    plt.xlabel('T')
    plt.ylabel('f')
    plt.gca().invert_xaxis()
    plt.show()
    return

def wrXSLX(squ, use, tim, filename):
    data = {'square':squ,'utilization':use,'timecost':tim}
    df = pd.DataFrame(data)
    df.to_excel(filename,sheet_name='layout',header=0)
    return df

def drawP(m3):
    Lw,Pw,Lh,Ph = m.lcs_xy(m3.l,m3.x,m3.y,m3.w,m3.h)
    print(Pw)
    print(Ph)
    h,w = m3.h,m3.w
    for i in range(len(Pw)):
        x,y = [Pw[i], Pw[i], Pw[i]+w[i], Pw[i]+w[i], Pw[i]],[Ph[i], Ph[i]+h[i], Ph[i]+h[i], Ph[i], Ph[i]]
        plt.plot(x,y,color='r')
        plt.scatter(x,y,color='b')
    plt.show()
    return

# %%
print("本次测试的退火环境为：")
print(sa.iter,sa.T0,sa.alpha)
squ = []
use = []
for i in range(30):
    squ.append(mmm[i].s_cur)
    use.append(mmm[i].use)
print(use)
index = use.index(max(use))
history = {'f': fff[index], 'T': TTT[index]}
print('本次最优解为：'+str(max(use)))
draw(history)

drawP(mmm[index])

wrXSLX(squ,use,sss,'result_moreHH.xlsx')
# Out:
# 本次测试的退火环境为：
# 4000 400 0.95
# [0.827756734006734, 0.8226211223422796, 0.8368258695883417, 0.8369148936170213, 0.8162481842705955, 0.7894367139416645, 0.7973310810810811, 0.8347835314091681, 0.7917673107890499, 0.844823883161512, 0.827756734006734, 0.7802499338799259, 0.8338102808691044, 0.8494457241577886, 0.7819043201696263, 0.8292982887662954, 0.8522370274076482, 0.7980320551836072, 0.8215329991645781, 0.7934709521247982, 0.8418705857173432, 0.8506397549107947, 0.8118120528343423, 0.8470068906115418, 0.8504864864864865, 0.7989235300091398, 0.7750738916256158, 0.8071477428180575, 0.8362624902558288, 0.8093621399176955]
# 本次最优解为：0.8522370274076482
# [ 602.  119.  959.  910.  910.    0.  735.  406. 1120. 1085.  497.  133.
#   469.  497.  497.  910.    0.    0.    0.  133. 1120.  350.  910.  735.
#   763.    0.  497.  910.  119.    0.  763.  910. 1085.]
# [735. 315.   0.   0. 693. 931. 931. 931. 315. 693. 315. 756. 756. 133.
#  434. 140. 315.   0. 133. 616.   0.   0. 553. 784. 553. 616. 637. 343.
#  434. 434. 343. 812. 609.]
#        square  utilization     timecost
# 0   1397088.0     0.827757  5212.610944
# 1   1405810.0     0.822621  5237.406154
# 2   1381947.0     0.836826  5259.034049
# 3   1381800.0     0.836915  5231.481722
# 4   1416786.0     0.816248  5197.076622
# 5   1464904.0     0.789437  5217.072274
# 6   1450400.0     0.797331  5231.110734
# 7   1385328.0     0.834784  5223.705543
# 8   1460592.0     0.791767  5207.035520
# 9   1368864.0     0.844824  5215.484151
# 10  1397088.0     0.827757  5214.661048
# 11  1482152.0     0.780250  5212.913726
# 12  1386945.0     0.833810  5231.552639
# 13  1361416.0     0.849446  5196.447439
# 14  1479016.0     0.781904  5211.377050
# 15  1394491.0     0.829298  5219.100075
# 16  1356957.0     0.852237  5220.863177
# 17  1449126.0     0.798032  5221.028293
# 18  1407672.0     0.821533  5228.014257
# 19  1457456.0     0.793471  5228.362932
# 20  1373666.0     0.841871  5244.951367
# 21  1359505.0     0.850640  5238.471080
# 22  1424528.0     0.811812  5221.983896
# 23  1365336.0     0.847007  5212.693910
# 24  1359750.0     0.850486  5252.378228
# 25  1447509.0     0.798924  5217.354164
# 26  1492050.0     0.775074  5220.324317
# 27  1432760.0     0.807148  5206.275620
# 28  1382878.0     0.836262  5274.301852
# 29  1428840.0     0.809362  5239.004113

# %%
# Out:
# 0.6610924369747899
# 0.6610924369747899
