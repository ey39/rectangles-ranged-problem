# %%
# 导入必要的包
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import copy
import time
import pandas as pd

# %%
'''
产生初始解和初始目标函数X0和f0，初始化最优值记录器X*和f*

既然序列对可以表达模块的位置信息以及整体的最大长度和宽度
那么我们对模块进行乱序，随机生成一个序列对，一个正序列和一个负序列
目标函数就是该序列形成的矩形面积除以总面积，这样子就可以用求目标函数的最小值的方法求解该问题

while(不满足回火终止条件)
    t=t0
        while t>1e-3
            for i=0 i<L i++
                从四种新解中任选一种产生新解Xnew
                计算评价新解的目标函数fnew
                计算评价目标函数差df=fnew-f
                
                if df<0 or exp(-df/t)>random(0,1)
                    接受新解X=Xnew f=fnew
                    与最优值记录器比较，记录最优值
                else
                    还原原来的解
            下降温度 t=a*t
        以记录器的最优解作为下一个循环的初始解
    达不到要求，产生回火温度

'''

# %%
'''
首先
    我们要确定初始温度T0和降温系数α还有终止温度Tf（决定了一共生成
    多少组新解、接受新解的程度）、迭代次数iter（生成一批新解中的新
    解的个数）。
评价函数设置
    整体面积利用率的倒数，一般模拟退火算法都是对最小值进行求解的，
    于是我们需要的面积利用率越大越好，所以我们取倒数即可。
    （面积利用率=sum(模块面积)/生成的矩形画布的面积，生成的矩形画
    布的面积我们可以通过求解LCS得到）

伪代码：
生成初始解x&y&h&w
while T(当前温度)>Tf
    while n(当前循环次数)<iter
        得到上一次的解或者是初始解x&y&h&w
            得到上一次解的评价函数的值f
        从四种方法中生成新解x_new&y_new&h_new&w_new
            得到评价函数值f_new
        Metropolis（f,f_new）  #Metropolis准则
            根据Metropolis准则的结果来决定是否接受新解或者是还原原来的解
    下降温度T=α*T
以记录器中的最优解作为布局问题的最终解


'''

# %%
class module():
    def __init__(self, name='', typ='', w=0., h=0., pos=[], s=0.):
        self.name = name  #模块名称
        self.typ = typ    #模块类型
        self.w = w        #模块宽度
        self.h = h        #模块高度
        self.pos = pos    #模块位置:右下角、右上角、左上角、左下角(左下角一般为(0,0))
        self.s = s        #模块面积

# %%
def rdfile(filename,n):
    #filename是要读取的文件名，n为其中所包含的模块数
    
    #用于存储所有模块对象的列表
    modules = np.zeros(n-1,dtype=type(module('a','b',0.,0.,[],0.))) 
    t = 0
    s_total = 0.
    b1,b2 = 0,0

    #通过文件名打开数据流，按照行的顺序有规律地依次将模块名...读出，顺便创建模块对象放入数组中方便调用
    with open(filename,'r') as f:
        for line in f:
            line = line.split(' ')
            if 'MODULE' in line:
                #print(line[1].split(';')[0])
                name = line[1].split(';')[0]

            if 'TYPE' in line:
                typ = line[2]

            if 'DIMENSIONS' in line:
                #print(line[2:])
                w = 0.
                h = 0.
                pos = np.zeros(8)
                for i in range(10)[2:]:
                    if i != 9:
                        pos[i-2] = int(line[i])
                    else:
                        pos[i-2] = int(line[i].split(";")[0])
                # 用两个坐标值相减即可得到模块的宽高
                h = pos[3]-pos[1]
                w = pos[2]-pos[4]
                s = h*w
                if t == n-1:
                    # 这里的s是parent模块的面积，其实实际上并没有使用到
                    s_total = s
                if t<n-1:
                    modules[t] = module(name,typ,w,h,pos,s)
                    t = t+1
                
    return modules,s_total

# %%
# 读取ami33和ami49并计算出它们模块的总面积（不包括parent）
modules,st = rdfile('ami33.yal',34)
modules1,st1 = rdfile('ami49.yal',50)
s = 0.
for i in range(33):
    s = s + modules[i].s
s1 = 0.
for i in range(49):
    s1 = s1 + modules1[i].s
print(s,s1)
# Out:
# 1156449.0 35445424.0

# %%
# m类，用于存储一组模块的布局
# x为正向序列，y为负向序列，modules则存储着从文件读取出来的各个模块的信息，比如宽w和高h
# m类中还存储着这组模块布局所代表的信息比如面积利用率use、总面积s_cur...其中的iuse是用于模拟退火算法，它是面积利用率的倒数
class m():
    def __init__(self, modules,s_total):
        self.modules = modules
        self.s_total = s_total
        self.l = len(modules)
        self.s_cur,self.iuse,self.use = 0.,0.,0.
        
        # 产生一个比较优的解，在此基础上进行模拟退火，这里随机产生可能没有对模块进行旋转
        # 可能在一定程度上会导致我们的初始解较差

        self.x,self.y,self.modules = self.xyInit()
        self.w,self.h = m.whSort(self.l, self.x, self.y, self.modules)
        self.s_cur,self.iuse,self.use = m.calSC(self.l, self.x, self.y, self.w, self.h, self.s_total) 
        
    # 计算当前模块布局的信息：总面积s_cur、面积利用率及其倒数
    def calSC(l,x,y,w,h,s_total):
        Lw,Pw,Lh,Ph = m.lcs_xy(l,x,y,w,h)
        s_cur = Lw*Lh
        iuse = s_cur/s_total
        use = s_total/s_cur
            
        return s_cur,iuse,use
    
    # 根据x和y序列还有模块序列（包含旋转信息），来生成新的模块宽高序列，用于LCS算法
    def whSort(l,x,y,modules):
        w = np.zeros(l)
        h = np.zeros(l)
        for i in range(l):
            w[i] = modules[i].w
            h[i] = modules[i].h
        return w,h
    
    # 初始化生成一组正向和反向序列--生成一个0到（总模块个数-1）长度的顺序序列，然后用shuffle打乱，随机翻转模块
    def xyInit(self):
        l = self.l
        tmp = np.zeros(l,dtype='int')
        for i in range(l):
            tmp[i] = i
            
        np.random.shuffle(tmp)
        x = copy.deepcopy(tmp)
        np.random.shuffle(tmp)
        y = copy.deepcopy(tmp)
        
        # 模块随机翻转
        md = copy.deepcopy(self.modules)
        for i in range(l):
            yes = random.randint(0,1)
            if yes:
                md[i].w,md[i].h = md[i].h,md[i].w 
            
        return x,y,md
    
    # lcs快速算法
    def lcs_xy(n,x,y,w,h):
        xr = x[::-1]
        Lw,Pw = m.lcs(n,x,y,w)
        Lh,Ph = m.lcs(n,xr,y,h)
        return Lw,Pw,Lh,Ph
    
    # lcs快速算法核心
    def lcs(n,x,y,w):
        # n个模块，x为正序列，y为负序列，w为每个模块的宽度/高度 
        class mdd():
            def __init__(self,x,y):
                self.x = x
                self.y = y

        match = np.zeros(n,dtype=type(mdd(3,4)))
        for i in range(len(x)):
            for j in range(len(y)):
                if x[i]==y[j]:
                    match[int(x[i]-1)] = mdd(i,j)
                    break
                    
        # 模块的位置P，总长度L
        P = np.zeros(n)
        L = np.zeros(n)

        for i in range(n):
            b = int(x[i]-1)
            p = int(match[b].y)
            P[b] = L[p]
            t = P[b] + w[b]
            for j in range(n)[p:n]:
                if t > L[j]:
                    L[j] = t
                else:
                    break

        return L[n-1],P
    
    def refresh(self):
        # 由于x,y,modules的改变，需要更新数据
        self.w,self.h = m.whSort(self.l, self.x, self.y, self.modules)
        self.s_cur,self.iuse,self.use = m.calSC(self.l, self.x, self.y, self.w, self.h, self.s_total) 
    
    def exchangeX(self,pos1,pos2):
        # 第1个随机模块与第2个随机模块交换正序列中的位置
        id1 = np.array(np.where(self.x==pos1))[0][0]
        id2 = np.array(np.where(self.x==pos2))[0][0] 
        x1 = copy.deepcopy(self.x)
        x1[id1],x1[id2] = x1[id2],x1[id1]
        self.x = x1
        return
    
    def exchangeY(self,pos1,pos2):
        # 第1个随机模块与第2个随机模块交换负序列中的位置
        id1 = np.array(np.where(self.y==pos1))[0][0]
        id2 = np.array(np.where(self.y==pos2))[0][0]
        y1 = copy.deepcopy(self.y)
        y1[id1],y1[id2] = y1[id2],y1[id1]
        self.y = y1
        return
    
    def exchangeXY(self,pos1,pos2):
        # 第1个随机模块与第2个随机模块交换正负序列中的位置
        self.exchangeX(pos1,pos2)
        self.exchangeY(pos1,pos2)
        return
    
    def exchangeWH(self,pos):
        # 旋转模块
        md = copy.deepcopy(self.modules)
        md[pos].w,md[pos].h = md[pos].h,md[pos].w 
        self.modules = md
        return

# %%
# SA类 进行模拟退火算法的框架
# 包含3个主要的方法：产生新解、Metropolis准则、运行
class SA:
    def __init__(self, m1, m2, m3, s_total, iter=10000, T0=400, Tf=0.01, alpha=0.95):
        self.iter = iter         #内循环迭代次数,即为L =100
        self.alpha = alpha       #降温系数，alpha=0.95
        self.T0 = T0             #初始温度T0为400
        self.Tf = Tf             #温度终值Tf为0.01
        self.T = T0              #当前温度
        
        # 生成初始解
        self.m1 = m1
        # 用于保存局部最优解&全局最优解
        self.m2 = m2
        self.m3 = m3
        
        # 模块的一些相关信息，模块个数&模块总面积
        self.l = self.m1.l
        self.s_total = self.m1.s_total
        
        # 存放解的序列对
        self.xi = np.zeros((self.iter,self.l),dtype='int')
        self.yi = np.zeros((self.iter,self.l),dtype='int')
        self.modulesi = np.zeros((self.iter,self.l),dtype=type(module()))
                                 
        # 存放f的历史，用于生成图像
        self.history = {'f': [], 'T': []}

    def generate_new(self):   #扰动产生新解的过程
        rand,rand1,rand2 = 0,0,0
        # 选择产生新解的方式
        rand = random.randint(1,4)
        
        while rand1 == rand2:
            rand1 = random.randint(0,self.l-1)
            rand2 = random.randint(0,self.l-1)
            
        if rand == 1:
            #正向序列中交换两个模块的顺序
            self.m1.exchangeX(rand1,rand2)
        elif rand == 2:
            #负向序列中交换两个模块的顺序
            self.m1.exchangeY(rand1,rand2)
        elif rand == 3:
            #正向序列和负向序列中同时交换两个模块的顺序
            self.m1.exchangeXY(rand1,rand2)
        else:
            #将某个模块旋转，即将模块中的宽和高对调
            self.m1.exchangeWH(rand1)
            
        self.m1.refresh()
            
        return 

    def Metrospolis(self, f, f_new):   #Metropolis准则
        if f_new <= f:
            if self.m1.iuse < self.m3.iuse:
                self.m3.x,self.m3.y,self.m3.modules = copy.deepcopy(self.m1.x),copy.deepcopy(self.m1.y),copy.deepcopy(self.m1.modules)
                self.m3.refresh()
            return 1
        else:
            p = math.exp((f - f_new) / self.T)
            if np.random.rand() < p:
                return 1
            else:
                return 0

    
    def run(self):
        count = 0   #迭代计数器
        count1 = 0  #回火计数器
        
        #外循环迭代，当前温度小于终止温度的阈值
        while self.T > self.Tf:  
            #用于存放一次迭代的中间结果
            t= []   
            #内循环迭代
            for i in range(self.iter): 
                #f为迭代一次后的值
                f = self.m2.iuse
                #产生新解
                self.generate_new()
                x_new,y_new,modules_new = copy.deepcopy(self.m1.x),copy.deepcopy(self.m1.y),copy.deepcopy(self.m1.modules)
                #产生新值
                f_new = self.m1.iuse
                #判断是否接受新值
                if self.Metrospolis(f, f_new):
                    self.xi[i] = x_new
                    self.yi[i] = y_new
                    self.modulesi[i] = modules_new
                    t.append(f_new)
                else:
                    t.append(self.m1.iuse)
                    if i>= 1:
                        self.m1.x = copy.deepcopy(self.xi[i-1])
                        self.m1.y = copy.deepcopy(self.yi[i-1])
                        self.m1.modules = copy.deepcopy(self.modulesi[i-1])
                        self.m1.refresh()
            
                    
            f_best = min(t)
            idx = t.index(f_best)
            
            # 将当前局部最优解作为下一次迭代的初始解
            self.m1.x = copy.deepcopy(self.m3.x)
            self.m1.y = copy.deepcopy(self.m3.y)
            self.m1.modules = copy.deepcopy(self.m3.modules)
            self.m1.refresh()
            
            # 保存局部最优解，但是好像没用
            self.m2.x = copy.deepcopy(self.xi[idx])
            self.m2.y = copy.deepcopy(self.yi[idx])
            self.m2.modules = copy.deepcopy(self.modulesi[idx])
            self.m2.refresh()
            
            # 迭代L次记录在该温度下最优解
            self.history['f'].append(f_best)
            self.history['T'].append(self.T)
            
            #温度按照一定的比例下降（冷却）+回火
            self.T = self.T * self.alpha  
            #if self.T <= self.Tf:
                #if self.m3.use < 0.9:
                    #self.T = self.T0/2
                    #count1 += 1
                    #print("现在的结果好像不是很好，我的建议是回火！这是第" + str(count1) + "次回火")
                    
            count += 1
            
            print("第"+str(count)+"次迭代，局部最优结果为："+str(1/f_best))
            self.m3.refresh()
            print("当前最优结果:"+str(self.m3.use))
            
            
        return

# %%
mmm = []
TTT = []
fff = []
sss = []
for i in range(30):
    t1 = time.time()
    m1 = m(modules,s)
    m2 = m(modules,s)
    m3 = m(modules,s)
    sa = SA(m1,m2,m3,s)
    sa.run()
    t2 = time.time()
    t = t2-t1
    mmm.append(sa.m3)
    TTT.append(sa.history['T'])
    fff.append(sa.history['f'])
    sss.append(t)
    print("本次退火用时："+str(t))
# Out:
# 第1次迭代，局部最优结果为：0.5972517461281506
# 当前最优结果:0.5972517461281506
# 第2次迭代，局部最优结果为：0.5620623958085258
# 当前最优结果:0.5972517461281506
# 第3次迭代，局部最优结果为：0.6074903474903475
# 当前最优结果:0.6074903474903475
# 第4次迭代，局部最优结果为：0.594903206291591
# 当前最优结果:0.6074903474903475
# 第5次迭代，局部最优结果为：0.5590401970770069
# 当前最优结果:0.6074903474903475
# 第6次迭代，局部最优结果为：0.5788105456774985
# 当前最优结果:0.6074903474903475
# 第7次迭代，局部最优结果为：0.5305383837248511
# 当前最优结果:0.6074903474903475
# 第8次迭代，局部最优结果为：0.5274202198980961
# 当前最优结果:0.6074903474903475
# 第9次迭代，局部最优结果为：0.659706498951782
# 当前最优结果:0.659706498951782
# 第10次迭代，局部最优结果为：0.5866225889838934
# 当前最优结果:0.659706498951782
# 第11次迭代，局部最优结果为：0.6357171717171717
# 当前最优结果:0.659706498951782
# 第12次迭代，局部最优结果为：0.6357171717171717
# 当前最优结果:0.659706498951782
# 第13次迭代，局部最优结果为：0.644413499344692
# 当前最优结果:0.659706498951782
# 第14次迭代，局部最优结果为：0.5853422619047619
# 当前最优结果:0.659706498951782
# 第15次迭代，局部最优结果为：0.659706498951782
# 当前最优结果:0.659706498951782
# 第16次迭代，局部最优结果为：0.6028352490421456
# 当前最优结果:0.659706498951782
# 第17次迭代，局部最优结果为：0.6071465322082733
# 当前最优结果:0.659706498951782
# 第18次迭代，局部最优结果为：0.5700724637681159
# 当前最优结果:0.659706498951782
# 第19次迭代，局部最优结果为：0.659706498951782
# 当前最优结果:0.659706498951782
# 第20次迭代，局部最优结果为：0.659706498951782
# 当前最优结果:0.659706498951782
# 第21次迭代，局部最优结果为：0.581878698224852
# 当前最优结果:0.659706498951782
# 第22次迭代，局部最优结果为：0.5889060784509432
# 当前最优结果:0.659706498951782
# 第23次迭代，局部最优结果为：0.5622498570611778
# 当前最优结果:0.659706498951782
# 第24次迭代，局部最优结果为：0.5761962890625
# 当前最优结果:0.659706498951782
# 第25次迭代，局部最优结果为：0.659706498951782
# 当前最优结果:0.659706498951782
# 第26次迭代，局部最优结果为：0.5700724637681159
# 当前最优结果:0.659706498951782
# 第27次迭代，局部最优结果为：0.6453650533223954
# 当前最优结果:0.659706498951782
# 第28次迭代，局部最优结果为：0.5731876138433516
# 当前最优结果:0.659706498951782
# 第29次迭代，局部最优结果为：0.5642257763752421
# 当前最优结果:0.659706498951782
# 第30次迭代，局部最优结果为：0.5991926475068549
# 当前最优结果:0.659706498951782
# 第31次迭代，局部最优结果为：0.5614473308592635
# 当前最优结果:0.659706498951782
# 第32次迭代，局部最优结果为：0.6357171717171717
# 当前最优结果:0.659706498951782
# 第33次迭代，局部最优结果为：0.5541701887855733
# 当前最优结果:0.659706498951782
# 第34次迭代，局部最优结果为：0.6243650793650793
# 当前最优结果:0.659706498951782
# 第35次迭代，局部最优结果为：0.5830286561264821
# 当前最优结果:0.659706498951782
# 第36次迭代，局部最优结果为：0.5107446601311433
# 当前最优结果:0.659706498951782
# 第37次迭代，局部最优结果为：0.5795211786372007
# 当前最优结果:0.659706498951782
# 第38次迭代，局部最优结果为：0.6216024020227561
# 当前最优结果:0.659706498951782
# 第39次迭代，局部最优结果为：0.6206706114398423
# 当前最优结果:0.659706498951782
# 第40次迭代，局部最优结果为：0.6767311827956989
# 当前最优结果:0.6767311827956989
# 第41次迭代，局部最优结果为：0.6620196353436185
# 当前最优结果:0.6767311827956989
# 第42次迭代，局部最优结果为：0.5681375027081679
# 当前最优结果:0.6767311827956989
# 第43次迭代，局部最优结果为：0.6767311827956989
# 当前最优结果:0.6767311827956989
# 第44次迭代，局部最优结果为：0.5291704035874439
# 当前最优结果:0.6767311827956989
# 第45次迭代，局部最优结果为：0.6634339686287739
# 当前最优结果:0.6767311827956989
# 第46次迭代，局部最优结果为：0.5873525459160818
# 当前最优结果:0.6767311827956989
# 第47次迭代，局部最优结果为：0.5856327543424318
# 当前最优结果:0.6767311827956989
# 第48次迭代，局部最优结果为：0.6045338114754099
# 当前最优结果:0.6767311827956989
# 第49次迭代，局部最优结果为：0.5300260510240747
# 当前最优结果:0.6767311827956989
# 第50次迭代，局部最优结果为：0.6767311827956989
# 当前最优结果:0.6767311827956989
# 第51次迭代，局部最优结果为：0.6098449612403101
# 当前最优结果:0.6767311827956989
# 第52次迭代，局部最优结果为：0.6395934959349593
# 当前最优结果:0.6767311827956989
# 第53次迭代，局部最优结果为：0.6243650793650793
# 当前最优结果:0.6767311827956989
# 第54次迭代，局部最优结果为：0.5878938846680782
# 当前最优结果:0.6767311827956989
# 第55次迭代，局部最优结果为：0.6357171717171717
# 当前最优结果:0.6767311827956989
# 第56次迭代，局部最优结果为：0.6767311827956989
# 当前最优结果:0.6767311827956989
# 第57次迭代，局部最优结果为：0.5859962756052142
# 当前最优结果:0.6767311827956989
# 第58次迭代，局部最优结果为：0.645188627665391
# 当前最优结果:0.6767311827956989
# 第59次迭代，局部最优结果为：0.6189614476789929
# 当前最优结果:0.6767311827956989
# 第60次迭代，局部最优结果为：0.5833889506859473
# 当前最优结果:0.6767311827956989
# 第61次迭代，局部最优结果为：0.6042242703533026
# 当前最优结果:0.6767311827956989
# 第62次迭代，局部最优结果为：0.6767311827956989
# 当前最优结果:0.6767311827956989
# 第63次迭代，局部最优结果为：0.659706498951782
# 当前最优结果:0.6767311827956989
# 第64次迭代，局部最优结果为：0.6385551948051948
# 当前最优结果:0.6767311827956989
# 第65次迭代，局部最优结果为：0.5231413751828701
# 当前最优结果:0.6767311827956989
# 第66次迭代，局部最优结果为：0.6767311827956989
# 当前最优结果:0.6767311827956989
# 第67次迭代，局部最优结果为：0.5840964213235659
# 当前最优结果:0.6767311827956989
# 第68次迭代，局部最优结果为：0.5572319025357699
# 当前最优结果:0.6767311827956989
# 第69次迭代，局部最优结果为：0.5959848484848485
# 当前最优结果:0.6767311827956989
# 第70次迭代，局部最优结果为：0.565645671555939
# 当前最优结果:0.6767311827956989
# 第71次迭代，局部最优结果为：0.5724229929662867
# 当前最优结果:0.6767311827956989
# 第72次迭代，局部最优结果为：0.6474897119341564
# 当前最优结果:0.6767311827956989
# 第73次迭代，局部最优结果为：0.6767311827956989
# 当前最优结果:0.6767311827956989
# 第74次迭代，局部最优结果为：0.6767311827956989
# 当前最优结果:0.6767311827956989
# 第75次迭代，局部最优结果为：0.6580326771873083
# 当前最优结果:0.6767311827956989
# 第76次迭代，局部最优结果为：0.6811255411255411
# 当前最优结果:0.6811255411255411
# 第77次迭代，局部最优结果为：0.6098449612403101
# 当前最优结果:0.6811255411255411
# 第78次迭代，局部最优结果为：0.5859962756052142
# 当前最优结果:0.6811255411255411
# 第79次迭代，局部最优结果为：0.5757183978143143
# 当前最优结果:0.6811255411255411
# 第80次迭代，局部最优结果为：0.6063198458574182
# 当前最优结果:0.6811255411255411
# 第81次迭代，局部最优结果为：0.6811255411255411
# 当前最优结果:0.6811255411255411
# 第82次迭代，局部最优结果为：0.5495761922503726
# 当前最优结果:0.6811255411255411
# 第83次迭代，局部最优结果为：0.6410876297060901
# 当前最优结果:0.6811255411255411
# 第84次迭代，局部最优结果为：0.5886710565698893
# 当前最优结果:0.6811255411255411
# 第85次迭代，局部最优结果为：0.6577392564517028
# 当前最优结果:0.6811255411255411
# 第86次迭代，局部最优结果为：0.6811255411255411
# 当前最优结果:0.6811255411255411
# 第87次迭代，局部最优结果为：0.6767311827956989
# 当前最优结果:0.6811255411255411
# 第88次迭代，局部最优结果为：0.5729371495156944
# 当前最优结果:0.6811255411255411
# 第89次迭代，局部最优结果为：0.6318875502008032
# 当前最优结果:0.6811255411255411
# 第90次迭代，局部最优结果为：0.5326096768369742
# 当前最优结果:0.6811255411255411
# 第91次迭代，局部最优结果为：0.6737367970311161
# 当前最优结果:0.6811255411255411
# 第92次迭代，局部最优结果为：0.6811255411255411
# 当前最优结果:0.6811255411255411
# 第93次迭代，局部最优结果为：0.6811255411255411
# 当前最优结果:0.6811255411255411
# 第94次迭代，局部最优结果为：0.6280870768575687
# 当前最优结果:0.6811255411255411
# 第95次迭代，局部最优结果为：0.6681104033970275
# 当前最优结果:0.6811255411255411
# 第96次迭代，局部最优结果为：0.6634339686287739
# 当前最优结果:0.6811255411255411
# 第97次迭代，局部最优结果为：0.6438509384548232
# 当前最优结果:0.6811255411255411
# 第98次迭代，局部最优结果为：0.6811255411255411
# 当前最优结果:0.6811255411255411
# 第99次迭代，局部最优结果为：0.6281037924151697
# 当前最优结果:0.6811255411255411
# 第100次迭代，局部最优结果为：0.6666949152542373
# 当前最优结果:0.6811255411255411
# 第101次迭代，局部最优结果为：0.6186045292514154
# 当前最优结果:0.6811255411255411
# 第102次迭代，局部最优结果为：0.6992888888888888
# 当前最优结果:0.6992888888888888
# 第103次迭代，局部最优结果为：0.6518352804706272
# 当前最优结果:0.6992888888888888
# 第104次迭代，局部最优结果为：0.6870742358078603
# 当前最优结果:0.6992888888888888
# 第105次迭代，局部最优结果为：0.617633204229038
# 当前最优结果:0.6992888888888888
# 第106次迭代，局部最优结果为：0.6992888888888888
# 当前最优结果:0.6992888888888888
# 第107次迭代，局部最优结果为：0.6992888888888888
# 当前最优结果:0.6992888888888888
# 第108次迭代，局部最优结果为：0.6165360501567398
# 当前最优结果:0.6992888888888888
# 第109次迭代，局部最优结果为：0.6681104033970275
# 当前最优结果:0.6992888888888888
# 第110次迭代，局部最优结果为：0.6474897119341564
# 当前最优结果:0.6992888888888888
# 第111次迭代，局部最优结果为：0.614609375
# 当前最优结果:0.6992888888888888
# 第112次迭代，局部最优结果为：0.6161497493734336
# 当前最优结果:0.6992888888888888
# 第113次迭代，局部最优结果为：0.6992888888888888
# 当前最优结果:0.6992888888888888
# 第114次迭代，局部最优结果为：0.63341384863124
# 当前最优结果:0.6992888888888888
# 第115次迭代，局部最优结果为：0.6208502130793918
# 当前最优结果:0.6992888888888888
# 第116次迭代，局部最优结果为：0.6436051268066539
# 当前最优结果:0.6992888888888888
# 第117次迭代，局部最优结果为：0.6689625850340135
# 当前最优结果:0.6992888888888888
# 第118次迭代，局部最优结果为：0.6474897119341564
# 当前最优结果:0.6992888888888888
# 第119次迭代，局部最优结果为：0.6194488188976378
# 当前最优结果:0.6992888888888888
# 第120次迭代，局部最优结果为：0.6229806778587267
# 当前最优结果:0.6992888888888888
# 第121次迭代，局部最优结果为：0.6992888888888888
# 当前最优结果:0.6992888888888888
# 第122次迭代，局部最优结果为：0.6730451149261393
# 当前最优结果:0.6992888888888888
# 第123次迭代，局部最优结果为：0.6787162453627815
# 当前最优结果:0.6992888888888888
# 第124次迭代，局部最优结果为：0.6992888888888888
# 当前最优结果:0.6992888888888888
# 第125次迭代，局部最优结果为：0.6458949096880131
# 当前最优结果:0.6992888888888888
# 第126次迭代，局部最优结果为：0.5892883895131086
# 当前最优结果:0.6992888888888888
# 第127次迭代，局部最优结果为：0.6814795564795565
# 当前最优结果:0.6992888888888888
# 第128次迭代，局部最优结果为：0.6402180989583334
# 当前最优结果:0.6992888888888888
# 第129次迭代，局部最优结果为：0.637004048582996
# 当前最优结果:0.6992888888888888
# 第130次迭代，局部最优结果为：0.6992888888888888
# 当前最优结果:0.6992888888888888
# 第131次迭代，局部最优结果为：0.6811255411255411
# 当前最优结果:0.6992888888888888
# 第132次迭代，局部最优结果为：0.6992888888888888
# 当前最优结果:0.6992888888888888
# 第133次迭代，局部最优结果为：0.6303685897435898
# 当前最优结果:0.6992888888888888
# 第134次迭代，局部最优结果为：0.6946578366445916
# 当前最优结果:0.6992888888888888
# 第135次迭代，局部最优结果为：0.659706498951782
# 当前最优结果:0.6992888888888888
# 第136次迭代，局部最优结果为：0.6900877192982456
# 当前最优结果:0.6992888888888888
# 第137次迭代，局部最优结果为：0.6930056377730797
# 当前最优结果:0.6992888888888888
# 第138次迭代，局部最优结果为：0.6855773420479303
# 当前最优结果:0.6992888888888888
# 第139次迭代，局部最优结果为：0.6855773420479303
# 当前最优结果:0.6992888888888888
# 第140次迭代，局部最优结果为：0.6588777219430486
# 当前最优结果:0.6992888888888888
# 第141次迭代，局部最优结果为：0.6870742358078603
# 当前最优结果:0.6992888888888888
# 第142次迭代，局部最优结果为：0.653839760638298
# 当前最优结果:0.6992888888888888
# 第143次迭代，局部最优结果为：0.6662808424143187
# 当前最优结果:0.6992888888888888
# 第144次迭代，局部最优结果为：0.6717042349726775
# 当前最优结果:0.6992888888888888
# 第145次迭代，局部最优结果为：0.6736021919684904
# 当前最优结果:0.6992888888888888
# 第146次迭代，局部最优结果为：0.6961946902654867
# 当前最优结果:0.6992888888888888
# 第147次迭代，局部最优结果为：0.6855375141603974
# 当前最优结果:0.6992888888888888
# 第148次迭代，局部最优结果为：0.7087387387387387
# 当前最优结果:0.7087387387387387
# 第149次迭代，局部最优结果为：0.6638445094509451
# 当前最优结果:0.7087387387387387
# 第150次迭代，局部最优结果为：0.6634339686287739
# 当前最优结果:0.7087387387387387
# 第151次迭代，局部最优结果为：0.6904511146217307
# 当前最优结果:0.7087387387387387
# 第152次迭代，局部最优结果为：0.7087387387387387
# 当前最优结果:0.7087387387387387
# 第153次迭代，局部最优结果为：0.6750858123569794
# 当前最优结果:0.7087387387387387
# 第154次迭代，局部最优结果为：0.683195831524099
# 当前最优结果:0.7087387387387387
# 第155次迭代，局部最优结果为：0.7087387387387387
# 当前最优结果:0.7087387387387387
# 第156次迭代，局部最优结果为：0.6713221071794289
# 当前最优结果:0.7087387387387387
# 第157次迭代，局部最优结果为：0.6897650222118307
# 当前最优结果:0.7087387387387387
# 第158次迭代，局部最优结果为：0.6706734867860188
# 当前最优结果:0.7087387387387387
# 第159次迭代，局部最优结果为：0.6970583023214603
# 当前最优结果:0.7087387387387387
# 第160次迭代，局部最优结果为：0.7056027266204257
# 当前最优结果:0.7087387387387387
# 第161次迭代，局部最优结果为：0.7087387387387387
# 当前最优结果:0.7087387387387387
# 第162次迭代，局部最优结果为：0.7087387387387387
# 当前最优结果:0.7087387387387387
# 第163次迭代，局部最优结果为：0.7097618188379646
# 当前最优结果:0.7097618188379646
# 第164次迭代，局部最优结果为：0.7144673508309871
# 当前最优结果:0.7144673508309872
# 第165次迭代，局部最优结果为：0.709505772005772
# 当前最优结果:0.7144673508309872
# 第166次迭代，局部最优结果为：0.7183818829330655
# 当前最优结果:0.7183818829330655
# 第167次迭代，局部最优结果为：0.7124184979473557
# 当前最优结果:0.7183818829330655
# 第168次迭代，局部最优结果为：0.710274467316721
# 当前最优结果:0.7183818829330655
# 第169次迭代，局部最优结果为：0.709505772005772
# 当前最优结果:0.7183818829330655
# 第170次迭代，局部最优结果为：0.7081008100810081
# 当前最优结果:0.7183818829330655
# 第171次迭代，局部最优结果为：0.7144673508309871
# 当前最优结果:0.7183818829330655
# 第172次迭代，局部最优结果为：0.74663081303385
# 当前最优结果:0.74663081303385
# 第173次迭代，局部最优结果为：0.74663081303385
# 当前最优结果:0.74663081303385
# 第174次迭代，局部最优结果为：0.74663081303385
# 当前最优结果:0.74663081303385
# 第175次迭代，局部最优结果为：0.745169234655216
# 当前最优结果:0.74663081303385
# 第176次迭代，局部最优结果为：0.74663081303385
# 当前最优结果:0.74663081303385
# 第177次迭代，局部最优结果为：0.74663081303385
# 当前最优结果:0.74663081303385
# 第178次迭代，局部最优结果为：0.7177919708029197
# 当前最优结果:0.74663081303385
# 第179次迭代，局部最优结果为：0.74663081303385
# 当前最优结果:0.74663081303385
# 第180次迭代，局部最优结果为：0.722627066748316
# 当前最优结果:0.74663081303385
# 第181次迭代，局部最优结果为：0.6662808424143187
# 当前最优结果:0.74663081303385
# 第182次迭代，局部最优结果为：0.7349817819438822
# 当前最优结果:0.74663081303385
# 第183次迭代，局部最优结果为：0.7183162892622352
# 当前最优结果:0.74663081303385
# 第184次迭代，局部最优结果为：0.7382695195195195
# 当前最优结果:0.74663081303385
# 第185次迭代，局部最优结果为：0.7382695195195195
# 当前最优结果:0.74663081303385
# 第186次迭代，局部最优结果为：0.74663081303385
# 当前最优结果:0.74663081303385
# 第187次迭代，局部最优结果为：0.74663081303385
# 当前最优结果:0.74663081303385
# 第188次迭代，局部最优结果为：0.74663081303385
# 当前最优结果:0.74663081303385
# 第189次迭代，局部最优结果为：0.7432215399149741
# 当前最优结果:0.74663081303385
# 第190次迭代，局部最优结果为：0.7331780055917987
# 当前最优结果:0.74663081303385
# 第191次迭代，局部最优结果为：0.74663081303385
# 当前最优结果:0.74663081303385
# 第192次迭代，局部最优结果为：0.74663081303385
# 当前最优结果:0.74663081303385
# 第193次迭代，局部最优结果为：0.7248464373464374
# 当前最优结果:0.74663081303385
# 第194次迭代，局部最优结果为：0.7184474885844749
# 当前最优结果:0.74663081303385
# 第195次迭代，局部最优结果为：0.7354169263367818
# 当前最优结果:0.74663081303385
# 第196次迭代，局部最优结果为：0.7183162892622352
# 当前最优结果:0.74663081303385
# 第197次迭代，局部最优结果为：0.7202014037229173
# 当前最优结果:0.74663081303385
# 第198次迭代，局部最优结果为：0.7202014037229173
# 当前最优结果:0.74663081303385
# 第199次迭代，局部最优结果为：0.74663081303385
# 当前最优结果:0.74663081303385
# 第200次迭代，局部最优结果为：0.7298902118447503
# 当前最优结果:0.74663081303385
# 第201次迭代，局部最优结果为：0.74663081303385
# 当前最优结果:0.74663081303385
# 第202次迭代，局部最优结果为：0.7298902118447503
# 当前最优结果:0.74663081303385
# 第203次迭代，局部最优结果为：0.7072308291630457
# 当前最优结果:0.74663081303385
# 第204次迭代，局部最优结果为：0.7331780055917987
# 当前最优结果:0.74663081303385
# 第205次迭代，局部最优结果为：0.7202014037229173
# 当前最优结果:0.74663081303385
# 第206次迭代，局部最优结果为：0.74663081303385
# 当前最优结果:0.74663081303385
# 第207次迭代，局部最优结果为：0.74663081303385
# 当前最优结果:0.74663081303385
# 本次退火用时：6497.710978746414
# 第1次迭代，局部最优结果为：0.5481720629906629
# 当前最优结果:0.5481720629906629
# 第2次迭代，局部最优结果为：0.5367767467248908
# 当前最优结果:0.5481720629906629
# 第3次迭代，局部最优结果为：0.5873525459160818
# 当前最优结果:0.5873525459160819
# 第4次迭代，局部最优结果为：0.5737868326363902
# 当前最优结果:0.5873525459160819
# 第5次迭代，局部最优结果为：0.548528796541626
# 当前最优结果:0.5873525459160819
# 第6次迭代，局部最优结果为：0.5821083267561168
# 当前最优结果:0.5873525459160819
# 第7次迭代，局部最优结果为：0.5442407471463162
# 当前最优结果:0.5873525459160819
# 第8次迭代，局部最优结果为：0.5673999278759466
# 当前最优结果:0.5873525459160819
# 第9次迭代，局部最优结果为：0.5388110131957445
# 当前最优结果:0.5873525459160819
# 第10次迭代，局部最优结果为：0.5873525459160818
# 当前最优结果:0.5873525459160819
# 第11次迭代，局部最优结果为：0.5777761457109283
# 当前最优结果:0.5873525459160819
# 第12次迭代，局部最优结果为：0.5769569256343813
# 当前最优结果:0.5873525459160819
# 第13次迭代，局部最优结果为：0.5536242083040113
# 当前最优结果:0.5873525459160819
# 第14次迭代，局部最优结果为：0.5228863878057427
# 当前最优结果:0.5873525459160819
# 第15次迭代，局部最优结果为：0.5185893210283454
# 当前最优结果:0.5873525459160819
# 第16次迭代，局部最优结果为：0.5644686804907799
# 当前最优结果:0.5873525459160819
# 第17次迭代，局部最优结果为：0.5339955200579225
# 当前最优结果:0.5873525459160819
# 第18次迭代，局部最优结果为：0.5953984712026035
# 当前最优结果:0.5953984712026035
# 第19次迭代，局部最优结果为：0.5455743313530133
# 当前最优结果:0.5953984712026035
# 第20次迭代，局部最优结果为：0.5856908874329958
# 当前最优结果:0.5953984712026035
# 第21次迭代，局部最优结果为：0.5644686804907799
# 当前最优结果:0.5953984712026035
# 第22次迭代，局部最优结果为：0.6036370146810578
# 当前最优结果:0.6036370146810579
# 第23次迭代，局部最优结果为：0.6036370146810578
# 当前最优结果:0.6036370146810579
# 第24次迭代，局部最优结果为：0.5732293791897406
# 当前最优结果:0.6036370146810579
# 第25次迭代，局部最优结果为：0.6071465322082733
# 当前最优结果:0.6071465322082733
# 第26次迭代，局部最优结果为：0.5510647240123283
# 当前最优结果:0.6071465322082733
# 第27次迭代，局部最优结果为：0.5838941118258288
# 当前最优结果:0.6071465322082733
# 第28次迭代，局部最优结果为：0.6138420724094882
# 当前最优结果:0.6138420724094882
# 第29次迭代，局部最优结果为：0.5616611137553547
# 当前最优结果:0.6138420724094882
# 第30次迭代，局部最优结果为：0.6601309017677333
# 当前最优结果:0.6601309017677333
# 第31次迭代，局部最优结果为：0.5580488035562281
# 当前最优结果:0.6601309017677333
# 第32次迭代，局部最优结果为：0.6082104937635295
# 当前最优结果:0.6601309017677333
# 第33次迭代，局部最优结果为：0.5922161999397771
# 当前最优结果:0.6601309017677333
# 第34次迭代，局部最优结果为：0.5118412491867274
# 当前最优结果:0.6601309017677333
# 第35次迭代，局部最优结果为：0.6601309017677333
# 当前最优结果:0.6601309017677333
# 第36次迭代，局部最优结果为：0.6424488240418118
# 当前最优结果:0.6601309017677333
# 第37次迭代，局部最优结果为：0.6491638244031247
# 当前最优结果:0.6601309017677333
# 第38次迭代，局部最优结果为：0.5333077235956072
# 当前最优结果:0.6601309017677333
# 第39次迭代，局部最优结果为：0.5609269162210339
# 当前最优结果:0.6601309017677333
# 第40次迭代，局部最优结果为：0.6225698382969743
# 当前最优结果:0.6601309017677333
# 第41次迭代，局部最优结果为：0.6631729796560638
# 当前最优结果:0.6631729796560638
# 第42次迭代，局部最优结果为：0.6631729796560638
# 当前最优结果:0.6631729796560638
# 第43次迭代，局部最优结果为：0.5534943714821764
# 当前最优结果:0.6631729796560638
# 第44次迭代，局部最优结果为：0.6631729796560638
# 当前最优结果:0.6631729796560638
# 第45次迭代，局部最优结果为：0.6693420306296086
# 当前最优结果:0.6693420306296086
# 第46次迭代，局部最优结果为：0.6756269323256613
# 当前最优结果:0.6756269323256613
# 第47次迭代，局部最优结果为：0.6882162540460153
# 当前最优结果:0.6882162540460153
# 第48次迭代，局部最优结果为：0.6738137383657854
# 当前最优结果:0.6882162540460153
# 第49次迭代，局部最优结果为：0.681814242380471
# 当前最优结果:0.6882162540460153
# 第50次迭代，局部最优结果为：0.6850002902420619
# 当前最优结果:0.6882162540460153
# 第51次迭代，局部最优结果为：0.5289095065214469
# 当前最优结果:0.6882162540460153
# 第52次迭代，局部最优结果为：0.6551647558504289
# 当前最优结果:0.6882162540460153
# 第53次迭代，局部最优结果为：0.5703893467385263
# 当前最优结果:0.6882162540460153
# 第54次迭代，局部最优结果为：0.6839680055642496
# 当前最优结果:0.6882162540460153
# 第55次迭代，局部最优结果为：0.6882162540460153
# 当前最优结果:0.6882162540460153
# 第56次迭代，局部最优结果为：0.6155712050078248
# 当前最优结果:0.6882162540460153
# 第57次迭代，局部最优结果为：0.5303237983956138
# 当前最优结果:0.6882162540460153
# 第58次迭代，局部最优结果为：0.6556379698308192
# 当前最优结果:0.6882162540460153
# 第59次迭代，局部最优结果为：0.6179728208216595
# 当前最优结果:0.6882162540460153
# 第60次迭代，局部最优结果为：0.651781275890638
# 当前最优结果:0.6882162540460153
# 第61次迭代，局部最优结果为：0.5584449387156311
# 当前最优结果:0.6882162540460153
# 第62次迭代，局部最优结果为：0.67243147757707
# 当前最优结果:0.6882162540460153
# 第63次迭代，局部最优结果为：0.5624508472152713
# 当前最优结果:0.6882162540460153
# 第64次迭代，局部最优结果为：0.6053711588775458
# 当前最优结果:0.6882162540460153
# 第65次迭代，局部最优结果为：0.6882162540460153
# 当前最优结果:0.6882162540460153
# 第66次迭代，局部最优结果为：0.5302165708123652
# 当前最优结果:0.6882162540460153
# 第67次迭代，局部最优结果为：0.5958945614300863
# 当前最优结果:0.6882162540460153
# 第68次迭代，局部最优结果为：0.6482366512854317
# 当前最优结果:0.6882162540460153
# 第69次迭代，局部最优结果为：0.6007789430811526
# 当前最优结果:0.6882162540460153
# 第70次迭代，局部最优结果为：0.6882162540460153
# 当前最优结果:0.6882162540460153
# 第71次迭代，局部最优结果为：0.6603155950982038
# 当前最优结果:0.6882162540460153
# 第72次迭代，局部最优结果为：0.6882162540460153
# 当前最优结果:0.6882162540460153
# 第73次迭代，局部最优结果为：0.6797718828307268
# 当前最优结果:0.6882162540460153
# 第74次迭代，局部最优结果为：0.5942590960594234
# 当前最优结果:0.6882162540460153
# 第75次迭代，局部最优结果为：0.5471807474728739
# 当前最优结果:0.6882162540460153
# 第76次迭代，局部最优结果为：0.6882162540460153
# 当前最优结果:0.6882162540460153
# 第77次迭代，局部最优结果为：0.6190101502871981
# 当前最优结果:0.6882162540460153
# 第78次迭代，局部最优结果为：0.6882162540460153
# 当前最优结果:0.6882162540460153
# 第79次迭代，局部最优结果为：0.6595405767940979
# 当前最优结果:0.6882162540460153
# 第80次迭代，局部最优结果为：0.6882162540460153
# 当前最优结果:0.6882162540460153
# 第81次迭代，局部最优结果为：0.6556379698308192
# 当前最优结果:0.6882162540460153
# 第82次迭代，局部最优结果为：0.6318537159991433
# 当前最优结果:0.6882162540460153
# 第83次迭代，局部最优结果为：0.6057440583132283
# 当前最优结果:0.6882162540460153
# 第84次迭代，局部最优结果为：0.6882162540460153
# 当前最优结果:0.6882162540460153
# 第85次迭代，局部最优结果为：0.5687536148062464
# 当前最优结果:0.6882162540460153
# 第86次迭代，局部最优结果为：0.6556379698308192
# 当前最优结果:0.6882162540460153
# 第87次迭代，局部最优结果为：0.5434512296214424
# 当前最优结果:0.6882162540460153
# 第88次迭代，局部最优结果为：0.6382098431584641
# 当前最优结果:0.6882162540460153
# 第89次迭代，局部最优结果为：0.6486285934150497
# 当前最优结果:0.6882162540460153
# 第90次迭代，局部最优结果为：0.6107919254658385
# 当前最优结果:0.6882162540460153
# 第91次迭代，局部最优结果为：0.5770980046948356
# 当前最优结果:0.6882162540460153
# 第92次迭代，局部最优结果为：0.6882162540460153
# 当前最优结果:0.6882162540460153
# 第93次迭代，局部最优结果为：0.6166971518160439
# 当前最优结果:0.6882162540460153
# 第94次迭代，局部最优结果为：0.6007942366927169
# 当前最优结果:0.6882162540460153
# 第95次迭代，局部最优结果为：0.6882162540460153
# 当前最优结果:0.6882162540460153
# 第96次迭代，局部最优结果为：0.6319044686604729
# 当前最优结果:0.6882162540460153
# 第97次迭代，局部最优结果为：0.6382098431584641
# 当前最优结果:0.6882162540460153
# 第98次迭代，局部最优结果为：0.6534053156146179
# 当前最优结果:0.6882162540460153
# 第99次迭代，局部最优结果为：0.6882162540460153
# 当前最优结果:0.6882162540460153
# 第100次迭代，局部最优结果为：0.5673317307692308
# 当前最优结果:0.6882162540460153
# 第101次迭代，局部最优结果为：0.6797718828307268
# 当前最优结果:0.6882162540460153
# 第102次迭代，局部最优结果为：0.5842988710635769
# 当前最优结果:0.6882162540460153
# 第103次迭代，局部最优结果为：0.5925284326278527
# 当前最优结果:0.6882162540460153
# 第104次迭代，局部最优结果为：0.5812767843948574
# 当前最优结果:0.6882162540460153
# 第105次迭代，局部最优结果为：0.6045028430920547
# 当前最优结果:0.6882162540460153
# 第106次迭代，局部最优结果为：0.6882162540460153
# 当前最优结果:0.6882162540460153
# 第107次迭代，局部最优结果为：0.6049211841599386
# 当前最优结果:0.6882162540460153
# 第108次迭代，局部最优结果为：0.6369696642556407
# 当前最优结果:0.6882162540460153
# 第109次迭代，局部最优结果为：0.67243147757707
# 当前最优结果:0.6882162540460153
# 第110次迭代，局部最优结果为：0.6318537159991433
# 当前最优结果:0.6882162540460153
# 第111次迭代，局部最优结果为：0.6947396308616173
# 当前最优结果:0.6947396308616173
# 第112次迭代，局部最优结果为：0.6947396308616173
# 当前最优结果:0.6947396308616173
# 第113次迭代，局部最优结果为：0.6947396308616173
# 当前最优结果:0.6947396308616173
# 第114次迭代，局部最优结果为：0.6369009067357513
# 当前最优结果:0.6947396308616173
# 第115次迭代，局部最优结果为：0.6724697971278779
# 当前最优结果:0.6947396308616173
# 第116次迭代，局部最优结果为：0.5902611044417767
# 当前最优结果:0.6947396308616173
# 第117次迭代，局部最优结果为：0.6330061152236884
# 当前最优结果:0.6947396308616173
# 第118次迭代，局部最优结果为：0.5814486326681448
# 当前最优结果:0.6947396308616173
# 第119次迭代，局部最优结果为：0.5880257125772373
# 当前最优结果:0.6947396308616173
# 第120次迭代，局部最优结果为：0.6211770279517819
# 当前最优结果:0.6947396308616173
# 第121次迭代，局部最优结果为：0.6389701104613386
# 当前最优结果:0.6947396308616173
# 第122次迭代，局部最优结果为：0.6283880930826987
# 当前最优结果:0.6947396308616173
# 第123次迭代，局部最优结果为：0.6778974579922448
# 当前最优结果:0.6947396308616173
# 第124次迭代，局部最优结果为：0.6738137383657854
# 当前最优结果:0.6947396308616173
# 第125次迭代，局部最优结果为：0.6279533844189017
# 当前最优结果:0.6947396308616173
# 第126次迭代，局部最优结果为：0.6512417218543046
# 当前最优结果:0.6947396308616173
# 第127次迭代，局部最优结果为：0.6367977982839567
# 当前最优结果:0.6947396308616173
# 第128次迭代，局部最优结果为：0.6254239983040067
# 当前最优结果:0.6947396308616173
# 第129次迭代，局部最优结果为：0.6469572368421053
# 当前最优结果:0.6947396308616173
# 第130次迭代，局部最优结果为：0.6486285934150497
# 当前最优结果:0.6947396308616173
# 第131次迭代，局部最优结果为：0.6264532568880395
# 当前最优结果:0.6947396308616173
# 第132次迭代，局部最优结果为：0.6947396308616173
# 当前最优结果:0.6947396308616173
# 第133次迭代，局部最优结果为：0.6603895013710895
# 当前最优结果:0.6947396308616173
# 第134次迭代，局部最优结果为：0.6904511146217307
# 当前最优结果:0.6947396308616173
# 第135次迭代，局部最优结果为：0.6947396308616173
# 当前最优结果:0.6947396308616173
# 第136次迭代，局部最优结果为：0.6693610142091381
# 当前最优结果:0.6947396308616173
# 第137次迭代，局部最优结果为：0.6679402275428766
# 当前最优结果:0.6947396308616173
# 第138次迭代，局部最优结果为：0.6994754156663999
# 当前最优结果:0.6994754156663999
# 第139次迭代，局部最优结果为：0.669645897173987
# 当前最优结果:0.6994754156663999
# 第140次迭代，局部最优结果为：0.6437806873977087
# 当前最优结果:0.6994754156663999
# 第141次迭代，局部最优结果为：0.6303685897435898
# 当前最优结果:0.6994754156663999
# 第142次迭代，局部最优结果为：0.7097618188379646
# 当前最优结果:0.7097618188379646
# 第143次迭代，局部最优结果为：0.6732563115104836
# 当前最优结果:0.7097618188379646
# 第144次迭代，局部最优结果为：0.6677701383583736
# 当前最优结果:0.7097618188379646
# 第145次迭代，局部最优结果为：0.6633034484696889
# 当前最优结果:0.7097618188379646
# 第146次迭代，局部最优结果为：0.6755689136968656
# 当前最优结果:0.7097618188379646
# 第147次迭代，局部最优结果为：0.7097618188379646
# 当前最优结果:0.7097618188379646
# 第148次迭代，局部最优结果为：0.7097618188379646
# 当前最优结果:0.7097618188379646
# 第149次迭代，局部最优结果为：0.6832551676220253
# 当前最优结果:0.7097618188379646
# 第150次迭代，局部最优结果为：0.7097618188379646
# 当前最优结果:0.7097618188379646
# 第151次迭代，局部最优结果为：0.7054340028694405
# 当前最优结果:0.7097618188379646
# 第152次迭代，局部最优结果为：0.7003679743604961
# 当前最优结果:0.7097618188379646
# 第153次迭代，局部最优结果为：0.6802617167233527
# 当前最优结果:0.7097618188379646
# 第154次迭代，局部最优结果为：0.6902088085629058
# 当前最优结果:0.7097618188379646
# 第155次迭代，局部最优结果为：0.7054340028694405
# 当前最优结果:0.7097618188379646
# 第156次迭代，局部最优结果为：0.7097618188379646
# 当前最优结果:0.7097618188379646
# 第157次迭代，局部最优结果为：0.693453605218311
# 当前最优结果:0.7097618188379646
# 第158次迭代，局部最优结果为：0.7106594399277326
# 当前最优结果:0.7106594399277326
# 第159次迭代，局部最优结果为：0.7113019891500905
# 当前最优结果:0.7113019891500905
# 第160次迭代，局部最优结果为：0.7254034117104656
# 当前最优结果:0.7254034117104656
# 第161次迭代，局部最优结果为：0.7164845173041894
# 当前最优结果:0.7254034117104656
# 第162次迭代，局部最优结果为：0.7254034117104656
# 当前最优结果:0.7254034117104656
# 第163次迭代，局部最优结果为：0.7235131820968731
# 当前最优结果:0.7254034117104656
# 第164次迭代，局部最优结果为：0.7254034117104656
# 当前最优结果:0.7254034117104656
# 第165次迭代，局部最优结果为：0.7148135808825756
# 当前最优结果:0.7254034117104656
# 第166次迭代，局部最优结果为：0.7200695630949475
# 当前最优结果:0.7254034117104656
# 第167次迭代，局部最优结果为：0.7194330132601738
# 当前最优结果:0.7254034117104656
# 第168次迭代，局部最优结果为：0.7200695630949475
# 当前最优结果:0.7254034117104656
# 第169次迭代，局部最优结果为：0.7200695630949475
# 当前最优结果:0.7254034117104656
# 第170次迭代，局部最优结果为：0.7284259259259259
# 当前最优结果:0.7284259259259259
# 第171次迭代，局部最优结果为：0.7376465072667605
# 当前最优结果:0.7376465072667604
# 第172次迭代，局部最优结果为：0.7407721280602637
# 当前最优结果:0.7407721280602636
# 第173次迭代，局部最优结果为：0.7407721280602637
# 当前最优结果:0.7407721280602636
# 第174次迭代，局部最优结果为：0.7407721280602637
# 当前最优结果:0.7407721280602636
# 第175次迭代，局部最优结果为：0.7407721280602637
# 当前最优结果:0.7407721280602636
# 第176次迭代，局部最优结果为：0.7384543178973717
# 当前最优结果:0.7407721280602636
# 第177次迭代，局部最优结果为：0.7384543178973717
# 当前最优结果:0.7407721280602636
# 第178次迭代，局部最优结果为：0.7284259259259259
# 当前最优结果:0.7407721280602636
# 第179次迭代，局部最优结果为：0.7407721280602637
# 当前最优结果:0.7407721280602636
# 第180次迭代，局部最优结果为：0.7439243498817967
# 当前最优结果:0.7439243498817967
# 第181次迭代，局部最优结果为：0.7576078582434514
# 当前最优结果:0.7576078582434514
# 第182次迭代，局部最优结果为：0.7439243498817967
# 当前最优结果:0.7576078582434514
# 第183次迭代，局部最优结果为：0.7284259259259259
# 当前最优结果:0.7576078582434514
# 第184次迭代，局部最优结果为：0.7439243498817967
# 当前最优结果:0.7576078582434514
# 第185次迭代，局部最优结果为：0.7740062967335695
# 当前最优结果:0.7740062967335695
# 第186次迭代，局部最优结果为：0.7740062967335695
# 当前最优结果:0.7740062967335695
# 第187次迭代，局部最优结果为：0.7512414056531704
# 当前最优结果:0.7740062967335695
# 第188次迭代，局部最优结果为：0.7512414056531704
# 当前最优结果:0.7740062967335695
# 第189次迭代，局部最优结果为：0.7480032961460445
# 当前最优结果:0.7740062967335695
# 第190次迭代，局部最优结果为：0.7407721280602637
# 当前最优结果:0.7740062967335695
# 第191次迭代，局部最优结果为：0.76736246586032
# 当前最优结果:0.7740062967335695
# 第192次迭代，局部最优结果为：0.7740062967335695
# 当前最优结果:0.7740062967335695
# 第193次迭代，局部最优结果为：0.7740062967335695
# 当前最优结果:0.7740062967335695
# 第194次迭代，局部最优结果为：0.7503099666189794
# 当前最优结果:0.7740062967335695
# 第195次迭代，局部最优结果为：0.7740062967335695
# 当前最优结果:0.7740062967335695
# 第196次迭代，局部最优结果为：0.7740062967335695
# 当前最优结果:0.7740062967335695
# 第197次迭代，局部最优结果为：0.7740062967335695
# 当前最优结果:0.7740062967335695
# 第198次迭代，局部最优结果为：0.7608317214700193
# 当前最优结果:0.7740062967335695
# 第199次迭代，局部最优结果为：0.7576078582434514
# 当前最优结果:0.7740062967335695
# 第200次迭代，局部最优结果为：0.7740062967335695
# 当前最优结果:0.7740062967335695
# 第201次迭代，局部最优结果为：0.7758892760865278
# 当前最优结果:0.7758892760865277
# 第202次迭代，局部最优结果为：0.7551111822108463
# 当前最优结果:0.7758892760865277
# 第203次迭代，局部最优结果为：0.7758892760865278
# 当前最优结果:0.7758892760865277
# 第204次迭代，局部最优结果为：0.7740062967335695
# 当前最优结果:0.7758892760865277
# 第205次迭代，局部最优结果为：0.7740062967335695
# 当前最优结果:0.7758892760865277
# 第206次迭代，局部最优结果为：0.7841905901116427
# 当前最优结果:0.7841905901116427
# 第207次迭代，局部最优结果为：0.7841905901116427
# 当前最优结果:0.7841905901116427
# 本次退火用时：6530.004365205765
# 第1次迭代，局部最优结果为：0.536923286923287
# 当前最优结果:0.536923286923287
# 第2次迭代，局部最优结果为：0.5221229149152692
# 当前最优结果:0.536923286923287
# 第3次迭代，局部最优结果为：0.5577454803261255
# 当前最优结果:0.5577454803261255
# 第4次迭代，局部最优结果为：0.5308367071524966
# 当前最优结果:0.5577454803261255
# 第5次迭代，局部最优结果为：0.5562075791855203
# 当前最优结果:0.5577454803261255
# 第6次迭代，局部最优结果为：0.5384176666514578
# 当前最优结果:0.5577454803261255
# 第7次迭代，局部最优结果为：0.5552915156933792
# 当前最优结果:0.5577454803261255
# 第8次迭代，局部最优结果为：0.5757183978143143
# 当前最优结果:0.5757183978143143
# 第9次迭代，局部最优结果为：0.5603276353276353
# 当前最优结果:0.5757183978143143
# 第10次迭代，局部最优结果为：0.5137800417972832
# 当前最优结果:0.5757183978143143
# 第11次迭代，局部最优结果为：0.5588681032441393
# 当前最优结果:0.5757183978143143
# 第12次迭代，局部最优结果为：0.5757183978143143
# 当前最优结果:0.5757183978143143
# 第13次迭代，局部最优结果为：0.5815775855696015
# 当前最优结果:0.5815775855696015
# 第14次迭代，局部最优结果为：0.5815775855696015
# 当前最优结果:0.5815775855696015
# 第15次迭代，局部最优结果为：0.575325435132368
# 当前最优结果:0.5815775855696015
# 第16次迭代，局部最优结果为：0.5208783932906643
# 当前最优结果:0.5815775855696015
# 第17次迭代，局部最优结果为：0.5850810650007436
# 当前最优结果:0.5850810650007437
# 第18次迭代，局部最优结果为：0.597493670886076
# 当前最优结果:0.597493670886076
# 第19次迭代，局部最优结果为：0.5728398058252427
# 当前最优结果:0.597493670886076
# 第20次迭代，局部最优结果为：0.5137800417972832
# 当前最优结果:0.597493670886076
# 第21次迭代，局部最优结果为：0.597493670886076
# 当前最优结果:0.597493670886076
# 第22次迭代，局部最优结果为：0.5504734804310304
# 当前最优结果:0.597493670886076
# 第23次迭代，局部最优结果为：0.5398339394771152
# 当前最优结果:0.597493670886076
# 第24次迭代，局部最优结果为：0.6142894325871942
# 当前最优结果:0.6142894325871942
# 第25次迭代，局部最优结果为：0.6142894325871942
# 当前最优结果:0.6142894325871942
# 第26次迭代，局部最优结果为：0.6142894325871942
# 当前最优结果:0.6142894325871942
# 第27次迭代，局部最优结果为：0.5496273870517001
# 当前最优结果:0.6142894325871942
# 第28次迭代，局部最优结果为：0.6142894325871942
# 当前最优结果:0.6142894325871942
# 第29次迭代，局部最优结果为：0.5442407471463162
# 当前最优结果:0.6142894325871942
# 第30次迭代，局部最优结果为：0.6410876297060901
# 当前最优结果:0.6410876297060901
# 第31次迭代，局部最优结果为：0.6410876297060901
# 当前最优结果:0.6410876297060901
# 第32次迭代，局部最优结果为：0.6135229281480711
# 当前最优结果:0.6410876297060901
# 第33次迭代，局部最优结果为：0.6147054227223004
# 当前最优结果:0.6410876297060901
# 第34次迭代，局部最优结果为：0.57552184939524
# 当前最优结果:0.6410876297060901
# 第35次迭代，局部最优结果为：0.6036061381074168
# 当前最优结果:0.6410876297060901
# 第36次迭代，局部最优结果为：0.6410876297060901
# 当前最优结果:0.6410876297060901
# 第37次迭代，局部最优结果为：0.5722703135229504
# 当前最优结果:0.6410876297060901
# 第38次迭代，局部最优结果为：0.57552184939524
# 当前最优结果:0.6410876297060901
# 第39次迭代，局部最优结果为：0.6410876297060901
# 当前最优结果:0.6410876297060901
# 第40次迭代，局部最优结果为：0.6383479389808504
# 当前最优结果:0.6410876297060901
# 第41次迭代，局部最优结果为：0.5927516576250753
# 当前最优结果:0.6410876297060901
# 第42次迭代，局部最优结果为：0.5993600325062853
# 当前最优结果:0.6410876297060901
# 第43次迭代，局部最优结果为：0.5848780729579699
# 当前最优结果:0.6410876297060901
# 第44次迭代，局部最优结果为：0.5226779465828055
# 当前最优结果:0.6410876297060901
# 第45次迭代，局部最优结果为：0.5983419531487679
# 当前最优结果:0.6410876297060901
# 第46次迭代，局部最优结果为：0.5745131450827653
# 当前最优结果:0.6410876297060901
# 第47次迭代，局部最优结果为：0.6410876297060901
# 当前最优结果:0.6410876297060901
# 第48次迭代，局部最优结果为：0.6410876297060901
# 当前最优结果:0.6410876297060901
# 第49次迭代，局部最优结果为：0.5943189544458714
# 当前最优结果:0.6410876297060901
# 第50次迭代，局部最优结果为：0.5317336938154782
# 当前最优结果:0.6410876297060901
# 第51次迭代，局部最优结果为：0.6206706114398423
# 当前最优结果:0.6410876297060901
# 第52次迭代，局部最优结果为：0.6095299586776859
# 当前最优结果:0.6410876297060901
# 第53次迭代，局部最优结果为：0.5872064092356688
# 当前最优结果:0.6410876297060901
# 第54次迭代，局部最优结果为：0.5786260664901441
# 当前最优结果:0.6410876297060901
# 第55次迭代，局部最优结果为：0.6406699603670123
# 当前最优结果:0.6410876297060901
# 第56次迭代，局部最优结果为：0.6042242703533026
# 当前最优结果:0.6410876297060901
# 第57次迭代，局部最优结果为：0.6329382106844025
# 当前最优结果:0.6410876297060901
# 第58次迭代，局部最优结果为：0.5767313425541274
# 当前最优结果:0.6410876297060901
# 第59次迭代，局部最优结果为：0.5504734804310304
# 当前最优结果:0.6410876297060901
# 第60次迭代，局部最优结果为：0.5286725505129698
# 当前最优结果:0.6410876297060901
# 第61次迭代，局部最优结果为：0.6060862865947612
# 当前最优结果:0.6410876297060901
# 第62次迭代，局部最优结果为：0.6410876297060901
# 当前最优结果:0.6410876297060901
# 第63次迭代，局部最优结果为：0.5889060784509432
# 当前最优结果:0.6410876297060901
# 第64次迭代，局部最优结果为：0.5723119452931762
# 当前最优结果:0.6410876297060901
# 第65次迭代，局部最优结果为：0.5584449387156311
# 当前最优结果:0.6410876297060901
# 第66次迭代，局部最优结果为：0.577126228786619
# 当前最优结果:0.6410876297060901
# 第67次迭代，局部最优结果为：0.6142894325871942
# 当前最优结果:0.6410876297060901
# 第68次迭代，局部最优结果为：0.613889972688256
# 当前最优结果:0.6410876297060901
# 第69次迭代，局部最优结果为：0.6410876297060901
# 当前最优结果:0.6410876297060901
# 第70次迭代，局部最优结果为：0.570844620743034
# 当前最优结果:0.6410876297060901
# 第71次迭代，局部最优结果为：0.6410876297060901
# 当前最优结果:0.6410876297060901
# 第72次迭代，局部最优结果为：0.6410876297060901
# 当前最优结果:0.6410876297060901
# 第73次迭代，局部最优结果为：0.5594510027023183
# 当前最优结果:0.6410876297060901
# 第74次迭代，局部最优结果为：0.5761400253881457
# 当前最优结果:0.6410876297060901
# 第75次迭代，局部最优结果为：0.6410876297060901
# 当前最优结果:0.6410876297060901
# 第76次迭代，局部最优结果为：0.6438509384548232
# 当前最优结果:0.6438509384548232
# 第77次迭代，局部最优结果为：0.6410876297060901
# 当前最优结果:0.6438509384548232
# 第78次迭代，局部最优结果为：0.5747369959088253
# 当前最优结果:0.6438509384548232
# 第79次迭代，局部最优结果为：0.5738844984802431
# 当前最优结果:0.6438509384548232
# 第80次迭代，局部最优结果为：0.607209015128126
# 当前最优结果:0.6438509384548232
# 第81次迭代，局部最优结果为：0.563175603121197
# 当前最优结果:0.6438509384548232
# 第82次迭代，局部最优结果为：0.5679871005005777
# 当前最优结果:0.6438509384548232
# 第83次迭代，局部最优结果为：0.5876011452757376
# 当前最优结果:0.6438509384548232
# 第84次迭代，局部最优结果为：0.6438509384548232
# 当前最优结果:0.6438509384548232
# 第85次迭代，局部最优结果为：0.549832261671792
# 当前最优结果:0.6438509384548232
# 第86次迭代，局部最优结果为：0.6438509384548232
# 当前最优结果:0.6438509384548232
# 第87次迭代，局部最优结果为：0.6438509384548232
# 当前最优结果:0.6438509384548232
# 第88次迭代，局部最优结果为：0.6128219775654341
# 当前最优结果:0.6438509384548232
# 第89次迭代，局部最优结果为：0.5904087656977035
# 当前最优结果:0.6438509384548232
# 第90次迭代，局部最优结果为：0.6438509384548232
# 当前最优结果:0.6438509384548232
# 第91次迭代，局部最优结果为：0.5751852212906999
# 当前最优结果:0.6438509384548232
# 第92次迭代，局部最优结果为：0.5961052737926854
# 当前最优结果:0.6438509384548232
# 第93次迭代，局部最优结果为：0.5853422619047619
# 当前最优结果:0.6438509384548232
# 第94次迭代，局部最优结果为：0.5781158142269254
# 当前最优结果:0.6438509384548232
# 第95次迭代，局部最优结果为：0.6089009287925696
# 当前最优结果:0.6438509384548232
# 第96次迭代，局部最优结果为：0.5879671150971599
# 当前最优结果:0.6438509384548232
# 第97次迭代，局部最优结果为：0.5750730994152047
# 当前最优结果:0.6438509384548232
# 第98次迭代，局部最优结果为：0.5780591750759283
# 当前最优结果:0.6438509384548232
# 第99次迭代，局部最优结果为：0.6438509384548232
# 当前最优结果:0.6438509384548232
# 第100次迭代，局部最优结果为：0.621897233201581
# 当前最优结果:0.6438509384548232
# 第101次迭代，局部最优结果为：0.5838218923933209
# 当前最优结果:0.6438509384548232
# 第102次迭代，局部最优结果为：0.5699898565425301
# 当前最优结果:0.6438509384548232
# 第103次迭代，局部最优结果为：0.6257888317335737
# 当前最优结果:0.6438509384548232
# 第104次迭代，局部最优结果为：0.6048126697760238
# 当前最优结果:0.6438509384548232
# 第105次迭代，局部最优结果为：0.5638618119266054
# 当前最优结果:0.6438509384548232
# 第106次迭代，局部最优结果为：0.5877913927077106
# 当前最优结果:0.6438509384548232
# 第107次迭代，局部最优结果为：0.6410876297060901
# 当前最优结果:0.6438509384548232
# 第108次迭代，局部最优结果为：0.62952787409976
# 当前最优结果:0.6438509384548232
# 第109次迭代，局部最优结果为：0.6410876297060901
# 当前最优结果:0.6438509384548232
# 第110次迭代，局部最优结果为：0.5965120687476305
# 当前最优结果:0.6438509384548232
# 第114次迭代，局部最优结果为：0.6175039246467818
# 当前最优结果:0.6499504296100462
# 第115次迭代，局部最优结果为：0.6903299403299403
# 当前最优结果:0.6903299403299403
# 第116次迭代，局部最优结果为：0.6844043614429881
# 当前最优结果:0.6903299403299403
# 第117次迭代，局部最优结果为：0.6751244350363294
# 当前最优结果:0.6903299403299403
# 第118次迭代，局部最优结果为：0.6217334035827187
# 当前最优结果:0.6903299403299403
# 第119次迭代，局部最优结果为：0.6204911136817751
# 当前最优结果:0.6903299403299403
# 第120次迭代，局部最优结果为：0.6456122114016851
# 当前最优结果:0.6903299403299403
# 第121次迭代，局部最优结果为：0.6903299403299403
# 当前最优结果:0.6903299403299403
# 第122次迭代，局部最优结果为：0.6485394740457806
# 当前最优结果:0.6903299403299403
# 第123次迭代，局部最优结果为：0.6903299403299403
# 当前最优结果:0.6903299403299403
# 第124次迭代，局部最优结果为：0.6903299403299403
# 当前最优结果:0.6903299403299403
# 第125次迭代，局部最优结果为：0.6785796434732605
# 当前最优结果:0.6903299403299403
# 第126次迭代，局部最优结果为：0.6416104828186168
# 当前最优结果:0.6903299403299403
# 第127次迭代，局部最优结果为：0.6903299403299403
# 当前最优结果:0.6903299403299403
# 第128次迭代，局部最优结果为：0.6424488240418118
# 当前最优结果:0.6903299403299403
# 第129次迭代，局部最优结果为：0.6721633629528366
# 当前最优结果:0.6903299403299403
# 第130次迭代，局部最优结果为：0.6700261185555303
# 当前最优结果:0.6903299403299403
# 第131次迭代，局部最优结果为：0.6903299403299403
# 当前最优结果:0.6903299403299403
# 第132次迭代，局部最优结果为：0.6903299403299403
# 当前最优结果:0.6903299403299403
# 第133次迭代，局部最优结果为：0.6977796174200988
# 当前最优结果:0.6977796174200988
# 第134次迭代，局部最优结果为：0.6977796174200988
# 当前最优结果:0.6977796174200988
# 第135次迭代，局部最优结果为：0.6977796174200988
# 当前最优结果:0.6977796174200988
# 第136次迭代，局部最优结果为：0.6607777808886525
# 当前最优结果:0.6977796174200988
# 第137次迭代，局部最优结果为：0.6977796174200988
# 当前最优结果:0.6977796174200988
# 第138次迭代，局部最优结果为：0.6591537494763301
# 当前最优结果:0.6977796174200988
# 第139次迭代，局部最优结果为：0.665229156096736
# 当前最优结果:0.6977796174200988
# 第140次迭代，局部最优结果为：0.6977796174200988
# 当前最优结果:0.6977796174200988
# 第141次迭代，局部最优结果为：0.7016797978296417
# 当前最优结果:0.7016797978296417
# 第142次迭代，局部最优结果为：0.693331374853114
# 当前最优结果:0.7016797978296417
# 第143次迭代，局部最优结果为：0.7016797978296417
# 当前最优结果:0.7016797978296417
# 第144次迭代，局部最优结果为：0.6797523041474655
# 当前最优结果:0.7016797978296417
# 第145次迭代，局部最优结果为：0.6797523041474655
# 当前最优结果:0.7016797978296417
# 第146次迭代，局部最优结果为：0.7017841213202498
# 当前最优结果:0.7017841213202498
# 第147次迭代，局部最优结果为：0.6925176056338028
# 当前最优结果:0.7017841213202498
# 第148次迭代，局部最优结果为：0.6967701936702881
# 当前最优结果:0.7017841213202498
# 第149次迭代，局部最优结果为：0.6967701936702881
# 当前最优结果:0.7017841213202498
# 第150次迭代，局部最优结果为：0.7057715311004785
# 当前最优结果:0.7057715311004785
# 第151次迭代，局部最优结果为：0.6905723314606741
# 当前最优结果:0.7057715311004785
# 第152次迭代，局部最优结果为：0.7062361601532108
# 当前最优结果:0.7062361601532109
# 第153次迭代，局部最优结果为：0.7299353601583521
# 当前最优结果:0.7299353601583521
# 第154次迭代，局部最优结果为：0.7416101055806938
# 当前最优结果:0.7416101055806938
# 第155次迭代，局部最优结果为：0.7368864743349569
# 当前最优结果:0.7416101055806938
# 第156次迭代，局部最优结果为：0.7416101055806938
# 当前最优结果:0.7416101055806938
# 第157次迭代，局部最优结果为：0.7368864743349569
# 当前最优结果:0.7416101055806938
# 第158次迭代，局部最优结果为：0.7404932228915663
# 当前最优结果:0.7416101055806938
# 第159次迭代，局部最优结果为：0.7368864743349569
# 当前最优结果:0.7416101055806938
# 第160次迭代，局部最优结果为：0.721654843444227
# 当前最优结果:0.7416101055806938
# 第161次迭代，局部最优结果为：0.7391481365487003
# 当前最优结果:0.7416101055806938
# 第162次迭代，局部最优结果为：0.7416101055806938
# 当前最优结果:0.7416101055806938
# 第163次迭代，局部最优结果为：0.7416101055806938
# 当前最优结果:0.7416101055806938
# 第164次迭代，局部最优结果为：0.7521991330953596
# 当前最优结果:0.7521991330953595
# 第165次迭代，局部最优结果为：0.73986645349384
# 当前最优结果:0.7521991330953595
# 第166次迭代，局部最优结果为：0.7521991330953596
# 当前最优结果:0.7521991330953595
# 第167次迭代，局部最优结果为：0.7416101055806938
# 当前最优结果:0.7521991330953595
# 第168次迭代，局部最优结果为：0.7416101055806938
# 当前最优结果:0.7521991330953595
# 第169次迭代，局部最优结果为：0.7521991330953596
# 当前最优结果:0.7521991330953595
# 第170次迭代，局部最优结果为：0.7521991330953596
# 当前最优结果:0.7521991330953595
# 第171次迭代，局部最优结果为：0.7718799058084772
# 当前最优结果:0.7718799058084772
# 第172次迭代，局部最优结果为：0.7564423076923077
# 当前最优结果:0.7718799058084772
# 第173次迭代，局部最优结果为：0.7471508167658605
# 当前最优结果:0.7718799058084772
# 第174次迭代，局部最优结果为：0.745169234655216
# 当前最优结果:0.7718799058084772
# 第175次迭代，局部最优结果为：0.7506918158974522
# 当前最优结果:0.7718799058084772
# 第176次迭代，局部最优结果为：0.7703681942812377
# 当前最优结果:0.7718799058084772
# 第177次迭代，局部最优结果为：0.7703681942812377
# 当前最优结果:0.7718799058084772
# 第178次迭代，局部最优结果为：0.7703681942812377
# 当前最优结果:0.7718799058084772
# 第179次迭代，局部最优结果为：0.7593629343629344
# 当前最优结果:0.7718799058084772
# 第180次迭代，局部最优结果为：0.760905309991295
# 当前最优结果:0.7718799058084772
# 第181次迭代，局部最优结果为：0.760905309991295
# 当前最优结果:0.7718799058084772
# 第182次迭代，局部最优结果为：0.760905309991295
# 当前最优结果:0.7718799058084772
# 第183次迭代，局部最优结果为：0.7645286686103012
# 当前最优结果:0.7718799058084772
# 第184次迭代，局部最优结果为：0.7645286686103012
# 当前最优结果:0.7718799058084772
# 第185次迭代，局部最优结果为：0.7645286686103012
# 当前最优结果:0.7718799058084772
# 第186次迭代，局部最优结果为：0.760905309991295
# 当前最优结果:0.7718799058084772
# 第187次迭代，局部最优结果为：0.760905309991295
# 当前最优结果:0.7718799058084772
# 第188次迭代，局部最优结果为：0.7593629343629344
# 当前最优结果:0.7718799058084772
# 第189次迭代，局部最优结果为：0.760905309991295
# 当前最优结果:0.7718799058084772
# 第190次迭代，局部最优结果为：0.7718799058084772
# 当前最优结果:0.7718799058084772
# 第191次迭代，局部最优结果为：0.760905309991295
# 当前最优结果:0.7718799058084772
# 第192次迭代，局部最优结果为：0.7645286686103012
# 当前最优结果:0.7718799058084772
# 第193次迭代，局部最优结果为：0.7669634732874041
# 当前最优结果:0.7718799058084772
# 第194次迭代，局部最优结果为：0.7621092740893826
# 当前最优结果:0.7718799058084772
# 第195次迭代，局部最优结果为：0.7645286686103012
# 当前最优结果:0.7718799058084772
# 第196次迭代，局部最优结果为：0.760905309991295
# 当前最优结果:0.7718799058084772
# 第197次迭代，局部最优结果为：0.7718799058084772
# 当前最优结果:0.7718799058084772
# 第198次迭代，局部最优结果为：0.7739555322358497
# 当前最优结果:0.7739555322358497
# 第199次迭代，局部最优结果为：0.7718799058084772
# 当前最优结果:0.7739555322358497
# 第200次迭代，局部最优结果为：0.7645286686103012
# 当前最优结果:0.7739555322358497
# 第201次迭代，局部最优结果为：0.7771667544783983
# 当前最优结果:0.7771667544783983
# 第202次迭代，局部最优结果为：0.7771667544783983
# 当前最优结果:0.7771667544783983
# 第203次迭代，局部最优结果为：0.7756087942423346
# 当前最优结果:0.7771667544783983
# 第204次迭代，局部最优结果为：0.7771667544783983
# 当前最优结果:0.7771667544783983
# 第205次迭代，局部最优结果为：0.782526525198939
# 当前最优结果:0.782526525198939
# 第206次迭代，局部最优结果为：0.7756087942423346
# 当前最优结果:0.782526525198939
# 第207次迭代，局部最优结果为：0.7771667544783983
# 当前最优结果:0.782526525198939
# 本次退火用时：6490.177808046341
# 第1次迭代，局部最优结果为：0.5436014372581537
# 当前最优结果:0.5436014372581537
# 第2次迭代，局部最优结果为：0.5406129741616272
# 当前最优结果:0.5436014372581537
# 第3次迭代，局部最优结果为：0.561367204224347
# 当前最优结果:0.561367204224347
# 第4次迭代，局部最优结果为：0.5721454545454545
# 当前最优结果:0.5721454545454545
# 第5次迭代，局部最优结果为：0.5236985754227134
# 当前最优结果:0.5721454545454545
# 第6次迭代，局部最优结果为：0.5803905174109778
# 当前最优结果:0.5803905174109778
# 第7次迭代，局部最优结果为：0.5308367071524966
# 当前最优结果:0.5803905174109778
# 第8次迭代，局部最优结果为：0.5890530624469625
# 当前最优结果:0.5890530624469625
# 第9次迭代，局部最优结果为：0.5305383837248511
# 当前最优结果:0.5890530624469625
# 第10次迭代，局部最优结果为：0.6149937460913071
# 当前最优结果:0.6149937460913071
# 第11次迭代，局部最优结果为：0.5593184188074699
# 当前最优结果:0.6149937460913071
# 第12次迭代，局部最优结果为：0.5897890843662535
# 当前最优结果:0.6149937460913071
# 第13次迭代，局部最优结果为：0.6149937460913071
# 当前最优结果:0.6149937460913071
# 第14次迭代，局部最优结果为：0.6149937460913071
# 当前最优结果:0.6149937460913071
# 第15次迭代，局部最优结果为：0.593288084464555
# 当前最优结果:0.6149937460913071
# 第16次迭代，局部最优结果为：0.5520701754385965
# 当前最优结果:0.6149937460913071
# 第17次迭代，局部最优结果为：0.5946633743196936
# 当前最优结果:0.6149937460913071
# 第18次迭代，局部最优结果为：0.5534943714821764
# 当前最优结果:0.6149937460913071
# 第19次迭代，局部最优结果为：0.6149937460913071
# 当前最优结果:0.6149937460913071
# 第20次迭代，局部最优结果为：0.5492692236082666
# 当前最优结果:0.6149937460913071
# 第21次迭代，局部最优结果为：0.5634310542398778
# 当前最优结果:0.6149937460913071
# 第22次迭代，局部最优结果为：0.5336453669787004
# 当前最优结果:0.6149937460913071
# 第23次迭代，局部最优结果为：0.5361061263430479
# 当前最优结果:0.6149937460913071
# 第24次迭代，局部最优结果为：0.6225862614751503
# 当前最优结果:0.6225862614751504
# 第25次迭代，局部最优结果为：0.6114407108992461
# 当前最优结果:0.6225862614751504
# 第26次迭代，局部最优结果为：0.6389701104613386
# 当前最优结果:0.6389701104613386
# 第27次迭代，局部最优结果为：0.6449417937366781
# 当前最优结果:0.6449417937366781
# 第28次迭代，局部最优结果为：0.5545347744360902
# 当前最优结果:0.6449417937366781
# 第29次迭代，局部最优结果为：0.5570740688287779
# 当前最优结果:0.6449417937366781
# 第30次迭代，局部最优结果为：0.5717296511627907
# 当前最优结果:0.6449417937366781
# 第31次迭代，局部最优结果为：0.5643472022955524
# 当前最优结果:0.6449417937366781
# 第32次迭代，局部最优结果为：0.6449417937366781
# 当前最优结果:0.6449417937366781
# 第33次迭代，局部最优结果为：0.565266334546848
# 当前最优结果:0.6449417937366781
# 第34次迭代，局部最优结果为：0.5415433331038755
# 当前最优结果:0.6449417937366781
# 第35次迭代，局部最优结果为：0.5815345949142519
# 当前最优结果:0.6449417937366781
# 第36次迭代，局部最优结果为：0.5983419531487679
# 当前最优结果:0.6449417937366781
# 第37次迭代，局部最优结果为：0.580304893041554
# 当前最优结果:0.6449417937366781
# 第38次迭代，局部最优结果为：0.5463194444444445
# 当前最优结果:0.6449417937366781
# 第39次迭代，局部最优结果为：0.6284048246665069
# 当前最优结果:0.6449417937366781
# 第40次迭代，局部最优结果为：0.6449417937366781
# 当前最优结果:0.6449417937366781
# 第41次迭代，局部最优结果为：0.6551465689540307
# 当前最优结果:0.6551465689540307
# 第42次迭代，局部最优结果为：0.5910889601282309
# 当前最优结果:0.6551465689540307
# 第43次迭代，局部最优结果为：0.5544305581657584
# 当前最优结果:0.6551465689540307
# 第44次迭代，局部最优结果为：0.5744012850467289
# 当前最优结果:0.6551465689540307
# 第45次迭代，局部最优结果为：0.5451584588376606
# 当前最优结果:0.6551465689540307
# 第46次迭代，局部最优结果为：0.5671272377748408
# 当前最优结果:0.6551465689540307
# 第47次迭代，局部最优结果为：0.5179065174456879
# 当前最优结果:0.6551465689540307
# 第48次迭代，局部最优结果为：0.6001525746980292
# 当前最优结果:0.6551465689540307
# 第49次迭代，局部最优结果为：0.5820796132787451
# 当前最优结果:0.6551465689540307
# 第50次迭代，局部最优结果为：0.5756341463414634
# 当前最优结果:0.6551465689540307
# 第51次迭代，局部最优结果为：0.5615542019605977
# 当前最优结果:0.6551465689540307
# 第52次迭代，局部最优结果为：0.6551465689540307
# 当前最优结果:0.6551465689540307
# 第53次迭代，局部最优结果为：0.6089009287925696
# 当前最优结果:0.6551465689540307
# 第54次迭代，局部最优结果为：0.5750590872542092
# 当前最优结果:0.6551465689540307
# 第55次迭代，局部最优结果为：0.597493670886076
# 当前最优结果:0.6551465689540307
# 第56次迭代，局部最优结果为：0.6551465689540307
# 当前最优结果:0.6551465689540307
# 第57次迭代，局部最优结果为：0.6551465689540307
# 当前最优结果:0.6551465689540307
# 第58次迭代，局部最优结果为：0.6276194021912562
# 当前最优结果:0.6551465689540307
# 第59次迭代，局部最优结果为：0.6530798605346173
# 当前最优结果:0.6551465689540307
# 第60次迭代，局部最优结果为：0.6303685897435898
# 当前最优结果:0.6551465689540307
# 第61次迭代，局部最优结果为：0.5603276353276353
# 当前最优结果:0.6551465689540307
# 第62次迭代，局部最优结果为：0.5653611210923464
# 当前最优结果:0.6551465689540307
# 第63次迭代，局部最优结果为：0.6165360501567398
# 当前最优结果:0.6551465689540307
# 第64次迭代，局部最优结果为：0.6292593185090386
# 当前最优结果:0.6551465689540307
# 第65次迭代，局部最优结果为：0.5937956020731646
# 当前最优结果:0.6551465689540307
# 第66次迭代，局部最优结果为：0.5983419531487679
# 当前最优结果:0.6551465689540307
# 第67次迭代，局部最优结果为：0.5296929706436844
# 当前最优结果:0.6551465689540307
# 第68次迭代，局部最优结果为：0.6551465689540307
# 当前最优结果:0.6551465689540307
# 第69次迭代，局部最优结果为：0.6254571474002226
# 当前最优结果:0.6551465689540307
# 第70次迭代，局部最优结果为：0.5212695467797509
# 当前最优结果:0.6551465689540307
# 第71次迭代，局部最优结果为：0.5711485407289095
# 当前最优结果:0.6551465689540307
# 第72次迭代，局部最优结果为：0.5472061210294459
# 当前最优结果:0.6551465689540307
# 第73次迭代，局部最优结果为：0.6494496422674739
# 当前最优结果:0.6551465689540307
# 第74次迭代，局部最优结果为：0.6409483460974418
# 当前最优结果:0.6551465689540307
# 第75次迭代，局部最优结果为：0.5638079311992356
# 当前最优结果:0.6551465689540307
# 第76次迭代，局部最优结果为：0.6551465689540307
# 当前最优结果:0.6551465689540307
# 第77次迭代，局部最优结果为：0.5633369137128535
# 当前最优结果:0.6551465689540307
# 第78次迭代，局部最优结果为：0.5615542019605977
# 当前最优结果:0.6551465689540307
# 第79次迭代，局部最优结果为：0.6551465689540307
# 当前最优结果:0.6551465689540307
# 第80次迭代，局部最优结果为：0.5633369137128535
# 当前最优结果:0.6551465689540307
# 第81次迭代，局部最优结果为：0.602004897459443
# 当前最优结果:0.6551465689540307
# 第82次迭代，局部最优结果为：0.6172455277748718
# 当前最优结果:0.6551465689540307
# 第83次迭代，局部最优结果为：0.5635925112236126
# 当前最优结果:0.6551465689540307
# 第84次迭代，局部最优结果为：0.5983419531487679
# 当前最优结果:0.6551465689540307
# 第85次迭代，局部最优结果为：0.6551465689540307
# 当前最优结果:0.6551465689540307
# 第86次迭代，局部最优结果为：0.6281873835507054
# 当前最优结果:0.6551465689540307
# 第87次迭代，局部最优结果为：0.6551465689540307
# 当前最优结果:0.6551465689540307
# 第88次迭代，局部最优结果为：0.6551465689540307
# 当前最优结果:0.6551465689540307
# 第89次迭代，局部最优结果为：0.5941842900302114
# 当前最优结果:0.6551465689540307
# 第90次迭代，局部最优结果为：0.599177435324583
# 当前最优结果:0.6551465689540307
# 第91次迭代，局部最优结果为：0.5687536148062464
# 当前最优结果:0.6551465689540307
# 第92次迭代，局部最优结果为：0.6551465689540307
# 当前最优结果:0.6551465689540307
# 第93次迭代，局部最优结果为：0.6349475383373688
# 当前最优结果:0.6551465689540307
# 第94次迭代，局部最优结果为：0.6329382106844025
# 当前最优结果:0.6551465689540307
# 第95次迭代，局部最优结果为：0.6165360501567398
# 当前最优结果:0.6551465689540307
# 第96次迭代，局部最优结果为：0.6551465689540307
# 当前最优结果:0.6551465689540307
# 第97次迭代，局部最优结果为：0.6106970967241112
# 当前最优结果:0.6551465689540307
# 第98次迭代，局部最优结果为：0.6551465689540307
# 当前最优结果:0.6551465689540307
# 第99次迭代，局部最优结果为：0.6614259290398521
# 当前最优结果:0.661425929039852
# 第100次迭代，局部最优结果为：0.6256892895015908
# 当前最优结果:0.661425929039852
# 第101次迭代，局部最优结果为：0.5877913927077106
# 当前最优结果:0.661425929039852
# 第102次迭代，局部最优结果为：0.5772250348521535
# 当前最优结果:0.661425929039852
# 第103次迭代，局部最优结果为：0.6389701104613386
# 当前最优结果:0.661425929039852
# 第104次迭代，局部最优结果为：0.6283546325878594
# 当前最优结果:0.661425929039852
# 第105次迭代，局部最优结果为：0.5754516860507644
# 当前最优结果:0.661425929039852
# 第106次迭代，局部最优结果为：0.6614259290398521
# 当前最优结果:0.661425929039852
# 第107次迭代，局部最优结果为：0.645470955037742
# 当前最优结果:0.661425929039852
# 第108次迭代，局部最优结果为：0.6153785982478098
# 当前最优结果:0.661425929039852
# 第109次迭代，局部最优结果为：0.6635458839406208
# 当前最优结果:0.6635458839406208
# 第110次迭代，局部最优结果为：0.6635458839406208
# 当前最优结果:0.6635458839406208
# 第111次迭代，局部最优结果为：0.6635458839406208
# 当前最优结果:0.6635458839406208
# 第112次迭代，局部最优结果为：0.6089009287925696
# 当前最优结果:0.6635458839406208
# 第113次迭代，局部最优结果为：0.6292593185090386
# 当前最优结果:0.6635458839406208
# 第114次迭代，局部最优结果为：0.6143214118382009
# 当前最优结果:0.6635458839406208
# 第115次迭代，局部最优结果为：0.6089009287925696
# 当前最优结果:0.6635458839406208
# 第116次迭代，局部最优结果为：0.6635458839406208
# 当前最优结果:0.6635458839406208
# 第117次迭代，局部最优结果为：0.602004897459443
# 当前最优结果:0.6635458839406208
# 第118次迭代，局部最优结果为：0.6311777920410784
# 当前最优结果:0.6635458839406208
# 第119次迭代，局部最优结果为：0.6410528031290743
# 当前最优结果:0.6635458839406208
# 第120次迭代，局部最优结果为：0.6611665172568355
# 当前最优结果:0.6635458839406208
# 第121次迭代，局部最优结果为：0.6635458839406208
# 当前最优结果:0.6635458839406208
# 第122次迭代，局部最优结果为：0.6635458839406208
# 当前最优结果:0.6635458839406208
# 第123次迭代，局部最优结果为：0.6635458839406208
# 当前最优结果:0.6635458839406208
# 第124次迭代，局部最优结果为：0.6449417937366781
# 当前最优结果:0.6635458839406208
# 第125次迭代，局部最优结果为：0.6479696894819207
# 当前最优结果:0.6635458839406208
# 第126次迭代，局部最优结果为：0.6563125695216908
# 当前最优结果:0.6635458839406208
# 第127次迭代，局部最优结果为：0.6440969379400687
# 当前最优结果:0.6635458839406208
# 第128次迭代，局部最优结果为：0.6753949175824175
# 当前最优结果:0.6753949175824175
# 第129次迭代，局部最优结果为：0.6753949175824175
# 当前最优结果:0.6753949175824175
# 第130次迭代，局部最优结果为：0.6689246641346862
# 当前最优结果:0.6753949175824175
# 第131次迭代，局部最优结果为：0.6527186238176891
# 当前最优结果:0.6753949175824175
# 第132次迭代，局部最优结果为：0.6703306066803
# 当前最优结果:0.6753949175824175
# 第133次迭代，局部最优结果为：0.6710930391264786
# 当前最优结果:0.6753949175824175
# 第134次迭代，局部最优结果为：0.6753949175824175
# 当前最优结果:0.6753949175824175
# 第135次迭代，局部最优结果为：0.6753949175824175
# 当前最优结果:0.6753949175824175
# 第136次迭代，局部最优结果为：0.6585467939059099
# 当前最优结果:0.6753949175824175
# 第137次迭代，局部最优结果为：0.6572447018853212
# 当前最优结果:0.6753949175824175
# 第138次迭代，局部最优结果为：0.6753949175824175
# 当前最优结果:0.6753949175824175
# 第139次迭代，局部最优结果为：0.6852190575733821
# 当前最优结果:0.6852190575733821
# 第140次迭代，局部最优结果为：0.699620560858481
# 当前最优结果:0.699620560858481
# 第141次迭代，局部最优结果为：0.686035695599093
# 当前最优结果:0.699620560858481
# 第142次迭代，局部最优结果为：0.6852190575733821
# 当前最优结果:0.699620560858481
# 第143次迭代，局部最优结果为：0.6962768468255841
# 当前最优结果:0.699620560858481
# 第144次迭代，局部最优结果为：0.6971818504076569
# 当前最优结果:0.699620560858481
# 第145次迭代，局部最优结果为：0.7010336838353235
# 当前最优结果:0.7010336838353235
# 第146次迭代，局部最优结果为：0.6935758786881392
# 当前最优结果:0.7010336838353235
# 第147次迭代，局部最优结果为：0.6971818504076569
# 当前最优结果:0.7010336838353235
# 第148次迭代，局部最优结果为：0.6852190575733821
# 当前最优结果:0.7010336838353235
# 第149次迭代，局部最优结果为：0.6896037868162692
# 当前最优结果:0.7010336838353235
# 第150次迭代，局部最优结果为：0.6896037868162692
# 当前最优结果:0.7010336838353235
# 第151次迭代，局部最优结果为：0.6814795564795565
# 当前最优结果:0.7010336838353235
# 第152次迭代，局部最优结果为：0.6798893786189613
# 当前最优结果:0.7010336838353235
# 第153次迭代，局部最优结果为：0.6992888888888888
# 当前最优结果:0.7010336838353235
# 第154次迭代，局部最优结果为：0.7204872241047715
# 当前最优结果:0.7204872241047715
# 第155次迭代，局部最优结果为：0.7125260393080337
# 当前最优结果:0.7204872241047715
# 第156次迭代，局部最优结果为：0.7324953445065177
# 当前最优结果:0.7324953445065177
# 第157次迭代，局部最优结果为：0.7045074626865672
# 当前最优结果:0.7324953445065177
# 第158次迭代，局部最优结果为：0.7449105198371366
# 当前最优结果:0.7449105198371366
# 第159次迭代，局部最优结果为：0.7324953445065177
# 当前最优结果:0.7449105198371366
# 第160次迭代，局部最优结果为：0.7324953445065177
# 当前最优结果:0.7449105198371366
# 第161次迭代，局部最优结果为：0.7490954103980194
# 当前最优结果:0.7490954103980194
# 第162次迭代，局部最优结果为：0.7533275878578952
# 当前最优结果:0.7533275878578952
# 第163次迭代，局部最优结果为：0.7449105198371366
# 当前最优结果:0.7533275878578952
# 第164次迭代，局部最优结果为：0.7537365866121615
# 当前最优结果:0.7537365866121615
# 第165次迭代，局部最优结果为：0.7537365866121615
# 当前最优结果:0.7537365866121615
# 第166次迭代，局部最优结果为：0.7384543178973717
# 当前最优结果:0.7537365866121615
# 第167次迭代，局部最优结果为：0.7292361883574341
# 当前最优结果:0.7537365866121615
# 第168次迭代，局部最优结果为：0.753544061302682
# 当前最优结果:0.7537365866121615
# 第169次迭代，局部最优结果为：0.753544061302682
# 当前最优结果:0.7537365866121615
# 第170次迭代，局部最优结果为：0.7366104868913859
# 当前最优结果:0.7537365866121615
# 第171次迭代，局部最优结果为：0.7341358715938783
# 当前最优结果:0.7537365866121615
# 第172次迭代，局部最优结果为：0.7449105198371366
# 当前最优结果:0.7537365866121615
# 第173次迭代，局部最优结果为：0.7449105198371366
# 当前最优结果:0.7537365866121615
# 第174次迭代，局部最优结果为：0.7537365866121615
# 当前最优结果:0.7537365866121615
# 第175次迭代，局部最优结果为：0.7537365866121615
# 当前最优结果:0.7537365866121615
# 第176次迭代，局部最优结果为：0.7537365866121615
# 当前最优结果:0.7537365866121615
# 第177次迭代，局部最优结果为：0.7473164244324119
# 当前最优结果:0.7537365866121615
# 第178次迭代，局部最优结果为：0.7537365866121615
# 当前最优结果:0.7537365866121615
# 第179次迭代，局部最优结果为：0.7537365866121615
# ...
# 第148次迭代，局部最优结果为：0.7438071225969114
# 当前最优结果:0.7438071225969114
# 第149次迭代，局部最优结果为：0.7410047095761382
# 当前最优结果:0.7438071225969114
# 第150次迭代，局部最优结果为：0.7387316889946163
# 当前最优结果:0.7438071225969114
# 第151次迭代，局部最优结果为：0.7357149537080332
# 当前最优结果:0.7438071225969114
# 第152次迭代，局部最优结果为：0.7167020953537807
# 当前最优结果:0.7438071225969114
# 第153次迭代，局部最优结果为：0.7167020953537807
# 当前最优结果:0.7438071225969114
# 第154次迭代，局部最优结果为：0.7167020953537807
# 当前最优结果:0.7438071225969114
# 第155次迭代，局部最优结果为：0.7411210551106925
# 当前最优结果:0.7438071225969114
# 第156次迭代，局部最优结果为：0.7438071225969114
# 当前最优结果:0.7438071225969114
# 第157次迭代，局部最优结果为：0.7438071225969114
# 当前最优结果:0.7438071225969114
# 第158次迭代，局部最优结果为：0.7438071225969114
# 当前最优结果:0.7438071225969114
# 第159次迭代，局部最优结果为：0.7454752203164977
# 当前最优结果:0.7454752203164977
# 第160次迭代，局部最优结果为：0.7454752203164977
# 当前最优结果:0.7454752203164977
# 第161次迭代，局部最优结果为：0.7528229665071771
# 当前最优结果:0.7528229665071771
# 第162次迭代，局部最优结果为：0.7528229665071771
# 当前最优结果:0.7528229665071771
# 第163次迭代，局部最优结果为：0.7456400859345381
# 当前最优结果:0.7528229665071771
# 第164次迭代，局部最优结果为：0.7411210551106925
# 当前最优结果:0.7528229665071771
# 第165次迭代，局部最优结果为：0.7463946869070209
# 当前最优结果:0.7528229665071771
# 第166次迭代，局部最优结果为：0.7350046714419184
# 当前最优结果:0.7528229665071771
# 第167次迭代，局部最优结果为：0.7574133504492939
# 当前最优结果:0.7574133504492939
# 第168次迭代，局部最优结果为：0.7384543178973717
# 当前最优结果:0.7574133504492939
# 第169次迭代，局部最优结果为：0.7411210551106925
# 当前最优结果:0.7574133504492939
# 第170次迭代，局部最优结果为：0.7411210551106925
# 当前最优结果:0.7574133504492939
# 第171次迭代，局部最优结果为：0.7411210551106925
# 当前最优结果:0.7574133504492939
# 第172次迭代，局部最优结果为：0.7438071225969114
# 当前最优结果:0.7574133504492939
# 第173次迭代，局部最优结果为：0.7614208284939993
# 当前最优结果:0.7614208284939993
# 第174次迭代，局部最优结果为：0.7690127077223851
# 当前最优结果:0.7690127077223852
# 第175次迭代，局部最优结果为：0.7690127077223851
# 当前最优结果:0.7690127077223852
# 第176次迭代，局部最优结果为：0.7608317214700193
# 当前最优结果:0.7690127077223852
# 第177次迭代，局部最优结果为：0.7737018095987411
# 当前最优结果:0.7737018095987411
# 第178次迭代，局部最优结果为：0.7690127077223851
# 当前最优结果:0.7737018095987411
# 第179次迭代，局部最优结果为：0.7690127077223851
# 当前最优结果:0.7737018095987411
# 第180次迭代，局部最优结果为：0.7660921219203428
# 当前最优结果:0.7737018095987411
# 第181次迭代，局部最优结果为：0.7614208284939993
# 当前最优结果:0.7737018095987411
# 第182次迭代，局部最优结果为：0.7737018095987411
# 当前最优结果:0.7737018095987411
# 第183次迭代，局部最优结果为：0.7586306653809064
# 当前最优结果:0.7737018095987411
# 第184次迭代，局部最优结果为：0.7701670800156637
# 当前最优结果:0.7737018095987411
# 第185次迭代，局部最优结果为：0.7660921219203428
# 当前最优结果:0.7737018095987411
# 第186次迭代，局部最优结果为：0.7608317214700193
# 当前最优结果:0.7737018095987411
# 第187次迭代，局部最优结果为：0.7574133504492939
# 当前最优结果:0.7737018095987411
# 第188次迭代，局部最优结果为：0.7643801010493587
# 当前最优结果:0.7737018095987411
# 第189次迭代，局部最优结果为：0.7614208284939993
# 当前最优结果:0.7737018095987411
# 第190次迭代，局部最优结果为：0.7690127077223851
# 当前最优结果:0.7737018095987411
# 第191次迭代，局部最优结果为：0.7690127077223851
# 当前最优结果:0.7737018095987411
# 第192次迭代，局部最优结果为：0.762060058120762
# 当前最优结果:0.7737018095987411
# 第193次迭代，局部最优结果为：0.7777558082056352
# 当前最优结果:0.7777558082056352
# 第194次迭代，局部最优结果为：0.7660921219203428
# 当前最优结果:0.7777558082056352
# 第195次迭代，局部最优结果为：0.7660921219203428
# 当前最优结果:0.7777558082056352
# 第196次迭代，局部最优结果为：0.7777558082056352
# 当前最优结果:0.7777558082056352
# 第197次迭代，局部最优结果为：0.7777558082056352
# 当前最优结果:0.7777558082056352
# 第198次迭代，局部最优结果为：0.7777558082056352
# 当前最优结果:0.7777558082056352
# 第199次迭代，局部最优结果为：0.7660921219203428
# 当前最优结果:0.7777558082056352
# 第200次迭代，局部最优结果为：0.7715266426936908
# 当前最优结果:0.7777558082056352
# 第204次迭代，局部最优结果为：0.779734372935113
# 当前最优结果:0.7797343729351129
# 第205次迭代，局部最优结果为：0.779734372935113
# 当前最优结果:0.7797343729351129
# 第206次迭代，局部最优结果为：0.7777558082056352
# 当前最优结果:0.7797343729351129
# 第207次迭代，局部最优结果为：0.779734372935113
# 当前最优结果:0.7797343729351129
# 本次退火用时：6517.968686580658
# 第1次迭代，局部最优结果为：0.5609402481342397
# 当前最优结果:0.5609402481342397
# 第2次迭代，局部最优结果为：0.6078971770039151
# 当前最优结果:0.6078971770039151
# 第3次迭代，局部最优结果为：0.6078971770039151
# 当前最优结果:0.6078971770039151
# 第4次迭代，局部最优结果为：0.5309561304836895
# 当前最优结果:0.6078971770039151
# 第5次迭代，局部最优结果为：0.5856908874329958
# 当前最优结果:0.6078971770039151
# 第6次迭代，局部最优结果为：0.5390817724988579
# 当前最优结果:0.6078971770039151
# 第7次迭代，局部最优结果为：0.6078971770039151
# 当前最优结果:0.6078971770039151
# 第8次迭代，局部最优结果为：0.53483049311095
# 当前最优结果:0.6078971770039151
# 第9次迭代，局部最优结果为：0.5706789824934714
# 当前最优结果:0.6078971770039151
# 第10次迭代，局部最优结果为：0.5610469262587362
# 当前最优结果:0.6078971770039151
# 第11次迭代，局部最优结果为：0.5601148661477122
# 当前最优结果:0.6078971770039151
# 第12次迭代，局部最优结果为：0.5575478384124735
# 当前最优结果:0.6078971770039151
# 第13次迭代，局部最优结果为：0.5949631945144701
# 当前最优结果:0.6078971770039151
# 第14次迭代，局部最优结果为：0.6078971770039151
# 当前最优结果:0.6078971770039151
# 第15次迭代，局部最优结果为：0.5356072984749455
# 当前最优结果:0.6078971770039151
# 第16次迭代，局部最优结果为：0.6078971770039151
# 当前最优结果:0.6078971770039151
# 第17次迭代，局部最优结果为：0.5396487858416792
# 当前最优结果:0.6078971770039151
# 第18次迭代，局部最优结果为：0.5592654028436018
# 当前最优结果:0.6078971770039151
# 第19次迭代，局部最优结果为：0.6078971770039151
# 当前最优结果:0.6078971770039151
# 第20次迭代，局部最优结果为：0.6078971770039151
# 当前最优结果:0.6078971770039151
# 第21次迭代，局部最优结果为：0.6078971770039151
# 当前最优结果:0.6078971770039151
# 第22次迭代，局部最优结果为：0.5289095065214469
# 当前最优结果:0.6078971770039151
# 第23次迭代，局部最优结果为：0.6078971770039151
# 当前最优结果:0.6078971770039151
# 第24次迭代，局部最优结果为：0.6057129658145981
# 当前最优结果:0.6078971770039151
# 第25次迭代，局部最优结果为：0.5795496402524372
# 当前最优结果:0.6078971770039151
# 第26次迭代，局部最优结果为：0.5726174301242236
# 当前最优结果:0.6078971770039151
# 第27次迭代，局部最优结果为：0.5830286561264821
# 当前最优结果:0.6078971770039151
# 第28次迭代，局部最优结果为：0.6078971770039151
# 当前最优结果:0.6078971770039151
# 第29次迭代，局部最优结果为：0.5448564041001016
# 当前最优结果:0.6078971770039151
# 第30次迭代，局部最优结果为：0.5777761457109283
# 当前最优结果:0.6078971770039151
# 第31次迭代，局部最优结果为：0.6078971770039151
# 当前最优结果:0.6078971770039151
# 第32次迭代，局部最优结果为：0.5537281216273287
# 当前最优结果:0.6078971770039151
# 第33次迭代，局部最优结果为：0.5273966480446928
# 当前最优结果:0.6078971770039151
# 第34次迭代，局部最优结果为：0.6078971770039151
# 当前最优结果:0.6078971770039151
# 第35次迭代，局部最优结果为：0.5552653867871259
# 当前最优结果:0.6078971770039151
# 第36次迭代，局部最优结果为：0.5372410653312087
# 当前最优结果:0.6078971770039151
# 第37次迭代，局部最优结果为：0.5680417829979783
# 当前最优结果:0.6078971770039151
# 第38次迭代，局部最优结果为：0.5994361475160012
# 当前最优结果:0.6078971770039151
# 第39次迭代，局部最优结果为：0.6078971770039151
# 当前最优结果:0.6078971770039151
# 第40次迭代，局部最优结果为：0.5460034702139965
# 当前最优结果:0.6078971770039151
# 第41次迭代，局部最优结果为：0.5907486671172186
# 当前最优结果:0.6078971770039151
# 第42次迭代，局部最优结果为：0.5677821348666009
# 当前最优结果:0.6078971770039151
# 第43次迭代，局部最优结果为：0.6078971770039151
# 当前最优结果:0.6078971770039151
# 第44次迭代，局部最优结果为：0.6078971770039151
# 当前最优结果:0.6078971770039151
# 第45次迭代，局部最优结果为：0.5777478580171359
# 当前最优结果:0.6078971770039151
# 第46次迭代，局部最优结果为：0.5825681279620853
# 当前最优结果:0.6078971770039151
# 第47次迭代，局部最优结果为：0.5198229152900753
# 当前最优结果:0.6078971770039151
# 第48次迭代，局部最优结果为：0.5732293791897406
# 当前最优结果:0.6078971770039151
# 第49次迭代，局部最优结果为：0.5726174301242236
# 当前最优结果:0.6078971770039151
# 第50次迭代，局部最优结果为：0.6078971770039151
# 当前最优结果:0.6078971770039151
# 第51次迭代，局部最优结果为：0.5482994145525509
# 当前最优结果:0.6078971770039151
# 第52次迭代，局部最优结果为：0.6083359109186514
# 当前最优结果:0.6083359109186514
# 第53次迭代，局部最优结果为：0.528554152109648
# 当前最优结果:0.6083359109186514
# 第54次迭代，局部最优结果为：0.5385405257393209
# 当前最优结果:0.6083359109186514
# 第55次迭代，局部最优结果为：0.5479938701588186
# 当前最优结果:0.6083359109186514
# 第56次迭代，局部最优结果为：0.551141936387838
# 当前最优结果:0.6083359109186514
# 第57次迭代，局部最优结果为：0.5943189544458714
# 当前最优结果:0.6083359109186514
# 第58次迭代，局部最优结果为：0.5905712784325501
# 当前最优结果:0.6083359109186514
# 第59次迭代，局部最优结果为：0.5629472378589829
# 当前最优结果:0.6083359109186514
# 第60次迭代，局部最优结果为：0.5607270135424092
# 当前最优结果:0.6083359109186514
# 第61次迭代，局部最优结果为：0.5567980748814495
# 当前最优结果:0.6083359109186514
# 第62次迭代，局部最优结果为：0.6230300150471213
# 当前最优结果:0.6230300150471213
# 第63次迭代，局部最优结果为：0.544165456180397
# 当前最优结果:0.6230300150471213
# 第64次迭代，局部最优结果为：0.53626448534424
# 当前最优结果:0.6230300150471213
# 第65次迭代，局部最优结果为：0.5619285714285714
# 当前最优结果:0.6230300150471213
# 第66次迭代，局部最优结果为：0.6141295862607338
# 当前最优结果:0.6230300150471213
# 第67次迭代，局部最优结果为：0.5915037593984962
# 当前最优结果:0.6230300150471213
# 第68次迭代，局部最优结果为：0.6230300150471213
# 当前最优结果:0.6230300150471213
# 第69次迭代，局部最优结果为：0.5736752552260573
# 当前最优结果:0.6230300150471213
# 第70次迭代，局部最优结果为：0.6141295862607338
# 当前最优结果:0.6230300150471213
# 第71次迭代，局部最优结果为：0.6054798737781882
# 当前最优结果:0.6230300150471213
# 第72次迭代，局部最优结果为：0.6403744403744404
# 当前最优结果:0.6403744403744404
# 第73次迭代，局部最优结果为：0.5642122878316997
# 当前最优结果:0.6403744403744404
# 第74次迭代，局部最优结果为：0.6243650793650793
# 当前最优结果:0.6403744403744404
# 第75次迭代，局部最优结果为：0.6403744403744404
# 当前最优结果:0.6403744403744404
# 第76次迭代，局部最优结果为：0.6214714556562039
# 当前最优结果:0.6403744403744404
# 第77次迭代，局部最优结果为：0.5645091848450058
# 当前最优结果:0.6403744403744404
# 第78次迭代，局部最优结果为：0.5306934700485699
# 当前最优结果:0.6403744403744404
# 第79次迭代，局部最优结果为：0.6467799397095094
# 当前最优结果:0.6467799397095094
# 第80次迭代，局部最优结果为：0.6467799397095094
# 当前最优结果:0.6467799397095094
# 第81次迭代，局部最优结果为：0.5996189024390244
# 当前最优结果:0.6467799397095094
# 第82次迭代，局部最优结果为：0.6467799397095094
# 当前最优结果:0.6467799397095094
# 第83次迭代，局部最优结果为：0.6123767514270888
# 当前最优结果:0.6467799397095094
# 第84次迭代，局部最优结果为：0.6156514934133298
# 当前最优结果:0.6467799397095094
# 第85次迭代，局部最优结果为：0.563390704447256
# 当前最优结果:0.6467799397095094
# 第86次迭代，局部最优结果为：0.6360598302115618
# 当前最优结果:0.6467799397095094
# 第87次迭代，局部最优结果为：0.629108356657337
# 当前最优结果:0.6467799397095094
# 第88次迭代，局部最优结果为：0.6467799397095094
# 当前最优结果:0.6467799397095094
# 第89次迭代，局部最优结果为：0.6189614476789929
# 当前最优结果:0.6467799397095094
# 第90次迭代，局部最优结果为：0.6082104937635295
# 当前最优结果:0.6467799397095094
# 第91次迭代，局部最优结果为：0.5727702948671277
# 当前最优结果:0.6467799397095094
# 第92次迭代，局部最优结果为：0.6467799397095094
# 当前最优结果:0.6467799397095094
# 第93次迭代，局部最优结果为：0.6467799397095094
# 当前最优结果:0.6467799397095094
# 第94次迭代，局部最优结果为：0.6467799397095094
# 当前最优结果:0.6467799397095094
# 第95次迭代，局部最优结果为：0.6059306803594352
# 当前最优结果:0.6467799397095094
# 第96次迭代，局部最优结果为：0.6156514934133298
# 当前最优结果:0.6467799397095094
# 第97次迭代，局部最优结果为：0.6467799397095094
# 当前最优结果:0.6467799397095094
# 第98次迭代，局部最优结果为：0.5727702948671277
# 当前最优结果:0.6467799397095094
# 第99次迭代，局部最优结果为：0.6467799397095094
# 当前最优结果:0.6467799397095094
# 第100次迭代，局部最优结果为：0.5876743027888447
# 当前最优结果:0.6467799397095094
# 第101次迭代，局部最优结果为：0.6200998423541777
# 当前最优结果:0.6467799397095094
# 第102次迭代，局部最优结果为：0.629108356657337
# 当前最优结果:0.6467799397095094
# 第103次迭代，局部最优结果为：0.5873964011050549
# 当前最优结果:0.6467799397095094
# 第104次迭代，局部最优结果为：0.6294942921156513
# 当前最优结果:0.6467799397095094
# 第105次迭代，局部最优结果为：0.6263202590096068
# 当前最优结果:0.6467799397095094
# 第106次迭代，局部最优结果为：0.6467799397095094
# 当前最优结果:0.6467799397095094
# 第107次迭代，局部最优结果为：0.5959848484848485
# 当前最优结果:0.6467799397095094
# 第108次迭代，局部最优结果为：0.6565316568376544
# 当前最优结果:0.6565316568376544
# 第109次迭代，局部最优结果为：0.6044718778813646
# 当前最优结果:0.6565316568376544
# 第110次迭代，局部最优结果为：0.650380291005291
# 当前最优结果:0.6565316568376544
# 第111次迭代，局部最优结果为：0.6184748427672956
# 当前最优结果:0.6565316568376544
# 第112次迭代，局部最优结果为：0.6565316568376544
# 当前最优结果:0.6565316568376544
# 第113次迭代，局部最优结果为：0.6353577774188338
# 当前最优结果:0.6565316568376544
# 第114次迭代，局部最优结果为：0.6353577774188338
# 当前最优结果:0.6565316568376544
# 第115次迭代，局部最优结果为：0.6237874983480904
# 当前最优结果:0.6565316568376544
# 第116次迭代，局部最优结果为：0.626087648556876
# 当前最优结果:0.6565316568376544
# 第117次迭代，局部最优结果为：0.6693420306296086
# 当前最优结果:0.6693420306296086
# 第118次迭代，局部最优结果为：0.6003510378510378
# 当前最优结果:0.6693420306296086
# 第119次迭代，局部最优结果为：0.627686170212766
# 当前最优结果:0.6693420306296086
# 第120次迭代，局部最优结果为：0.6563125695216908
# 当前最优结果:0.6693420306296086
# 第121次迭代，局部最优结果为：0.6338221076377699
# 当前最优结果:0.6693420306296086
# 第122次迭代，局部最优结果为：0.64738314680711
# 当前最优结果:0.6693420306296086
# 第123次迭代，局部最优结果为：0.6438509384548232
# 当前最优结果:0.6693420306296086
# 第124次迭代，局部最优结果为：0.6534053156146179
# 当前最优结果:0.6693420306296086
# 第125次迭代，局部最优结果为：0.6339242546333602
# 当前最优结果:0.6693420306296086
# 第126次迭代，局部最优结果为：0.6219955724225174
# 当前最优结果:0.6693420306296086
# 第127次迭代，局部最优结果为：0.6811255411255411
# 当前最优结果:0.6811255411255411
# 第128次迭代，局部最优结果为：0.6798893786189613
# 当前最优结果:0.6811255411255411
# 第129次迭代，局部最优结果为：0.657959297463061
# 当前最优结果:0.6811255411255411
# 第130次迭代，局部最优结果为：0.6786576949620428
# 当前最优结果:0.6811255411255411
# 第131次迭代，局部最优结果为：0.6618896710323359
# 当前最优结果:0.6811255411255411
# 第132次迭代，局部最优结果为：0.6880758017492712
# 当前最优结果:0.6880758017492712
# 第133次迭代，局部最优结果为：0.697635234998522
# 当前最优结果:0.697635234998522
# 第134次迭代，局部最优结果为：0.6626516172506738
# 当前最优结果:0.697635234998522
# 第135次迭代，局部最优结果为：0.6916043956043956
# 当前最优结果:0.697635234998522
# 第136次迭代，局部最优结果为：0.6732563115104836
# 当前最优结果:0.697635234998522
# 第137次迭代，局部最优结果为：0.6546740638002775
# 当前最优结果:0.697635234998522
# 第138次迭代，局部最优结果为：0.6480764478128347
# 当前最优结果:0.697635234998522
# 第139次迭代，局部最优结果为：0.6765953787053495
# 当前最优结果:0.697635234998522
# 第140次迭代，局部最优结果为：0.7010336838353235
# 当前最优结果:0.7010336838353235
# 第141次迭代，局部最优结果为：0.6972848406062575
# 当前最优结果:0.7010336838353235
# 第142次迭代，局部最优结果为：0.7138838475499093
# 当前最优结果:0.7138838475499093
# 第143次迭代，局部最优结果为：0.6882162540460153
# 当前最优结果:0.7138838475499093
# 第144次迭代，局部最优结果为：0.6837896566710125
# 当前最优结果:0.7138838475499093
# 第145次迭代，局部最优结果为：0.7209494134897361
# 当前最优结果:0.7209494134897361
# 第146次迭代，局部最优结果为：0.7270570838852777
# 当前最优结果:0.7270570838852777
# 第147次迭代，局部最优结果为：0.7367944555444554
# 当前最优结果:0.7367944555444556
# 第148次迭代，局部最优结果为：0.7209494134897361
# 当前最优结果:0.7367944555444556
# 第149次迭代，局部最优结果为：0.715268517396048
# 当前最优结果:0.7367944555444556
# 第150次迭代，局部最优结果为：0.7167456268221574
# 当前最优结果:0.7367944555444556
# 第151次迭代，局部最优结果为：0.7408651431441486
# 当前最优结果:0.7408651431441486
# 第152次迭代，局部最优结果为：0.7292361883574341
# 当前最优结果:0.7408651431441486
# 第153次迭代，局部最优结果为：0.7292361883574341
# 当前最优结果:0.7408651431441486
# 第154次迭代，局部最优结果为：0.7408651431441486
# 当前最优结果:0.7408651431441486
# 第155次迭代，局部最优结果为：0.7408651431441486
# 当前最优结果:0.7408651431441486
# 第156次迭代，局部最优结果为：0.7203992552119899
# 当前最优结果:0.7408651431441486
# 第157次迭代，局部最优结果为：0.7408651431441486
# 当前最优结果:0.7408651431441486
# 第158次迭代，局部最优结果为：0.7204872241047715
# 当前最优结果:0.7408651431441486
# 第159次迭代，局部最优结果为：0.700077123872805
# 当前最优结果:0.7408651431441486
# 第160次迭代，局部最优结果为：0.7408651431441486
# 当前最优结果:0.7408651431441486
# 第161次迭代，局部最优结果为：0.7408651431441486
# 当前最优结果:0.7408651431441486
# 第162次迭代，局部最优结果为：0.7358296439483694
# 当前最优结果:0.7408651431441486
# 第163次迭代，局部最优结果为：0.7408651431441486
# 当前最优结果:0.7408651431441486
# 第164次迭代，局部最优结果为：0.741703331238215
# 当前最优结果:0.741703331238215
# 第165次迭代，局部最优结果为：0.733793489413301
# 当前最优结果:0.741703331238215
# 第166次迭代，局部最优结果为：0.7408651431441486
# 当前最优结果:0.741703331238215
# 第167次迭代，局部最优结果为：0.7342272274763564
# 当前最优结果:0.741703331238215
# 第168次迭代，局部最优结果为：0.7329503105590062
# 当前最优结果:0.741703331238215
# 第169次迭代，局部最优结果为：0.7322453538518817
# 当前最优结果:0.741703331238215
# 第170次迭代，局部最优结果为：0.7373008434864105
# 当前最优结果:0.741703331238215
# 第171次迭代，局部最优结果为：0.7680617026815934
# 当前最优结果:0.7680617026815934
# 第172次迭代，局部最优结果为：0.7525829081632652
# 当前最优结果:0.7680617026815934
# 第173次迭代，局部最优结果为：0.7486676817662733
# 当前最优结果:0.7680617026815934
# 第174次迭代，局部最优结果为：0.7680617026815934
# 当前最优结果:0.7680617026815934
# 第175次迭代，局部最优结果为：0.7974388430869036
# 当前最优结果:0.7974388430869036
# 第176次迭代，局部最优结果为：0.7525829081632652
# 当前最优结果:0.7974388430869036
# 第177次迭代，局部最优结果为：0.7974388430869036
# 当前最优结果:0.7974388430869036
# 第178次迭代，局部最优结果为：0.7933909301778331
# 当前最优结果:0.7974388430869036
# 第179次迭代，局部最优结果为：0.7814900662251656
# 当前最优结果:0.7974388430869036
# 第180次迭代，局部最优结果为：0.7814900662251656
# 当前最优结果:0.7974388430869036
# 第181次迭代，局部最优结果为：0.7933909301778331
# 当前最优结果:0.7974388430869036
# 第182次迭代，局部最优结果为：0.7933909301778331
# 当前最优结果:0.7974388430869036
# 第183次迭代，局部最优结果为：0.7906532663316583
# 当前最优结果:0.7974388430869036
# 第184次迭代，局部最优结果为：0.7933909301778331
# 当前最优结果:0.7974388430869036
# 第185次迭代，局部最优结果为：0.7933909301778331
# 当前最优结果:0.7974388430869036
# 第186次迭代，局部最优结果为：0.7814900662251656
# 当前最优结果:0.7974388430869036
# 第187次迭代，局部最优结果为：0.7933909301778331
# 当前最优结果:0.7974388430869036
# 第188次迭代，局部最优结果为：0.789383905277945
# 当前最优结果:0.7974388430869036
# 第189次迭代，局部最优结果为：0.785417151985091
# 当前最优结果:0.7974388430869036
# 第190次迭代，局部最优结果为：0.789383905277945
# 当前最优结果:0.7974388430869036
# 第191次迭代，局部最优结果为：0.7933909301778331
# 当前最优结果:0.7974388430869036
# 第192次迭代，局部最优结果为：0.7776020559454383
# 当前最优结果:0.7974388430869036
# 第193次迭代，局部最优结果为：0.789383905277945
# 当前最优结果:0.7974388430869036
# 第194次迭代，局部最优结果为：0.7933909301778331
# 当前最优结果:0.7974388430869036
# 第195次迭代，局部最优结果为：0.7921925349087003
# 当前最优结果:0.7974388430869036
# 第196次迭代，局部最优结果为：0.789383905277945
# 当前最优结果:0.7974388430869036
# 第197次迭代，局部最优结果为：0.785417151985091
# 当前最优结果:0.7974388430869036
# 第198次迭代，局部最优结果为：0.789383905277945
# 当前最优结果:0.7974388430869036
# 第199次迭代，局部最优结果为：0.7921925349087003
# 当前最优结果:0.7974388430869036
# 第200次迭代，局部最优结果为：0.7814900662251656
# 当前最优结果:0.7974388430869036
# 第201次迭代，局部最优结果为：0.7933909301778331
# 当前最优结果:0.7974388430869036
# 第202次迭代，局部最优结果为：0.789383905277945
# 当前最优结果:0.7974388430869036
# 第203次迭代，局部最优结果为：0.7974388430869036
# 当前最优结果:0.7974388430869036
# 第204次迭代，局部最优结果为：0.7921925349087003
# 当前最优结果:0.7974388430869036
# 第205次迭代，局部最优结果为：0.789383905277945
# 当前最优结果:0.7974388430869036
# 第206次迭代，局部最优结果为：0.7933909301778331
# 当前最优结果:0.7974388430869036
# 第207次迭代，局部最优结果为：0.7933909301778331
# 当前最优结果:0.7974388430869036
# 本次退火用时：6499.48605799675

# %%
def draw(history):
    plt.plot(history['T'], history['f'])
    plt.title('SA')
    plt.xlabel('T')
    plt.ylabel('f')
    plt.gca().invert_xaxis()
    plt.show()
    return

def wrXSLX(squ, use, tim, filename):
    data = {'square':squ,'utilization':use,'timecost':tim}
    df = pd.DataFrame(data)
    df.to_excel(filename,sheet_name='layout',header=0)
    return df

def drawP(m3):
    Lw,Pw,Lh,Ph = m.lcs_xy(m3.l,m3.x,m3.y,m3.w,m3.h)
    print(Pw)
    print(Ph)
    h,w = m3.h,m3.w
    for i in range(len(Pw)):
        x,y = [Pw[i], Pw[i], Pw[i]+w[i], Pw[i]+w[i], Pw[i]],[Ph[i], Ph[i]+h[i], Ph[i]+h[i], Ph[i], Ph[i]]
        plt.plot(x,y,color='r')
        plt.scatter(x,y,color='b')
    plt.show()
    return

# %%
print("本次测试的退火环境为：")
print(sa.iter,sa.T0,sa.alpha)
squ = []
use = []
for i in range(30):
    squ.append(mmm[i].s_cur)
    use.append(mmm[i].use)
print(use)
index = use.index(max(use))
history = {'f': fff[index], 'T': TTT[index]}
print('本次最优解为：'+str(max(use)))
draw(history)

drawP(mmm[index])

wrXSLX(squ,use,sss,'result_moreIter.xlsx')
# Out:
# 本次测试的退火环境为：
# 10000 400 0.95
# [0.74663081303385, 0.7841905901116427, 0.782526525198939, 0.7946464646464646, 0.7775764364786505, 0.8220480668756531, 0.831841251938531, 0.7947535021551724, 0.7848686398403725, 0.8056598620877995, 0.7831757093081135, 0.8437365937365937, 0.7840342834363165, 0.8327511379273843, 0.8517141826055575, 0.8018005775437405, 0.771955647139633, 0.78554786313407, 0.808890564485725, 0.796255060728745, 0.7911833724438485, 0.8310211267605634, 0.8246331236897274, 0.7974388430869036, 0.8071477428180575, 0.7710981148103375, 0.8072305640113555, 0.823338566195709, 0.7797343729351129, 0.7974388430869036]
# 本次最优解为：0.8517141826055575
# [ 672.    0. 1008.  119.  133.  126.  266.  406.  602.  371.  119.  917.
#   266. 1008.  371.  735.  266.    0.  406.  392.  392. 1036.  707.  133.
#   602.  238.  553.  707.    0.  735.  553.  854.  735.]
# [1008.  756.  560. 1036.  406.    0.  273.  623.  581.  770.  770.    0.
#   119.  721.  889.  350.    0.  406.  273.    0.  140.    0.    0.  581.
#   350.  770.  889.  140.    0.  532.  987.  651.  875.]
#        square  utilization     timecost
# 0   1548890.0     0.746631  6497.710979
# 1   1474704.0     0.784191  6530.004365
# 2   1477840.0     0.782527  6490.177808
# 3   1455300.0     0.794646  6520.825596
# 4   1487248.0     0.777576  6488.975836
# 5   1406790.0     0.822048  6489.934999
# 6   1390228.0     0.831841  6515.990138
# 7   1455104.0     0.794754  6522.013101
# 8   1473430.0     0.784869  6475.609253
# 9   1435406.0     0.805660  6483.429015
# 10  1476615.0     0.783176  6491.346330
# 11  1370628.0     0.843737  6511.049349
# 12  1474998.0     0.784034  6538.580293
# 13  1388709.0     0.832751  6585.848228
# 14  1357790.0     0.851714  6538.318581
# 15  1442315.0     0.801801  6493.564739
# 16  1498077.0     0.771956  6462.731869
# 17  1472156.0     0.785548  6485.754187
# 18  1429673.0     0.808891  6515.526855
# 19  1452360.0     0.796255  6500.222849
# 20  1461670.0     0.791183  6514.474104
# 21  1391600.0     0.831021  6525.544717
# 22  1402380.0     0.824633  6522.286866
# 23  1450204.0     0.797439  6532.635016
# 24  1432760.0     0.807148  6503.418844
# 25  1499743.0     0.771098  6505.746323
# 26  1432613.0     0.807231  6524.275225
# 27  1404585.0     0.823339  6494.806999
# 28  1483132.0     0.779734  6517.968687
# 29  1450204.0     0.797439  6499.486058

# %%
# Out:
# 0.6977383592017739
# 0.6977383592017739

# %%
# Out:
# 0.35128899738032865
