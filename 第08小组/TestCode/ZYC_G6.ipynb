# %%
# 导入必要的包
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import copy
import time
import pandas as pd

# %%
'''
产生初始解和初始目标函数X0和f0，初始化最优值记录器X*和f*

既然序列对可以表达模块的位置信息以及整体的最大长度和宽度
那么我们对模块进行乱序，随机生成一个序列对，一个正序列和一个负序列
目标函数就是该序列形成的矩形面积除以总面积，这样子就可以用求目标函数的最小值的方法求解该问题

while(不满足回火终止条件)
    t=t0
        while t>1e-3
            for i=0 i<L i++
                从四种新解中任选一种产生新解Xnew
                计算评价新解的目标函数fnew
                计算评价目标函数差df=fnew-f
                
                if df<0 or exp(-df/t)>random(0,1)
                    接受新解X=Xnew f=fnew
                    与最优值记录器比较，记录最优值
                else
                    还原原来的解
            下降温度 t=a*t
        以记录器的最优解作为下一个循环的初始解
    达不到要求，产生回火温度

'''

# %%
'''
首先
    我们要确定初始温度T0和降温系数α还有终止温度Tf（决定了一共生成
    多少组新解、接受新解的程度）、迭代次数iter（生成一批新解中的新
    解的个数）。
评价函数设置
    整体面积利用率的倒数，一般模拟退火算法都是对最小值进行求解的，
    于是我们需要的面积利用率越大越好，所以我们取倒数即可。
    （面积利用率=sum(模块面积)/生成的矩形画布的面积，生成的矩形画
    布的面积我们可以通过求解LCS得到）

伪代码：
生成初始解x&y&h&w
while T(当前温度)>Tf
    while n(当前循环次数)<iter
        得到上一次的解或者是初始解x&y&h&w
            得到上一次解的评价函数的值f
        从四种方法中生成新解x_new&y_new&h_new&w_new
            得到评价函数值f_new
        Metropolis（f,f_new）  #Metropolis准则
            根据Metropolis准则的结果来决定是否接受新解或者是还原原来的解
    下降温度T=α*T
以记录器中的最优解作为布局问题的最终解


'''

# %%
class module():
    def __init__(self, name='', typ='', w=0., h=0., pos=[], s=0.):
        self.name = name  #模块名称
        self.typ = typ    #模块类型
        self.w = w        #模块宽度
        self.h = h        #模块高度
        self.pos = pos    #模块位置:右下角、右上角、左上角、左下角(左下角一般为(0,0))
        self.s = s        #模块面积

# %%
def rdfile(filename,n):
    #filename是要读取的文件名，n为其中所包含的模块数
    
    #用于存储所有模块对象的列表
    modules = np.zeros(n-1,dtype=type(module('a','b',0.,0.,[],0.))) 
    t = 0
    s_total = 0.
    b1,b2 = 0,0

    #通过文件名打开数据流，按照行的顺序有规律地依次将模块名...读出，顺便创建模块对象放入数组中方便调用
    with open(filename,'r') as f:
        for line in f:
            line = line.split(' ')
            if 'MODULE' in line:
                #print(line[1].split(';')[0])
                name = line[1].split(';')[0]

            if 'TYPE' in line:
                typ = line[2]

            if 'DIMENSIONS' in line:
                #print(line[2:])
                w = 0.
                h = 0.
                pos = np.zeros(8)
                for i in range(10)[2:]:
                    if i != 9:
                        pos[i-2] = int(line[i])
                    else:
                        pos[i-2] = int(line[i].split(";")[0])
                # 用两个坐标值相减即可得到模块的宽高
                h = pos[3]-pos[1]
                w = pos[2]-pos[4]
                s = h*w
                if t == n-1:
                    # 这里的s是parent模块的面积，其实实际上并没有使用到
                    s_total = s
                if t<n-1:
                    modules[t] = module(name,typ,w,h,pos,s)
                    t = t+1
                
    return modules,s_total

# %%
# 读取ami33和ami49并计算出它们模块的总面积（不包括parent）
modules,st = rdfile('ami33.yal',34)
modules1,st1 = rdfile('ami49.yal',50)
s = 0.
for i in range(33):
    s = s + modules[i].s
s1 = 0.
for i in range(49):
    s1 = s1 + modules1[i].s
print(s,s1)
# Out:
# 1156449.0 35445424.0

# %%
# m类，用于存储一组模块的布局
# x为正向序列，y为负向序列，modules则存储着从文件读取出来的各个模块的信息，比如宽w和高h
# m类中还存储着这组模块布局所代表的信息比如面积利用率use、总面积s_cur...其中的iuse是用于模拟退火算法，它是面积利用率的倒数
class m():
    def __init__(self, modules,s_total):
        self.modules = modules
        self.s_total = s_total
        self.l = len(modules)
        self.s_cur,self.iuse,self.use = 0.,0.,0.
        
        # 产生一个比较优的解，在此基础上进行模拟退火，这里随机产生可能没有对模块进行旋转
        # 可能在一定程度上会导致我们的初始解较差
        self.x,self.y,self.modules = self.xyInit()
        self.w,self.h = m.whSort(self.l, self.x, self.y, self.modules)
        self.s_cur,self.iuse,self.use = m.calSC(self.l, self.x, self.y, self.w, self.h, self.s_total) 

    # 计算当前模块布局的信息：总面积s_cur、面积利用率及其倒数
    def calSC(l,x,y,w,h,s_total):
        Lw,Pw,Lh,Ph = m.lcs_xy(l,x,y,w,h)
        s_cur = Lw*Lh
        iuse = s_cur/s_total
        use = s_total/s_cur
            
        return s_cur,iuse,use
    
    # 根据x和y序列还有模块序列（包含旋转信息），来生成新的模块宽高序列，用于LCS算法
    def whSort(l,x,y,modules):
        w = np.zeros(l)
        h = np.zeros(l)
        for i in range(l):
            w[i] = modules[i].w
            h[i] = modules[i].h
        return w,h
    
    # 初始化生成一组正向和反向序列--生成一个0到（总模块个数-1）长度的顺序序列，然后用shuffle打乱，随机翻转模块
    def xyInit(self):
        l = self.l
        tmp = np.zeros(l,dtype='int')
        for i in range(l):
            tmp[i] = i
            
        np.random.shuffle(tmp)
        x = copy.deepcopy(tmp)
        np.random.shuffle(tmp)
        y = copy.deepcopy(tmp)
        
        # 模块随机翻转
        md = copy.deepcopy(self.modules)
        for i in range(l):
            yes = random.randint(0,1)
            if yes:
                md[i].w,md[i].h = md[i].h,md[i].w 
            
        return x,y,md
    
    # lcs快速算法
    def lcs_xy(n,x,y,w,h):
        xr = x[::-1]
        Lw,Pw = m.lcs(n,x,y,w)
        Lh,Ph = m.lcs(n,xr,y,h)
        return Lw,Pw,Lh,Ph
    
    # lcs快速算法核心
    def lcs(n,x,y,w):
        # n个模块，x为正序列，y为负序列，w为每个模块的宽度/高度 
        class mdd():
            def __init__(self,x,y):
                self.x = x
                self.y = y

        match = np.zeros(n,dtype=type(mdd(3,4)))
        for i in range(len(x)):
            for j in range(len(y)):
                if x[i]==y[j]:
                    match[int(x[i]-1)] = mdd(i,j)
                    break
                    
        # 模块的位置P，总长度L
        P = np.zeros(n)
        L = np.zeros(n)

        for i in range(n):
            b = int(x[i]-1)
            p = int(match[b].y)
            P[b] = L[p]
            t = P[b] + w[b]
            for j in range(n)[p:n]:
                if t > L[j]:
                    L[j] = t
                else:
                    break

        return L[n-1],P
    
    def refresh(self):
        # 由于x,y,modules的改变，需要更新数据
        self.w,self.h = m.whSort(self.l, self.x, self.y, self.modules)
        self.s_cur,self.iuse,self.use = m.calSC(self.l, self.x, self.y, self.w, self.h, self.s_total) 
    
    def exchangeX(self,pos1,pos2):
        # 第1个随机模块与第2个随机模块交换正序列中的位置
        id1 = np.array(np.where(self.x==pos1))[0][0]
        id2 = np.array(np.where(self.x==pos2))[0][0] 
        x1 = copy.deepcopy(self.x)
        x1[id1],x1[id2] = x1[id2],x1[id1]
        self.x = x1
        return
    
    def exchangeY(self,pos1,pos2):
        # 第1个随机模块与第2个随机模块交换负序列中的位置
        id1 = np.array(np.where(self.y==pos1))[0][0]
        id2 = np.array(np.where(self.y==pos2))[0][0]
        y1 = copy.deepcopy(self.y)
        y1[id1],y1[id2] = y1[id2],y1[id1]
        self.y = y1
        return
    
    def exchangeXY(self,pos1,pos2):
        # 第1个随机模块与第2个随机模块交换正负序列中的位置
        self.exchangeX(pos1,pos2)
        self.exchangeY(pos1,pos2)
        return
    
    def exchangeWH(self,pos):
        # 旋转模块
        md = copy.deepcopy(self.modules)
        md[pos].w,md[pos].h = md[pos].h,md[pos].w 
        self.modules = md
        return

# %%
# SA类 进行模拟退火算法的框架
# 包含3个主要的方法：产生新解、Metropolis准则、运行
class SA:
    def __init__(self, m1, m2, m3, s_total, iter=4000, T0=400, Tf=0.01, alpha=0.95):
        self.iter = iter         #内循环迭代次数,即为L =100
        self.alpha = alpha       #降温系数，alpha=0.95
        self.T0 = T0             #初始温度T0为400
        self.Tf = Tf             #温度终值Tf为0.01
        self.T = T0              #当前温度
        
        # 生成初始解
        self.m1 = m1
        # 用于保存局部最优解&全局最优解
        self.m2 = m2
        self.m3 = m3
        
        # 模块的一些相关信息，模块个数&模块总面积
        self.l = self.m1.l
        self.s_total = self.m1.s_total
        
        # 存放解的序列对
        self.xi = np.zeros((self.iter,self.l),dtype='int')
        self.yi = np.zeros((self.iter,self.l),dtype='int')
        self.modulesi = np.zeros((self.iter,self.l),dtype=type(module()))
                                 
        # 存放f的历史，用于生成图像
        self.history = {'f': [], 'T': []}

    def generate_new(self):   #扰动产生新解的过程
        rand,rand1,rand2 = 0,0,0
        # 选择产生新解的方式
        rand = random.randint(1,4)
        
        while rand1 == rand2:
            rand1 = random.randint(0,self.l-1)
            rand2 = random.randint(0,self.l-1)
            
        if rand == 1:
            #正向序列中交换两个模块的顺序
            self.m1.exchangeX(rand1,rand2)
        elif rand == 2:
            #负向序列中交换两个模块的顺序
            self.m1.exchangeY(rand1,rand2)
        elif rand == 3:
            #正向序列和负向序列中同时交换两个模块的顺序
            self.m1.exchangeXY(rand1,rand2)
        else:
            #将某个模块旋转，即将模块中的宽和高对调
            self.m1.exchangeWH(rand1)
            
        self.m1.refresh()
            
        return 

    def Metrospolis(self, f, f_new):   #Metropolis准则
        if f_new <= f:
            if self.m1.iuse < self.m3.iuse:
                self.m3.x,self.m3.y,self.m3.modules = copy.deepcopy(self.m1.x),copy.deepcopy(self.m1.y),copy.deepcopy(self.m1.modules)
                self.m3.refresh()
            return 1
        else:
            p = math.exp((f - f_new) / self.T)
            if np.random.rand() < p:
                return 1
            else:
                return 0

    
    def run(self):
        count = 0   #迭代计数器
        count1 = 0  #回火计数器
        
        #外循环迭代，当前温度小于终止温度的阈值
        while self.T > self.Tf:  
            #用于存放一次迭代的中间结果
            t= []   
            #内循环迭代
            for i in range(self.iter): 
                #f为迭代一次后的值
                f = self.m2.iuse
                #产生新解
                self.generate_new()
                x_new,y_new,modules_new = copy.deepcopy(self.m1.x),copy.deepcopy(self.m1.y),copy.deepcopy(self.m1.modules)
                #产生新值
                f_new = self.m1.iuse
                #判断是否接受新值
                if self.Metrospolis(f, f_new):
                    self.xi[i] = x_new
                    self.yi[i] = y_new
                    self.modulesi[i] = modules_new
                    t.append(f_new)
                else:
                    t.append(self.m1.iuse)
                    if i>= 1:
                        self.m1.x = copy.deepcopy(self.xi[i-1])
                        self.m1.y = copy.deepcopy(self.yi[i-1])
                        self.m1.modules = copy.deepcopy(self.modulesi[i-1])
                        self.m1.refresh()
            
                    
            f_best = min(t)
            idx = t.index(f_best)
            
            # 将当前局部最优解作为下一次迭代的初始解
            self.m1.x = copy.deepcopy(self.m3.x)
            self.m1.y = copy.deepcopy(self.m3.y)
            self.m1.modules = copy.deepcopy(self.m3.modules)
            self.m1.refresh()
            
            # 保存局部最优解，但是好像没用
            self.m2.x = copy.deepcopy(self.xi[idx])
            self.m2.y = copy.deepcopy(self.yi[idx])
            self.m2.modules = copy.deepcopy(self.modulesi[idx])
            self.m2.refresh()
            
            # 迭代L次记录在该温度下最优解
            self.history['f'].append(f_best)
            self.history['T'].append(self.T)
            
            #温度按照一定的比例下降（冷却）+回火
            self.T = self.T * self.alpha  
            #if self.T <= self.Tf:
                #if self.m3.use < 0.9:
                    #self.T = self.T0/2
                    #count1 += 1
                    #print("现在的结果好像不是很好，我的建议是回火！这是第" + str(count1) + "次回火")
                    
            count += 1
            
            print("第"+str(count)+"次迭代，局部最优结果为："+str(1/f_best))
            self.m3.refresh()
            print("当前最优结果:"+str(self.m3.use))
            
            
        return

# %%
mmm = []
TTT = []
fff = []
sss = []
for i in range(30):
    t1 = time.time()
    m1 = m(modules1,s1)
    m2 = m(modules1,s1)
    m3 = m(modules1,s1)
    sa = SA(m1,m2,m3,s)
    sa.run()
    t2 = time.time()
    t = t2-t1
    mmm.append(sa.m3)
    TTT.append(sa.history['T'])
    fff.append(sa.history['f'])
    sss.append(t)
    print("本次退火用时："+str(t))
# Out:
# 第1次迭代，局部最优结果为：0.4797177569101809
# 当前最优结果:0.4797177569101809
# 第2次迭代，局部最优结果为：0.4797177569101809
# 当前最优结果:0.4797177569101809
# 第3次迭代，局部最优结果为：0.4900762034838976
# 当前最优结果:0.4900762034838975
# 第4次迭代，局部最优结果为：0.4826883040623498
# 当前最优结果:0.4900762034838975
# 第5次迭代，局部最优结果为：0.4924945533769063
# 当前最优结果:0.49249455337690634
# 第6次迭代，局部最优结果为：0.4757049663299663
# 当前最优结果:0.49249455337690634
# 第7次迭代，局部最优结果为：0.4892330000432844
# 当前最优结果:0.49249455337690634
# 第8次迭代，局部最优结果为：0.5040582424688385
# 当前最优结果:0.5040582424688385
# 第9次迭代，局部最优结果为：0.4965758878802357
# 当前最优结果:0.5040582424688385
# 第10次迭代，局部最优结果为：0.4656463390769674
# 当前最优结果:0.5040582424688385
# 第11次迭代，局部最优结果为：0.4928811268096982
# 当前最优结果:0.5040582424688385
# 第12次迭代，局部最优结果为：0.5040582424688385
# 当前最优结果:0.5040582424688385
# 第13次迭代，局部最优结果为：0.4879025295691962
# 当前最优结果:0.5040582424688385
# 第14次迭代，局部最优结果为：0.49105028782448135
# 当前最优结果:0.5040582424688385
# 第15次迭代，局部最优结果为：0.4820025959972601
# 当前最优结果:0.5040582424688385
# 第16次迭代，局部最优结果为：0.5285610736999626
# 当前最优结果:0.5285610736999626
# 第17次迭代，局部最优结果为：0.4934378905205485
# 当前最优结果:0.5285610736999626
# 第18次迭代，局部最优结果为：0.5285610736999626
# 当前最优结果:0.5285610736999626
# 第19次迭代，局部最优结果为：0.5498516248297334
# 当前最优结果:0.5498516248297334
# 第20次迭代，局部最优结果为：0.5498516248297334
# 当前最优结果:0.5498516248297334
# 第21次迭代，局部最优结果为：0.5510176721511274
# 当前最优结果:0.5510176721511274
# 第22次迭代，局部最优结果为：0.5510176721511274
# 当前最优结果:0.5510176721511274
# 第23次迭代，局部最优结果为：0.570126103404792
# 当前最优结果:0.570126103404792
# 第24次迭代，局部最优结果为：0.5002351196897526
# 当前最优结果:0.570126103404792
# 第25次迭代，局部最优结果为：0.5551789770982993
# 当前最优结果:0.570126103404792
# 第26次迭代，局部最优结果为：0.5664012828623867
# 当前最优结果:0.570126103404792
# 第27次迭代，局部最优结果为：0.570126103404792
# 当前最优结果:0.570126103404792
# 第28次迭代，局部最优结果为：0.5108500985858997
# 当前最优结果:0.570126103404792
# 第29次迭代，局部最优结果为：0.4792550033921303
# 当前最优结果:0.570126103404792
# 第30次迭代，局部最优结果为：0.570126103404792
# 当前最优结果:0.570126103404792
# 第31次迭代，局部最优结果为：0.5114366515837104
# 当前最优结果:0.570126103404792
# 第32次迭代，局部最优结果为：0.5294028103044497
# 当前最优结果:0.570126103404792
# 第33次迭代，局部最优结果为：0.570126103404792
# 当前最优结果:0.570126103404792
# 第34次迭代，局部最优结果为：0.5717953420135705
# 当前最优结果:0.5717953420135705
# 第35次迭代，局部最优结果为：0.475045181355861
# 当前最优结果:0.5717953420135705
# 第36次迭代，局部最优结果为：0.5717953420135705
# 当前最优结果:0.5717953420135705
# 第37次迭代，局部最优结果为：0.4984345026789848
# 当前最优结果:0.5717953420135705
# 第38次迭代，局部最优结果为：0.5287867180509828
# 当前最优结果:0.5717953420135705
# 第39次迭代，局部最优结果为：0.5738783851538749
# 当前最优结果:0.5738783851538749
# 第40次迭代，局部最优结果为：0.5730382650797875
# 当前最优结果:0.5738783851538749
# 第41次迭代，局部最优结果为：0.5738783851538749
# 当前最优结果:0.5738783851538749
# 第42次迭代，局部最优结果为：0.5413388890884491
# 当前最优结果:0.5738783851538749
# 第43次迭代，局部最优结果为：0.577905601891797
# 当前最优结果:0.5779056018917968
# 第44次迭代，局部最优结果为：0.6160585930846534
# 当前最优结果:0.6160585930846534
# 第45次迭代，局部最优结果为：0.6160585930846534
# 当前最优结果:0.6160585930846534
# 第46次迭代，局部最优结果为：0.5004261442249156
# 当前最优结果:0.6160585930846534
# 第47次迭代，局部最优结果为：0.6455025699600229
# 当前最优结果:0.6455025699600229
# 第48次迭代，局部最优结果为：0.6455025699600229
# 当前最优结果:0.6455025699600229
# 第49次迭代，局部最优结果为：0.5779166826449873
# 当前最优结果:0.6455025699600229
# 第50次迭代，局部最优结果为：0.6237032336386712
# 当前最优结果:0.6455025699600229
# 第51次迭代，局部最优结果为：0.6419623364867503
# 当前最优结果:0.6455025699600229
# 第52次迭代，局部最优结果为：0.5841780534289498
# 当前最优结果:0.6455025699600229
# 第53次迭代，局部最优结果为：0.5553102440252654
# 当前最优结果:0.6455025699600229
# 第54次迭代，局部最优结果为：0.615618191721133
# 当前最优结果:0.6455025699600229
# 第55次迭代，局部最优结果为：0.6261998088616185
# 当前最优结果:0.6455025699600229
# 第56次迭代，局部最优结果为：0.5855854105548108
# 当前最优结果:0.6455025699600229
# 第57次迭代，局部最优结果为：0.6023214374927143
# 当前最优结果:0.6455025699600229
# 第58次迭代，局部最优结果为：0.6033563540519801
# 当前最优结果:0.6455025699600229
# 第59次迭代，局部最优结果为：0.6356287256776516
# 当前最优结果:0.6455025699600229
# 第60次迭代，局部最优结果为：0.5245321545833188
# 当前最优结果:0.6455025699600229
# 第61次迭代，局部最优结果为：0.6518310265282583
# 当前最优结果:0.6518310265282584
# 第62次迭代，局部最优结果为：0.6220983832129343
# 当前最优结果:0.6518310265282584
# 第63次迭代，局部最优结果为：0.6332738032706517
# 当前最优结果:0.6518310265282584
# 第64次迭代，局部最优结果为：0.6518310265282583
# 当前最优结果:0.6518310265282584
# 第65次迭代，局部最优结果为：0.6099703184025904
# 当前最优结果:0.6518310265282584
# 第66次迭代，局部最优结果为：0.6010103024260551
# 当前最优结果:0.6518310265282584
# 第67次迭代，局部最优结果为：0.5989798622151563
# 当前最优结果:0.6518310265282584
# 第68次迭代，局部最优结果为：0.5685702428411534
# 当前最优结果:0.6518310265282584
# 第69次迭代，局部最优结果为：0.6199232140408611
# 当前最优结果:0.6518310265282584
# 第70次迭代，局部最优结果为：0.6328483143315067
# 当前最优结果:0.6518310265282584
# 第71次迭代，局部最优结果为：0.6627964082829393
# 当前最优结果:0.6627964082829394
# 第72次迭代，局部最优结果为：0.6412225649753572
# 当前最优结果:0.6627964082829394
# 第73次迭代，局部最优结果为：0.6110131295316481
# 当前最优结果:0.6627964082829394
# 第74次迭代，局部最优结果为：0.5958596512037851
# 当前最优结果:0.6627964082829394
# 第75次迭代，局部最优结果为：0.5118129846606667
# 当前最优结果:0.6627964082829394
# 第76次迭代，局部最优结果为：0.6168360734020056
# 当前最优结果:0.6627964082829394
# 第77次迭代，局部最优结果为：0.6134776192818495
# 当前最优结果:0.6627964082829394
# 第78次迭代，局部最优结果为：0.6168360734020056
# 当前最优结果:0.6627964082829394
# 第79次迭代，局部最优结果为：0.643859368046284
# 当前最优结果:0.6627964082829394
# 第80次迭代，局部最优结果为：0.625645212626102
# 当前最优结果:0.6627964082829394
# 第81次迭代，局部最优结果为：0.5772673297667232
# 当前最优结果:0.6627964082829394
# 第82次迭代，局部最优结果为：0.5550000767235956
# 当前最优结果:0.6627964082829394
# 第83次迭代，局部最优结果为：0.6264948382179727
# 当前最优结果:0.6627964082829394
# 第84次迭代，局部最优结果为：0.6566594045025417
# 当前最优结果:0.6627964082829394
# 第85次迭代，局部最优结果为：0.5622157351016437
# 当前最优结果:0.6627964082829394
# 第86次迭代，局部最优结果为：0.6550894733029051
# 当前最优结果:0.6627964082829394
# 第87次迭代，局部最优结果为：0.6482560848836793
# 当前最优结果:0.6627964082829394
# 第88次迭代，局部最优结果为：0.5509370963417903
# 当前最优结果:0.6627964082829394
# 第89次迭代，局部最优结果为：0.5935246722131967
# 当前最优结果:0.6627964082829394
# 第90次迭代，局部最优结果为：0.6554456163241636
# 当前最优结果:0.6627964082829394
# 第91次迭代，局部最优结果为：0.6627964082829393
# 当前最优结果:0.6627964082829394
# 第92次迭代，局部最优结果为：0.6377852230647153
# 当前最优结果:0.6627964082829394
# 第93次迭代，局部最优结果为：0.615618191721133
# 当前最优结果:0.6627964082829394
# 第94次迭代，局部最优结果为：0.6004017197589682
# 当前最优结果:0.6627964082829394
# 第95次迭代，局部最优结果为：0.5568405754261504
# 当前最优结果:0.6627964082829394
# 第96次迭代，局部最优结果为：0.6294714492072608
# 当前最优结果:0.6627964082829394
# 第97次迭代，局部最优结果为：0.6157125104267742
# 当前最优结果:0.6627964082829394
# 第98次迭代，局部最优结果为：0.6627964082829393
# 当前最优结果:0.6627964082829394
# 第99次迭代，局部最优结果为：0.660327892795852
# 当前最优结果:0.6627964082829394
# 第100次迭代，局部最优结果为：0.6025421893481268
# 当前最优结果:0.6627964082829394
# 第101次迭代，局部最优结果为：0.6690492045874954
# 当前最优结果:0.6690492045874954
# 第102次迭代，局部最优结果为：0.6231917019883524
# 当前最优结果:0.6690492045874954
# 第103次迭代，局部最优结果为：0.6574471952593886
# 当前最优结果:0.6690492045874954
# 第104次迭代，局部最优结果为：0.6412225649753572
# 当前最优结果:0.6690492045874954
# 第105次迭代，局部最优结果为：0.6665339820138582
# 当前最优结果:0.6690492045874954
# 第106次迭代，局部最优结果为：0.6690492045874954
# 当前最优结果:0.6690492045874954
# 第107次迭代，局部最优结果为：0.645019081927453
# 当前最优结果:0.6690492045874954
# 第108次迭代，局部最优结果为：0.6030887438596959
# 当前最优结果:0.6690492045874954
# 第109次迭代，局部最优结果为：0.6499335130278526
# 当前最优结果:0.6690492045874954
# 第110次迭代，局部最优结果为：0.6690492045874954
# 当前最优结果:0.6690492045874954
# 第111次迭代，局部最优结果为：0.6506350062960964
# 当前最优结果:0.6690492045874954
# 第112次迭代，局部最优结果为：0.5591960420531848
# 当前最优结果:0.6690492045874954
# 第113次迭代，局部最优结果为：0.6640376000587501
# 当前最优结果:0.6690492045874954
# 第114次迭代，局部最优结果为：0.6413817562774862
# 当前最优结果:0.6690492045874954
# 第115次迭代，局部最优结果为：0.6810680525740971
# 当前最优结果:0.6810680525740971
# 第116次迭代，局部最优结果为：0.6499335130278526
# 当前最优结果:0.6810680525740971
# 第117次迭代，局部最优结果为：0.6283887556899128
# 当前最优结果:0.6810680525740971
# 第118次迭代，局部最优结果为：0.642019312695257
# 当前最优结果:0.6810680525740971
# 第119次迭代，局部最优结果为：0.6709406465878651
# 当前最优结果:0.6810680525740971
# 第120次迭代，局部最优结果为：0.6756734541378666
# 当前最优结果:0.6810680525740971
# 第121次迭代，局部最优结果为：0.6599905112952082
# 当前最优结果:0.6810680525740971
# 第122次迭代，局部最优结果为：0.5989203510514987
# 当前最优结果:0.6810680525740971
# 第123次迭代，局部最优结果为：0.6029278896323634
# 当前最优结果:0.6810680525740971
# 第124次迭代，局部最优结果为：0.6677399106450541
# 当前最优结果:0.6810680525740971
# 第125次迭代，局部最优结果为：0.6783600285081961
# 当前最优结果:0.6810680525740971
# 第126次迭代，局部最优结果为：0.6270118090852986
# 当前最优结果:0.6810680525740971
# 第127次迭代，局部最优结果为：0.6377852230647153
# 当前最优结果:0.6810680525740971
# 第128次迭代，局部最优结果为：0.6354098591054425
# 当前最优结果:0.6810680525740971
# 第129次迭代，局部最优结果为：0.6550894733029051
# 当前最优结果:0.6810680525740971
# 第130次迭代，局部最优结果为：0.6474669721814471
# 当前最优结果:0.6810680525740971
# 第131次迭代，局部最优结果为：0.6474669721814471
# 当前最优结果:0.6810680525740971
# 第132次迭代，局部最优结果为：0.6810680525740971
# 当前最优结果:0.6810680525740971
# 第133次迭代，局部最优结果为：0.6685545286506469
# 当前最优结果:0.6810680525740971
# 第134次迭代，局部最优结果为：0.6220256316770656
# 当前最优结果:0.6810680525740971
# 第135次迭代，局部最优结果为：0.596166081524337
# 当前最优结果:0.6810680525740971
# 第136次迭代，局部最优结果为：0.6783600285081961
# 当前最优结果:0.6810680525740971
# 第137次迭代，局部最优结果为：0.6879336579427875
# 当前最优结果:0.6879336579427876
# 第138次迭代，局部最优结果为：0.6574471952593886
# 当前最优结果:0.6879336579427876
# 第139次迭代，局部最优结果为：0.6879336579427875
# 当前最优结果:0.6879336579427876
# 第140次迭代，局部最优结果为：0.6536404117510988
# 当前最优结果:0.6879336579427876
# 第141次迭代，局部最优结果为：0.6190743530056141
# 当前最优结果:0.6879336579427876
# 第142次迭代，局部最优结果为：0.6194263479863266
# 当前最优结果:0.6879336579427876
# 第143次迭代，局部最优结果为：0.6837977842477407
# 当前最优结果:0.6879336579427876
# 第144次迭代，局部最优结果为：0.6777041611704041
# 当前最优结果:0.6879336579427876
# 第145次迭代，局部最优结果为：0.6203059614461137
# 当前最优结果:0.6879336579427876
# 第146次迭代，局部最优结果为：0.6700904105528382
# 当前最优结果:0.6879336579427876
# 第147次迭代，局部最优结果为：0.6848932197676929
# 当前最优结果:0.6879336579427876
# 第148次迭代，局部最优结果为：0.663806045478738
# 当前最优结果:0.6879336579427876
# 第149次迭代，局部最优结果为：0.6557165441123148
# 当前最优结果:0.6879336579427876
# 第150次迭代，局部最优结果为：0.6259418860218403
# 当前最优结果:0.6879336579427876
# 第151次迭代，局部最优结果为：0.6810680525740971
# 当前最优结果:0.6879336579427876
# 第152次迭代，局部最优结果为：0.6700904105528382
# 当前最优结果:0.6879336579427876
# 第153次迭代，局部最优结果为：0.6599182601080135
# 当前最优结果:0.6879336579427876
# 第154次迭代，局部最优结果为：0.6931650926039494
# 当前最优结果:0.6931650926039494
# 第155次迭代，局部最优结果为：0.6917703942284888
# 当前最优结果:0.6931650926039494
# 第156次迭代，局部最优结果为：0.6754614654843987
# 当前最优结果:0.6931650926039494
# 第157次迭代，局部最优结果为：0.6754614654843987
# 当前最优结果:0.6931650926039494
# 第158次迭代，局部最优结果为：0.6931650926039494
# 当前最优结果:0.6931650926039494
# 第159次迭代，局部最优结果为：0.6945654261243615
# 当前最优结果:0.6945654261243615
# 第160次迭代，局部最优结果为：0.6862472773085009
# 当前最优结果:0.6945654261243615
# 第161次迭代，局部最优结果为：0.6841599515756819
# 当前最优结果:0.6945654261243615
# 第162次迭代，局部最优结果为：0.6945654261243615
# 当前最优结果:0.6945654261243615
# 第163次迭代，局部最优结果为：0.7079206758058075
# 当前最优结果:0.7079206758058076
# 第164次迭代，局部最优结果为：0.7079206758058075
# 当前最优结果:0.7079206758058076
# 第165次迭代，局部最优结果为：0.7079206758058075
# 当前最优结果:0.7079206758058076
# 第166次迭代，局部最优结果为：0.7164011187082564
# 当前最优结果:0.7164011187082564
# 第167次迭代，局部最优结果为：0.7098351840294541
# 当前最优结果:0.7164011187082564
# 第168次迭代，局部最优结果为：0.7164011187082564
# 当前最优结果:0.7164011187082564
# 第169次迭代，局部最优结果为：0.7164011187082564
# 当前最优结果:0.7164011187082564
# 第170次迭代，局部最优结果为：0.7164011187082564
# 当前最优结果:0.7164011187082564
# 第171次迭代，局部最优结果为：0.7049349029391128
# 当前最优结果:0.7164011187082564
# 第172次迭代，局部最优结果为：0.7042403803842004
# 当前最优结果:0.7164011187082564
# 第173次迭代，局部最优结果为：0.7069437983511264
# 当前最优结果:0.7164011187082564
# 第174次迭代，局部最优结果为：0.7164011187082564
# 当前最优结果:0.7164011187082564
# 第175次迭代，局部最优结果为：0.7098351840294541
# 当前最优结果:0.7164011187082564
# 第176次迭代，局部最优结果为：0.7098351840294541
# 当前最优结果:0.7164011187082564
# 第177次迭代，局部最优结果为：0.7065460725518158
# 当前最优结果:0.7164011187082564
# 第178次迭代，局部最优结果为：0.7195022001543689
# 当前最优结果:0.7195022001543688
# 第179次迭代，局部最优结果为：0.7112002516910493
# 当前最优结果:0.7195022001543688
# 第180次迭代，局部最优结果为：0.7284401156842368
# 当前最优结果:0.7284401156842368
# 第181次迭代，局部最优结果为：0.7165714376282818
# 当前最优结果:0.7284401156842368
# 第182次迭代，局部最优结果为：0.7195022001543689
# 当前最优结果:0.7284401156842368
# 第183次迭代，局部最优结果为：0.7284401156842368
# 当前最优结果:0.7284401156842368
# 第184次迭代，局部最优结果为：0.7284401156842368
# 当前最优结果:0.7284401156842368
# 第185次迭代，局部最优结果为：0.7284401156842368
# 当前最优结果:0.7284401156842368
# 第186次迭代，局部最优结果为：0.7284401156842368
# 当前最优结果:0.7284401156842368
# 第187次迭代，局部最优结果为：0.7186530124024908
# 当前最优结果:0.7284401156842368
# 第188次迭代，局部最优结果为：0.7255235497071332
# 当前最优结果:0.7284401156842368
# 第189次迭代，局部最优结果为：0.7200350374263418
# 当前最优结果:0.7284401156842368
# 第190次迭代，局部最优结果为：0.7284401156842368
# 当前最优结果:0.7284401156842368
# 第191次迭代，局部最优结果为：0.7284401156842368
# 当前最优结果:0.7284401156842368
# 第192次迭代，局部最优结果为：0.722815095485903
# 当前最优结果:0.7284401156842368
# 第193次迭代，局部最优结果为：0.7428932925827336
# 当前最优结果:0.7428932925827336
# 第194次迭代，局部最优结果为：0.7351651076665406
# 当前最优结果:0.7428932925827336
# 第195次迭代，局部最优结果为：0.7370437390978302
# 当前最优结果:0.7428932925827336
# 第196次迭代，局部最优结果为：0.7428932925827336
# 当前最优结果:0.7428932925827336
# 第197次迭代，局部最优结果为：0.7428932925827336
# 当前最优结果:0.7428932925827336
# 第198次迭代，局部最优结果为：0.7383075315174081
# 当前最优结果:0.7428932925827336
# 第199次迭代，局部最优结果为：0.7284401156842368
# 当前最优结果:0.7428932925827336
# 第200次迭代，局部最优结果为：0.7518438141801159
# 当前最优结果:0.7518438141801159
# 第201次迭代，局部最优结果为：0.7439690636827382
# 当前最优结果:0.7518438141801159
# 第202次迭代，局部最优结果为：0.7414222167558371
# 当前最优结果:0.7518438141801159
# 第203次迭代，局部最优结果为：0.7625625650951074
# 当前最优结果:0.7625625650951073
# 第204次迭代，局部最优结果为：0.7518438141801159
# 当前最优结果:0.7625625650951073
# 第205次迭代，局部最优结果为：0.7625625650951074
# 当前最优结果:0.7625625650951073
# 第206次迭代，局部最优结果为：0.7610126411823125
# 当前最优结果:0.7625625650951073
# 第207次迭代，局部最优结果为：0.7625625650951074
# 当前最优结果:0.7625625650951073
# 本次退火用时：4160.604020833969
# 第1次迭代，局部最优结果为：0.5030599074238917
# 当前最优结果:0.5030599074238917
# 第2次迭代，局部最优结果为：0.5061461645246518
# 当前最优结果:0.5061461645246518
# 第3次迭代，局部最优结果为：0.5061461645246518
# 当前最优结果:0.5061461645246518
# 第4次迭代，局部最优结果为：0.5061461645246518
# 当前最优结果:0.5061461645246518
# 第5次迭代，局部最优结果为：0.5314127202416634
# 当前最优结果:0.5314127202416634
# 第6次迭代，局部最优结果为：0.527561903428318
# 当前最优结果:0.5314127202416634
# 第7次迭代，局部最优结果为：0.5314127202416634
# 当前最优结果:0.5314127202416634
# 第8次迭代，局部最优结果为：0.5475889842697309
# 当前最优结果:0.547588984269731
# 第9次迭代，局部最优结果为：0.5415382772612256
# 当前最优结果:0.547588984269731
# 第10次迭代，局部最优结果为：0.5328595337434882
# 当前最优结果:0.547588984269731
# 第11次迭代，局部最优结果为：0.5640992049009791
# 当前最优结果:0.5640992049009791
# 第12次迭代，局部最优结果为：0.5578660645153329
# 当前最优结果:0.5640992049009791
# 第13次迭代，局部最优结果为：0.5277035307849431
# 当前最优结果:0.5640992049009791
# 第14次迭代，局部最优结果为：0.5650456800769875
# 当前最优结果:0.5650456800769875
# 第15次迭代，局部最优结果为：0.5057158836689039
# 当前最优结果:0.5650456800769875
# 第16次迭代，局部最优结果为：0.5493755714941021
# 当前最优结果:0.5650456800769875
# 第17次迭代，局部最优结果为：0.5232406408138347
# 当前最优结果:0.5650456800769875
# 第18次迭代，局部最优结果为：0.5050859386782703
# 当前最优结果:0.5650456800769875
# 第19次迭代，局部最优结果为：0.5286769628349836
# 当前最优结果:0.5650456800769875
# 第20次迭代，局部最优结果为：0.5650456800769875
# 当前最优结果:0.5650456800769875
# 第21次迭代，局部最优结果为：0.5717194198206856
# 当前最优结果:0.5717194198206856
# 第22次迭代，局部最优结果为：0.530692255773689
# 当前最优结果:0.5717194198206856
# 第23次迭代，局部最优结果为：0.5524045745564733
# 当前最优结果:0.5717194198206856
# 第24次迭代，局部最优结果为：0.5914573521716379
# 当前最优结果:0.5914573521716379
# 第25次迭代，局部最优结果为：0.6006988732993197
# 当前最优结果:0.6006988732993197
# 第26次迭代，局部最优结果为：0.6006988732993197
# 当前最优结果:0.6006988732993197
# 第27次迭代，局部最优结果为：0.6147559930924765
# 当前最优结果:0.6147559930924765
# 第28次迭代，局部最优结果为：0.5898138363795286
# 当前最优结果:0.6147559930924765
# 第29次迭代，局部最优结果为：0.5858339137336205
# 当前最优结果:0.6147559930924765
# 第30次迭代，局部最优结果为：0.5609322609561443
# 当前最优结果:0.6147559930924765
# 第31次迭代，局部最优结果为：0.6147559930924765
# 当前最优结果:0.6147559930924765
# 第32次迭代，局部最优结果为：0.6456224027874962
# 当前最优结果:0.6456224027874963
# 第33次迭代，局部最优结果为：0.613800359773275
# 当前最优结果:0.6456224027874963
# 第34次迭代，局部最优结果为：0.5767297683437085
# 当前最优结果:0.6456224027874963
# 第35次迭代，局部最优结果为：0.6248237928079825
# 当前最优结果:0.6456224027874963
# 第36次迭代，局部最优结果为：0.6048294314381271
# 当前最优结果:0.6456224027874963
# 第37次迭代，局部最优结果为：0.6171855269714075
# 当前最优结果:0.6456224027874963
# 第38次迭代，局部最优结果为：0.5404684913002158
# 当前最优结果:0.6456224027874963
# 第39次迭代，局部最优结果为：0.6456224027874962
# 当前最优结果:0.6456224027874963
# 第40次迭代，局部最优结果为：0.5883899347332392
# 当前最优结果:0.6456224027874963
# 第41次迭代，局部最优结果为：0.5341248744757516
# 当前最优结果:0.6456224027874963
# 第42次迭代，局部最优结果为：0.6456224027874962
# 当前最优结果:0.6456224027874963
# 第43次迭代，局部最优结果为：0.6272510336024861
# 当前最优结果:0.6456224027874963
# 第44次迭代，局部最优结果为：0.6380012277124331
# 当前最优结果:0.6456224027874963
# 第45次迭代，局部最优结果为：0.599237880645482
# 当前最优结果:0.6456224027874963
# 第46次迭代，局部最优结果为：0.6209406610310326
# 当前最优结果:0.6456224027874963
# 第47次迭代，局部最优结果为：0.5107289107289107
# 当前最优结果:0.6456224027874963
# 第48次迭代，局部最优结果为：0.6004037130980996
# 当前最优结果:0.6456224027874963
# 第49次迭代，局部最优结果为：0.6456224027874962
# 当前最优结果:0.6456224027874963
# 第50次迭代，局部最优结果为：0.5883325091741926
# 当前最优结果:0.6456224027874963
# 第51次迭代，局部最优结果为：0.6456224027874962
# 当前最优结果:0.6456224027874963
# 第52次迭代，局部最优结果为：0.5893064299586803
# 当前最优结果:0.6456224027874963
# 第53次迭代，局部最优结果为：0.5275342026195269
# 当前最优结果:0.6456224027874963
# 第54次迭代，局部最优结果为：0.6247115557336502
# 当前最优结果:0.6456224027874963
# 第55次迭代，局部最优结果为：0.5923368685843056
# 当前最优结果:0.6456224027874963
# 第56次迭代，局部最优结果为：0.5855929953176912
# 当前最优结果:0.6456224027874963
# 第57次迭代，局部最优结果为：0.6442745480843909
# 当前最优结果:0.6456224027874963
# 第58次迭代，局部最优结果为：0.6591197352499526
# 当前最优结果:0.6591197352499526
# 第59次迭代，局部最优结果为：0.6295086988909697
# 当前最优结果:0.6591197352499526
# 第60次迭代，局部最优结果为：0.6005313143388458
# 当前最优结果:0.6591197352499526
# 第61次迭代，局部最优结果为：0.6527344652344652
# 当前最优结果:0.6591197352499526
# 第62次迭代，局部最优结果为：0.5948659245809321
# 当前最优结果:0.6591197352499526
# 第63次迭代，局部最优结果为：0.6631390969861647
# 当前最优结果:0.6631390969861647
# 第64次迭代，局部最优结果为：0.5962073558307289
# 当前最优结果:0.6631390969861647
# 第65次迭代，局部最优结果为：0.6374255401642522
# 当前最优结果:0.6631390969861647
# 第66次迭代，局部最优结果为：0.6294385854999826
# 当前最优结果:0.6631390969861647
# 第67次迭代，局部最优结果为：0.6404595454126913
# 当前最优结果:0.6631390969861647
# 第68次迭代，局部最优结果为：0.5764356385148919
# 当前最优结果:0.6631390969861647
# 第69次迭代，局部最优结果为：0.6284477156548965
# 当前最优结果:0.6631390969861647
# 第70次迭代，局部最优结果为：0.5704858044164037
# 当前最优结果:0.6631390969861647
# 第71次迭代，局部最优结果为：0.6689155699564274
# 当前最优结果:0.6689155699564275
# 第72次迭代，局部最优结果为：0.6359729636584868
# 当前最优结果:0.6689155699564275
# 第73次迭代，局部最优结果为：0.5116435662612425
# 当前最优结果:0.6689155699564275
# 第74次迭代，局部最优结果为：0.5614686532687967
# 当前最优结果:0.6689155699564275
# 第75次迭代，局部最优结果为：0.6689155699564274
# 当前最优结果:0.6689155699564275
# 第76次迭代，局部最优结果为：0.6339219988923086
# 当前最优结果:0.6689155699564275
# 第77次迭代，局部最优结果为：0.5666532975710025
# 当前最优结果:0.6689155699564275
# 第78次迭代，局部最优结果为：0.6383277622666417
# 当前最优结果:0.6689155699564275
# 第79次迭代，局部最优结果为：0.6093989041575965
# 当前最优结果:0.6689155699564275
# 第80次迭代，局部最优结果为：0.6339219988923086
# 当前最优结果:0.6689155699564275
# 第81次迭代，局部最优结果为：0.6651366361396153
# 当前最优结果:0.6689155699564275
# 第82次迭代，局部最优结果为：0.6181432868471425
# 当前最优结果:0.6689155699564275
# 第83次迭代，局部最优结果为：0.6580931586608443
# 当前最优结果:0.6689155699564275
# 第84次迭代，局部最优结果为：0.6689155699564274
# 当前最优结果:0.6689155699564275
# 第85次迭代，局部最优结果为：0.6759815794982208
# 当前最优结果:0.6759815794982208
# 第86次迭代，局部最优结果为：0.6329767871643379
# 当前最优结果:0.6759815794982208
# 第87次迭代，局部最优结果为：0.5477482061673316
# 当前最优结果:0.6759815794982208
# 第88次迭代，局部最优结果为：0.5807151848331492
# 当前最优结果:0.6759815794982208
# 第89次迭代，局部最优结果为：0.5271067481229306
# 当前最优结果:0.6759815794982208
# 第90次迭代，局部最优结果为：0.6759815794982208
# 当前最优结果:0.6759815794982208
# 第91次迭代，局部最优结果为：0.5808737324583803
# 当前最优结果:0.6759815794982208
# 第92次迭代，局部最优结果为：0.6745494151348771
# 当前最优结果:0.6759815794982208
# 第93次迭代，局部最优结果为：0.5656359666956505
# 当前最优结果:0.6759815794982208
# 第94次迭代，局部最优结果为：0.6552033969537556
# 当前最优结果:0.6759815794982208
# 第95次迭代，局部最优结果为：0.5728349699081406
# 当前最优结果:0.6759815794982208
# 第96次迭代，局部最优结果为：0.6157586323133339
# 当前最优结果:0.6759815794982208
# 第97次迭代，局部最优结果为：0.6524330408681598
# 当前最优结果:0.6759815794982208
# 第98次迭代，局部最优结果为：0.5773355169694706
# 当前最优结果:0.6759815794982208
# 第99次迭代，局部最优结果为：0.62704224570747
# 当前最优结果:0.6759815794982208
# 第100次迭代，局部最优结果为：0.6653568800588668
# 当前最优结果:0.6759815794982208
# 第101次迭代，局部最优结果为：0.5689369319486698
# 当前最优结果:0.6759815794982208
# 第102次迭代，局部最优结果为：0.5378020311361575
# 当前最优结果:0.6759815794982208
# 第103次迭代，局部最优结果为：0.6445087529223927
# 当前最优结果:0.6759815794982208
# 第104次迭代，局部最优结果为：0.6759815794982208
# 当前最优结果:0.6759815794982208
# 第105次迭代，局部最优结果为：0.639929228591649
# 当前最优结果:0.6759815794982208
# 第106次迭代，局部最优结果为：0.5975963174817179
# 当前最优结果:0.6759815794982208
# 第107次迭代，局部最优结果为：0.6406183580355371
# 当前最优结果:0.6759815794982208
# 第108次迭代，局部最优结果为：0.6759815794982208
# 当前最优结果:0.6759815794982208
# 第109次迭代，局部最优结果为：0.5574481989063358
# 当前最优结果:0.6759815794982208
# 第110次迭代，局部最优结果为：0.6759815794982208
# 当前最优结果:0.6759815794982208
# 第111次迭代，局部最优结果为：0.6218502420774648
# 当前最优结果:0.6759815794982208
# 第112次迭代，局部最优结果为：0.6220256316770656
# 当前最优结果:0.6759815794982208
# 第113次迭代，局部最优结果为：0.6380507493860962
# 当前最优结果:0.6759815794982208
# 第114次迭代，局部最优结果为：0.6646916992560793
# 当前最优结果:0.6759815794982208
# 第115次迭代，局部最优结果为：0.6425850649535234
# 当前最优结果:0.6759815794982208
# 第116次迭代，局部最优结果为：0.6606535517927924
# 当前最优结果:0.6759815794982208
# 第117次迭代，局部最优结果为：0.6018663968689263
# 当前最优结果:0.6759815794982208
# 第118次迭代，局部最优结果为：0.5726300057312397
# 当前最优结果:0.6759815794982208
# 第119次迭代，局部最优结果为：0.6759815794982208
# 当前最优结果:0.6759815794982208
# 第120次迭代，局部最优结果为：0.6367455010862179
# 当前最优结果:0.6759815794982208
# 第121次迭代，局部最优结果为：0.6304699484032911
# 当前最优结果:0.6759815794982208
# 第122次迭代，局部最优结果为：0.6948776767222664
# 当前最优结果:0.6948776767222664
# 第123次迭代，局部最优结果为：0.7103537942439204
# 当前最优结果:0.7103537942439204
# 第124次迭代，局部最优结果为：0.5946194769410852
# 当前最优结果:0.7103537942439204
# 第125次迭代，局部最优结果为：0.6547337170993085
# 当前最优结果:0.7103537942439204
# 第126次迭代，局部最优结果为：0.6570482892925007
# 当前最优结果:0.7103537942439204
# 第127次迭代，局部最优结果为：0.7103537942439204
# 当前最优结果:0.7103537942439204
# 第128次迭代，局部最优结果为：0.7141322718728775
# 当前最优结果:0.7141322718728774
# 第129次迭代，局部最优结果为：0.7141322718728775
# 当前最优结果:0.7141322718728774
# 第130次迭代，局部最优结果为：0.7179511610272779
# 当前最优结果:0.7179511610272779
# 第131次迭代，局部最优结果为：0.7053830881865377
# 当前最优结果:0.7179511610272779
# 第132次迭代，局部最优结果为：0.7179511610272779
# 当前最优结果:0.7179511610272779
# 第133次迭代，局部最优结果为：0.6769253803971478
# 当前最优结果:0.7179511610272779
# 第134次迭代，局部最优结果为：0.7053775855276758
# 当前最优结果:0.7179511610272779
# 第135次迭代，局部最优结果为：0.6712843355605048
# 当前最优结果:0.7179511610272779
# 第136次迭代，局部最优结果为：0.6475411597046671
# 当前最优结果:0.7179511610272779
# 第137次迭代，局部最优结果为：0.645479530285184
# 当前最优结果:0.7179511610272779
# 第138次迭代，局部最优结果为：0.6743934546051209
# 当前最优结果:0.7179511610272779
# 第139次迭代，局部最优结果为：0.6696189876698634
# 当前最优结果:0.7179511610272779
# 第140次迭代，局部最优结果为：0.6871155387871258
# 当前最优结果:0.7179511610272779
# 第141次迭代，局部最优结果为：0.6465017677950288
# 当前最优结果:0.7179511610272779
# 第142次迭代，局部最优结果为：0.6701872584225526
# 当前最优结果:0.7179511610272779
# 第143次迭代，局部最优结果为：0.6947415329768271
# 当前最优结果:0.7179511610272779
# 第144次迭代，局部最优结果为：0.7141322718728775
# 当前最优结果:0.7179511610272779
# 第145次迭代，局部最优结果为：0.6314385474860335
# 当前最优结果:0.7179511610272779
# 第146次迭代，局部最优结果为：0.660279674321808
# 当前最优结果:0.7179511610272779
# 第147次迭代，局部最优结果为：0.6401602843205969
# 当前最优结果:0.7179511610272779
# 第148次迭代，局部最优结果为：0.7166736678581903
# 当前最优结果:0.7179511610272779
# 第149次迭代，局部最优结果为：0.6553696066564713
# 当前最优结果:0.7179511610272779
# 第150次迭代，局部最优结果为：0.7179511610272779
# 当前最优结果:0.7179511610272779
# 第151次迭代，局部最优结果为：0.728337434604526
# 当前最优结果:0.728337434604526
# 第152次迭代，局部最优结果为：0.6932474651639737
# 当前最优结果:0.728337434604526
# 第153次迭代，局部最优结果为：0.7203160972190136
# 当前最优结果:0.728337434604526
# 第154次迭代，局部最优结果为：0.6809141910463496
# 当前最优结果:0.728337434604526
# 第155次迭代，局部最优结果为：0.728337434604526
# 当前最优结果:0.728337434604526
# 第156次迭代，局部最优结果为：0.6954655755231067
# 当前最优结果:0.728337434604526
# 第157次迭代，局部最优结果为：0.7203160972190136
# 当前最优结果:0.728337434604526
# 第158次迭代，局部最优结果为：0.6867059046895766
# 当前最优结果:0.728337434604526
# 第159次迭代，局部最优结果为：0.6939470917337549
# 当前最优结果:0.728337434604526
# 第160次迭代，局部最优结果为：0.7140251269376248
# 当前最优结果:0.728337434604526
# 第161次迭代，局部最优结果为：0.7140251269376248
# 当前最优结果:0.728337434604526
# 第162次迭代，局部最优结果为：0.6988599914982416
# 当前最优结果:0.728337434604526
# 第163次迭代，局部最优结果为：0.7063142724350587
# 当前最优结果:0.728337434604526
# 第164次迭代，局部最优结果为：0.6963948768897823
# 当前最优结果:0.728337434604526
# 第165次迭代，局部最优结果为：0.7140251269376248
# 当前最优结果:0.728337434604526
# 第166次迭代，局部最优结果为：0.728337434604526
# 当前最优结果:0.728337434604526
# 第167次迭代，局部最优结果为：0.7140251269376248
# 当前最优结果:0.728337434604526
# 第168次迭代，局部最优结果为：0.7140251269376248
# 当前最优结果:0.728337434604526
# 第169次迭代，局部最优结果为：0.724407556360257
# 当前最优结果:0.728337434604526
# 第170次迭代，局部最优结果为：0.728337434604526
# 当前最优结果:0.728337434604526
# 第171次迭代，局部最优结果为：0.7140251269376248
# 当前最优结果:0.728337434604526
# 第172次迭代，局部最优结果为：0.728337434604526
# 当前最优结果:0.728337434604526
# 第173次迭代，局部最优结果为：0.7187329849174334
# 当前最优结果:0.728337434604526
# 第174次迭代，局部最优结果为：0.7166168696851298
# 当前最优结果:0.728337434604526
# 第175次迭代，局部最优结果为：0.7128683209492086
# 当前最优结果:0.728337434604526
# 第176次迭代，局部最优结果为：0.7197599261311173
# 当前最优结果:0.728337434604526
# 第177次迭代，局部最优结果为：0.7140251269376248
# 当前最优结果:0.728337434604526
# 第178次迭代，局部最优结果为：0.7203160972190136
# 当前最优结果:0.728337434604526
# 第179次迭代，局部最优结果为：0.728337434604526
# 当前最优结果:0.728337434604526
# 第180次迭代，局部最优结果为：0.7197599261311173
# 当前最优结果:0.728337434604526
# 第181次迭代，局部最优结果为：0.7032763615858757
# 当前最优结果:0.728337434604526
# 第182次迭代，局部最优结果为：0.7008642405921792
# 当前最优结果:0.728337434604526
# 第183次迭代，局部最优结果为：0.725651643554186
# 当前最优结果:0.728337434604526
# 第184次迭代，局部最优结果为：0.728337434604526
# 当前最优结果:0.728337434604526
# 第185次迭代，局部最优结果为：0.7287395228884591
# 当前最优结果:0.7287395228884591
# 第186次迭代，局部最优结果为：0.7286338216570775
# 当前最优结果:0.7287395228884591
# 第187次迭代，局部最优结果为：0.7086085968418165
# 当前最优结果:0.7287395228884591
# 第188次迭代，局部最优结果为：0.7154884552691133
# 当前最优结果:0.7287395228884591
# 第189次迭代，局部最优结果为：0.7293567251461989
# 当前最优结果:0.7293567251461989
# 第190次迭代，局部最优结果为：0.7293567251461989
# 当前最优结果:0.7293567251461989
# 第191次迭代，局部最优结果为：0.7293567251461989
# 当前最优结果:0.7293567251461989
# 第192次迭代，局部最优结果为：0.7202845387596436
# 当前最优结果:0.7293567251461989
# 第193次迭代，局部最优结果为：0.7320345041146683
# 当前最优结果:0.7320345041146683
# 第194次迭代，局部最优结果为：0.729277312008775
# 当前最优结果:0.7320345041146683
# 第195次迭代，局部最优结果为：0.7320345041146683
# 当前最优结果:0.7320345041146683
# 第196次迭代，局部最优结果为：0.7261294829995343
# 当前最优结果:0.7320345041146683
# 第197次迭代，局部最优结果为：0.7320345041146683
# 当前最优结果:0.7320345041146683
# 第198次迭代，局部最优结果为：0.7286338216570775
# 当前最优结果:0.7320345041146683
# 第199次迭代，局部最优结果为：0.7320345041146683
# 当前最优结果:0.7320345041146683
# 第200次迭代，局部最优结果为：0.7326127819548872
# 当前最优结果:0.7326127819548872
# 第201次迭代，局部最优结果为：0.7425272631717251
# 当前最优结果:0.7425272631717251
# 第202次迭代，局部最优结果为：0.727906489993721
# 当前最优结果:0.7425272631717251
# 第203次迭代，局部最优结果为：0.744777938850817
# 当前最优结果:0.7447779388508171
# 第204次迭代，局部最优结果为：0.7320345041146683
# 当前最优结果:0.7447779388508171
# 第205次迭代，局部最优结果为：0.745686953653307
# 当前最优结果:0.745686953653307
# 第206次迭代，局部最优结果为：0.7354012817593285
# 当前最优结果:0.745686953653307
# 第207次迭代，局部最优结果为：0.7425272631717251
# 当前最优结果:0.745686953653307
# 本次退火用时：4163.729730606079
# 第1次迭代，局部最优结果为：0.5007947628726662
# 当前最优结果:0.5007947628726662
# 第2次迭代，局部最优结果为：0.4891112673770758
# 当前最优结果:0.5007947628726662
# 第3次迭代，局部最优结果为：0.5000207369640531
# 当前最优结果:0.5007947628726662
# 第4次迭代，局部最优结果为：0.4896409812097255
# 当前最优结果:0.5007947628726662
# 第5次迭代，局部最优结果为：0.5099167075515855
# 当前最优结果:0.5099167075515855
# 第6次迭代，局部最优结果为：0.5209165670502499
# 当前最优结果:0.5209165670502499
# 第7次迭代，局部最优结果为：0.5369318013123126
# 当前最优结果:0.5369318013123126
# 第8次迭代，局部最优结果为：0.5369318013123126
# 当前最优结果:0.5369318013123126
# 第9次迭代，局部最优结果为：0.5519493599799784
# 当前最优结果:0.5519493599799784
# 第10次迭代，局部最优结果为：0.5685273442903311
# 当前最优结果:0.5685273442903311
# 第11次迭代，局部最优结果为：0.5424658191700612
# 当前最优结果:0.5685273442903311
# 第12次迭代，局部最优结果为：0.5596286554231781
# 当前最优结果:0.5685273442903311
# 第13次迭代，局部最优结果为：0.49349983081003784
# 当前最优结果:0.5685273442903311
# 第14次迭代，局部最优结果为：0.5580537057723522
# 当前最优结果:0.5685273442903311
# 第15次迭代，局部最优结果为：0.5480486577893071
# 当前最优结果:0.5685273442903311
# 第16次迭代，局部最优结果为：0.5132160715603308
# 当前最优结果:0.5685273442903311
# 第17次迭代，局部最优结果为：0.5675175266272933
# 当前最优结果:0.5685273442903311
# 第18次迭代，局部最优结果为：0.5780903366045456
# 当前最优结果:0.5780903366045456
# 第19次迭代，局部最优结果为：0.523906090664689
# 当前最优结果:0.5780903366045456
# 第20次迭代，局部最优结果为：0.5178541770470021
# 当前最优结果:0.5780903366045456
# 第21次迭代，局部最优结果为：0.493785495849716
# 当前最优结果:0.5780903366045456
# 第22次迭代，局部最优结果为：0.5469778358497871
# 当前最优结果:0.5780903366045456
# 第23次迭代，局部最优结果为：0.5312971896281237
# 当前最优结果:0.5780903366045456
# 第24次迭代，局部最优结果为：0.5395509808309092
# 当前最优结果:0.5780903366045456
# 第25次迭代，局部最优结果为：0.5780903366045456
# 当前最优结果:0.5780903366045456
# 第26次迭代，局部最优结果为：0.5388066905415955
# 当前最优结果:0.5780903366045456
# 第27次迭代，局部最优结果为：0.5780903366045456
# 当前最优结果:0.5780903366045456
# 第28次迭代，局部最优结果为：0.5605966669973217
# 当前最优结果:0.5780903366045456
# 第29次迭代，局部最优结果为：0.5275372803435159
# 当前最优结果:0.5780903366045456
# 第30次迭代，局部最优结果为：0.5616029116746477
# 当前最优结果:0.5780903366045456
# 第31次迭代，局部最优结果为：0.5250987224157956
# 当前最优结果:0.5780903366045456
# 第32次迭代，局部最优结果为：0.5764926027344859
# 当前最优结果:0.5780903366045456
# 第33次迭代，局部最优结果为：0.5955751104905054
# 当前最优结果:0.5955751104905054
# 第34次迭代，局部最优结果为：0.5224862909609906
# 当前最优结果:0.5955751104905054
# 第35次迭代，局部最优结果为：0.5764926027344859
# 当前最优结果:0.5955751104905054
# 第36次迭代，局部最优结果为：0.533316818689858
# 当前最优结果:0.5955751104905054
# 第37次迭代，局部最优结果为：0.5606036182375042
# 当前最优结果:0.5955751104905054
# 第38次迭代，局部最优结果为：0.5759766607851505
# 当前最优结果:0.5955751104905054
# 第39次迭代，局部最优结果为：0.5955751104905054
# 当前最优结果:0.5955751104905054
# 第40次迭代，局部最优结果为：0.6074379610098215
# 当前最优结果:0.6074379610098214
# 第41次迭代，局部最优结果为：0.6074379610098215
# 当前最优结果:0.6074379610098214
# 第42次迭代，局部最优结果为：0.608513072445237
# 当前最优结果:0.608513072445237
# 第43次迭代，局部最优结果为：0.5851515102489848
# 当前最优结果:0.608513072445237
# 第44次迭代，局部最优结果为：0.6063666418546013
# 当前最优结果:0.608513072445237
# 第45次迭代，局部最优结果为：0.608513072445237
# 当前最优结果:0.608513072445237
# 第46次迭代，局部最优结果为：0.5905495869117983
# 当前最优结果:0.608513072445237
# 第47次迭代，局部最优结果为：0.6236645170190019
# 当前最优结果:0.6236645170190019
# 第48次迭代，局部最优结果为：0.6236645170190019
# 当前最优结果:0.6236645170190019
# 第49次迭代，局部最优结果为：0.5723164950345901
# 当前最优结果:0.6236645170190019
# 第50次迭代，局部最优结果为：0.587110095317248
# 当前最优结果:0.6236645170190019
# 第51次迭代，局部最优结果为：0.6236645170190019
# 当前最优结果:0.6236645170190019
# 第52次迭代，局部最优结果为：0.6526025578105604
# 当前最优结果:0.6526025578105603
# 第53次迭代，局部最优结果为：0.5789212532132235
# 当前最优结果:0.6526025578105603
# 第54次迭代，局部最优结果为：0.6526025578105604
# 当前最优结果:0.6526025578105603
# 第55次迭代，局部最优结果为：0.6053862247886852
# 当前最优结果:0.6526025578105603
# 第56次迭代，局部最优结果为：0.6057370240360138
# 当前最优结果:0.6526025578105603
# 第57次迭代，局部最优结果为：0.6193181623602335
# 当前最优结果:0.6526025578105603
# 第58次迭代，局部最优结果为：0.5928417353448332
# 当前最优结果:0.6526025578105603
# 第59次迭代，局部最优结果为：0.6235204473911949
# 当前最优结果:0.6526025578105603
# 第60次迭代，局部最优结果为：0.6318268209514226
# 当前最优结果:0.6526025578105603
# 第61次迭代，局部最优结果为：0.6526025578105604
# 当前最优结果:0.6526025578105603
# 第62次迭代，局部最优结果为：0.6115296695567489
# 当前最优结果:0.6526025578105603
# 第63次迭代，局部最优结果为：0.6465711108807031
# 当前最优结果:0.6526025578105603
# 第64次迭代，局部最优结果为：0.5999037999037999
# 当前最优结果:0.6526025578105603
# 第65次迭代，局部最优结果为：0.6526025578105604
# 当前最优结果:0.6526025578105603
# 第66次迭代，局部最优结果为：0.6259657187162518
# 当前最优结果:0.6526025578105603
# 第67次迭代，局部最优结果为：0.6318268209514226
# 当前最优结果:0.6526025578105603
# 第68次迭代，局部最优结果为：0.5326005966738232
# 当前最优结果:0.6526025578105603
# 第69次迭代，局部最优结果为：0.6213054546828781
# 当前最优结果:0.6526025578105603
# 第70次迭代，局部最优结果为：0.6526025578105604
# 当前最优结果:0.6526025578105603
# 第71次迭代，局部最优结果为：0.6480539818030008
# 当前最优结果:0.6526025578105603
# 第72次迭代，局部最优结果为：0.6526025578105604
# 当前最优结果:0.6526025578105603
# 第73次迭代，局部最优结果为：0.5845953922592283
# 当前最优结果:0.6526025578105603
# 第74次迭代，局部最优结果为：0.6268727078610401
# 当前最优结果:0.6526025578105603
# 第75次迭代，局部最优结果为：0.5401101461048657
# 当前最优结果:0.6526025578105603
# 第76次迭代，局部最优结果为：0.5376885019742162
# 当前最优结果:0.6526025578105603
# 第77次迭代，局部最优结果为：0.5847409400139683
# 当前最优结果:0.6526025578105603
# 第78次迭代，局部最优结果为：0.6564115221557582
# 当前最优结果:0.6564115221557582
# 第79次迭代，局部最优结果为：0.6414363543499234
# 当前最优结果:0.6564115221557582
# 第80次迭代，局部最优结果为：0.6097687623491965
# 当前最优结果:0.6564115221557582
# 第81次迭代，局部最优结果为：0.6443893331052865
# 当前最优结果:0.6564115221557582
# 第82次迭代，局部最优结果为：0.5354913596039276
# 当前最优结果:0.6564115221557582
# 第83次迭代，局部最优结果为：0.6172529370405008
# 当前最优结果:0.6564115221557582
# 第84次迭代，局部最优结果为：0.6564115221557582
# 当前最优结果:0.6564115221557582
# 第85次迭代，局部最优结果为：0.6259657187162518
# 当前最优结果:0.6564115221557582
# 第86次迭代，局部最优结果为：0.6271596717923108
# 当前最优结果:0.6564115221557582
# 第87次迭代，局部最优结果为：0.630645836239364
# 当前最优结果:0.6564115221557582
# 第88次迭代，局部最优结果为：0.6279981525789234
# 当前最优结果:0.6564115221557582
# 第89次迭代，局部最优结果为：0.5908853281752359
# 当前最优结果:0.6564115221557582
# 第90次迭代，局部最优结果为：0.570018281535649
# 当前最优结果:0.6564115221557582
# 第91次迭代，局部最优结果为：0.6564115221557582
# 当前最优结果:0.6564115221557582
# 第92次迭代，局部最优结果为：0.6259657187162518
# 当前最优结果:0.6564115221557582
# 第93次迭代，局部最优结果为：0.6271292237696278
# 当前最优结果:0.6564115221557582
# 第94次迭代，局部最优结果为：0.5854830354830355
# 当前最优结果:0.6564115221557582
# 第95次迭代，局部最优结果为：0.651549214584234
# 当前最优结果:0.6564115221557582
# 第96次迭代，局部最优结果为：0.6659890551001318
# 当前最优结果:0.6659890551001318
# 第97次迭代，局部最优结果为：0.6136108387254386
# 当前最优结果:0.6659890551001318
# 第98次迭代，局部最优结果为：0.6391963919639196
# 当前最优结果:0.6659890551001318
# 第99次迭代，局部最优结果为：0.5713870458135861
# 当前最优结果:0.6659890551001318
# 第100次迭代，局部最优结果为：0.598361523597766
# 当前最优结果:0.6659890551001318
# 第101次迭代，局部最优结果为：0.654236307068953
# 当前最优结果:0.6659890551001318
# 第102次迭代，局部最优结果为：0.6504103637527603
# 当前最优结果:0.6659890551001318
# 第103次迭代，局部最优结果为：0.6332738032706517
# 当前最优结果:0.6659890551001318
# 第104次迭代，局部最优结果为：0.5549268460329929
# 当前最优结果:0.6659890551001318
# 第105次迭代，局部最优结果为：0.6492195465184738
# 当前最优结果:0.6659890551001318
# 第106次迭代，局部最优结果为：0.5855455937729686
# 当前最优结果:0.6659890551001318
# 第107次迭代，局部最优结果为：0.6634042553191489
# 当前最优结果:0.6659890551001318
# 第108次迭代，局部最优结果为：0.5843441621806761
# 当前最优结果:0.6659890551001318
# 第109次迭代，局部最优结果为：0.6500877117303655
# 当前最优结果:0.6659890551001318
# 第110次迭代，局部最优结果为：0.654236307068953
# 当前最优结果:0.6659890551001318
# 第111次迭代，局部最优结果为：0.6659890551001318
# 当前最优结果:0.6659890551001318
# 第112次迭代，局部最优结果为：0.603364406157624
# 当前最优结果:0.6659890551001318
# 第113次迭代，局部最优结果为：0.5980291005291005
# 当前最优结果:0.6659890551001318
# 第114次迭代，局部最优结果为：0.6709406465878651
# 当前最优结果:0.6709406465878651
# 第115次迭代，局部最优结果为：0.6159641683271173
# 当前最优结果:0.6709406465878651
# 第116次迭代，局部最优结果为：0.673444156463193
# 当前最优结果:0.673444156463193
# 第117次迭代，局部最优结果为：0.6134630519145703
# 当前最优结果:0.673444156463193
# 第118次迭代，局部最优结果为：0.673444156463193
# 当前最优结果:0.673444156463193
# 第119次迭代，局部最优结果为：0.6066310648346931
# 当前最优结果:0.673444156463193
# 第120次迭代，局部最优结果为：0.6330211002366251
# 当前最优结果:0.673444156463193
# 第121次迭代，局部最优结果为：0.6696958587463292
# 当前最优结果:0.673444156463193
# 第122次迭代，局部最优结果为：0.6116454942706008
# 当前最优结果:0.673444156463193
# 第123次迭代，局部最优结果为：0.6576910767798435
# 当前最优结果:0.673444156463193
# 第124次迭代，局部最优结果为：0.655136936675844
# 当前最优结果:0.673444156463193
# 第125次迭代，局部最优结果为：0.6594081355833321
# 当前最优结果:0.673444156463193
# 第126次迭代，局部最优结果为：0.6223638566158252
# 当前最优结果:0.673444156463193
# 第127次迭代，局部最优结果为：0.6046332795046423
# 当前最优结果:0.673444156463193
# 第128次迭代，局部最优结果为：0.5844990303813833
# 当前最优结果:0.673444156463193
# 第129次迭代，局部最优结果为：0.6563019415714026
# 当前最优结果:0.673444156463193
# 第130次迭代，局部最优结果为：0.6739787494922165
# 当前最优结果:0.6739787494922165
# 第131次迭代，局部最优结果为：0.659937525544462
# 当前最优结果:0.6739787494922165
# 第132次迭代，局部最优结果为：0.6739787494922165
# 当前最优结果:0.6739787494922165
# 第133次迭代，局部最优结果为：0.6739787494922165
# 当前最优结果:0.6739787494922165
# 第134次迭代，局部最优结果为：0.6504805478821363
# 当前最优结果:0.6739787494922165
# 第135次迭代，局部最优结果为：0.6575093439595119
# 当前最优结果:0.6739787494922165
# 第136次迭代，局部最优结果为：0.698045331027668
# 当前最优结果:0.698045331027668
# 第137次迭代，局部最优结果为：0.7193705448065173
# 当前最优结果:0.7193705448065173
# 第138次迭代，局部最优结果为：0.6820595600881031
# 当前最优结果:0.7193705448065173
# 第139次迭代，局部最优结果为：0.6600627783049857
# 当前最优结果:0.7193705448065173
# 第140次迭代，局部最优结果为：0.7055894998868523
# 当前最优结果:0.7193705448065173
# 第141次迭代，局部最优结果为：0.7057712421361558
# 当前最优结果:0.7193705448065173
# 第142次迭代，局部最优结果为：0.6903812970513232
# 当前最优结果:0.7193705448065173
# 第143次迭代，局部最优结果为：0.684517320736434
# 当前最优结果:0.7193705448065173
# 第144次迭代，局部最优结果为：0.6758123283319942
# 当前最优结果:0.7193705448065173
# 第145次迭代，局部最优结果为：0.6939311149312377
# 当前最优结果:0.7193705448065173
# 第146次迭代，局部最优结果为：0.7279006303180571
# 当前最优结果:0.7279006303180571
# 第147次迭代，局部最优结果为：0.6822860074852107
# 当前最优结果:0.7279006303180571
# 第148次迭代，局部最优结果为：0.7279006303180571
# 当前最优结果:0.7279006303180571
# 第149次迭代，局部最优结果为：0.7279006303180571
# 当前最优结果:0.7279006303180571
# 第150次迭代，局部最优结果为：0.7337006353405117
# 当前最优结果:0.7337006353405117
# 第151次迭代，局部最优结果为：0.7176263774637603
# 当前最优结果:0.7337006353405117
# 第152次迭代，局部最优结果为：0.7366354378818737
# 当前最优结果:0.7366354378818737
# 第153次迭代，局部最优结果为：0.7503900414937759
# 当前最优结果:0.750390041493776
# 第154次迭代，局部最优结果为：0.7160210319597099
# 当前最优结果:0.750390041493776
# 第155次迭代，局部最优结果为：0.6533995245218119
# 当前最优结果:0.750390041493776
# 第156次迭代，局部最优结果为：0.7396482617586911
# 当前最优结果:0.750390041493776
# 第157次迭代，局部最优结果为：0.7345231229133327
# 当前最优结果:0.750390041493776
# 第158次迭代，局部最优结果为：0.7306828282828283
# 当前最优结果:0.750390041493776
# 第159次迭代，局部最优结果为：0.7119450109049108
# 当前最优结果:0.750390041493776
# 第160次迭代，局部最优结果为：0.7009457364341085
# 当前最优结果:0.750390041493776
# 第161次迭代，局部最优结果为：0.7156470122675109
# 当前最优结果:0.750390041493776
# 第162次迭代，局部最优结果为：0.6784720085838841
# 当前最优结果:0.750390041493776
# 第163次迭代，局部最优结果为：0.7146571823750247
# 当前最优结果:0.750390041493776
# 第164次迭代，局部最优结果为：0.7263248790087756
# 当前最优结果:0.750390041493776
# 第165次迭代，局部最优结果为：0.7549195588468571
# 当前最优结果:0.7549195588468571
# 第166次迭代，局部最优结果为：0.7380755118948987
# 当前最优结果:0.7549195588468571
# 第167次迭代，局部最优结果为：0.7243147118665791
# 当前最优结果:0.7549195588468571
# 第168次迭代，局部最优结果为：0.7371218482257131
# 当前最优结果:0.7549195588468571
# 第169次迭代，局部最优结果为：0.7426644819245443
# 当前最优结果:0.7549195588468571
# 第170次迭代，局部最优结果为：0.7549195588468571
# 当前最优结果:0.7549195588468571
# 第171次迭代，局部最优结果为：0.7197427386552683
# 当前最优结果:0.7549195588468571
# 第172次迭代，局部最优结果为：0.7340758901751936
# 当前最优结果:0.7549195588468571
# 第173次迭代，局部最优结果为：0.7472892561983471
# 当前最优结果:0.7549195588468571
# 第174次迭代，局部最优结果为：0.7676608172240192
# 当前最优结果:0.7676608172240192
# 第175次迭代，局部最优结果为：0.7413583890856618
# 当前最优结果:0.7676608172240192
# 第176次迭代，局部最优结果为：0.7393942367448402
# 当前最优结果:0.7676608172240192
# 第177次迭代，局部最优结果为：0.71715681609086
# 当前最优结果:0.7676608172240192
# 第178次迭代，局部最优结果为：0.7413583890856618
# 当前最优结果:0.7676608172240192
# 第179次迭代，局部最优结果为：0.7676608172240192
# 当前最优结果:0.7676608172240192
# 第180次迭代，局部最优结果为：0.763054852320675
# 当前最优结果:0.7676608172240192
# 第181次迭代，局部最优结果为：0.7451707542194093
# 当前最优结果:0.7676608172240192
# 第182次迭代，局部最优结果为：0.7413583890856618
# 当前最优结果:0.7676608172240192
# 第183次迭代，局部最优结果为：0.7676608172240192
# 当前最优结果:0.7676608172240192
# 第184次迭代，局部最优结果为：0.7676608172240192
# 当前最优结果:0.7676608172240192
# 第185次迭代，局部最优结果为：0.7676608172240192
# 当前最优结果:0.7676608172240192
# 第186次迭代，局部最优结果为：0.7602064837234329
# 当前最优结果:0.7676608172240192
# 第187次迭代，局部最优结果为：0.7676608172240192
# 当前最优结果:0.7676608172240192
# 第188次迭代，局部最优结果为：0.7554998537828467
# 当前最优结果:0.7676608172240192
# 第189次迭代，局部最优结果为：0.7322983227645634
# 当前最优结果:0.7676608172240192
# 第190次迭代，局部最优结果为：0.7585038293446075
# 当前最优结果:0.7676608172240192
# 第191次迭代，局部最优结果为：0.7554998537828467
# 当前最优结果:0.7676608172240192
# 第192次迭代，局部最优结果为：0.7676608172240192
# 当前最优结果:0.7676608172240192
# 第193次迭代，局部最优结果为：0.7676608172240192
# 当前最优结果:0.7676608172240192
# 第194次迭代，局部最优结果为：0.7676608172240192
# 当前最优结果:0.7676608172240192
# 第195次迭代，局部最优结果为：0.7676608172240192
# 当前最优结果:0.7676608172240192
# 第196次迭代，局部最优结果为：0.7676608172240192
# 当前最优结果:0.7676608172240192
# 第197次迭代，局部最优结果为：0.7709136172970023
# 当前最优结果:0.7709136172970024
# 第198次迭代，局部最优结果为：0.7384281187730704
# 当前最优结果:0.7709136172970024
# 第199次迭代，局部最优结果为：0.7681172962733288
# 当前最优结果:0.7709136172970024
# 第200次迭代，局部最优结果为：0.7681172962733288
# 当前最优结果:0.7709136172970024
# 第201次迭代，局部最优结果为：0.7709136172970023
# 当前最优结果:0.7709136172970024
# 第202次迭代，局部最优结果为：0.7549195588468571
# 当前最优结果:0.7709136172970024
# 第203次迭代，局部最优结果为：0.7676608172240192
# 当前最优结果:0.7709136172970024
# 第204次迭代，局部最优结果为：0.7540067710678608
# 当前最优结果:0.7709136172970024
# 第205次迭代，局部最优结果为：0.7681172962733288
# 当前最优结果:0.7709136172970024
# 第206次迭代，局部最优结果为：0.7585038293446075
# 当前最优结果:0.7709136172970024
# 第207次迭代，局部最优结果为：0.7681172962733288
# 当前最优结果:0.7709136172970024
# 本次退火用时：4151.603736162186
# 第1次迭代，局部最优结果为：0.4902249932230957
# 当前最优结果:0.4902249932230957
# 第2次迭代，局部最优结果为：0.5284128097241702
# 当前最优结果:0.5284128097241702
# 第3次迭代，局部最优结果为：0.49179810725552053
# 当前最优结果:0.5284128097241702
# 第4次迭代，局部最优结果为：0.5004261442249156
# 当前最优结果:0.5284128097241702
# 第5次迭代，局部最优结果为：0.5180885807597547
# 当前最优结果:0.5284128097241702
# 第6次迭代，局部最优结果为：0.5284745762711864
# 当前最优结果:0.5284745762711864
# 第7次迭代，局部最优结果为：0.5472161704187848
# 当前最优结果:0.5472161704187848
# 第8次迭代，局部最优结果为：0.5472161704187848
# 当前最优结果:0.5472161704187848
# 第9次迭代，局部最优结果为：0.5472161704187848
# 当前最优结果:0.5472161704187848
# 第10次迭代，局部最优结果为：0.5539630270634543
# 当前最优结果:0.5539630270634543
# 第11次迭代，局部最优结果为：0.5305101103884865
# 当前最优结果:0.5539630270634543
# 第12次迭代，局部最优结果为：0.5000110595001106
# 当前最优结果:0.5539630270634543
# 第13次迭代，局部最优结果为：0.535618239761163
# 当前最优结果:0.5539630270634543
# 第14次迭代，局部最优结果为：0.5602146140787827
# 当前最优结果:0.5602146140787827
# 第15次迭代，局部最优结果为：0.5602146140787827
# 当前最优结果:0.5602146140787827
# 第16次迭代，局部最优结果为：0.564326280971104
# 当前最优结果:0.564326280971104
# 第17次迭代，局部最优结果为：0.5192861552597953
# 当前最优结果:0.564326280971104
# 第18次迭代，局部最优结果为：0.5633681718353296
# 当前最优结果:0.564326280971104
# 第19次迭代，局部最优结果为：0.5242462894248608
# 当前最优结果:0.564326280971104
# 第20次迭代，局部最优结果为：0.49950006905123606
# 当前最优结果:0.564326280971104
# 第21次迭代，局部最优结果为：0.583810307813988
# 当前最优结果:0.583810307813988
# 第22次迭代，局部最优结果为：0.583810307813988
# 当前最优结果:0.583810307813988
# 第23次迭代，局部最优结果为：0.583810307813988
# 当前最优结果:0.583810307813988
# 第24次迭代，局部最优结果为：0.5495575436378665
# 当前最优结果:0.583810307813988
# 第25次迭代，局部最优结果为：0.5893179522273275
# 当前最优结果:0.5893179522273275
# 第26次迭代，局部最优结果为：0.5293873130177688
# 当前最优结果:0.5893179522273275
# 第27次迭代，局部最优结果为：0.5957595403752899
# 当前最优结果:0.5957595403752899
# 第28次迭代，局部最优结果为：0.5957595403752899
# 当前最优结果:0.5957595403752899
# 第29次迭代，局部最优结果为：0.602732968937475
# 当前最优结果:0.602732968937475
# 第30次迭代，局部最优结果为：0.6173203618364909
# 当前最优结果:0.6173203618364909
# 第31次迭代，局部最优结果为：0.562577771141307
# 当前最优结果:0.6173203618364909
# 第32次迭代，局部最优结果为：0.602403698818137
# 当前最优结果:0.6173203618364909
# 第33次迭代，局部最优结果为：0.4684495192307693
# 当前最优结果:0.6173203618364909
# 第34次迭代，局部最优结果为：0.5498516248297334
# 当前最优结果:0.6173203618364909
# 第35次迭代，局部最优结果为：0.6015860976940375
# 当前最优结果:0.6173203618364909
# 第36次迭代，局部最优结果为：0.5896676752921536
# 当前最优结果:0.6173203618364909
# 第37次迭代，局部最优结果为：0.6173203618364909
# 当前最优结果:0.6173203618364909
# 第38次迭代，局部最优结果为：0.5546936584617744
# 当前最优结果:0.6173203618364909
# 第39次迭代，局部最优结果为：0.6285853319429962
# 当前最优结果:0.6285853319429962
# 第40次迭代，局部最优结果为：0.6285853319429962
# 当前最优结果:0.6285853319429962
# 第41次迭代，局部最优结果为：0.5338568265682657
# 当前最优结果:0.6285853319429962
# 第42次迭代，局部最优结果为：0.5416112608565439
# 当前最优结果:0.6285853319429962
# 第43次迭代，局部最优结果为：0.5679987939243941
# 当前最优结果:0.6285853319429962
# 第44次迭代，局部最优结果为：0.5787378392217102
# 当前最优结果:0.6285853319429962
# 第45次迭代，局部最优结果为：0.6262605274822695
# 当前最优结果:0.6285853319429962
# 第46次迭代，局部最优结果为：0.609146425672239
# 当前最优结果:0.6285853319429962
# 第47次迭代，局部最优结果为：0.6053862247886852
# 当前最优结果:0.6285853319429962
# 第48次迭代，局部最优结果为：0.6015860976940375
# 当前最优结果:0.6285853319429962
# 第49次迭代，局部最优结果为：0.5956810456138502
# 当前最优结果:0.6285853319429962
# 第50次迭代，局部最优结果为：0.4976061283115225
# 当前最优结果:0.6285853319429962
# 第51次迭代，局部最优结果为：0.6346294216732172
# 当前最优结果:0.6346294216732173
# 第52次迭代，局部最优结果为：0.6266250866250866
# 当前最优结果:0.6346294216732173
# 第53次迭代，局部最优结果为：0.6210302197802198
# 当前最优结果:0.6346294216732173
# 第54次迭代，局部最优结果为：0.6334734482275466
# 当前最优结果:0.6346294216732173
# 第55次迭代，局部最优结果为：0.6346294216732172
# 当前最优结果:0.6346294216732173
# 第56次迭代，局部最优结果为：0.6346294216732172
# 当前最优结果:0.6346294216732173
# 第57次迭代，局部最优结果为：0.6467630376161423
# 当前最优结果:0.6467630376161423
# 第58次迭代，局部最优结果为：0.6900783399411592
# 当前最优结果:0.6900783399411592
# 第59次迭代，局部最优结果为：0.7246542901678561
# 当前最优结果:0.7246542901678561
# 第60次迭代，局部最优结果为：0.7246542901678561
# 当前最优结果:0.7246542901678561
# 第61次迭代，局部最优结果为：0.7040758721914869
# 当前最优结果:0.7246542901678561
# 第62次迭代，局部最优结果为：0.7030631008891118
# 当前最优结果:0.7246542901678561
# 第63次迭代，局部最优结果为：0.7246542901678561
# 当前最优结果:0.7246542901678561
# 第64次迭代，局部最优结果为：0.7246542901678561
# 当前最优结果:0.7246542901678561
# 第65次迭代，局部最优结果为：0.7246542901678561
# 当前最优结果:0.7246542901678561
# 第66次迭代，局部最优结果为：0.587201600124685
# 当前最优结果:0.7246542901678561
# 第67次迭代，局部最优结果为：0.7164039566934592
# 当前最优结果:0.7246542901678561
# 第68次迭代，局部最优结果为：0.6780192258664387
# 当前最优结果:0.7246542901678561
# 第69次迭代，局部最优结果为：0.7246542901678561
# 当前最优结果:0.7246542901678561
# 第70次迭代，局部最优结果为：0.6528475711892797
# 当前最优结果:0.7246542901678561
# 第71次迭代，局部最优结果为：0.676603736877156
# 当前最优结果:0.7246542901678561
# 第72次迭代，局部最优结果为：0.7127503182554478
# 当前最优结果:0.7246542901678561
# 第73次迭代，局部最优结果为：0.6148646810825513
# 当前最优结果:0.7246542901678561
# 第74次迭代，局部最优结果为：0.7218831456547858
# 当前最优结果:0.7246542901678561
# 第75次迭代，局部最优结果为：0.7246542901678561
# 当前最优结果:0.7246542901678561
# 第76次迭代，局部最优结果为：0.7232660635583391
# 当前最优结果:0.7246542901678561
# 第77次迭代，局部最优结果为：0.6176640356299973
# 当前最优结果:0.7246542901678561
# 第78次迭代，局部最优结果为：0.6612381304091878
# 当前最优结果:0.7246542901678561
# 第79次迭代，局部最优结果为：0.6998173487709739
# 当前最优结果:0.7246542901678561
# 第80次迭代，局部最优结果为：0.6940163330467887
# 当前最优结果:0.7246542901678561
# 第81次迭代，局部最优结果为：0.7246542901678561
# 当前最优结果:0.7246542901678561
# 第82次迭代，局部最优结果为：0.6334113229751881
# 当前最优结果:0.7246542901678561
# 第83次迭代，局部最优结果为：0.7246542901678561
# 当前最优结果:0.7246542901678561
# 第84次迭代，局部最优结果为：0.733846522178442
# 当前最优结果:0.733846522178442
# 第85次迭代，局部最优结果为：0.7028199228951623
# 当前最优结果:0.733846522178442
# 第86次迭代，局部最优结果为：0.6984092655742516
# 当前最优结果:0.733846522178442
# 第87次迭代，局部最优结果为：0.6942188099808061
# 当前最优结果:0.733846522178442
# 第88次迭代，局部最优结果为：0.733846522178442
# 当前最优结果:0.733846522178442
# 第89次迭代，局部最优结果为：0.7385306489157512
# 当前最优结果:0.7385306489157513
# 第90次迭代，局部最优结果为：0.6339397763522276
# 当前最优结果:0.7385306489157513
# 第97次迭代，局部最优结果为：0.7385306489157512
# 当前最优结果:0.7385306489157513
# 第98次迭代，局部最优结果为：0.6983202687569989
# 当前最优结果:0.7385306489157513
# 第99次迭代，局部最优结果为：0.734302420009745
# 当前最优结果:0.7385306489157513
# 第100次迭代，局部最优结果为：0.7385306489157512
# 当前最优结果:0.7385306489157513
# 第101次迭代，局部最优结果为：0.698895102354719
# 当前最优结果:0.7385306489157513
# 第102次迭代，局部最优结果为：0.7034268155120775
# 当前最优结果:0.7385306489157513
# 第103次迭代，局部最优结果为：0.5944377060550181
# 当前最优结果:0.7385306489157513
# 第104次迭代，局部最优结果为：0.7385306489157512
# 当前最优结果:0.7385306489157513
# 第105次迭代，局部最优结果为：0.5578041189733719
# 当前最优结果:0.7385306489157513
# 第106次迭代，局部最优结果为：0.7385306489157512
# 当前最优结果:0.7385306489157513
# 第107次迭代，局部最优结果为：0.7369626432917262
# 当前最优结果:0.7385306489157513
# 第108次迭代，局部最优结果为：0.7142168826963026
# 当前最优结果:0.7385306489157513
# 第109次迭代，局部最优结果为：0.6928331436934193
# 当前最优结果:0.7385306489157513
# 第110次迭代，局部最优结果为：0.6991680069281208
# 当前最优结果:0.7385306489157513
# 第111次迭代，局部最优结果为：0.5937487687963754
# 当前最优结果:0.7385306489157513
# 第112次迭代，局部最优结果为：0.6945067436787612
# 当前最优结果:0.7385306489157513
# 第113次迭代，局部最优结果为：0.7385306489157512
# 当前最优结果:0.7385306489157513
# 第114次迭代，局部最优结果为：0.6907979678368158
# 当前最优结果:0.7385306489157513
# 第115次迭代，局部最优结果为：0.720143993756023
# 当前最优结果:0.7385306489157513
# 第116次迭代，局部最优结果为：0.6900783399411592
# 当前最优结果:0.7385306489157513
# 第117次迭代，局部最优结果为：0.7300781171151167
# 当前最优结果:0.7385306489157513
# 第118次迭代，局部最优结果为：0.6180989196154227
# 当前最优结果:0.7385306489157513
# 第119次迭代，局部最优结果为：0.7385306489157512
# 当前最优结果:0.7385306489157513
# 第120次迭代，局部最优结果为：0.7385306489157512
# 当前最优结果:0.7385306489157513
# 第121次迭代，局部最优结果为：0.7385306489157512
# 当前最优结果:0.7385306489157513
# 第122次迭代，局部最优结果为：0.7300781171151167
# 当前最优结果:0.7385306489157513
# 第123次迭代，局部最优结果为：0.7385306489157512
# 当前最优结果:0.7385306489157513
# 第124次迭代，局部最优结果为：0.6534349379785301
# 当前最优结果:0.7385306489157513
# 第125次迭代，局部最优结果为：0.6945387510561487
# 当前最优结果:0.7385306489157513
# 第126次迭代，局部最优结果为：0.7307566420850591
# 当前最优结果:0.7385306489157513
# 第127次迭代，局部最优结果为：0.6534349379785301
# 当前最优结果:0.7385306489157513
# 第128次迭代，局部最优结果为：0.7385306489157512
# 当前最优结果:0.7385306489157513
# 第129次迭代，局部最优结果为：0.734302420009745
# 当前最优结果:0.7385306489157513
# 第130次迭代，局部最优结果为：0.6545867840389181
# 当前最优结果:0.7385306489157513
# 第131次迭代，局部最优结果为：0.733242511231126
# 当前最优结果:0.7385306489157513
# 第132次迭代，局部最优结果为：0.6499545358160731
# 当前最优结果:0.7385306489157513
# 第133次迭代，局部最优结果为：0.6427951944266724
# 当前最优结果:0.7385306489157513
# 第134次迭代，局部最优结果为：0.6914529979888507
# 当前最优结果:0.7385306489157513
# 第135次迭代，局部最优结果为：0.7075938272764266
# 当前最优结果:0.7385306489157513
# 第136次迭代，局部最优结果为：0.6928331436934193
# 当前最优结果:0.7385306489157513
# 第137次迭代，局部最优结果为：0.7091254156471547
# 当前最优结果:0.7385306489157513
# 第138次迭代，局部最优结果为：0.656161446106622
# 当前最优结果:0.7385306489157513
# 第139次迭代，局部最优结果为：0.7069437983511264
# 当前最优结果:0.7385306489157513
# 第140次迭代，局部最优结果为：0.7385306489157512
# 当前最优结果:0.7385306489157513
# 第141次迭代，局部最优结果为：0.7137602222853715
# 当前最优结果:0.7385306489157513
# 第142次迭代，局部最优结果为：0.7059751251161375
# 当前最优结果:0.7385306489157513
# 第143次迭代，局部最优结果为：0.7059751251161375
# 当前最优结果:0.7385306489157513
# 第144次迭代，局部最优结果为：0.7219811324521025
# 当前最优结果:0.7385306489157513
# 第145次迭代，局部最优结果为：0.6992112588926693
# 当前最优结果:0.7385306489157513
# 第146次迭代，局部最优结果为：0.7385306489157512
# 当前最优结果:0.7385306489157513
# 第147次迭代，局部最优结果为：0.6876511475808782
# 当前最优结果:0.7385306489157513
# 第148次迭代，局部最优结果为：0.6992112588926693
# 当前最优结果:0.7385306489157513
# 第149次迭代，局部最优结果为：0.7300781171151167
# 当前最优结果:0.7385306489157513
# 第150次迭代，局部最优结果为：0.7141435521577051
# 当前最优结果:0.7385306489157513
# 第151次迭代，局部最优结果为：0.658860390556689
# 当前最优结果:0.7385306489157513
# 第152次迭代，局部最优结果为：0.7385306489157512
# 当前最优结果:0.7385306489157513
# 第153次迭代，局部最优结果为：0.7385306489157512
# 当前最优结果:0.7385306489157513
# 第154次迭代，局部最优结果为：0.7385306489157512
# 当前最优结果:0.7385306489157513
# 第155次迭代，局部最优结果为：0.7012311211927335
# 当前最优结果:0.7385306489157513
# 第156次迭代，局部最优结果为：0.6932474651639737
# 当前最优结果:0.7385306489157513
# 第157次迭代，局部最优结果为：0.6900783399411592
# 当前最优结果:0.7385306489157513
# 第158次迭代，局部最优结果为：0.7385306489157512
# 当前最优结果:0.7385306489157513
# 第159次迭代，局部最优结果为：0.7216411746162226
# 当前最优结果:0.7385306489157513
# 第160次迭代，局部最优结果为：0.7083865407967409
# 当前最优结果:0.7385306489157513
# 第161次迭代，局部最优结果为：0.7385306489157512
# 当前最优结果:0.7385306489157513
# 第162次迭代，局部最优结果为：0.6800691937424789
# 当前最优结果:0.7385306489157513
# 第163次迭代，局部最优结果为：0.7035636476812948
# 当前最优结果:0.7385306489157513
# 第164次迭代，局部最优结果为：0.7007420323549356
# 当前最优结果:0.7385306489157513
# 第165次迭代，局部最优结果为：0.7397571830617188
# 当前最优结果:0.7397571830617187
# 第166次迭代，局部最优结果为：0.7359968744022498
# 当前最优结果:0.7397571830617187
# 第167次迭代，局部最优结果为：0.7035636476812948
# 当前最优结果:0.7397571830617187
# 第168次迭代，局部最优结果为：0.7179996188540211
# 当前最优结果:0.7397571830617187
# 第169次迭代，局部最优结果为：0.7429665417734832
# 当前最优结果:0.7429665417734832
# 第170次迭代，局部最优结果为：0.7310402257265167
# 当前最优结果:0.7429665417734832
# 第171次迭代，局部最优结果为：0.7318537943537943
# 当前最优结果:0.7429665417734832
# 第172次迭代，局部最优结果为：0.7429665417734832
# 当前最优结果:0.7429665417734832
# 第173次迭代，局部最优结果为：0.7429665417734832
# 当前最优结果:0.7429665417734832
# 第174次迭代，局部最优结果为：0.7429665417734832
# 当前最优结果:0.7429665417734832
# 第175次迭代，局部最优结果为：0.7429665417734832
# 当前最优结果:0.7429665417734832
# 第176次迭代，局部最优结果为：0.7080980759140778
# 当前最优结果:0.7429665417734832
# 第177次迭代，局部最优结果为：0.736575431736722
# 当前最优结果:0.7429665417734832
# 第178次迭代，局部最优结果为：0.7429665417734832
# 当前最优结果:0.7429665417734832
# 第179次迭代，局部最优结果为：0.7429665417734832
# 当前最优结果:0.7429665417734832
# 第180次迭代，局部最优结果为：0.7429665417734832
# 当前最优结果:0.7429665417734832
# ...
# 当前最优结果:0.6842634984297552
# 第151次迭代，局部最优结果为：0.6729429626101453
# 当前最优结果:0.6842634984297552
# 第152次迭代，局部最优结果为：0.6701127575767681
# 当前最优结果:0.6842634984297552
# 第153次迭代，局部最优结果为：0.6812168514946962
# 当前最优结果:0.6842634984297552
# 第154次迭代，局部最优结果为：0.6842634984297552
# 当前最优结果:0.6842634984297552
# 第155次迭代，局部最优结果为：0.6842634984297552
# 当前最优结果:0.6842634984297552
# 第156次迭代，局部最优结果为：0.6842634984297552
# 当前最优结果:0.6842634984297552
# 第157次迭代，局部最优结果为：0.6594562268444236
# 当前最优结果:0.6842634984297552
# 第158次迭代，局部最优结果为：0.6733589008452173
# 当前最优结果:0.6842634984297552
# 第159次迭代，局部最优结果为：0.696961171596493
# 当前最优结果:0.696961171596493
# 第160次迭代，局部最优结果为：0.696961171596493
# 当前最优结果:0.696961171596493
# 第161次迭代，局部最优结果为：0.696961171596493
# 当前最优结果:0.696961171596493
# 第162次迭代，局部最优结果为：0.6801331352601591
# 当前最优结果:0.696961171596493
# 第163次迭代，局部最优结果为：0.696961171596493
# 当前最优结果:0.696961171596493
# 第164次迭代，局部最优结果为：0.6842634984297552
# 当前最优结果:0.696961171596493
# 第165次迭代，局部最优结果为：0.728959832315537
# 当前最优结果:0.728959832315537
# 第166次迭代，局部最优结果为：0.7002644713863644
# 当前最优结果:0.728959832315537
# 第167次迭代，局部最优结果为：0.698768179780838
# 当前最优结果:0.728959832315537
# 第168次迭代，局部最优结果为：0.709222750785328
# 当前最优结果:0.728959832315537
# 第169次迭代，局部最优结果为：0.714953843720967
# 当前最优结果:0.728959832315537
# 第170次迭代，局部最优结果为：0.7109206698639831
# 当前最优结果:0.728959832315537
# 第171次迭代，局部最优结果为：0.696961171596493
# 当前最优结果:0.728959832315537
# 第172次迭代，局部最优结果为：0.728959832315537
# 当前最优结果:0.728959832315537
# 第173次迭代，局部最优结果为：0.7354521238740113
# 当前最优结果:0.7354521238740113
# 第174次迭代，局部最优结果为：0.7369055865694144
# 当前最优结果:0.7369055865694144
# 第175次迭代，局部最优结果为：0.7369055865694144
# 当前最优结果:0.7369055865694144
# 第176次迭代，局部最优结果为：0.7414921358634149
# 当前最优结果:0.741492135863415
# 第177次迭代，局部最优结果为：0.7342368312072172
# 当前最优结果:0.741492135863415
# 第178次迭代，局部最优结果为：0.6810680525740971
# 当前最优结果:0.741492135863415
# 第179次迭代，局部最优结果为：0.7039306205382514
# 当前最优结果:0.741492135863415
# 第180次迭代，局部最优结果为：0.7372961513372472
# 当前最优结果:0.741492135863415
# 第181次迭代，局部最优结果为：0.7243147118665791
# 当前最优结果:0.741492135863415
# 第182次迭代，局部最优结果为：0.7308777290105645
# 当前最优结果:0.741492135863415
# 第183次迭代，局部最优结果为：0.7308777290105645
# 当前最优结果:0.741492135863415
# 第184次迭代，局部最优结果为：0.73256233163875
# 当前最优结果:0.741492135863415
# 第185次迭代，局部最优结果为：0.7421524571663076
# 当前最优结果:0.7421524571663076
# 第186次迭代，局部最优结果为：0.7308777290105645
# 当前最优结果:0.7421524571663076
# 第187次迭代，局部最优结果为：0.7340758901751936
# 当前最优结果:0.7421524571663076
# 第188次迭代，局部最优结果为：0.7209047385562292
# 当前最优结果:0.7421524571663076
# 第189次迭代，局部最优结果为：0.7308777290105645
# 当前最优结果:0.7421524571663076
# 第190次迭代，局部最优结果为：0.7431130834976989
# 当前最优结果:0.7431130834976989
# 第191次迭代，局部最优结果为：0.7431130834976989
# 当前最优结果:0.7431130834976989
# 第192次迭代，局部最优结果为：0.7231445937300064
# 当前最优结果:0.7431130834976989
# 第193次迭代，局部最优结果为：0.7431130834976989
# 当前最优结果:0.7431130834976989
# 第194次迭代，局部最优结果为：0.7150018977732794
# 当前最优结果:0.7431130834976989
# 第195次迭代，局部最优结果为：0.7502499533282166
# 当前最优结果:0.7502499533282168
# 第196次迭代，局部最优结果为：0.7477867506895084
# 当前最优结果:0.7502499533282168
# 第197次迭代，局部最优结果为：0.7266313082610094
# 当前最优结果:0.7502499533282168
# 第198次迭代，局部最优结果为：0.7611792039868004
# 当前最优结果:0.7611792039868005
# 第199次迭代，局部最优结果为：0.759647656292662
# 当前最优结果:0.7611792039868005
# 第200次迭代，局部最优结果为：0.755089770354906
# 当前最优结果:0.7611792039868005
# 第201次迭代，局部最优结果为：0.7477867506895084
# 当前最优结果:0.7611792039868005
# 第202次迭代，局部最优结果为：0.7692085204845515
# 当前最优结果:0.7692085204845516
# 第203次迭代，局部最优结果为：0.7741079378124787
# 当前最优结果:0.7741079378124786
# 第204次迭代，局部最优结果为：0.7708347541430813
# 当前最优结果:0.7741079378124786
# 第205次迭代，局部最优结果为：0.7708347541430813
# 当前最优结果:0.7741079378124786
# 第206次迭代，局部最优结果为：0.7741079378124787
# 当前最优结果:0.7741079378124786
# 第207次迭代，局部最优结果为：0.7692085204845515
# 当前最优结果:0.7741079378124786
# 本次退火用时：4120.5319101810455
# 第1次迭代，局部最优结果为：0.5847674110289791
# 当前最优结果:0.584767411028979
# 第2次迭代，局部最优结果为：0.5546936584617744
# 当前最优结果:0.584767411028979
# 第3次迭代，局部最优结果为：0.5437805200740901
# 当前最优结果:0.584767411028979
# 第4次迭代，局部最优结果为：0.5314127202416634
# 当前最优结果:0.584767411028979
# 第5次迭代，局部最优结果为：0.56589438373825
# 当前最优结果:0.584767411028979
# 第6次迭代，局部最优结果为：0.5982388006377897
# 当前最优结果:0.5982388006377897
# 第7次迭代，局部最优结果为：0.5982388006377897
# 当前最优结果:0.5982388006377897
# 第8次迭代，局部最优结果为：0.5394592401680031
# 当前最优结果:0.5982388006377897
# 第9次迭代，局部最优结果为：0.6057755758994818
# 当前最优结果:0.6057755758994818
# 第10次迭代，局部最优结果为：0.5307483256733991
# 当前最优结果:0.6057755758994818
# 第11次迭代，局部最优结果为：0.6057755758994818
# 当前最优结果:0.6057755758994818
# 第12次迭代，局部最优结果为：0.6000172529346578
# 当前最优结果:0.6057755758994818
# 第13次迭代，局部最优结果为：0.6011601429402477
# 当前最优结果:0.6057755758994818
# 第14次迭代，局部最优结果为：0.6057755758994818
# 当前最优结果:0.6057755758994818
# 第15次迭代，局部最优结果为：0.6057755758994818
# 当前最优结果:0.6057755758994818
# 第16次迭代，局部最优结果为：0.5095417212572024
# 当前最优结果:0.6057755758994818
# 第17次迭代，局部最优结果为：0.5726300057312397
# 当前最优结果:0.6057755758994818
# 第18次迭代，局部最优结果为：0.5780385989810073
# 当前最优结果:0.6057755758994818
# 第19次迭代，局部最优结果为：0.6057755758994818
# 当前最优结果:0.6057755758994818
# 第20次迭代，局部最优结果为：0.6007707129094412
# 当前最优结果:0.6057755758994818
# 第21次迭代，局部最优结果为：0.565324763828018
# 当前最优结果:0.6057755758994818
# 第22次迭代，局部最优结果为：0.5140753585286468
# 当前最优结果:0.6057755758994818
# 第23次迭代，局部最优结果为：0.6068346241090963
# 当前最优结果:0.6068346241090963
# 第24次迭代，局部最优结果为：0.564572927072927
# 当前最优结果:0.6068346241090963
# 第25次迭代，局部最优结果为：0.48453768453768453
# 当前最优结果:0.6068346241090963
# 第26次迭代，局部最优结果为：0.5595386167164808
# 当前最优结果:0.6068346241090963
# 第27次迭代，局部最优结果为：0.5465612495315465
# 当前最优结果:0.6068346241090963
# 第28次迭代，局部最优结果为：0.5748378893833439
# 当前最优结果:0.6068346241090963
# 第29次迭代，局部最优结果为：0.5829502743196807
# 当前最优结果:0.6068346241090963
# 第30次迭代，局部最优结果为：0.6042353004069577
# 当前最优结果:0.6068346241090963
# 第31次迭代，局部最优结果为：0.5385627922213289
# 当前最优结果:0.6068346241090963
# 第32次迭代，局部最优结果为：0.5898523118672373
# 当前最优结果:0.6068346241090963
# 第33次迭代，局部最优结果为：0.6068346241090963
# 当前最优结果:0.6068346241090963
# 第34次迭代，局部最优结果为：0.5602632100723703
# 当前最优结果:0.6068346241090963
# 第35次迭代，局部最优结果为：0.5697668557025835
# 当前最优结果:0.6068346241090963
# 第36次迭代，局部最优结果为：0.6068346241090963
# 当前最优结果:0.6068346241090963
# 第37次迭代，局部最优结果为：0.5748378893833439
# 当前最优结果:0.6068346241090963
# 第38次迭代，局部最优结果为：0.5999256910072849
# 当前最优结果:0.6068346241090963
# 第39次迭代，局部最优结果为：0.5469910712125245
# 当前最优结果:0.6068346241090963
# 第40次迭代，局部最优结果为：0.49855817210407627
# 当前最优结果:0.6068346241090963
# 第41次迭代，局部最优结果为：0.5863334543756809
# 当前最优结果:0.6068346241090963
# 第42次迭代，局部最优结果为：0.6100341036738192
# 当前最优结果:0.610034103673819
# 第43次迭代，局部最优结果为：0.5421714559817722
# 当前最优结果:0.610034103673819
# 第44次迭代，局部最优结果为：0.5985457024746889
# 当前最优结果:0.610034103673819
# 第45次迭代，局部最优结果为：0.5952496938896422
# 当前最优结果:0.610034103673819
# 第46次迭代，局部最优结果为：0.5863334543756809
# 当前最优结果:0.610034103673819
# 第47次迭代，局部最优结果为：0.5695443494035096
# 当前最优结果:0.610034103673819
# 第48次迭代，局部最优结果为：0.575774942054456
# 当前最优结果:0.610034103673819
# 第49次迭代，局部最优结果为：0.5047490126575213
# 当前最优结果:0.610034103673819
# 第50次迭代，局部最优结果为：0.4942889082644786
# 当前最优结果:0.610034103673819
# 第51次迭代，局部最优结果为：0.6100341036738192
# 当前最优结果:0.610034103673819
# 第52次迭代，局部最优结果为：0.6085949856974592
# 当前最优结果:0.610034103673819
# 第53次迭代，局部最优结果为：0.6100341036738192
# 当前最优结果:0.610034103673819
# 第54次迭代，局部最优结果为：0.5589523429797151
# 当前最优结果:0.610034103673819
# 第55次迭代，局部最优结果为：0.5784712626029991
# 当前最优结果:0.610034103673819
# 第56次迭代，局部最优结果为：0.5565252714247028
# 当前最优结果:0.610034103673819
# 第57次迭代，局部最优结果为：0.529415208787091
# 当前最优结果:0.610034103673819
# 第58次迭代，局部最优结果为：0.5160542866600464
# 当前最优结果:0.610034103673819
# 第59次迭代，局部最优结果为：0.529663300452213
# 当前最优结果:0.610034103673819
# 第60次迭代，局部最优结果为：0.5299380228861116
# 当前最优结果:0.610034103673819
# 第61次迭代，局部最优结果为：0.4961862221100344
# 当前最优结果:0.610034103673819
# 第62次迭代，局部最优结果为：0.5777800497127777
# 当前最优结果:0.610034103673819
# 第63次迭代，局部最优结果为：0.5898523118672373
# 当前最优结果:0.610034103673819
# 第64次迭代，局部最优结果为：0.6244160471788993
# 当前最优结果:0.6244160471788993
# 第65次迭代，局部最优结果为：0.561066262929617
# 当前最优结果:0.6244160471788993
# 第66次迭代，局部最优结果为：0.6244160471788993
# 当前最优结果:0.6244160471788993
# 第67次迭代，局部最优结果为：0.615945286848953
# 当前最优结果:0.6244160471788993
# 第68次迭代，局部最优结果为：0.5963725102229258
# 当前最优结果:0.6244160471788993
# 第69次迭代，局部最优结果为：0.6032134649317381
# 当前最优结果:0.6244160471788993
# 第70次迭代，局部最优结果为：0.560541063281095
# 当前最优结果:0.6244160471788993
# 第71次迭代，局部最优结果为：0.6244160471788993
# 当前最优结果:0.6244160471788993
# 第72次迭代，局部最优结果为：0.5148598287824308
# 当前最优结果:0.6244160471788993
# 第73次迭代，局部最优结果为：0.5513872797121776
# 当前最优结果:0.6244160471788993
# 第74次迭代，局部最优结果为：0.6244160471788993
# 当前最优结果:0.6244160471788993
# 第75次迭代，局部最优结果为：0.5370290631894972
# 当前最优结果:0.6244160471788993
# 第76次迭代，局部最优结果为：0.5951830861686512
# 当前最优结果:0.6244160471788993
# 第77次迭代，局部最优结果为：0.5595161115666042
# 当前最优结果:0.6244160471788993
# 第78次迭代，局部最优结果为：0.59513020242009
# 当前最优结果:0.6244160471788993
# 第79次迭代，局部最优结果为：0.6100341036738192
# 当前最优结果:0.6244160471788993
# 第80次迭代，局部最优结果为：0.6244160471788993
# 当前最优结果:0.6244160471788993
# 第81次迭代，局部最优结果为：0.5665379108985023
# 当前最优结果:0.6244160471788993
# 第82次迭代，局部最优结果为：0.5821021392198896
# 当前最优结果:0.6244160471788993
# 第83次迭代，局部最优结果为：0.625645212626102
# 当前最优结果:0.6256452126261018
# 第84次迭代，局部最优结果为：0.4967805028129395
# 当前最优结果:0.6256452126261018
# 第85次迭代，局部最优结果为：0.6033764847190711
# 当前最优结果:0.6256452126261018
# 第86次迭代，局部最优结果为：0.615903332152685
# 当前最优结果:0.6256452126261018
# 第87次迭代，局部最优结果为：0.5864779670251268
# 当前最优结果:0.6256452126261018
# 第88次迭代，局部最优结果为：0.6289613533290671
# 当前最优结果:0.6289613533290671
# 第89次迭代，局部最优结果为：0.5462789271614
# 当前最优结果:0.6289613533290671
# 第90次迭代，局部最优结果为：0.6028535235682378
# 当前最优结果:0.6289613533290671
# 第91次迭代，局部最优结果为：0.5949950977489126
# 当前最优结果:0.6289613533290671
# 第92次迭代，局部最优结果为：0.5866111338172996
# 当前最优结果:0.6289613533290671
# 第93次迭代，局部最优结果为：0.5444484585741811
# 当前最优结果:0.6289613533290671
# 第94次迭代，局部最优结果为：0.5685702428411534
# 当前最优结果:0.6289613533290671
# 第95次迭代，局部最优结果为：0.5625830214681462
# 当前最优结果:0.6289613533290671
# 第96次迭代，局部最优结果为：0.6289613533290671
# 当前最优结果:0.6289613533290671
# 第97次迭代，局部最优结果为：0.6234538108305638
# 当前最优结果:0.6289613533290671
# 第98次迭代，局部最优结果为：0.625645212626102
# 当前最优结果:0.6289613533290671
# 第99次迭代，局部最优结果为：0.6323128347855275
# 当前最优结果:0.6323128347855275
# 第100次迭代，局部最优结果为：0.6153542530096704
# 当前最优结果:0.6323128347855275
# 第101次迭代，局部最优结果为：0.6323128347855275
# 当前最优结果:0.6323128347855275
# 第102次迭代，局部最优结果为：0.5792105052446153
# 当前最优结果:0.6323128347855275
# 第103次迭代，局部最优结果为：0.6040697985142429
# 当前最优结果:0.6323128347855275
# 第104次迭代，局部最优结果为：0.615903332152685
# 当前最优结果:0.6323128347855275
# 第105次迭代，局部最优结果为：0.5943107278535091
# 当前最优结果:0.6323128347855275
# 第106次迭代，局部最优结果为：0.6539145778793445
# 当前最优结果:0.6539145778793445
# 第107次迭代，局部最优结果为：0.6040133064354518
# 当前最优结果:0.6539145778793445
# 第108次迭代，局部最优结果为：0.5546936584617744
# 当前最优结果:0.6539145778793445
# 第109次迭代，局部最优结果为：0.67549678768863
# 当前最优结果:0.6754967876886299
# 第110次迭代，局部最优结果为：0.6036342759486235
# 当前最优结果:0.6754967876886299
# 第111次迭代，局部最优结果为：0.6259787191327042
# 当前最优结果:0.6754967876886299
# 第112次迭代，局部最优结果为：0.5936785986290937
# 当前最优结果:0.6754967876886299
# 第113次迭代，局部最优结果为：0.6165248459062892
# 当前最优结果:0.6754967876886299
# 第114次迭代，局部最优结果为：0.6665339820138582
# 当前最优结果:0.6754967876886299
# 第115次迭代，局部最优结果为：0.6573181547229613
# 当前最优结果:0.6754967876886299
# 第116次迭代，局部最优结果为：0.67549678768863
# 当前最优结果:0.6754967876886299
# 第117次迭代，局部最优结果为：0.67549678768863
# 当前最优结果:0.6754967876886299
# 第118次迭代，局部最优结果为：0.67549678768863
# 当前最优结果:0.6754967876886299
# 第119次迭代，局部最优结果为：0.6423842000568343
# 当前最优结果:0.6754967876886299
# 第120次迭代，局部最优结果为：0.6466104118993136
# 当前最优结果:0.6754967876886299
# 第121次迭代，局部最优结果为：0.6937687258553951
# 当前最优结果:0.6937687258553952
# 第122次迭代，局部最优结果为：0.657547595153948
# 当前最优结果:0.6937687258553952
# 第123次迭代，局部最优结果为：0.6781107511399088
# 当前最优结果:0.6937687258553952
# 第124次迭代，局部最优结果为：0.6781107511399088
# 当前最优结果:0.6937687258553952
# 第125次迭代，局部最优结果为：0.6781107511399088
# 当前最优结果:0.6937687258553952
# 第126次迭代，局部最优结果为：0.6109573954142047
# 当前最优结果:0.6937687258553952
# 第127次迭代，局部最优结果为：0.6285285306159332
# 当前最优结果:0.6937687258553952
# 第128次迭代，局部最优结果为：0.6937687258553951
# 当前最优结果:0.6937687258553952
# 第129次迭代，局部最优结果为：0.6603495934068744
# 当前最优结果:0.6937687258553952
# 第130次迭代，局部最优结果为：0.6711199186539304
# 当前最优结果:0.6937687258553952
# 第131次迭代，局部最优结果为：0.6757390966430514
# 当前最优结果:0.6937687258553952
# 第132次迭代，局部最优结果为：0.6711199186539304
# 当前最优结果:0.6937687258553952
# 第133次迭代，局部最优结果为：0.6937687258553951
# 当前最优结果:0.6937687258553952
# 第134次迭代，局部最优结果为：0.6204975124378109
# 当前最优结果:0.6937687258553952
# 第135次迭代，局部最优结果为：0.6154673418824362
# 当前最优结果:0.6937687258553952
# 第136次迭代，局部最优结果为：0.6937687258553951
# 当前最优结果:0.6937687258553952
# 第137次迭代，局部最优结果为：0.6824688189897542
# 当前最优结果:0.6937687258553952
# 第138次迭代，局部最优结果为：0.6903654840162776
# 当前最优结果:0.6937687258553952
# 第139次迭代，局部最优结果为：0.67459722393193
# 当前最优结果:0.6937687258553952
# 第140次迭代，局部最优结果为：0.6520072828222739
# 当前最优结果:0.6937687258553952
# 第141次迭代，局部最优结果为：0.6907847743463397
# 当前最优结果:0.6937687258553952
# 第142次迭代，局部最优结果为：0.647128707202565
# 当前最优结果:0.6937687258553952
# 第143次迭代，局部最优结果为：0.6633336879055419
# 当前最优结果:0.6937687258553952
# 第144次迭代，局部最优结果为：0.6409975578547402
# 当前最优结果:0.6937687258553952
# 第145次迭代，局部最优结果为：0.6409975578547402
# 当前最优结果:0.6937687258553952
# 第146次迭代，局部最优结果为：0.6937687258553951
# 当前最优结果:0.6937687258553952
# 第147次迭代，局部最优结果为：0.6937687258553951
# 当前最优结果:0.6937687258553952
# 第148次迭代，局部最优结果为：0.6937687258553951
# 当前最优结果:0.6937687258553952
# 第149次迭代，局部最优结果为：0.6937687258553951
# 当前最优结果:0.6937687258553952
# 第150次迭代，局部最优结果为：0.6677744298712041
# 当前最优结果:0.6937687258553952
# 第151次迭代，局部最优结果为：0.6925386394620345
# 当前最优结果:0.6937687258553952
# 第152次迭代，局部最优结果为：0.6773335730390945
# 当前最优结果:0.6937687258553952
# 第153次迭代，局部最优结果为：0.6691234691234691
# 当前最优结果:0.6937687258553952
# 第154次迭代，局部最优结果为：0.6848932197676929
# 当前最优结果:0.6937687258553952
# 第155次迭代，局部最优结果为：0.6773335730390945
# 当前最优结果:0.6937687258553952
# 第156次迭代，局部最优结果为：0.6861301129486932
# 当前最优结果:0.6937687258553952
# 第157次迭代，局部最优结果为：0.7050393369252481
# 当前最优结果:0.7050393369252481
# 第158次迭代，局部最优结果为：0.6753076046976232
# 当前最优结果:0.7050393369252481
# 第159次迭代，局部最优结果为：0.6861301129486932
# 当前最优结果:0.7050393369252481
# 第160次迭代，局部最优结果为：0.7050393369252481
# 当前最优结果:0.7050393369252481
# 第161次迭代，局部最优结果为：0.6932182339502292
# 当前最优结果:0.7050393369252481
# 第162次迭代，局部最优结果为：0.7050393369252481
# 当前最优结果:0.7050393369252481
# 第163次迭代，局部最优结果为：0.7050393369252481
# 当前最优结果:0.7050393369252481
# 第164次迭代，局部最优结果为：0.6804735063703614
# 当前最优结果:0.7050393369252481
# 第165次迭代，局部最优结果为：0.6773335730390945
# 当前最优结果:0.7050393369252481
# 第166次迭代，局部最优结果为：0.7050393369252481
# 当前最优结果:0.7050393369252481
# 第167次迭代，局部最优结果为：0.7050393369252481
# 当前最优结果:0.7050393369252481
# 第168次迭代，局部最优结果为：0.6799157831415895
# 当前最优结果:0.7050393369252481
# 第169次迭代，局部最优结果为：0.6616300383052051
# 当前最优结果:0.7050393369252481
# 第170次迭代，局部最优结果为：0.6921198668146503
# 当前最优结果:0.7050393369252481
# 第171次迭代，局部最优结果为：0.7076270523234884
# 当前最优结果:0.7076270523234884
# 第172次迭代，局部最优结果为：0.7076270523234884
# 当前最优结果:0.7076270523234884
# 第173次迭代，局部最优结果为：0.7076270523234884
# 当前最优结果:0.7076270523234884
# 第174次迭代，局部最优结果为：0.7045504129655602
# 当前最优结果:0.7076270523234884
# 第175次迭代，局部最优结果为：0.7081368940402538
# 当前最优结果:0.7081368940402537
# 第176次迭代，局部最优结果为：0.6921198668146503
# 当前最优结果:0.7081368940402537
# 第177次迭代，局部最优结果为：0.7043967343886327
# 当前最优结果:0.7081368940402537
# 第178次迭代，局部最优结果为：0.7100442099146427
# 当前最优结果:0.7100442099146427
# 第179次迭代，局部最优结果为：0.7100442099146427
# 当前最优结果:0.7100442099146427
# 第180次迭代，局部最优结果为：0.699809224553922
# 当前最优结果:0.7100442099146427
# 第181次迭代，局部最优结果为：0.7054298642533937
# 当前最优结果:0.7100442099146427
# 第182次迭代，局部最优结果为：0.7054298642533937
# 当前最优结果:0.7100442099146427
# 第183次迭代，局部最优结果为：0.7054298642533937
# 当前最优结果:0.7100442099146427
# 第184次迭代，局部最优结果为：0.7067890740111074
# 当前最优结果:0.7100442099146427
# 第185次迭代，局部最优结果为：0.7100442099146427
# 当前最优结果:0.7100442099146427
# 第186次迭代，局部最优结果为：0.7100442099146427
# 当前最优结果:0.7100442099146427
# 第187次迭代，局部最优结果为：0.7116116364265955
# 当前最优结果:0.7116116364265955
# 第188次迭代，局部最优结果为：0.7100442099146427
# 当前最优结果:0.7116116364265955
# 第189次迭代，局部最优结果为：0.7053830881865377
# 当前最优结果:0.7116116364265955
# 第190次迭代，局部最优结果为：0.7100442099146427
# 当前最优结果:0.7116116364265955
# 第191次迭代，局部最优结果为：0.7053830881865377
# 当前最优结果:0.7116116364265955
# 第192次迭代，局部最优结果为：0.7054298642533937
# 当前最优结果:0.7116116364265955
# 第193次迭代，局部最优结果为：0.7136644541084917
# 当前最优结果:0.7136644541084917
# 第194次迭代，局部最优结果为：0.7136644541084917
# 当前最优结果:0.7136644541084917
# 第195次迭代，局部最优结果为：0.7178542649936688
# 当前最优结果:0.7178542649936687
# 第196次迭代，局部最优结果为：0.7351382113821138
# 当前最优结果:0.7351382113821138
# 第197次迭代，局部最优结果为：0.7351382113821138
# 当前最优结果:0.7351382113821138
# 第198次迭代，局部最优结果为：0.7351382113821138
# 当前最优结果:0.7351382113821138
# 第199次迭代，局部最优结果为：0.7351382113821138
# 当前最优结果:0.7351382113821138
# 第200次迭代，局部最优结果为：0.7235612316753088
# 当前最优结果:0.7351382113821138
# 第201次迭代，局部最优结果为：0.7396482617586911
# 当前最优结果:0.7396482617586913
# 第202次迭代，局部最优结果为：0.726281124497992
# 当前最优结果:0.7396482617586913
# 第203次迭代，局部最优结果为：0.7166594674708631
# 当前最优结果:0.7396482617586913
# 第204次迭代，局部最优结果为：0.67459722393193
# 当前最优结果:0.7396482617586913
# 第205次迭代，局部最优结果为：0.6785891181988742
# 当前最优结果:0.7396482617586913
# 第206次迭代，局部最优结果为：0.714798418972332
# 当前最优结果:0.7396482617586913
# 第207次迭代，局部最优结果为：0.7190616302186879
# 当前最优结果:0.7396482617586913
# 本次退火用时：4116.053118467331

# %%
def draw(history):
    plt.plot(history['T'], history['f'])
    plt.title('SA')
    plt.xlabel('T')
    plt.ylabel('f')
    plt.gca().invert_xaxis()
    plt.show()
    return

def wrXSLX(squ, use, tim, filename):
    data = {'square':squ,'utilization':use,'timecost':tim}
    df = pd.DataFrame(data)
    df.to_excel(filename,sheet_name='layout',header=0)
    return df

def drawP(m3):
    Lw,Pw,Lh,Ph = m.lcs_xy(m3.l,m3.x,m3.y,m3.w,m3.h)
    print(Pw)
    print(Ph)
    h,w = m3.h,m3.w
    for i in range(len(Pw)):
        x,y = [Pw[i], Pw[i], Pw[i]+w[i], Pw[i]+w[i], Pw[i]],[Ph[i], Ph[i]+h[i], Ph[i]+h[i], Ph[i], Ph[i]]
        plt.plot(x,y,color='r')
        plt.scatter(x,y,color='b')
    plt.show()
    return

# %%
print("本次测试的退火环境为：")
print(sa.iter,sa.T0,sa.alpha)
squ = []
use = []
for i in range(len(mmm)):
    squ.append(mmm[i].s_cur)
    use.append(mmm[i].use)
print(use)
index = use.index(max(use))
history = {'f': fff[index], 'T': TTT[index]}
print('本次最优解为：'+str(max(use)))
draw(history)

drawP(mmm[index])

wrXSLX(squ,use,sss,'result_49HH.xlsx')
# Out:
# 本次测试的退火环境为：
# 4000 400 0.95
# [0.7625625650951073, 0.745686953653307, 0.7709136172970024, 0.7624661126640611, 0.7966345094929739, 0.769365597985161, 0.7858989791883048, 0.7438160654793732, 0.7506734908201852, 0.7659149143425873, 0.7200350374263418, 0.7633382859458364, 0.7382562938590225, 0.7610638835114889, 0.7393760987775461, 0.7827490834801352, 0.766216708611909, 0.8138793879387939, 0.7746749769753046, 0.7531306871894821, 0.7944786623672164, 0.750038363754754, 0.7752893766612364, 0.7270870523150158, 0.7593063777973716, 0.7864697491563163, 0.7337363573660081, 0.7724018929492765, 0.7741079378124786, 0.7396482617586913]
# 本次最优解为：0.8138793879387939
# [1792. 1162.    0. 5390. 2926. 4312. 5936. 3724. 4368. 1736. 4970. 3584.
#  1960.  868. 1330.  532. 4900.    0.  532. 2996.  868. 4830. 2926. 3794.
#  1008. 2996. 4060. 6286. 2030. 6174. 2926. 4592. 1008. 3584. 2926. 2590.
#  2030. 1960. 5026.    0.    0. 6902.    0.  392.    0. 4732.  868. 1694.
#  3976.]
# [4452.    0.  672. 2926.  742.  980. 1862. 3220.    0. 2884. 2758. 2814.
#   672. 5180. 2884. 2884. 1862. 3794. 3724. 3948. 5586.    0. 1666. 3948.
#   672. 3598. 1862. 1862. 1386.    0.    0. 3948.  994. 2254. 1274. 2380.
#  2380.  938. 4452. 4872. 5264.    0. 2884. 4116.    0. 2254. 4746. 3724.
#     0.]
#         square  utilization     timecost
# 0   46481988.0     0.762563  4160.604021
# 1   47533920.0     0.745687  4163.729731
# 2   45978464.0     0.770914  4151.603736
# 3   46487868.0     0.762466  4174.809673
# 4   44493960.0     0.796635  4129.241653
# 5   46070976.0     0.769366  4163.193036
# 6   45101756.0     0.785899  4188.156169
# 7   47653480.0     0.743816  4144.396573
# 8   47218164.0     0.750673  4147.546282
# 9   46278540.0     0.765915  4150.758583
# 10  49227360.0     0.720035  4168.258198
# 11  46434752.0     0.763338  4147.562927
# 12  48012356.0     0.738256  4148.173368
# 13  46573520.0     0.761064  4136.745201
# 14  47939640.0     0.739376  4129.128819
# 15  45283252.0     0.782749  4169.454647
# 16  46260312.0     0.766217  4143.157999
# 17  43551200.0     0.813879  4139.482268
# 18  45755220.0     0.774675  4141.344993
# 19  47064108.0     0.753131  4125.473532
# 20  44614696.0     0.794479  4114.302231
# 21  47258148.0     0.750038  4151.543817
# 22  45718960.0     0.775289  4149.682105
# 23  48749904.0     0.727087  4141.527677
# 24  46681320.0     0.759306  4120.575669
# 25  45069024.0     0.786470  4128.959790
# 26  48308120.0     0.733736  4112.891360
# 27  45889872.0     0.772402  4162.205966
# 28  45788736.0     0.774108  4120.531910
# 29  47922000.0     0.739648  4116.053118

# %%
# Out:
# 0.6977383592017739
# 0.6977383592017739

# %%
# Out:
# 0.35128899738032865
