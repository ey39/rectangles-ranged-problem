# %%
# 导入必要的包
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import copy
import pandas as pd
import time

# %%
'''
产生初始解和初始目标函数X0和f0，初始化最优值记录器X*和f*

既然序列对可以表达模块的位置信息以及整体的最大长度和宽度
那么我们对模块进行乱序，随机生成一个序列对，一个正序列和一个负序列
目标函数就是该序列形成的矩形面积除以总面积，这样子就可以用求目标函数的最小值的方法求解该问题

while(不满足回火终止条件)
    t=t0
        while t>1e-3
            for i=0 i<L i++
                从四种新解中任选一种产生新解Xnew
                计算评价新解的目标函数fnew
                计算评价目标函数差df=fnew-f
                
                if df<0 or exp(-df/t)>random(0,1)
                    接受新解X=Xnew f=fnew
                    与最优值记录器比较，记录最优值
                else
                    还原原来的解
            下降温度 t=a*t
        以记录器的最优解作为下一个循环的初始解
    达不到要求，产生回火温度

'''

# %%
'''
首先
    我们要确定初始温度T0和降温系数α还有终止温度Tf（决定了一共生成
    多少组新解、接受新解的程度）、迭代次数iter（生成一批新解中的新
    解的个数）。
评价函数设置
    整体面积利用率的倒数，一般模拟退火算法都是对最小值进行求解的，
    于是我们需要的面积利用率越大越好，所以我们取倒数即可。
    （面积利用率=sum(模块面积)/生成的矩形画布的面积，生成的矩形画
    布的面积我们可以通过求解LCS得到）

伪代码：
生成初始解x&y&h&w
while T(当前温度)>Tf
    while n(当前循环次数)<iter
        得到上一次的解或者是初始解x&y&h&w
            得到上一次解的评价函数的值f
        从四种方法中生成新解x_new&y_new&h_new&w_new
            得到评价函数值f_new
        Metropolis（f,f_new）  #Metropolis准则
            根据Metropolis准则的结果来决定是否接受新解或者是还原原来的解
    下降温度T=α*T
以记录器中的最优解作为布局问题的最终解


'''

# %%
class module():
    def __init__(self, name='', typ='', w=0., h=0., pos=[], s=0.):
        self.name = name  #模块名称
        self.typ = typ    #模块类型
        self.w = w        #模块宽度
        self.h = h        #模块高度
        self.pos = pos    #模块位置:右下角、右上角、左上角、左下角(左下角一般为(0,0))
        self.s = s        #模块面积

# %%
def rdfile(filename,n):
    #filename是要读取的文件名，n为其中所包含的模块数
    
    #用于存储所有模块对象的列表
    modules = np.zeros(n-1,dtype=type(module('a','b',0.,0.,[],0.))) 
    t = 0
    s_total = 0.
    b1,b2 = 0,0

    #通过文件名打开数据流，按照行的顺序有规律地依次将模块名...读出，顺便创建模块对象放入数组中方便调用
    with open(filename,'r') as f:
        for line in f:
            line = line.split(' ')
            if 'MODULE' in line:
                #print(line[1].split(';')[0])
                name = line[1].split(';')[0]

            if 'TYPE' in line:
                typ = line[2]

            if 'DIMENSIONS' in line:
                #print(line[2:])
                w = 0.
                h = 0.
                pos = np.zeros(8)
                for i in range(10)[2:]:
                    if i != 9:
                        pos[i-2] = int(line[i])
                    else:
                        pos[i-2] = int(line[i].split(";")[0])
                # 用两个坐标值相减即可得到模块的宽高
                h = pos[3]-pos[1]
                w = pos[2]-pos[4]
                s = h*w
                if t == n-1:
                    # 这里的s是parent模块的面积，其实实际上并没有使用到
                    s_total = s
                if t<n-1:
                    modules[t] = module(name,typ,w,h,pos,s)
                    t = t+1
                
    return modules,s_total

# %%
# 读取ami33和ami49并计算出它们模块的总面积（不包括parent）
modules,st = rdfile('ami33.yal',34)
modules1,st1 = rdfile('ami49.yal',50)
s = 0.
for i in range(33):
    s = s + modules[i].s
s1 = 0.
for i in range(49):
    s1 = s1 + modules1[i].s
print(s,s1)
# Out:
# 1156449.0 35445424.0

# %%
# m类，用于存储一组模块的布局
# x为正向序列，y为负向序列，modules则存储着从文件读取出来的各个模块的信息，比如宽w和高h
# m类中还存储着这组模块布局所代表的信息比如面积利用率use、总面积s_cur...其中的iuse是用于模拟退火算法，它是面积利用率的倒数
class m():
    def __init__(self, modules,s_total):
        self.modules = modules
        self.s_total = s_total
        self.l = len(modules)
        self.s_cur,self.iuse,self.use = 0.,0.,0.
        
        # 产生一个比较优的解，在此基础上进行模拟退火，这里随机产生可能没有对模块进行旋转
        # 可能在一定程度上会导致我们的初始解较差
        self.x,self.y,self.modules = self.xyInit()
        self.w,self.h = m.whSort(self.l, self.x, self.y, self.modules)
        self.s_cur,self.iuse,self.use = m.calSC(self.l, self.x, self.y, self.w, self.h, self.s_total) 
        
    # 计算当前模块布局的信息：总面积s_cur、面积利用率及其倒数
    def calSC(l,x,y,w,h,s_total):
        Lw,Pw,Lh,Ph = m.lcs_xy(l,x,y,w,h)
        s_cur = Lw*Lh
        iuse = s_cur/s_total
        use = s_total/s_cur
            
        return s_cur,iuse,use
    
    # 根据x和y序列还有模块序列（包含旋转信息），来生成新的模块宽高序列，用于LCS算法
    def whSort(l,x,y,modules):
        w = np.zeros(l)
        h = np.zeros(l)
        for i in range(l):
            w[i] = modules[i].w
            h[i] = modules[i].h
        return w,h
    
    # 初始化生成一组正向和反向序列--生成一个0到（总模块个数-1）长度的顺序序列，然后用shuffle打乱，随机翻转模块
    def xyInit(self):
        l = self.l
        tmp = np.zeros(l,dtype='int')
        for i in range(l):
            tmp[i] = i
            
        np.random.shuffle(tmp)
        x = copy.deepcopy(tmp)
        np.random.shuffle(tmp)
        y = copy.deepcopy(tmp)
        
        # 模块随机翻转
        md = copy.deepcopy(self.modules)
        for i in range(l):
            yes = random.randint(0,1)
            if yes:
                md[i].w,md[i].h = md[i].h,md[i].w 
            
        return x,y,md
    
    # lcs快速算法
    def lcs_xy(n,x,y,w,h):
        xr = x[::-1]
        Lw,Pw = m.lcs(n,x,y,w)
        Lh,Ph = m.lcs(n,xr,y,h)
        return Lw,Pw,Lh,Ph
    
    # lcs快速算法核心
    def lcs(n,x,y,w):
        # n个模块，x为正序列，y为负序列，w为每个模块的宽度/高度 
        class mdd():
            def __init__(self,x,y):
                self.x = x
                self.y = y

        match = np.zeros(n,dtype=type(mdd(3,4)))
        for i in range(len(x)):
            for j in range(len(y)):
                if x[i]==y[j]:
                    match[int(x[i]-1)] = mdd(i,j)
                    break
                    
        # 模块的位置P，总长度L
        P = np.zeros(n)
        L = np.zeros(n)

        for i in range(n):
            b = int(x[i]-1)
            p = int(match[b].y)
            P[b] = L[p]
            t = P[b] + w[b]
            for j in range(n)[p:n]:
                if t > L[j]:
                    L[j] = t
                else:
                    break

        return L[n-1],P
    
    def refresh(self):
        # 由于x,y,modules的改变，需要更新数据
        self.w,self.h = m.whSort(self.l, self.x, self.y, self.modules)
        self.s_cur,self.iuse,self.use = m.calSC(self.l, self.x, self.y, self.w, self.h, self.s_total) 
    
    def exchangeX(self,pos1,pos2):
        # 第1个随机模块与第2个随机模块交换正序列中的位置
        id1 = np.array(np.where(self.x==pos1))[0][0]
        id2 = np.array(np.where(self.x==pos2))[0][0] 
        x1 = copy.deepcopy(self.x)
        x1[id1],x1[id2] = x1[id2],x1[id1]
        self.x = x1
        return
    
    def exchangeY(self,pos1,pos2):
        # 第1个随机模块与第2个随机模块交换负序列中的位置
        id1 = np.array(np.where(self.y==pos1))[0][0]
        id2 = np.array(np.where(self.y==pos2))[0][0]
        y1 = copy.deepcopy(self.y)
        y1[id1],y1[id2] = y1[id2],y1[id1]
        self.y = y1
        return
    
    def exchangeXY(self,pos1,pos2):
        # 第1个随机模块与第2个随机模块交换正负序列中的位置
        self.exchangeX(pos1,pos2)
        self.exchangeY(pos1,pos2)
        return
    
    def exchangeWH(self,pos):
        # 旋转模块
        md = copy.deepcopy(self.modules)
        md[pos].w,md[pos].h = md[pos].h,md[pos].w 
        self.modules = md
        return

# %%
# SA类 进行模拟退火算法的框架
# 包含3个主要的方法：产生新解、Metropolis准则、运行
class SA:
    def __init__(self, m1, m2, m3, s_total, iter=4000, T0=400, Tf=0.01, alpha=0.98):
        self.iter = iter         #内循环迭代次数,即为L =100
        self.alpha = alpha       #降温系数，alpha=0.95
        self.T0 = T0             #初始温度T0为400
        self.Tf = Tf             #温度终值Tf为0.01
        self.T = T0              #当前温度
        
        # 生成初始解
        self.m1 = m1
        # 用于保存局部最优解&全局最优解
        self.m2 = m2
        self.m3 = m3
        
        # 模块的一些相关信息，模块个数&模块总面积
        self.l = self.m1.l
        self.s_total = self.m1.s_total
        
        # 存放解的序列对
        self.xi = np.zeros((self.iter,self.l),dtype='int')
        self.yi = np.zeros((self.iter,self.l),dtype='int')
        self.modulesi = np.zeros((self.iter,self.l),dtype=type(module()))
                                 
        # 存放f的历史，用于生成图像
        self.history = {'f': [], 'T': []}

    def generate_new(self):   #扰动产生新解的过程
        rand,rand1,rand2 = 0,0,0
        # 选择产生新解的方式
        rand = random.randint(1,4)
        
        while rand1 == rand2:
            rand1 = random.randint(0,self.l-1)
            rand2 = random.randint(0,self.l-1)
            
        if rand == 1:
            #正向序列中交换两个模块的顺序
            self.m1.exchangeX(rand1,rand2)
        elif rand == 2:
            #负向序列中交换两个模块的顺序
            self.m1.exchangeY(rand1,rand2)
        elif rand == 3:
            #正向序列和负向序列中同时交换两个模块的顺序
            self.m1.exchangeXY(rand1,rand2)
        else:
            #将某个模块旋转，即将模块中的宽和高对调
            self.m1.exchangeWH(rand1)
            
        self.m1.refresh()
            
        return 

    def Metrospolis(self, f, f_new):   #Metropolis准则
        if f_new <= f:
            if self.m1.iuse < self.m3.iuse:
                self.m3.x,self.m3.y,self.m3.modules = copy.deepcopy(self.m1.x),copy.deepcopy(self.m1.y),copy.deepcopy(self.m1.modules)
                self.m3.refresh()
            return 1
        else:
            p = math.exp((f - f_new) / self.T)
            if np.random.rand() < p:
                return 1
            else:
                return 0

    
    def run(self):
        count = 0   #迭代计数器
        count1 = 0  #回火计数器
        
        #外循环迭代，当前温度小于终止温度的阈值
        while self.T > self.Tf:  
            #用于存放一次迭代的中间结果
            t= []   
            #内循环迭代
            for i in range(self.iter): 
                #f为迭代一次后的值
                f = self.m2.iuse
                #产生新解
                self.generate_new()
                x_new,y_new,modules_new = copy.deepcopy(self.m1.x),copy.deepcopy(self.m1.y),copy.deepcopy(self.m1.modules)
                #产生新值
                f_new = self.m1.iuse
                #判断是否接受新值
                if self.Metrospolis(f, f_new):
                    self.xi[i] = x_new
                    self.yi[i] = y_new
                    self.modulesi[i] = modules_new
                    t.append(f_new)
                else:
                    t.append(self.m1.iuse)
                    if i>= 1:
                        self.m1.x = copy.deepcopy(self.xi[i-1])
                        self.m1.y = copy.deepcopy(self.yi[i-1])
                        self.m1.modules = copy.deepcopy(self.modulesi[i-1])
                        self.m1.refresh()
            
                    
            f_best = min(t)
            idx = t.index(f_best)
            
            # 将当前局部最优解作为下一次迭代的初始解
            self.m1.x = copy.deepcopy(self.m3.x)
            self.m1.y = copy.deepcopy(self.m3.y)
            self.m1.modules = copy.deepcopy(self.m3.modules)
            self.m1.refresh()
            
            # 保存局部最优解，但是好像没用
            self.m2.x = copy.deepcopy(self.xi[idx])
            self.m2.y = copy.deepcopy(self.yi[idx])
            self.m2.modules = copy.deepcopy(self.modulesi[idx])
            self.m2.refresh()
            
            # 迭代L次记录在该温度下最优解
            self.history['f'].append(f_best)
            self.history['T'].append(self.T)
            
            #温度按照一定的比例下降（冷却）+回火
            self.T = self.T * self.alpha  
            #if self.T <= self.Tf:
                #if self.m3.use < 0.9:
                    #self.T = self.T0/2
                    #count1 += 1
                    #print("现在的结果好像不是很好，我的建议是回火！这是第" + str(count1) + "次回火")
                    
            count += 1
            
            print("第"+str(count)+"次迭代，局部最优结果为："+str(1/f_best))
            self.m3.refresh()
            print("当前最优结果:"+str(self.m3.use))
            
            
        return

# %%
#mmm = []
#TTT = []
#fff = []
#sss = []
for i in range(30-len(mmm)):
    print(len(mmm)+i+1)
    t1 = time.time()
    m1 = m(modules,s)
    m2 = m(modules,s)
    m3 = m(modules,s)
    sa = SA(m1,m2,m3,s)
    sa.run()
    t2 = time.time()
    t = t2-t1
    mmm.append(sa.m3)
    TTT.append(sa.history['T'])
    fff.append(sa.history['f'])
    sss.append(t)
    print("本次退火用时："+str(t))
# Out:
# 21
# 第1次迭代，局部最优结果为：0.5042948717948719
# 当前最优结果:0.5042948717948718
# 第2次迭代，局部最优结果为：0.532129329004329
# 当前最优结果:0.532129329004329
# 第3次迭代，局部最优结果为：0.5690004339649934
# 当前最优结果:0.5690004339649934
# 第4次迭代，局部最优结果为：0.5690004339649934
# 当前最优结果:0.5690004339649934
# 第5次迭代，局部最优结果为：0.5857781087118391
# 当前最优结果:0.5857781087118392
# 第6次迭代，局部最优结果为：0.5963010687485788
# 当前最优结果:0.5963010687485788
# 第7次迭代，局部最优结果为：0.5963010687485788
# 当前最优结果:0.5963010687485788
# 第8次迭代，局部最优结果为：0.5186577004219409
# 当前最优结果:0.5963010687485788
# 第9次迭代，局部最优结果为：0.5937956020731646
# 当前最优结果:0.5963010687485788
# 第10次迭代，局部最优结果为：0.5789667353547248
# 当前最优结果:0.5963010687485788
# 第11次迭代，局部最优结果为：0.6309078272027374
# 当前最优结果:0.6309078272027374
# 第12次迭代，局部最优结果为：0.5203042328042328
# 当前最优结果:0.6309078272027374
# 第13次迭代，局部最优结果为：0.5888473053892216
# 当前最优结果:0.6309078272027374
# 第14次迭代，局部最优结果为：0.6117894081965938
# 当前最优结果:0.6309078272027374
# 第15次迭代，局部最优结果为：0.6198392688307596
# 当前最优结果:0.6309078272027374
# 第16次迭代，局部最优结果为：0.49066528066528065
# 当前最优结果:0.6309078272027374
# 第17次迭代，局部最优结果为：0.6309078272027374
# 当前最优结果:0.6309078272027374
# 第18次迭代，局部最优结果为：0.532129329004329
# 当前最优结果:0.6309078272027374
# 第19次迭代，局部最优结果为：0.5424020959735245
# 当前最优结果:0.6309078272027374
# 第20次迭代，局部最优结果为：0.5888473053892216
# 当前最优结果:0.6309078272027374
# 第21次迭代，局部最优结果为：0.5927516576250753
# 当前最优结果:0.6309078272027374
# 第22次迭代，局部最优结果为：0.6197741596638655
# 当前最优结果:0.6309078272027374
# 第23次迭代，局部最优结果为：0.5388356164383562
# 当前最优结果:0.6309078272027374
# 第24次迭代，局部最优结果为：0.6309078272027374
# 当前最优结果:0.6309078272027374
# 第25次迭代，局部最优结果为：0.5388110131957445
# 当前最优结果:0.6309078272027374
# 第26次迭代，局部最优结果为：0.6281037924151697
# 当前最优结果:0.6309078272027374
# 第27次迭代，局部最优结果为：0.5407492267155459
# 当前最优结果:0.6309078272027374
# 第28次迭代，局部最优结果为：0.5006363752068219
# 当前最优结果:0.6309078272027374
# 第29次迭代，局部最优结果为：0.6309078272027374
# 当前最优结果:0.6309078272027374
# 第30次迭代，局部最优结果为：0.6309078272027374
# 当前最优结果:0.6309078272027374
# 第31次迭代，局部最优结果为：0.6020663265306123
# 当前最优结果:0.6309078272027374
# 第32次迭代，局部最优结果为：0.6225698382969743
# 当前最优结果:0.6309078272027374
# 第33次迭代，局部最优结果为：0.5488604651162791
# 当前最优结果:0.6309078272027374
# 第34次迭代，局部最优结果为：0.6308740978348035
# 当前最优结果:0.6309078272027374
# 第35次迭代，局部最优结果为：0.5618215577985145
# 当前最优结果:0.6309078272027374
# 第36次迭代，局部最优结果为：0.6309078272027374
# 当前最优结果:0.6309078272027374
# 第37次迭代，局部最优结果为：0.6309078272027374
# 当前最优结果:0.6309078272027374
# 第38次迭代，局部最优结果为：0.6309078272027374
# 当前最优结果:0.6309078272027374
# 第39次迭代，局部最优结果为：0.6309078272027374
# 当前最优结果:0.6309078272027374
# 第40次迭代，局部最优结果为：0.6309078272027374
# 当前最优结果:0.6309078272027374
# 第41次迭代，局部最优结果为：0.5777478580171359
# 当前最优结果:0.6309078272027374
# 第42次迭代，局部最优结果为：0.6309078272027374
# 当前最优结果:0.6309078272027374
# 第43次迭代，局部最优结果为：0.6009931245225363
# 当前最优结果:0.6309078272027374
# 第44次迭代，局部最优结果为：0.540315934065934
# 当前最优结果:0.6309078272027374
# 第45次迭代，局部最优结果为：0.6309078272027374
# 当前最优结果:0.6309078272027374
# 第46次迭代，局部最优结果为：0.5511161965253129
# 当前最优结果:0.6309078272027374
# 第47次迭代，局部最优结果为：0.6039459542453555
# 当前最优结果:0.6309078272027374
# 第48次迭代，局部最优结果为：0.6309078272027374
# 当前最优结果:0.6309078272027374
# 第49次迭代，局部最优结果为：0.5561682573347473
# 当前最优结果:0.6309078272027374
# 第50次迭代，局部最优结果为：0.6493781642086727
# 当前最优结果:0.6493781642086727
# 第51次迭代，局部最优结果为：0.5407120601173021
# 当前最优结果:0.6493781642086727
# 第52次迭代，局部最优结果为：0.6412269738629571
# 当前最优结果:0.6493781642086727
# 第53次迭代，局部最优结果为：0.6493781642086727
# 当前最优结果:0.6493781642086727
# 第54次迭代，局部最优结果为：0.602435164386359
# 当前最优结果:0.6493781642086727
# 第55次迭代，局部最优结果为：0.6493781642086727
# 当前最优结果:0.6493781642086727
# 第56次迭代，局部最优结果为：0.5849360563101021
# 当前最优结果:0.6493781642086727
# 第57次迭代，局部最优结果为：0.6493781642086727
# 当前最优结果:0.6493781642086727
# 第58次迭代，局部最优结果为：0.6549284049284049
# 当前最优结果:0.654928404928405
# 第59次迭代，局部最优结果为：0.6343331720690212
# 当前最优结果:0.654928404928405
# 第60次迭代，局部最优结果为：0.6465318869165023
# 当前最优结果:0.654928404928405
# 第61次迭代，局部最优结果为：0.6704829545454546
# 当前最优结果:0.6704829545454546
# 第62次迭代，局部最优结果为：0.5754516860507644
# 当前最优结果:0.6704829545454546
# 第63次迭代，局部最优结果为：0.6704829545454546
# 当前最优结果:0.6704829545454546
# 第64次迭代，局部最优结果为：0.6045338114754099
# 当前最优结果:0.6704829545454546
# 第65次迭代，局部最优结果为：0.6704829545454546
# 当前最优结果:0.6704829545454546
# 第66次迭代，局部最优结果为：0.6797523041474655
# 当前最优结果:0.6797523041474655
# 第67次迭代，局部最优结果为：0.6755302401465495
# 当前最优结果:0.6797523041474655
# 第68次迭代，局部最优结果为：0.6797523041474655
# 当前最优结果:0.6797523041474655
# 第69次迭代，局部最优结果为：0.6797523041474655
# 当前最优结果:0.6797523041474655
# 第70次迭代，局部最优结果为：0.6797523041474655
# 当前最优结果:0.6797523041474655
# 第71次迭代，局部最优结果为：0.6704829545454546
# 当前最优结果:0.6797523041474655
# 第72次迭代，局部最优结果为：0.688356763693636
# 当前最优结果:0.6883567636936359
# 第73次迭代，局部最优结果为：0.6370900256444864
# 当前最优结果:0.6883567636936359
# 第74次迭代，局部最优结果为：0.6097819346837536
# 当前最优结果:0.6883567636936359
# 第75次迭代，局部最优结果为：0.6370900256444864
# 当前最优结果:0.6883567636936359
# 第76次迭代，局部最优结果为：0.6672415255435243
# 当前最优结果:0.6883567636936359
# 第77次迭代，局部最优结果为：0.6840274758716633
# 当前最优结果:0.6883567636936359
# 第78次迭代，局部最优结果为：0.6039459542453555
# 当前最优结果:0.6883567636936359
# 第79次迭代，局部最优结果为：0.688356763693636
# 当前最优结果:0.6883567636936359
# 第80次迭代，局部最优结果为：0.5511290661560376
# 当前最优结果:0.6883567636936359
# 第81次迭代，局部最优结果为：0.688356763693636
# 当前最优结果:0.6883567636936359
# 第82次迭代，局部最优结果为：0.48651824366110086
# 当前最优结果:0.6883567636936359
# 第83次迭代，局部最优结果为：0.5379758377023023
# 当前最优结果:0.6883567636936359
# 第84次迭代，局部最优结果为：0.5967986648460022
# 当前最优结果:0.6883567636936359
# 第85次迭代，局部最优结果为：0.6139698231009365
# 当前最优结果:0.6883567636936359
# 第86次迭代，局部最优结果为：0.5747369959088253
# 当前最优结果:0.6883567636936359
# 第87次迭代，局部最优结果为：0.688356763693636
# 当前最优结果:0.6883567636936359
# 第88次迭代，局部最优结果为：0.6592089827383945
# 当前最优结果:0.6883567636936359
# 第89次迭代，局部最优结果为：0.6551829437565931
# 当前最优结果:0.6883567636936359
# 第90次迭代，局部最优结果为：0.5541701887855733
# 当前最优结果:0.6883567636936359
# 第91次迭代，局部最优结果为：0.6214878209348256
# 当前最优结果:0.6883567636936359
# 第92次迭代，局部最优结果为：0.6466381719546277
# 当前最优结果:0.6883567636936359
# 第93次迭代，局部最优结果为：0.6144653596813247
# 当前最优结果:0.6883567636936359
# 第94次迭代，局部最优结果为：0.5114641123439667
# 当前最优结果:0.6883567636936359
# 第95次迭代，局部最优结果为：0.6042242703533026
# 当前最优结果:0.6883567636936359
# 第96次迭代，局部最优结果为：0.5235359361135759
# 当前最优结果:0.6883567636936359
# 第97次迭代，局部最优结果为：0.577126228786619
# 当前最优结果:0.6883567636936359
# 第98次迭代，局部最优结果为：0.5391310307017544
# 当前最优结果:0.6883567636936359
# 第99次迭代，局部最优结果为：0.6370900256444864
# 当前最优结果:0.6883567636936359
# 第100次迭代，局部最优结果为：0.6139698231009365
# 当前最优结果:0.6883567636936359
# 第101次迭代，局部最优结果为：0.6308740978348035
# 当前最优结果:0.6883567636936359
# 第102次迭代，局部最优结果为：0.6410528031290743
# 当前最优结果:0.6883567636936359
# 第103次迭代，局部最优结果为：0.7155287412078584
# 当前最优结果:0.7155287412078584
# 第104次迭代，局部最优结果为：0.6008860147159916
# 当前最优结果:0.7155287412078584
# 第105次迭代，局部最优结果为：0.6435524772993756
# 当前最优结果:0.7155287412078584
# 第106次迭代，局部最优结果为：0.6512596925963741
# 当前最优结果:0.7155287412078584
# 第107次迭代，局部最优结果为：0.6512596925963741
# 当前最优结果:0.7155287412078584
# 第108次迭代，局部最优结果为：0.7062361601532108
# 当前最优结果:0.7155287412078584
# 第109次迭代，局部最优结果为：0.6449417937366781
# 当前最优结果:0.7155287412078584
# 第110次迭代，局部最优结果为：0.7155287412078584
# 当前最优结果:0.7155287412078584
# 第111次迭代，局部最优结果为：0.527325945124676
# 当前最优结果:0.7155287412078584
# 第112次迭代，局部最优结果为：0.6008860147159916
# 当前最优结果:0.7155287412078584
# 第113次迭代，局部最优结果为：0.5475234891543904
# 当前最优结果:0.7155287412078584
# 第114次迭代，局部最优结果为：0.6523938522777532
# 当前最优结果:0.7155287412078584
# 第115次迭代，局部最优结果为：0.5700724637681159
# 当前最优结果:0.7155287412078584
# 第116次迭代，局部最优结果为：0.6266029470330545
# 当前最优结果:0.7155287412078584
# 第117次迭代，局部最优结果为：0.6635458839406208
# 当前最优结果:0.7155287412078584
# 第118次迭代，局部最优结果为：0.5132883862548934
# 当前最优结果:0.7155287412078584
# 第119次迭代，局部最优结果为：0.5556314153875129
# 当前最优结果:0.7155287412078584
# 第120次迭代，局部最优结果为：0.7155287412078584
# 当前最优结果:0.7155287412078584
# 第121次迭代，局部最优结果为：0.7155287412078584
# 当前最优结果:0.7155287412078584
# 第122次迭代，局部最优结果为：0.725559517953763
# 当前最优结果:0.725559517953763
# 第123次迭代，局部最优结果为：0.6389701104613386
# 当前最优结果:0.725559517953763
# 第124次迭代，局部最优结果为：0.5565223542727787
# 当前最优结果:0.725559517953763
# 第125次迭代，局部最优结果为：0.5888913840856351
# 当前最优结果:0.725559517953763
# 第126次迭代，局部最优结果为：0.617633204229038
# 当前最优结果:0.725559517953763
# 第127次迭代，局部最优结果为：0.6603895013710895
# 当前最优结果:0.725559517953763
# 第128次迭代，局部最优结果为：0.6373480961382663
# 当前最优结果:0.725559517953763
# 第129次迭代，局部最优结果为：0.6230793600506891
# 当前最优结果:0.725559517953763
# 第130次迭代，局部最优结果为：0.6663937203523831
# 当前最优结果:0.725559517953763
# 第131次迭代，局部最优结果为：0.7161366670712466
# 当前最优结果:0.725559517953763
# 第132次迭代，局部最优结果为：0.6798110435809546
# 当前最优结果:0.725559517953763
# 第133次迭代，局部最优结果为：0.62357324032974
# 当前最优结果:0.725559517953763
# 第134次迭代，局部最优结果为：0.5564173896642777
# 当前最优结果:0.725559517953763
# 第135次迭代，局部最优结果为：0.725559517953763
# 当前最优结果:0.725559517953763
# 第136次迭代，局部最优结果为：0.687034233814625
# 当前最优结果:0.725559517953763
# 第137次迭代，局部最优结果为：0.6810076177285318
# 当前最优结果:0.725559517953763
# 第138次迭代，局部最优结果为：0.6206706114398423
# 当前最优结果:0.725559517953763
# 第139次迭代，局部最优结果为：0.6093096504363092
# 当前最优结果:0.725559517953763
# 第140次迭代，局部最优结果为：0.6230793600506891
# 当前最优结果:0.725559517953763
# 第141次迭代，局部最优结果为：0.725559517953763
# 当前最优结果:0.725559517953763
# 第142次迭代，局部最优结果为：0.6454179998359176
# 当前最优结果:0.725559517953763
# 第143次迭代，局部最优结果为：0.7024525269361271
# 当前最优结果:0.725559517953763
# 第144次迭代，局部最优结果为：0.725559517953763
# 当前最优结果:0.725559517953763
# 第145次迭代，局部最优结果为：0.6635458839406208
# 当前最优结果:0.725559517953763
# 第146次迭代，局部最优结果为：0.6980066248669112
# 当前最优结果:0.725559517953763
# 第147次迭代，局部最优结果为：0.7161366670712466
# 当前最优结果:0.725559517953763
# 第148次迭代，局部最优结果为：0.6721633629528366
# 当前最优结果:0.725559517953763
# 第149次迭代，局部最优结果为：0.6286224163647987
# 当前最优结果:0.725559517953763
# 第150次迭代，局部最优结果为：0.6214878209348256
# 当前最优结果:0.725559517953763
# 第151次迭代，局部最优结果为：0.6449417937366781
# 当前最优结果:0.725559517953763
# 第152次迭代，局部最优结果为：0.6694179714091218
# 当前最优结果:0.725559517953763
# 第153次迭代，局部最优结果为：0.5643472022955524
# 当前最优结果:0.725559517953763
# 第154次迭代，局部最优结果为：0.6449417937366781
# 当前最优结果:0.725559517953763
# 第155次迭代，局部最优结果为：0.6311777920410784
# 当前最优结果:0.725559517953763
# 第156次迭代，局部最优结果为：0.7352336448598131
# 当前最优结果:0.7352336448598131
# 第157次迭代，局部最优结果为：0.5267257348182204
# 当前最优结果:0.7352336448598131
# 第158次迭代，局部最优结果为：0.7352336448598131
# 当前最优结果:0.7352336448598131
# 第159次迭代，局部最优结果为：0.6666949152542373
# 当前最优结果:0.7352336448598131
# 第160次迭代，局部最优结果为：0.5986454951298701
# 当前最优结果:0.7352336448598131
# 第161次迭代，局部最优结果为：0.658326359832636
# 当前最优结果:0.7352336448598131
# 第162次迭代，局部最优结果为：0.6603895013710895
# 当前最优结果:0.7352336448598131
# 第163次迭代，局部最优结果为：0.6683942225998301
# 当前最优结果:0.7352336448598131
# 第164次迭代，局部最优结果为：0.6318875502008032
# 当前最优结果:0.7352336448598131
# 第165次迭代，局部最优结果为：0.6811255411255411
# 当前最优结果:0.7352336448598131
# 第166次迭代，局部最优结果为：0.553858068149817
# 当前最优结果:0.7352336448598131
# 第167次迭代，局部最优结果为：0.687034233814625
# 当前最优结果:0.7352336448598131
# 第168次迭代，局部最优结果为：0.527325945124676
# 当前最优结果:0.7352336448598131
# 第169次迭代，局部最优结果为：0.6695319148936171
# 当前最优结果:0.7352336448598131
# 第170次迭代，局部最优结果为：0.6492888387575999
# 当前最优结果:0.7352336448598131
# 第171次迭代，局部最优结果为：0.7352336448598131
# 当前最优结果:0.7352336448598131
# 第172次迭代，局部最优结果为：0.6856968534820883
# 当前最优结果:0.7352336448598131
# 第173次迭代，局部最优结果为：0.7352336448598131
# 当前最优结果:0.7352336448598131
# 第174次迭代，局部最优结果为：0.633737010284364
# 当前最优结果:0.7352336448598131
# 第175次迭代，局部最优结果为：0.6302002670226969
# 当前最优结果:0.7352336448598131
# 第176次迭代，局部最优结果为：0.6243650793650793
# 当前最优结果:0.7352336448598131
# 第177次迭代，局部最优结果为：0.6961946902654867
# 当前最优结果:0.7352336448598131
# 第178次迭代，局部最优结果为：0.6234414623837701
# 当前最优结果:0.7352336448598131
# 第179次迭代，局部最优结果为：0.5336453669787004
# 当前最优结果:0.7352336448598131
# 第180次迭代，局部最优结果为：0.6410528031290743
# 当前最优结果:0.7352336448598131
# 第181次迭代，局部最优结果为：0.6528630705394192
# 当前最优结果:0.7352336448598131
# 第182次迭代，局部最优结果为：0.5579432624113475
# 当前最优结果:0.7352336448598131
# 第183次迭代，局部最优结果为：0.580504722550177
# 当前最优结果:0.7352336448598131
# 第184次迭代，局部最优结果为：0.7024525269361271
# 当前最优结果:0.7352336448598131
# 第185次迭代，局部最优结果为：0.6525742409998341
# 当前最优结果:0.7352336448598131
# 第186次迭代，局部最优结果为：0.6230793600506891
# 当前最优结果:0.7352336448598131
# 第187次迭代，局部最优结果为：0.5804476143630103
# 当前最优结果:0.7352336448598131
# 第188次迭代，局部最优结果为：0.6936166460941633
# 当前最优结果:0.7352336448598131
# 第189次迭代，局部最优结果为：0.7352336448598131
# 当前最优结果:0.7352336448598131
# 第190次迭代，局部最优结果为：0.7303645478739864
# 当前最优结果:0.7352336448598131
# 第191次迭代，局部最优结果为：0.549141421192238
# 当前最优结果:0.7352336448598131
# 第192次迭代，局部最优结果为：0.6374858192426125
# 当前最优结果:0.7352336448598131
# 第193次迭代，局部最优结果为：0.5399450926561428
# 当前最优结果:0.7352336448598131
# 第194次迭代，局部最优结果为：0.6230793600506891
# 当前最优结果:0.7352336448598131
# 第195次迭代，局部最优结果为：0.5438018433179723
# 当前最优结果:0.7352336448598131
# 第196次迭代，局部最优结果为：0.6870742358078603
# 当前最优结果:0.7352336448598131
# 第197次迭代，局部最优结果为：0.6525742409998341
# 当前最优结果:0.7352336448598131
# 第198次迭代，局部最优结果为：0.7303645478739864
# 当前最优结果:0.7352336448598131
# 第199次迭代，局部最优结果为：0.7303645478739864
# 当前最优结果:0.7352336448598131
# 第200次迭代，局部最优结果为：0.7352336448598131
# 当前最优结果:0.7352336448598131
# 第201次迭代，局部最优结果为：0.7352336448598131
# 当前最优结果:0.7352336448598131
# 第202次迭代，局部最优结果为：0.7208172988821696
# 当前最优结果:0.7352336448598131
# 第203次迭代，局部最优结果为：0.6643677513793492
# 当前最优结果:0.7352336448598131
# 第204次迭代，局部最优结果为：0.5961353877241728
# 当前最优结果:0.7352336448598131
# 第205次迭代，局部最优结果为：0.6980066248669112
# 当前最优结果:0.7352336448598131
# 第206次迭代，局部最优结果为：0.6374858192426125
# 当前最优结果:0.7352336448598131
# 第207次迭代，局部最优结果为：0.6753949175824175
# 当前最优结果:0.7352336448598131
# 第208次迭代，局部最优结果为：0.5961353877241728
# 当前最优结果:0.7352336448598131
# 第209次迭代，局部最优结果为：0.7108520827685914
# 当前最优结果:0.7352336448598131
# 第210次迭代，局部最优结果为：0.7352336448598131
# 当前最优结果:0.7352336448598131
# 第211次迭代，局部最优结果为：0.5790945896209054
# 当前最优结果:0.7352336448598131
# 第212次迭代，局部最优结果为：0.5509103641456583
# 当前最优结果:0.7352336448598131
# 第213次迭代，局部最优结果为：0.6059617952141316
# 当前最优结果:0.7352336448598131
# 第214次迭代，局部最优结果为：0.7250691244239631
# 当前最优结果:0.7352336448598131
# 第215次迭代，局部最优结果为：0.7352336448598131
# 当前最优结果:0.7352336448598131
# 第216次迭代，局部最优结果为：0.7122464992757123
# 当前最优结果:0.7352336448598131
# 第217次迭代，局部最优结果为：0.7352336448598131
# 当前最优结果:0.7352336448598131
# 第218次迭代，局部最优结果为：0.6528630705394192
# 当前最优结果:0.7352336448598131
# 第219次迭代，局部最优结果为：0.5353157321720196
# 当前最优结果:0.7352336448598131
# 第220次迭代，局部最优结果为：0.6338221076377699
# 当前最优结果:0.7352336448598131
# 第221次迭代，局部最优结果为：0.5993752539618041
# 当前最优结果:0.7352336448598131
# 第222次迭代，局部最优结果为：0.6603895013710895
# 当前最优结果:0.7352336448598131
# 第223次迭代，局部最优结果为：0.6230793600506891
# 当前最优结果:0.7352336448598131
# 第224次迭代，局部最优结果为：0.6395934959349593
# 当前最优结果:0.7352336448598131
# 第225次迭代，局部最优结果为：0.6045338114754099
# 当前最优结果:0.7352336448598131
# 第226次迭代，局部最优结果为：0.7069554277498203
# 当前最优结果:0.7352336448598131
# 第227次迭代，局部最优结果为：0.6724697971278779
# 当前最优结果:0.7352336448598131
# 第228次迭代，局部最优结果为：0.6724697971278779
# 当前最优结果:0.7352336448598131
# 第229次迭代，局部最优结果为：0.6449417937366781
# 当前最优结果:0.7352336448598131
# 第230次迭代，局部最优结果为：0.7090794375676001
# 当前最优结果:0.7352336448598131
# 第231次迭代，局部最优结果为：0.6936166460941633
# 当前最优结果:0.7352336448598131
# 第232次迭代，局部最优结果为：0.7352336448598131
# 当前最优结果:0.7352336448598131
# 第233次迭代，局部最优结果为：0.6065379969674385
# 当前最优结果:0.7352336448598131
# 第234次迭代，局部最优结果为：0.6856968534820883
# 当前最优结果:0.7352336448598131
# 第235次迭代，局部最优结果为：0.7303645478739864
# 当前最优结果:0.7352336448598131
# 第236次迭代，局部最优结果为：0.7352336448598131
# 当前最优结果:0.7352336448598131
# 第237次迭代，局部最优结果为：0.5653611210923464
# 当前最优结果:0.7352336448598131
# 第238次迭代，局部最优结果为：0.7352336448598131
# 当前最优结果:0.7352336448598131
# 第239次迭代，局部最优结果为：0.5676046176046176
# 当前最优结果:0.7352336448598131
# 第240次迭代，局部最优结果为：0.6389701104613386
# 当前最优结果:0.7352336448598131
# 第241次迭代，局部最优结果为：0.6230793600506891
# 当前最优结果:0.7352336448598131
# 第242次迭代，局部最优结果为：0.57552184939524
# 当前最优结果:0.7352336448598131
# 第243次迭代，局部最优结果为：0.5961353877241728
# 当前最优结果:0.7352336448598131
# 第244次迭代，局部最优结果为：0.5646712604076946
# 当前最优结果:0.7352336448598131
# 第245次迭代，局部最优结果为：0.6175039246467818
# 当前最优结果:0.7352336448598131
# 第246次迭代，局部最优结果为：0.6266195836873407
# 当前最优结果:0.7352336448598131
# 第247次迭代，局部最优结果为：0.6501652892561983
# 当前最优结果:0.7352336448598131
# 第248次迭代，局部最优结果为：0.6245633534455383
# 当前最优结果:0.7352336448598131
# 第249次迭代，局部最优结果为：0.6266195836873407
# 当前最优结果:0.7352336448598131
# 第250次迭代，局部最优结果为：0.7352336448598131
# 当前最优结果:0.7352336448598131
# 第251次迭代，局部最优结果为：0.6915436005625879
# 当前最优结果:0.7352336448598131
# 第252次迭代，局部最优结果为：0.711945701357466
# 当前最优结果:0.7352336448598131
# 第253次迭代，局部最优结果为：0.6711693777727221
# 当前最优结果:0.7352336448598131
# 第254次迭代，局部最优结果为：0.7024525269361271
# 当前最优结果:0.7352336448598131
# 第255次迭代，局部最优结果为：0.6870742358078603
# 当前最优结果:0.7352336448598131
# 第256次迭代，局部最优结果为：0.5888913840856351
# 当前最优结果:0.7352336448598131
# 第257次迭代，局部最优结果为：0.5940347344575888
# 当前最优结果:0.7352336448598131
# 第258次迭代，局部最优结果为：0.6289574672209786
# 当前最优结果:0.7352336448598131
# 第259次迭代，局部最优结果为：0.6698359539081569
# 当前最优结果:0.7352336448598131
# 第260次迭代，局部最优结果为：0.6786576949620428
# 当前最优结果:0.7352336448598131
# 第261次迭代，局部最优结果为：0.6406004017154334
# 当前最优结果:0.7352336448598131
# 第262次迭代，局部最优结果为：0.7250691244239631
# 当前最优结果:0.7352336448598131
# 第263次迭代，局部最优结果为：0.6117894081965938
# 当前最优结果:0.7352336448598131
# 第264次迭代，局部最优结果为：0.7069554277498203
# 当前最优结果:0.7352336448598131
# 第265次迭代，局部最优结果为：0.592394578313253
# 当前最优结果:0.7352336448598131
# 第266次迭代，局部最优结果为：0.7352336448598131
# 当前最优结果:0.7352336448598131
# 第267次迭代，局部最优结果为：0.6230793600506891
# 当前最优结果:0.7352336448598131
# 第268次迭代，局部最优结果为：0.6230793600506891
# 当前最优结果:0.7352336448598131
# 第269次迭代，局部最优结果为：0.6961946902654867
# 当前最优结果:0.7352336448598131
# 第270次迭代，局部最优结果为：0.7352336448598131
# 当前最优结果:0.7352336448598131
# 第271次迭代，局部最优结果为：0.6225698382969743
# 当前最优结果:0.7352336448598131
# 第272次迭代，局部最优结果为：0.6050297374897456
# 当前最优结果:0.7352336448598131
# 第273次迭代，局部最优结果为：0.6528630705394192
# 当前最优结果:0.7352336448598131
# 第274次迭代，局部最优结果为：0.6230793600506891
# 当前最优结果:0.7352336448598131
# 第275次迭代，局部最优结果为：0.6400618338621756
# 当前最优结果:0.7352336448598131
# 第276次迭代，局部最优结果为：0.6723931623931624
# 当前最优结果:0.7352336448598131
# 第277次迭代，局部最优结果为：0.6666949152542373
# 当前最优结果:0.7352336448598131
# 第278次迭代，局部最优结果为：0.6263535031847134
# 当前最优结果:0.7352336448598131
# 第279次迭代，局部最优结果为：0.7352336448598131
# 当前最优结果:0.7352336448598131
# 第280次迭代，局部最优结果为：0.637004048582996
# 当前最优结果:0.7352336448598131
# 第281次迭代，局部最优结果为：0.7299353601583521
# 当前最优结果:0.7352336448598131
# 第282次迭代，局部最优结果为：0.6674490950226244
# 当前最优结果:0.7352336448598131
# 第283次迭代，局部最优结果为：0.7352336448598131
# 当前最优结果:0.7352336448598131
# 第284次迭代，局部最优结果为：0.6374858192426125
# 当前最优结果:0.7352336448598131
# 第285次迭代，局部最优结果为：0.7352336448598131
# 当前最优结果:0.7352336448598131
# 第286次迭代，局部最优结果为：0.7352336448598131
# 当前最优结果:0.7352336448598131
# 第287次迭代，局部最优结果为：0.7352336448598131
# 当前最优结果:0.7352336448598131
# 第288次迭代，局部最优结果为：0.645170990404855
# 当前最优结果:0.7352336448598131
# 第289次迭代，局部最优结果为：0.7303645478739864
# 当前最优结果:0.7352336448598131
# 第290次迭代，局部最优结果为：0.6545288146874481
# 当前最优结果:0.7352336448598131
# 第291次迭代，局部最优结果为：0.5895091794679655
# 当前最优结果:0.7352336448598131
# 第292次迭代，局部最优结果为：0.6268525896414343
# 当前最优结果:0.7352336448598131
# 第293次迭代，局部最优结果为：0.6466381719546277
# 当前最优结果:0.7352336448598131
# 第294次迭代，局部最优结果为：0.6000762776506483
# 当前最优结果:0.7352336448598131
# 第295次迭代，局部最优结果为：0.6149937460913071
# 当前最优结果:0.7352336448598131
# 第296次迭代，局部最优结果为：0.6683374394698836
# 当前最优结果:0.7352336448598131
# 第297次迭代，局部最优结果为：0.5996189024390244
# 当前最优结果:0.7352336448598131
# 第298次迭代，局部最优结果为：0.6850002902420619
# 当前最优结果:0.7352336448598131
# 第299次迭代，局部最优结果为：0.7151818181818183
# 当前最优结果:0.7352336448598131
# 第300次迭代，局部最优结果为：0.7303645478739864
# 当前最优结果:0.7352336448598131
# 第301次迭代，局部最优结果为：0.7069554277498203
# 当前最优结果:0.7352336448598131
# 第302次迭代，局部最优结果为：0.6593194770365404
# 当前最优结果:0.7352336448598131
# 第303次迭代，局部最优结果为：0.6303685897435898
# 当前最优结果:0.7352336448598131
# 第304次迭代，局部最优结果为：0.5970704310868244
# 当前最优结果:0.7352336448598131
# 第305次迭代，局部最优结果为：0.6226519628535246
# 当前最优结果:0.7352336448598131
# 第306次迭代，局部最优结果为：0.6713603003925585
# 当前最优结果:0.7352336448598131
# 第307次迭代，局部最优结果为：0.7155287412078584
# 当前最优结果:0.7352336448598131
# 第308次迭代，局部最优结果为：0.725559517953763
# 当前最优结果:0.7352336448598131
# 第309次迭代，局部最优结果为：0.6245137731205843
# 当前最优结果:0.7352336448598131
# 第310次迭代，局部最优结果为：0.6378476257398449
# 当前最优结果:0.7352336448598131
# 第311次迭代，局部最优结果为：0.7514327559857361
# 当前最优结果:0.7514327559857361
# 第312次迭代，局部最优结果为：0.657317922294945
# 当前最优结果:0.7514327559857361
# 第313次迭代，局部最优结果为：0.7514327559857361
# 当前最优结果:0.7514327559857361
# 第314次迭代，局部最优结果为：0.7514327559857361
# 当前最优结果:0.7514327559857361
# 第315次迭代，局部最优结果为：0.6797523041474655
# 当前最优结果:0.7514327559857361
# 第316次迭代，局部最优结果为：0.6831562798506382
# 当前最优结果:0.7514327559857361
# 第317次迭代，局部最优结果为：0.6446951486013985
# 当前最优结果:0.7514327559857361
# 第318次迭代，局部最优结果为：0.6406699603670123
# 当前最优结果:0.7514327559857361
# 第319次迭代，局部最优结果为：0.6135229281480711
# 当前最优结果:0.7514327559857361
# 第320次迭代，局部最优结果为：0.6626516172506738
# 当前最优结果:0.7514327559857361
# 第321次迭代，局部最优结果为：0.6649105507818003
# 当前最优结果:0.7514327559857361
# 第322次迭代，局部最优结果为：0.6260212201591512
# 当前最优结果:0.7514327559857361
# 第323次迭代，局部最优结果为：0.7442762535477767
# 当前最优结果:0.7514327559857361
# 第324次迭代，局部最优结果为：0.6757043060009161
# 当前最优结果:0.7514327559857361
# 第325次迭代，局部最优结果为：0.7514327559857361
# 当前最优结果:0.7514327559857361
# 第326次迭代，局部最优结果为：0.6900877192982456
# 当前最优结果:0.7514327559857361
# 第327次迭代，局部最优结果为：0.6674490950226244
# 当前最优结果:0.7514327559857361
# 第328次迭代，局部最优结果为：0.6961125530910808
# 当前最优结果:0.7514327559857361
# 第329次迭代，局部最优结果为：0.6757043060009161
# 当前最优结果:0.7514327559857361
# 第330次迭代，局部最优结果为：0.6780337853367042
# 当前最优结果:0.7514327559857361
# 第331次迭代，局部最优结果为：0.711902750965251
# 当前最优结果:0.7514327559857361
# 第332次迭代，局部最优结果为：0.6482722628138219
# 当前最优结果:0.7514327559857361
# 第333次迭代，局部最优结果为：0.6649105507818003
# 当前最优结果:0.7514327559857361
# 第334次迭代，局部最优结果为：0.7514327559857361
# 当前最优结果:0.7514327559857361
# 第335次迭代，局部最优结果为：0.7514327559857361
# 当前最优结果:0.7514327559857361
# 第336次迭代，局部最优结果为：0.7181414313534566
# 当前最优结果:0.7514327559857361
# 第337次迭代，局部最优结果为：0.6607037876879147
# 当前最优结果:0.7514327559857361
# 第338次迭代，局部最优结果为：0.6787162453627815
# 当前最优结果:0.7514327559857361
# 第339次迭代，局部最优结果为：0.6728532329798153
# 当前最优结果:0.7514327559857361
# 第340次迭代，局部最优结果为：0.7514327559857361
# 当前最优结果:0.7514327559857361
# 第341次迭代，局部最优结果为：0.6571166054126295
# 当前最优结果:0.7514327559857361
# 第342次迭代，局部最优结果为：0.711945701357466
# 当前最优结果:0.7514327559857361
# 第343次迭代，局部最优结果为：0.6562395729062396
# 当前最优结果:0.7514327559857361
# 第344次迭代，局部最优结果为：0.6649105507818003
# 当前最优结果:0.7514327559857361
# 第345次迭代，局部最优结果为：0.7464891194331984
# 当前最优结果:0.7514327559857361
# 第346次迭代，局部最优结果为：0.7273483727810651
# 当前最优结果:0.7514327559857361
# 第347次迭代，局部最优结果为：0.6728532329798153
# 当前最优结果:0.7514327559857361
# 第348次迭代，局部最优结果为：0.7442762535477767
# 当前最优结果:0.7514327559857361
# 第349次迭代，局部最优结果为：0.7004095441595442
# 当前最优结果:0.7514327559857361
# 第350次迭代，局部最优结果为：0.6828993055555556
# 当前最优结果:0.7514327559857361
# 第351次迭代，局部最优结果为：0.7004095441595442
# 当前最优结果:0.7514327559857361
# 第352次迭代，局部最优结果为：0.6578675958188154
# 当前最优结果:0.7514327559857361
# 第353次迭代，局部最优结果为：0.7514327559857361
# 当前最优结果:0.7514327559857361
# 第354次迭代，局部最优结果为：0.7104455147501505
# 当前最优结果:0.7514327559857361
# 第355次迭代，局部最优结果为：0.7289659006671609
# 当前最优结果:0.7514327559857361
# 第356次迭代，局部最优结果为：0.6811255411255411
# 当前最优结果:0.7514327559857361
# 第357次迭代，局部最优结果为：0.725559517953763
# 当前最优结果:0.7514327559857361
# 第358次迭代，局部最优结果为：0.7514327559857361
# 当前最优结果:0.7514327559857361
# 第359次迭代，局部最优结果为：0.7564423076923077
# 当前最优结果:0.7564423076923077
# 第360次迭代，局部最优结果为：0.733793489413301
# 当前最优结果:0.7564423076923077
# 第361次迭代，局部最优结果为：0.733793489413301
# 当前最优结果:0.7564423076923077
# 第362次迭代，局部最优结果为：0.7273483727810651
# 当前最优结果:0.7564423076923077
# 第363次迭代，局部最优结果为：0.6914625571311379
# 当前最优结果:0.7564423076923077
# 第364次迭代，局部最优结果为：0.7386854460093897
# 当前最优结果:0.7564423076923077
# 第365次迭代，局部最优结果为：0.7352336448598131
# 当前最优结果:0.7564423076923077
# 第366次迭代，局部最优结果为：0.7564423076923077
# 当前最优结果:0.7564423076923077
# 第367次迭代，局部最优结果为：0.7645286686103012
# 当前最优结果:0.7645286686103012
# 第368次迭代，局部最优结果为：0.7645286686103012
# 当前最优结果:0.7645286686103012
# 第369次迭代，局部最优结果为：0.7486676817662733
# 当前最优结果:0.7645286686103012
# 第370次迭代，局部最优结果为：0.7615191017036655
# 当前最优结果:0.7645286686103012
# 第371次迭代，局部最优结果为：0.7240458952018652
# 当前最优结果:0.7645286686103012
# 第372次迭代，局部最优结果为：0.7542665388302973
# 当前最优结果:0.7645286686103012
# 第373次迭代，局部最优结果为：0.7311564794448403
# 当前最优结果:0.7645286686103012
# 第374次迭代，局部最优结果为：0.753977381636956
# 当前最优结果:0.7645286686103012
# 第375次迭代，局部最优结果为：0.7260059062384643
# 当前最优结果:0.7645286686103012
# 第376次迭代，局部最优结果为：0.7183162892622352
# 当前最优结果:0.7645286686103012
# 第377次迭代，局部最优结果为：0.7092499098449333
# 当前最优结果:0.7645286686103012
# 第378次迭代，局部最优结果为：0.7115164305094965
# 当前最优结果:0.7645286686103012
# 第379次迭代，局部最优结果为：0.7115164305094965
# 当前最优结果:0.7645286686103012
# 第380次迭代，局部最优结果为：0.7297773654916512
# 当前最优结果:0.7645286686103012
# 第381次迭代，局部最优结果为：0.7281562384302109
# 当前最优结果:0.7645286686103012
# 第382次迭代，局部最优结果为：0.7124400036224228
# 当前最优结果:0.7645286686103012
# 第383次迭代，局部最优结果为：0.7092499098449333
# 当前最优结果:0.7645286686103012
# 第384次迭代，局部最优结果为：0.705898187473829
# 当前最优结果:0.7645286686103012
# 第385次迭代，局部最优结果为：0.7092499098449333
# 当前最优结果:0.7645286686103012
# 第386次迭代，局部最优结果为：0.723202794631366
# 当前最优结果:0.7645286686103012
# 第387次迭代，局部最优结果为：0.7092499098449333
# 当前最优结果:0.7645286686103012
# 第388次迭代，局部最优结果为：0.7247351450944266
# 当前最优结果:0.7645286686103012
# 第389次迭代，局部最优结果为：0.7439243498817967
# 当前最优结果:0.7645286686103012
# 第390次迭代，局部最优结果为：0.7122464992757123
# 当前最优结果:0.7645286686103012
# 第391次迭代，局部最优结果为：0.7649003403014099
# 当前最优结果:0.7649003403014099
# 第392次迭代，局部最优结果为：0.7649003403014099
# 当前最优结果:0.7649003403014099
# 第393次迭代，局部最优结果为：0.7631196042293141
# 当前最优结果:0.7649003403014099
# 第394次迭代，局部最优结果为：0.7649003403014099
# 当前最优结果:0.7649003403014099
# 第395次迭代，局部最优结果为：0.7631196042293141
# 当前最优结果:0.7649003403014099
# 第396次迭代，局部最优结果为：0.7492380952380951
# 当前最优结果:0.7649003403014099
# 第397次迭代，局部最优结果为：0.7393796992481203
# 当前最优结果:0.7649003403014099
# 第398次迭代，局部最优结果为：0.7439243498817967
# 当前最优结果:0.7649003403014099
# 第399次迭代，局部最优结果为：0.753977381636956
# 当前最优结果:0.7649003403014099
# 第400次迭代，局部最优结果为：0.7557398571840277
# 当前最优结果:0.7649003403014099
# 第401次迭代，局部最优结果为：0.7517199643266658
# 当前最优结果:0.7649003403014099
# 第402次迭代，局部最优结果为：0.743291761148904
# 当前最优结果:0.7649003403014099
# 第403次迭代，局部最优结果为：0.7303645478739864
# 当前最优结果:0.7649003403014099
# 第404次迭代，局部最优结果为：0.7492380952380951
# 当前最优结果:0.7649003403014099
# 第405次迭代，局部最优结果为：0.7649003403014099
# 当前最优结果:0.7649003403014099
# 第406次迭代，局部最优结果为：0.7649003403014099
# 当前最优结果:0.7649003403014099
# 第407次迭代，局部最优结果为：0.7545076726342711
# 当前最优结果:0.7649003403014099
# 第408次迭代，局部最优结果为：0.7286283226822265
# 当前最优结果:0.7649003403014099
# 第409次迭代，局部最优结果为：0.7303645478739864
# 当前最优结果:0.7649003403014099
# 第410次迭代，局部最优结果为：0.7649003403014099
# 当前最优结果:0.7649003403014099
# 第411次迭代，局部最优结果为：0.7463946869070209
# 当前最优结果:0.7649003403014099
# 第412次迭代，局部最优结果为：0.769464006259781
# 当前最优结果:0.769464006259781
# 第413次迭代，局部最优结果为：0.7649003403014099
# 当前最优结果:0.769464006259781
# 第414次迭代，局部最优结果为：0.7257826434590073
# 当前最优结果:0.769464006259781
# 第415次迭代，局部最优结果为：0.7914486921529175
# 当前最优结果:0.7914486921529175
# 第416次迭代，局部最优结果为：0.7579971736896197
# 当前最优结果:0.7914486921529175
# 第417次迭代，局部最优结果为：0.7539292103245592
# 当前最优结果:0.7914486921529175
# 第418次迭代，局部最优结果为：0.7697651663405088
# 当前最优结果:0.7914486921529175
# 第419次迭代，局部最优结果为：0.7662662337662338
# 当前最优结果:0.7914486921529175
# 第420次迭代，局部最优结果为：0.7554737516005122
# 当前最优结果:0.7914486921529175
# 第421次迭代，局部最优结果为：0.7502384131222581
# 当前最优结果:0.7914486921529175
# 第422次迭代，局部最优结果为：0.7407721280602637
# 当前最优结果:0.7914486921529175
# 第423次迭代，局部最优结果为：0.7951819407008086
# 当前最优结果:0.7951819407008086
# 第424次迭代，局部最优结果为：0.7627989657401423
# 当前最优结果:0.7951819407008086
# 第425次迭代，局部最优结果为：0.7525829081632652
# 当前最优结果:0.7951819407008086
# 第426次迭代，局部最优结果为：0.7506918158974522
# 当前最优结果:0.7951819407008086
# 第427次迭代，局部最优结果为：0.7525829081632652
# 当前最优结果:0.7951819407008086
# 第428次迭代，局部最优结果为：0.7914486921529175
# 当前最优结果:0.7951819407008086
# 第429次迭代，局部最优结果为：0.7951819407008086
# 当前最优结果:0.7951819407008086
# 第430次迭代，局部最优结果为：0.7593629343629344
# 当前最优结果:0.7951819407008086
# 第431次迭代，局部最优结果为：0.7645286686103012
# 当前最优结果:0.7951819407008086
# 第432次迭代，局部最优结果为：0.7951819407008086
# 当前最优结果:0.7951819407008086
# 第433次迭代，局部最优结果为：0.7625032308089946
# 当前最优结果:0.7951819407008086
# 第434次迭代，局部最优结果为：0.7559577194106342
# 当前最优结果:0.7951819407008086
# 第435次迭代，局部最优结果为：0.7667641325536062
# 当前最优结果:0.7951819407008086
# 第436次迭代，局部最优结果为：0.748382800608828
# 当前最优结果:0.7951819407008086
# 第437次迭代，局部最优结果为：0.7840863787375415
# 当前最优结果:0.7951819407008086
# 第438次迭代，局部最优结果为：0.7839821950571353
# 当前最优结果:0.7951819407008086
# 第439次迭代，局部最优结果为：0.7951819407008086
# 当前最优结果:0.7951819407008086
# 第440次迭代，局部最优结果为：0.789542352468888
# 当前最优结果:0.7951819407008086
# 第441次迭代，局部最优结果为：0.7593629343629344
# 当前最优结果:0.7951819407008086
# 第442次迭代，局部最优结果为：0.7623062015503876
# 当前最优结果:0.7951819407008086
# 第443次迭代，局部最优结果为：0.789542352468888
# 当前最优结果:0.7951819407008086
# 第444次迭代，局部最优结果为：0.7951819407008086
# 当前最优结果:0.7951819407008086
# 第445次迭代，局部最优结果为：0.7593629343629344
# 当前最优结果:0.7951819407008086
# 第446次迭代，局部最优结果为：0.7732961992136305
# 当前最优结果:0.7951819407008086
# 第447次迭代，局部最优结果为：0.7824486954215429
# 当前最优结果:0.7951819407008086
# 第448次迭代，局部最优结果为：0.7951819407008086
# 当前最优结果:0.7951819407008086
# 第449次迭代，局部最优结果为：0.7667641325536062
# 当前最优结果:0.7951819407008086
# 第450次迭代，局部最优结果为：0.7824486954215429
# 当前最优结果:0.7951819407008086
# 第451次迭代，局部最优结果为：0.7840863787375415
# 当前最优结果:0.7951819407008086
# 第452次迭代，局部最优结果为：0.7753794598856693
# 当前最优结果:0.7951819407008086
# 第453次迭代，局部最优结果为：0.7667641325536062
# 当前最优结果:0.7951819407008086
# 第454次迭代，局部最优结果为：0.7824486954215429
# 当前最优结果:0.7951819407008086
# 第455次迭代，局部最优结果为：0.7951819407008086
# 当前最优结果:0.7951819407008086
# 第456次迭代，局部最优结果为：0.7951819407008086
# 当前最优结果:0.7951819407008086
# 第457次迭代，局部最优结果为：0.7951819407008086
# 当前最优结果:0.7951819407008086
# 第458次迭代，局部最优结果为：0.7914486921529175
# 当前最优结果:0.7951819407008086
# 第459次迭代，局部最优结果为：0.8029189630536844
# 当前最优结果:0.8029189630536844
# 第460次迭代，局部最优结果为：0.8029189630536844
# 当前最优结果:0.8029189630536844
# 第461次迭代，局部最优结果为：0.7914486921529175
# 当前最优结果:0.8029189630536844
# 第462次迭代，局部最优结果为：0.8029189630536844
# 当前最优结果:0.8029189630536844
# 第463次迭代，局部最优结果为：0.776859776168532
# 当前最优结果:0.8029189630536844
# 第464次迭代，局部最优结果为：0.8029189630536844
# 当前最优结果:0.8029189630536844
# 第465次迭代，局部最优结果为：0.776859776168532
# 当前最优结果:0.8029189630536844
# 第466次迭代，局部最优结果为：0.7877503337783711
# 当前最优结果:0.8029189630536844
# 第467次迭代，局部最优结果为：0.8029189630536844
# 当前最优结果:0.8029189630536844
# 第468次迭代，局部最优结果为：0.7809211832439945
# 当前最优结果:0.8029189630536844
# 第469次迭代，局部最优结果为：0.8029189630536844
# 当前最优结果:0.8029189630536844
# 第470次迭代，局部最优结果为：0.7797601348002776
# 当前最优结果:0.8029189630536844
# 第471次迭代，局部最优结果为：0.8029189630536844
# 当前最优结果:0.8029189630536844
# 第472次迭代，局部最优结果为：0.8029189630536844
# 当前最优结果:0.8029189630536844
# 第473次迭代，局部最优结果为：0.7991670052824055
# 当前最优结果:0.8029189630536844
# 第474次迭代，局部最优结果为：0.8029189630536844
# 当前最优结果:0.8029189630536844
# 第475次迭代，局部最优结果为：0.7809211832439945
# 当前最优结果:0.8029189630536844
# 第476次迭代，局部最优结果为：0.7991670052824055
# 当前最优结果:0.8029189630536844
# 第477次迭代，局部最优结果为：0.7773715415019762
# 当前最优结果:0.8029189630536844
# 第478次迭代，局部最优结果为：0.8263655462184875
# 当前最优结果:0.8263655462184873
# 第479次迭代，局部最优结果为：0.7954499494438827
# 当前最优结果:0.8263655462184873
# 第480次迭代，局部最优结果为：0.8029189630536844
# 当前最优结果:0.8263655462184873
# 第481次迭代，局部最优结果为：0.8065960355434039
# 当前最优结果:0.8263655462184873
# 第482次迭代，局部最优结果为：0.8263655462184875
# 当前最优结果:0.8263655462184873
# 第483次迭代，局部最优结果为：0.8222198996655519
# 当前最优结果:0.8263655462184873
# 第484次迭代，局部最优结果为：0.8029189630536844
# 当前最优结果:0.8263655462184873
# 第485次迭代，局部最优结果为：0.8263655462184875
# 当前最优结果:0.8263655462184873
# 第486次迭代，局部最优结果为：0.8109194612424409
# 当前最优结果:0.8263655462184873
# 第487次迭代，局部最优结果为：0.8263655462184875
# 当前最优结果:0.8263655462184873
# 第488次迭代，局部最优结果为：0.8263655462184875
# 当前最优结果:0.8263655462184873
# 第489次迭代，局部最优结果为：0.8263655462184875
# 当前最优结果:0.8263655462184873
# 第490次迭代，局部最优结果为：0.8205047976637463
# 当前最优结果:0.8263655462184873
# 第491次迭代，局部最优结果为：0.8104739010989012
# 当前最优结果:0.8263655462184873
# 第492次迭代，局部最优结果为：0.8263655462184875
# 当前最优结果:0.8263655462184873
# 第493次迭代，局部最优结果为：0.8242299364391981
# 当前最优结果:0.8263655462184873
# 第494次迭代，局部最优结果为：0.8202481493066416
# 当前最优结果:0.8263655462184873
# 第495次迭代，局部最优结果为：0.8345473833097595
# 当前最优结果:0.8345473833097595
# 第496次迭代，局部最优结果为：0.8405513213191823
# 当前最优结果:0.8405513213191823
# 第497次迭代，局部最优结果为：0.8405513213191823
# 当前最优结果:0.8405513213191823
# 第498次迭代，局部最优结果为：0.8263655462184875
# 当前最优结果:0.8405513213191823
# 第499次迭代，局部最优结果为：0.8345473833097595
# 当前最优结果:0.8405513213191823
# 第500次迭代，局部最优结果为：0.8405513213191823
# 当前最优结果:0.8405513213191823
# 第501次迭代，局部最优结果为：0.8263655462184875
# 当前最优结果:0.8405513213191823
# 第502次迭代，局部最优结果为：0.8183425797503467
# 当前最优结果:0.8405513213191823
# 第503次迭代，局部最优结果为：0.8282505702754869
# 当前最优结果:0.8405513213191823
# 第504次迭代，局部最优结果为：0.8351971123221742
# 当前最优结果:0.8405513213191823
# 第505次迭代，局部最优结果为：0.8263655462184875
# 当前最优结果:0.8405513213191823
# 第506次迭代，局部最优结果为：0.8405513213191823
# 当前最优结果:0.8405513213191823
# 第507次迭代，局部最优结果为：0.8386993603411513
# 当前最优结果:0.8405513213191823
# 第508次迭代，局部最优结果为：0.844461142121082
# 当前最优结果:0.844461142121082
# 第509次迭代，局部最优结果为：0.8263655462184875
# 当前最优结果:0.844461142121082
# 第510次迭代，局部最优结果为：0.844461142121082
# 当前最优结果:0.844461142121082
# 第511次迭代，局部最优结果为：0.880634328358209
# 当前最优结果:0.880634328358209
# 第512次迭代，局部最优结果为：0.8386993603411513
# 当前最优结果:0.880634328358209
# 第513次迭代，局部最优结果为：0.8386993603411513
# 当前最优结果:0.880634328358209
# 第514次迭代，局部最优结果为：0.8591554423006916
# 当前最优结果:0.880634328358209
# 第515次迭代，局部最优结果为：0.880634328358209
# 当前最优结果:0.880634328358209
# 第516次迭代，局部最优结果为：0.8467637772675085
# 当前最优结果:0.880634328358209
# 第517次迭代，局部最优结果为：0.880634328358209
# 当前最优结果:0.880634328358209
# 第518次迭代，局部最优结果为：0.880634328358209
# 当前最优结果:0.880634328358209
# 第519次迭代，局部最优结果为：0.861193212917351
# 当前最优结果:0.880634328358209
# 第520次迭代，局部最优结果为：0.8591554423006916
# 当前最优结果:0.880634328358209
# 第521次迭代，局部最优结果为：0.880634328358209
# 当前最优结果:0.880634328358209
# 第522次迭代，局部最优结果为：0.8591554423006916
# 当前最优结果:0.880634328358209
# 第523次迭代，局部最优结果为：0.8591554423006916
# 当前最优结果:0.880634328358209
# 第524次迭代，局部最优结果为：0.8676200279391221
# 当前最优结果:0.880634328358209
# 第525次迭代，局部最优结果为：0.852791327913279
# 当前最优结果:0.880634328358209
# 本次退火用时：6555.772330284119
# 23
# 第1次迭代，局部最优结果为：0.5058621798306719
# 当前最优结果:0.5058621798306719
# 第2次迭代，局部最优结果为：0.5172255095332018
# 当前最优结果:0.5172255095332018
# 第3次迭代，局部最优结果为：0.540390163483995
# 当前最优结果:0.540390163483995
# 第4次迭代，局部最优结果为：0.5644686804907799
# 当前最优结果:0.5644686804907799
# 第5次迭代，局部最优结果为：0.5455743313530133
# 当前最优结果:0.5644686804907799
# 第6次迭代，局部最优结果为：0.5251668891855807
# 当前最优结果:0.5644686804907799
# 第7次迭代，局部最优结果为：0.49831088214180147
# 当前最优结果:0.5644686804907799
# 第8次迭代，局部最优结果为：0.5644686804907799
# 当前最优结果:0.5644686804907799
# 第9次迭代，局部最优结果为：0.5572319025357699
# 当前最优结果:0.5644686804907799
# 第10次迭代，局部最优结果为：0.5644686804907799
# 当前最优结果:0.5644686804907799
# 第11次迭代，局部最优结果为：0.5522639522639522
# 当前最优结果:0.5644686804907799
# 第12次迭代，局部最优结果为：0.5118412491867274
# 当前最优结果:0.5644686804907799
# 第13次迭代，局部最优结果为：0.5815345949142519
# 当前最优结果:0.581534594914252
# 第14次迭代，局部最优结果为：0.5413073394495413
# 当前最优结果:0.581534594914252
# 第15次迭代，局部最优结果为：0.5994970534444218
# 当前最优结果:0.5994970534444218
# 第16次迭代，局部最优结果为：0.5184070640952423
# 当前最优结果:0.5994970534444218
# 第17次迭代，局部最优结果为：0.5994970534444218
# 当前最优结果:0.5994970534444218
# 第18次迭代，局部最优结果为：0.5729371495156944
# 当前最优结果:0.5994970534444218
# 第19次迭代，局部最优结果为：0.517202840112202
# 当前最优结果:0.5994970534444218
# 第20次迭代，局部最优结果为：0.5878938846680782
# 当前最优结果:0.5994970534444218
# 第21次迭代，局部最优结果为：0.5994970534444218
# 当前最优结果:0.5994970534444218
# 第22次迭代，局部最优结果为：0.4992596039939076
# 当前最优结果:0.5994970534444218
# 第23次迭代，局部最优结果为：0.5955787720493603
# 当前最优结果:0.5994970534444218
# 第24次迭代，局部最优结果为：0.5694122756224668
# 当前最优结果:0.5994970534444218
# 第25次迭代，局部最优结果为：0.5473330241187384
# 当前最优结果:0.5994970534444218
# 第26次迭代，局部最优结果为：0.5207060121345836
# 当前最优结果:0.5994970534444218
# 第27次迭代，局部最优结果为：0.5658084004602992
# 当前最优结果:0.5994970534444218
# 第28次迭代，局部最优结果为：0.5585242332449829
# 当前最优结果:0.5994970534444218
# 第29次迭代，局部最优结果为：0.5281283566058002
# 当前最优结果:0.5994970534444218
# 第30次迭代，局部最优结果为：0.5994970534444218
# 当前最优结果:0.5994970534444218
# 第31次迭代，局部最优结果为：0.50602487135506
# 当前最优结果:0.5994970534444218
# 第32次迭代，局部最优结果为：0.5599553952737971
# 当前最优结果:0.5994970534444218
# 第33次迭代，局部最优结果为：0.5394514285714286
# 当前最优结果:0.5994970534444218
# 第34次迭代，局部最优结果为：0.5141382014639247
# 当前最优结果:0.5994970534444218
# 第35次迭代，局部最优结果为：0.5955787720493603
# 当前最优结果:0.5994970534444218
# 第36次迭代，局部最优结果为：0.48028083028083024
# 当前最优结果:0.5994970534444218
# 第37次迭代，局部最优结果为：0.5994970534444218
# 当前最优结果:0.5994970534444218
# 第38次迭代，局部最优结果为：0.572951058457953
# 当前最优结果:0.5994970534444218
# 第39次迭代，局部最优结果为：0.5187032967032967
# 当前最优结果:0.5994970534444218
# 第40次迭代，局部最优结果为：0.5271374966496918
# 当前最优结果:0.5994970534444218
# 第41次迭代，局部最优结果为：0.535412885662432
# 当前最优结果:0.5994970534444218
# 第42次迭代，局部最优结果为：0.5815345949142519
# 当前最优结果:0.5994970534444218
# 第43次迭代，局部最优结果为：0.5994970534444218
# 当前最优结果:0.5994970534444218
# 第44次迭代，局部最优结果为：0.592632583366814
# 当前最优结果:0.5994970534444218
# 第45次迭代，局部最优结果为：0.5498066439919862
# 当前最优结果:0.5994970534444218
# 第46次迭代，局部最优结果为：0.5482229965156794
# 当前最优结果:0.5994970534444218
# 第47次迭代，局部最优结果为：0.5666778716865156
# 当前最优结果:0.5994970534444218
# 第48次迭代，局部最优结果为：0.5599553952737971
# 当前最优结果:0.5994970534444218
# 第49次迭代，局部最优结果为：0.5994970534444218
# 当前最优结果:0.5994970534444218
# 第50次迭代，局部最优结果为：0.5994970534444218
# 当前最优结果:0.5994970534444218
# 第51次迭代，局部最优结果为：0.561367204224347
# 当前最优结果:0.5994970534444218
# 第52次迭代，局部最优结果为：0.5448060941828256
# 当前最优结果:0.5994970534444218
# 第53次迭代，局部最优结果为：0.5351700680272109
# 当前最优结果:0.5994970534444218
# 第54次迭代，局部最优结果为：0.6041624001638337
# 当前最优结果:0.6041624001638337
# 第55次迭代，局部最优结果为：0.5263380909901874
# 当前最优结果:0.6041624001638337
# 第56次迭代，局部最优结果为：0.5730623543123543
# 当前最优结果:0.6041624001638337
# 第57次迭代，局部最优结果为：0.6041624001638337
# 当前最优结果:0.6041624001638337
# 第58次迭代，局部最优结果为：0.6041624001638337
# 当前最优结果:0.6041624001638337
# 第59次迭代，局部最优结果为：0.5360208948444243
# 当前最优结果:0.6041624001638337
# 第60次迭代，局部最优结果为：0.592632583366814
# 当前最优结果:0.6041624001638337
# 第61次迭代，局部最优结果为：0.5245599217638691
# 当前最优结果:0.6041624001638337
# 第62次迭代，局部最优结果为：0.5837208151958845
# 当前最优结果:0.6041624001638337
# 第63次迭代，局部最优结果为：0.5210393853761921
# 当前最优结果:0.6041624001638337
# 第64次迭代，局部最优结果为：0.6025582107843137
# 当前最优结果:0.6041624001638337
# 第65次迭代，局部最优结果为：0.5755779923909862
# 当前最优结果:0.6041624001638337
# 第66次迭代，局部最优结果为：0.5585242332449829
# 当前最优结果:0.6041624001638337
# 第67次迭代，局部最优结果为：0.49356923269966746
# 当前最优结果:0.6041624001638337
# 第68次迭代，局部最优结果为：0.5107557132963989
# 当前最优结果:0.6041624001638337
# 第69次迭代，局部最优结果为：0.6041624001638337
# 当前最优结果:0.6041624001638337
# 第70次迭代，局部最优结果为：0.5233037694013304
# 当前最优结果:0.6041624001638337
# 第71次迭代，局部最优结果为：0.54100953603521
# 当前最优结果:0.6041624001638337
# 第72次迭代，局部最优结果为：0.5615007613247051
# 当前最优结果:0.6041624001638337
# 第73次迭代，局部最优结果为：0.6161497493734336
# 当前最优结果:0.6161497493734336
# 第74次迭代，局部最优结果为：0.5700724637681159
# 当前最优结果:0.6161497493734336
# 第75次迭代，局部最优结果为：0.6161497493734336
# 当前最优结果:0.6161497493734336
# 第76次迭代，局部最优结果为：0.6161497493734336
# 当前最优结果:0.6161497493734336
# 第77次迭代，局部最优结果为：0.6333288608613981
# 当前最优结果:0.6333288608613981
# 第78次迭代，局部最优结果为：0.5775640555025329
# 当前最优结果:0.6333288608613981
# 第79次迭代，局部最优结果为：0.5217766183233109
# 当前最优结果:0.6333288608613981
# 第80次迭代，局部最优结果为：0.5587357954545454
# 当前最优结果:0.6333288608613981
# 第81次迭代，局部最优结果为：0.6081634756616074
# 当前最优结果:0.6333288608613981
# 第82次迭代，局部最优结果为：0.6202954163162321
# 当前最优结果:0.6333288608613981
# 第83次迭代，局部最优结果为：0.6408091229975563
# 当前最优结果:0.6408091229975563
# 第84次迭代，局部最优结果为：0.5807332677165354
# 当前最优结果:0.6408091229975563
# 第85次迭代，局部最优结果为：0.6536767760697965
# 当前最优结果:0.6536767760697965
# 第86次迭代，局部最优结果为：0.6318875502008032
# 当前最优结果:0.6536767760697965
# 第87次迭代，局部最优结果为：0.5777761457109283
# 当前最优结果:0.6536767760697965
# 第88次迭代，局部最优结果为：0.6139698231009365
# 当前最优结果:0.6536767760697965
# 第89次迭代，局部最优结果为：0.6061485514690774
# 当前最优结果:0.6536767760697965
# 第90次迭代，局部最优结果为：0.5994970534444218
# 当前最优结果:0.6536767760697965
# 第91次迭代，局部最优结果为：0.599070971672251
# 当前最优结果:0.6536767760697965
# 第92次迭代，局部最优结果为：0.6194975982360815
# 当前最优结果:0.6536767760697965
# 第93次迭代，局部最优结果为：0.6073340195573854
# 当前最优结果:0.6536767760697965
# 第94次迭代，局部最优结果为：0.6007636502481863
# 当前最优结果:0.6536767760697965
# 第95次迭代，局部最优结果为：0.5825681279620853
# 当前最优结果:0.6536767760697965
# 第96次迭代，局部最优结果为：0.6139698231009365
# 当前最优结果:0.6536767760697965
# 第97次迭代，局部最优结果为：0.6536767760697965
# 当前最优结果:0.6536767760697965
# 第98次迭代，局部最优结果为：0.5587357954545454
# 当前最优结果:0.6536767760697965
# 第99次迭代，局部最优结果为：0.6344354838709678
# 当前最优结果:0.6536767760697965
# 第100次迭代，局部最优结果为：0.5233617917729239
# 当前最优结果:0.6536767760697965
# 第101次迭代，局部最优结果为：0.49684223822154855
# 当前最优结果:0.6536767760697965
# 第102次迭代，局部最优结果为：0.6723931623931624
# 当前最优结果:0.6723931623931624
# 第103次迭代，局部最优结果为：0.6266029470330545
# 当前最优结果:0.6723931623931624
# 第104次迭代，局部最优结果为：0.6723931623931624
# 当前最优结果:0.6723931623931624
# 第105次迭代，局部最优结果为：0.6499146334746929
# 当前最优结果:0.6723931623931624
# 第106次迭代，局部最优结果为：0.6407221392697163
# 当前最优结果:0.6723931623931624
# 第107次迭代，局部最优结果为：0.5770697833634897
# 当前最优结果:0.6723931623931624
# 第108次迭代，局部最优结果为：0.6698169433801618
# 当前最优结果:0.6723931623931624
# 第109次迭代，局部最优结果为：0.5906156156156156
# 当前最优结果:0.6723931623931624
# 第110次迭代，局部最优结果为：0.6011462047885889
# 当前最优结果:0.6723931623931624
# 第111次迭代，局部最优结果为：0.6625772038180797
# 当前最优结果:0.6723931623931624
# 第112次迭代，局部最优结果为：0.5843856782053186
# 当前最优结果:0.6723931623931624
# 第113次迭代，局部最优结果为：0.6563125695216908
# 当前最优结果:0.6723931623931624
# 第114次迭代，局部最优结果为：0.6723931623931624
# 当前最优结果:0.6723931623931624
# 第115次迭代，局部最优结果为：0.6723931623931624
# 当前最优结果:0.6723931623931624
# 第116次迭代，局部最优结果为：0.6051538461538462
# 当前最优结果:0.6723931623931624
# 第117次迭代，局部最优结果为：0.621897233201581
# 当前最优结果:0.6723931623931624
# 第118次迭代，局部最优结果为：0.6499146334746929
# 当前最优结果:0.6723931623931624
# 第119次迭代，局部最优结果为：0.5966628744785741
# 当前最优结果:0.6723931623931624
# 第120次迭代，局部最优结果为：0.6288569144684253
# 当前最优结果:0.6723931623931624
# 第121次迭代，局部最优结果为：0.5910149500413192
# 当前最优结果:0.6723931623931624
# 第122次迭代，局部最优结果为：0.6063354228753468
# 当前最优结果:0.6723931623931624
# 第123次迭代，局部最优结果为：0.692924251321198
# 当前最优结果:0.6929242513211978
# 第124次迭代，局部最优结果为：0.692924251321198
# 当前最优结果:0.6929242513211978
# 第125次迭代，局部最优结果为：0.5878938846680782
# 当前最优结果:0.6929242513211978
# 第126次迭代，局部最优结果为：0.545650012715881
# 当前最优结果:0.6929242513211978
# 第127次迭代，局部最优结果为：0.5856327543424318
# 当前最优结果:0.6929242513211978
# 第128次迭代，局部最优结果为：0.5251668891855807
# 当前最优结果:0.6929242513211978
# 第129次迭代，局部最优结果为：0.6133316008316008
# 当前最优结果:0.6929242513211978
# 第130次迭代，局部最优结果为：0.6874144409169022
# 当前最优结果:0.6929242513211978
# 第131次迭代，局部最优结果为：0.6672603901611535
# 当前最优结果:0.6929242513211978
# 第132次迭代，局部最优结果为：0.6133316008316008
# 当前最优结果:0.6929242513211978
# 第133次迭代，局部最优结果为：0.5856327543424318
# 当前最优结果:0.6929242513211978
# 第134次迭代，局部最优结果为：0.5006363752068219
# 当前最优结果:0.6929242513211978
# 第135次迭代，局部最优结果为：0.5539880756771983
# 当前最优结果:0.6929242513211978
# 第136次迭代，局部最优结果为：0.5215229592964158
# 当前最优结果:0.6929242513211978
# 第137次迭代，局部最优结果为：0.6955996345309322
# 当前最优结果:0.6955996345309322
# 第138次迭代，局部最优结果为：0.6475252414398596
# 当前最优结果:0.6955996345309322
# 第139次迭代，局部最优结果为：0.7092925407224859
# 当前最优结果:0.709292540722486
# 第140次迭代，局部最优结果为：0.6194488188976378
# 当前最优结果:0.709292540722486
# 第141次迭代，局部最优结果为：0.6553102873802582
# 当前最优结果:0.709292540722486
# 第142次迭代，局部最优结果为：0.7092925407224859
# 当前最优结果:0.709292540722486
# 第143次迭代，局部最优结果为：0.6220611491829204
# 当前最优结果:0.709292540722486
# 第144次迭代，局部最优结果为：0.6722399453116099
# 当前最优结果:0.709292540722486
# 第145次迭代，局部最优结果为：0.6722399453116099
# 当前最优结果:0.709292540722486
# 第146次迭代，局部最优结果为：0.5631352899069434
# 当前最优结果:0.709292540722486
# 第147次迭代，局部最优结果为：0.6636951631046119
# 当前最优结果:0.709292540722486
# 第148次迭代，局部最优结果为：0.7323589648110223
# 当前最优结果:0.7323589648110221
# 第149次迭代，局部最优结果为：0.683195831524099
# 当前最优结果:0.7323589648110221
# 第150次迭代，局部最优结果为：0.6908351140122354
# 当前最优结果:0.7323589648110221
# 第151次迭代，局部最优结果为：0.6672603901611535
# 当前最优结果:0.7323589648110221
# 第152次迭代，局部最优结果为：0.594169331084313
# 当前最优结果:0.7323589648110221
# 第153次迭代，局部最优结果为：0.6751051231442547
# 当前最优结果:0.7323589648110221
# 第154次迭代，局部最优结果为：0.6335838926174497
# 当前最优结果:0.7323589648110221
# 第155次迭代，局部最优结果为：0.7177701408108026
# 当前最优结果:0.7323589648110221
# 第156次迭代，局部最优结果为：0.6457358614462776
# 当前最优结果:0.7323589648110221
# 第157次迭代，局部最优结果为：0.6438860697331805
# 当前最优结果:0.7323589648110221
# 第158次迭代，局部最优结果为：0.6677134612120184
# 当前最优结果:0.7323589648110221
# 第159次迭代，局部最优结果为：0.6227012479881797
# 当前最优结果:0.7323589648110221
# 第160次迭代，局部最优结果为：0.579905646469114
# 当前最优结果:0.7323589648110221
# 第161次迭代，局部最优结果为：0.6299311375647253
# 当前最优结果:0.7323589648110221
# 第162次迭代，局部最优结果为：0.7323589648110223
# 当前最优结果:0.7323589648110221
# 第163次迭代，局部最优结果为：0.6756269323256613
# 当前最优结果:0.7323589648110221
# 第164次迭代，局部最优结果为：0.7004095441595442
# 当前最优结果:0.7323589648110221
# 第165次迭代，局部最优结果为：0.5789667353547248
# 当前最优结果:0.7323589648110221
# 第166次迭代，局部最优结果为：0.6112981765437215
# 当前最优结果:0.7323589648110221
# 第167次迭代，局部最优结果为：0.7106594399277326
# 当前最优结果:0.7323589648110221
# 第168次迭代，局部最优结果为：0.7177701408108026
# 当前最优结果:0.7323589648110221
# 第169次迭代，局部最优结果为：0.6194488188976378
# 当前最优结果:0.7323589648110221
# 第170次迭代，局部最优结果为：0.6454179998359176
# 当前最优结果:0.7323589648110221
# 第171次迭代，局部最优结果为：0.6034672326063055
# 当前最优结果:0.7323589648110221
# 第172次迭代，局部最优结果为：0.6756269323256613
# 当前最优结果:0.7323589648110221
# 第173次迭代，局部最优结果为：0.7323589648110223
# 当前最优结果:0.7323589648110221
# 第174次迭代，局部最优结果为：0.5947832661290323
# 当前最优结果:0.7323589648110221
# 第175次迭代，局部最优结果为：0.6689625850340135
# 当前最优结果:0.7323589648110221
# 第176次迭代，局部最优结果为：0.6655292989679092
# 当前最优结果:0.7323589648110221
# 第177次迭代，局部最优结果为：0.6756269323256613
# 当前最优结果:0.7323589648110221
# 第178次迭代，局部最优结果为：0.65751936256756
# 当前最优结果:0.7323589648110221
# 第179次迭代，局部最优结果为：0.6045647830319176
# 当前最优结果:0.7323589648110221
# 第180次迭代，局部最优结果为：0.6982957571453932
# 当前最优结果:0.7323589648110221
# 第181次迭代，局部最优结果为：0.735348185075557
# 当前最优结果:0.735348185075557
# 第182次迭代，局部最优结果为：0.6430089363557105
# 当前最优结果:0.735348185075557
# 第183次迭代，局部最优结果为：0.5826831917835276
# 当前最优结果:0.735348185075557
# 第184次迭代，局部最优结果为：0.6379510744695229
# 当前最优结果:0.735348185075557
# 第185次迭代，局部最优结果为：0.735348185075557
# 当前最优结果:0.735348185075557
# 第186次迭代，局部最优结果为：0.7264528441270623
# 当前最优结果:0.735348185075557
# 第187次迭代，局部最优结果为：0.7155287412078584
# 当前最优结果:0.735348185075557
# 第188次迭代，局部最优结果为：0.6296118447378952
# 当前最优结果:0.735348185075557
# 第189次迭代，局部最优结果为：0.735348185075557
# 当前最优结果:0.735348185075557
# 第190次迭代，局部最优结果为：0.5730623543123543
# 当前最优结果:0.735348185075557
# 第191次迭代，局部最优结果为：0.6465141761402547
# 当前最优结果:0.735348185075557
# 第192次迭代，局部最优结果为：0.7177701408108026
# 当前最优结果:0.735348185075557
# 第193次迭代，局部最优结果为：0.735348185075557
# 当前最优结果:0.735348185075557
# 第194次迭代，局部最优结果为：0.6753755902131922
# 当前最优结果:0.735348185075557
# 第195次迭代，局部最优结果为：0.6434296619411124
# 当前最优结果:0.735348185075557
# 第196次迭代，局部最优结果为：0.6824253990284525
# 当前最优结果:0.735348185075557
# 第197次迭代，局部最优结果为：0.6027428746552252
# 当前最优结果:0.735348185075557
# 第198次迭代，局部最优结果为：0.6800265083847173
# 当前最优结果:0.735348185075557
# 第199次迭代，局部最优结果为：0.735348185075557
# 当前最优结果:0.735348185075557
# 第200次迭代，局部最优结果为：0.7065110013471037
# 当前最优结果:0.735348185075557
# 第201次迭代，局部最优结果为：0.6722399453116099
# 当前最优结果:0.735348185075557
# 第202次迭代，局部最优结果为：0.6303685897435898
# 当前最优结果:0.735348185075557
# 第203次迭代，局部最优结果为：0.5661341393206678
# 当前最优结果:0.735348185075557
# 第204次迭代，局部最优结果为：0.7633911243369129
# 当前最优结果:0.7633911243369129
# 第205次迭代，局部最优结果为：0.6573362299465241
# 当前最优结果:0.7633911243369129
# 第206次迭代，局部最优结果为：0.7633911243369129
# 当前最优结果:0.7633911243369129
# 第207次迭代，局部最优结果为：0.6844043614429881
# 当前最优结果:0.7633911243369129
# 第208次迭代，局部最优结果为：0.7633911243369129
# 当前最优结果:0.7633911243369129
# 第209次迭代，局部最优结果为：0.6809093794177895
# 当前最优结果:0.7633911243369129
# 第210次迭代，局部最优结果为：0.6135229281480711
# 当前最优结果:0.7633911243369129
# 第211次迭代，局部最优结果为：0.597856925727024
# 当前最优结果:0.7633911243369129
# 第212次迭代，局部最优结果为：0.7293939487591556
# 当前最优结果:0.7633911243369129
# 第213次迭代，局部最优结果为：0.6329382106844025
# 当前最优结果:0.7633911243369129
# 第214次迭代，局部最优结果为：0.6329382106844025
# 当前最优结果:0.7633911243369129
# 第215次迭代，局部最优结果为：0.7633911243369129
# 当前最优结果:0.7633911243369129
# 第216次迭代，局部最优结果为：0.6328024453024453
# 当前最优结果:0.7633911243369129
# 第217次迭代，局部最优结果为：0.7293939487591556
# 当前最优结果:0.7633911243369129
# 第218次迭代，局部最优结果为：0.6299311375647253
# 当前最优结果:0.7633911243369129
# 第219次迭代，局部最优结果为：0.7308621330360461
# 当前最优结果:0.7633911243369129
# 第220次迭代，局部最优结果为：0.6622053872053872
# 当前最优结果:0.7633911243369129
# 第221次迭代，局部最优结果为：0.7633911243369129
# 当前最优结果:0.7633911243369129
# 第222次迭代，局部最优结果为：0.6671472184531886
# 当前最优结果:0.7633911243369129
# 第223次迭代，局部最优结果为：0.5714527845036319
# 当前最优结果:0.7633911243369129
# 第224次迭代，局部最优结果为：0.6117101238919704
# 当前最优结果:0.7633911243369129
# 第225次迭代，局部最优结果为：0.6303012498664673
# 当前最优结果:0.7633911243369129
# 第226次迭代，局部最优结果为：0.6623540637629097
# 当前最优结果:0.7633911243369129
# 第227次迭代，局部最优结果为：0.6782286338295304
# 当前最优结果:0.7633911243369129
# 第228次迭代，局部最优结果为：0.7633911243369129
# 当前最优结果:0.7633911243369129
# 第229次迭代，局部最优结果为：0.5525095982769922
# 当前最优结果:0.7633911243369129
# 第230次迭代，局部最优结果为：0.7633911243369129
# 当前最优结果:0.7633911243369129
# 第231次迭代，局部最优结果为：0.7633911243369129
# 当前最优结果:0.7633911243369129
# 第232次迭代，局部最优结果为：0.6820704005548812
# 当前最优结果:0.7633911243369129
# 第233次迭代，局部最优结果为：0.6622797171399708
# 当前最优结果:0.7633911243369129
# 第234次迭代，局部最优结果为：0.7633911243369129
# 当前最优结果:0.7633911243369129
# 第235次迭代，局部最优结果为：0.6722399453116099
# 当前最优结果:0.7633911243369129
# 第236次迭代，局部最优结果为：0.6536224659355268
# 当前最优结果:0.7633911243369129
# 第237次迭代，局部最优结果为：0.6277362555523047
# 当前最优结果:0.7633911243369129
# 第238次迭代，局部最优结果为：0.5361913849509269
# 当前最优结果:0.7633911243369129
# 第239次迭代，局部最优结果为：0.6876347532195093
# 当前最优结果:0.7633911243369129
# 第240次迭代，局部最优结果为：0.7633911243369129
# 当前最优结果:0.7633911243369129
# 第241次迭代，局部最优结果为：0.7010128612587995
# 当前最优结果:0.7633911243369129
# 第242次迭代，局部最优结果为：0.6772943809906445
# 当前最优结果:0.7633911243369129
# 第243次迭代，局部最优结果为：0.5814486326681448
# 当前最优结果:0.7633911243369129
# 第244次迭代，局部最优结果为：0.7037511927480916
# 当前最优结果:0.7633911243369129
# 第245次迭代，局部最优结果为：0.6826622700451233
# 当前最优结果:0.7633911243369129
# 第246次迭代，局部最优结果为：0.6478096179183136
# 当前最优结果:0.7633911243369129
# 第247次迭代，局部最优结果为：0.5691925525757283
# 当前最优结果:0.7633911243369129
# 第248次迭代，局部最优结果为：0.7092499098449333
# 当前最优结果:0.7633911243369129
# 第249次迭代，局部最优结果为：0.6006260497785921
# 当前最优结果:0.7633911243369129
# 第250次迭代，局部最优结果为：0.6478096179183136
# 当前最优结果:0.7633911243369129
# 第251次迭代，局部最优结果为：0.633074034334764
# 当前最优结果:0.7633911243369129
# 第252次迭代，局部最优结果为：0.6867943196368292
# 当前最优结果:0.7633911243369129
# 第253次迭代，局部最优结果为：0.6005343511450382
# 当前最优结果:0.7633911243369129
# 第254次迭代，局部最优结果为：0.7732201946073453
# 当前最优结果:0.7732201946073453
# 第255次迭代，局部最优结果为：0.7092925407224859
# 当前最优结果:0.7732201946073453
# 第256次迭代，局部最优结果为：0.76736246586032
# 当前最优结果:0.7732201946073453
# 第257次迭代，局部最优结果为：0.6798110435809546
# 当前最优结果:0.7732201946073453
# 第258次迭代，局部最优结果为：0.5736194827921447
# 当前最优结果:0.7732201946073453
# 第259次迭代，局部最优结果为：0.6890601734255934
# 当前最优结果:0.7732201946073453
# 第260次迭代，局部最优结果为：0.7083345838710645
# 当前最优结果:0.7732201946073453
# 第261次迭代，局部最优结果为：0.6086496802145658
# 当前最优结果:0.7732201946073453
# 第262次迭代，局部最优结果为：0.7188851660067012
# 当前最优结果:0.7732201946073453
# 第263次迭代，局部最优结果为：0.7407721280602637
# 当前最优结果:0.7732201946073453
# 第264次迭代，局部最优结果为：0.7732201946073453
# 当前最优结果:0.7732201946073453
# 第265次迭代，局部最优结果为：0.5950231948366277
# 当前最优结果:0.7732201946073453
# 第266次迭代，局部最优结果为：0.6174070004708837
# 当前最优结果:0.7732201946073453
# 第267次迭代，局部最优结果为：0.7323589648110223
# 当前最优结果:0.7732201946073453
# 第268次迭代，局部最优结果为：0.7414004335123927
# ...
# 当前最优结果:0.723136317676257
# 第263次迭代，局部最优结果为：0.6909969257795345
# 当前最优结果:0.723136317676257
# 第264次迭代，局部最优结果为：0.5830286561264821
# 当前最优结果:0.723136317676257
# 第265次迭代，局部最优结果为：0.723136317676257
# 当前最优结果:0.723136317676257
# 第266次迭代，局部最优结果为：0.5651580459770115
# 当前最优结果:0.723136317676257
# 第267次迭代，局部最优结果为：0.6492352552816901
# 当前最优结果:0.723136317676257
# 第268次迭代，局部最优结果为：0.634589013471001
# 当前最优结果:0.723136317676257
# 第269次迭代，局部最优结果为：0.6161497493734336
# 当前最优结果:0.723136317676257
# 第270次迭代，局部最优结果为：0.6909969257795345
# 当前最优结果:0.723136317676257
# 第271次迭代，局部最优结果为：0.7036672629695886
# 当前最优结果:0.723136317676257
# 第272次迭代，局部最优结果为：0.639697511790535
# 当前最优结果:0.723136317676257
# 第273次迭代，局部最优结果为：0.6375547031174024
# 当前最优结果:0.723136317676257
# 第274次迭代，局部最优结果为：0.6177787084783918
# 当前最优结果:0.723136317676257
# 第275次迭代，局部最优结果为：0.6478096179183136
# 当前最优结果:0.723136317676257
# 第276次迭代，局部最优结果为：0.6628749578699022
# 当前最优结果:0.723136317676257
# 第277次迭代，局部最优结果为：0.5826256541917646
# 当前最优结果:0.723136317676257
# 第278次迭代，局部最优结果为：0.5978872169022648
# 当前最优结果:0.723136317676257
# 第279次迭代，局部最优结果为：0.7118812777124243
# 当前最优结果:0.723136317676257
# 第280次迭代，局部最优结果为：0.6071465322082733
# 当前最优结果:0.723136317676257
# 第281次迭代，局部最优结果为：0.5596101863707498
# 当前最优结果:0.723136317676257
# 第282次迭代，局部最优结果为：0.6416104828186168
# 当前最优结果:0.723136317676257
# 第283次迭代，局部最优结果为：0.7036672629695886
# 当前最优结果:0.723136317676257
# 第284次迭代，局部最优结果为：0.6663184641445511
# 当前最优结果:0.723136317676257
# 第285次迭代，局部最优结果为：0.6909969257795345
# 当前最优结果:0.723136317676257
# 第286次迭代，局部最优结果为：0.6020663265306123
# 当前最优结果:0.723136317676257
# 第287次迭代，局部最优结果为：0.723136317676257
# 当前最优结果:0.723136317676257
# 第288次迭代，局部最优结果为：0.6303685897435898
# 当前最优结果:0.723136317676257
# 第289次迭代，局部最优结果为：0.6642181695373185
# 当前最优结果:0.723136317676257
# 第290次迭代，局部最优结果为：0.6759752534799794
# 当前最优结果:0.723136317676257
# 第291次迭代，局部最优结果为：0.723136317676257
# 当前最优结果:0.723136317676257
# 第292次迭代，局部最优结果为：0.5909705528846154
# 当前最优结果:0.723136317676257
# 第293次迭代，局部最优结果为：0.6611665172568355
# 当前最优结果:0.723136317676257
# 第294次迭代，局部最优结果为：0.6093096504363092
# 当前最优结果:0.723136317676257
# 第295次迭代，局部最优结果为：0.5886710565698893
# 当前最优结果:0.723136317676257
# 第296次迭代，局部最优结果为：0.6638818565400844
# 当前最优结果:0.723136317676257
# 第297次迭代，局部最优结果为：0.6982957571453932
# 当前最优结果:0.723136317676257
# 第298次迭代，局部最优结果为：0.7091220479538489
# 当前最优结果:0.723136317676257
# 第299次迭代，局部最优结果为：0.6961536192555012
# 当前最优结果:0.723136317676257
# 第300次迭代，局部最优结果为：0.5948732167162373
# 当前最优结果:0.723136317676257
# 第301次迭代，局部最优结果为：0.6242329665679222
# 当前最优结果:0.723136317676257
# 第302次迭代，局部最优结果为：0.6314479880136986
# 当前最优结果:0.723136317676257
# 第303次迭代，局部最优结果为：0.648771235362032
# 当前最优结果:0.723136317676257
# 第304次迭代，局部最优结果为：0.6492352552816901
# 当前最优结果:0.723136317676257
# 第305次迭代，局部最优结果为：0.6269025420352219
# 当前最优结果:0.723136317676257
# 第306次迭代，局部最优结果为：0.7009712198164484
# 当前最优结果:0.723136317676257
# 第307次迭代，局部最优结果为：0.6001678364357644
# 当前最优结果:0.723136317676257
# 第308次迭代，局部最优结果为：0.6852190575733821
# 当前最优结果:0.723136317676257
# 第309次迭代，局部最优结果为：0.7091220479538489
# 当前最优结果:0.723136317676257
# 第310次迭代，局部最优结果为：0.6770223752151463
# 当前最优结果:0.723136317676257
# 第311次迭代，局部最优结果为：0.6433419653809459
# 当前最优结果:0.723136317676257
# 第312次迭代，局部最优结果为：0.6956406401980724
# 当前最优结果:0.723136317676257
# 第313次迭代，局部最优结果为：0.7036672629695886
# 当前最优结果:0.723136317676257
# 第314次迭代，局部最优结果为：0.7146620639534883
# 当前最优结果:0.723136317676257
# 第315次迭代，局部最优结果为：0.6778779871323529
# 当前最优结果:0.723136317676257
# 第316次迭代，局部最优结果为：0.6492352552816901
# 当前最优结果:0.723136317676257
# 第317次迭代，局部最优结果为：0.6569336970439236
# 当前最优结果:0.723136317676257
# 第318次迭代，局部最优结果为：0.723136317676257
# 当前最优结果:0.723136317676257
# 第319次迭代，局部最优结果为：0.7091220479538489
# 当前最优结果:0.723136317676257
# 第320次迭代，局部最优结果为：0.6301161393672406
# 当前最优结果:0.723136317676257
# 第321次迭代，局部最优结果为：0.6493067018818092
# 当前最优结果:0.723136317676257
# 第322次迭代，局部最优结果为：0.6313804173354735
# 当前最优结果:0.723136317676257
# 第323次迭代，局部最优结果为：0.6726231190150478
# 当前最优结果:0.723136317676257
# 第324次迭代，局部最优结果为：0.6581060732809102
# 当前最优结果:0.723136317676257
# 第325次迭代，局部最优结果为：0.621897233201581
# 当前最优结果:0.723136317676257
# 第326次迭代，局部最优结果为：0.6759752534799794
# 当前最优结果:0.723136317676257
# 第327次迭代，局部最优结果为：0.7120960685514287
# 当前最优结果:0.723136317676257
# 第328次迭代，局部最优结果为：0.648771235362032
# 当前最优结果:0.723136317676257
# 第329次迭代，局部最优结果为：0.6674490950226244
# 当前最优结果:0.723136317676257
# 第330次迭代，局部最优结果为：0.6368321640582839
# 当前最优结果:0.723136317676257
# 第331次迭代，局部最优结果为：0.6441496765741423
# 当前最优结果:0.723136317676257
# 第332次迭代，局部最优结果为：0.723136317676257
# 当前最优结果:0.723136317676257
# 第333次迭代，局部最优结果为：0.706701401365433
# 当前最优结果:0.723136317676257
# 第334次迭代，局部最优结果为：0.6451004510045101
# 当前最优结果:0.723136317676257
# 第335次迭代，局部最优结果为：0.6644425675675675
# 当前最优结果:0.723136317676257
# 第336次迭代，局部最优结果为：0.6918679643527205
# 当前最优结果:0.723136317676257
# 第337次迭代，局部最优结果为：0.6436753395516281
# 当前最优结果:0.723136317676257
# 第338次迭代，局部最优结果为：0.6961536192555012
# 当前最优结果:0.723136317676257
# 第339次迭代，局部最优结果为：0.723136317676257
# 当前最优结果:0.723136317676257
# 第340次迭代，局部最优结果为：0.638140817650876
# 当前最优结果:0.723136317676257
# 第341次迭代，局部最优结果为：0.6595405767940979
# 当前最优结果:0.723136317676257
# 第342次迭代，局部最优结果为：0.6628749578699022
# 当前最优结果:0.723136317676257
# 第343次迭代，局部最优结果为：0.6889998248379752
# 当前最优结果:0.723136317676257
# 第344次迭代，局部最优结果为：0.723136317676257
# 当前最优结果:0.723136317676257
# 第345次迭代，局部最优结果为：0.7118812777124243
# 当前最优结果:0.723136317676257
# 第346次迭代，局部最优结果为：0.7149218466012359
# 当前最优结果:0.723136317676257
# 第347次迭代，局部最优结果为：0.7235353628253473
# 当前最优结果:0.7235353628253471
# 第348次迭代，局部最优结果为：0.7091220479538489
# 当前最优结果:0.7235353628253471
# 第349次迭代，局部最优结果为：0.6595405767940979
# 当前最优结果:0.7235353628253471
# 第350次迭代，局部最优结果为：0.674025417678138
# 当前最优结果:0.7235353628253471
# 第351次迭代，局部最优结果为：0.6582161981258368
# 当前最优结果:0.7235353628253471
# 第352次迭代，局部最优结果为：0.6652854122621565
# 当前最优结果:0.7235353628253471
# 第353次迭代，局部最优结果为：0.7065110013471037
# 当前最优结果:0.7235353628253471
# 第354次迭代，局部最优结果为：0.7184256187026271
# 当前最优结果:0.7235353628253471
# 第355次迭代，局部最优结果为：0.6592458100558659
# 当前最优结果:0.7235353628253471
# 第356次迭代，局部最优结果为：0.6601678321678321
# 当前最优结果:0.7235353628253471
# 第357次迭代，局部最优结果为：0.7012628138463823
# 当前最优结果:0.7235353628253471
# 第358次迭代，局部最优结果为：0.7235353628253473
# 当前最优结果:0.7235353628253471
# 第359次迭代，局部最优结果为：0.6969347980155918
# 当前最优结果:0.7235353628253471
# 第360次迭代，局部最优结果为：0.7235353628253473
# 当前最优结果:0.7235353628253471
# 第361次迭代，局部最优结果为：0.7235353628253473
# 当前最优结果:0.7235353628253471
# 第362次迭代，局部最优结果为：0.7235353628253473
# 当前最优结果:0.7235353628253471
# 第363次迭代，局部最优结果为：0.6980066248669112
# 当前最优结果:0.7235353628253471
# 第364次迭代，局部最优结果为：0.7235353628253473
# 当前最优结果:0.7235353628253471
# 第365次迭代，局部最优结果为：0.701283651274737
# 当前最优结果:0.7235353628253471
# 第366次迭代，局部最优结果为：0.701283651274737
# 当前最优结果:0.7235353628253471
# 第367次迭代，局部最优结果为：0.7180540343190945
# 当前最优结果:0.7235353628253471
# 第368次迭代，局部最优结果为：0.7128057988523104
# 当前最优结果:0.7235353628253471
# 第369次迭代，局部最优结果为：0.7149218466012359
# 当前最优结果:0.7235353628253471
# 第370次迭代，局部最优结果为：0.7020972780008925
# 当前最优结果:0.7235353628253471
# 第371次迭代，局部最优结果为：0.7347529653497712
# 当前最优结果:0.7347529653497712
# 第372次迭代，局部最优结果为：0.7202893242995788
# 当前最优结果:0.7347529653497712
# 第373次迭代，局部最优结果为：0.7347529653497712
# 当前最优结果:0.7347529653497712
# 第374次迭代，局部最优结果为：0.7135600907029478
# 当前最优结果:0.7347529653497712
# 第375次迭代，局部最优结果为：0.7009712198164484
# 当前最优结果:0.7347529653497712
# 第376次迭代，局部最优结果为：0.6956406401980724
# 当前最优结果:0.7347529653497712
# 第377次迭代，局部最优结果为：0.6889998248379752
# 当前最优结果:0.7347529653497712
# 第378次迭代，局部最优结果为：0.6837896566710125
# 当前最优结果:0.7347529653497712
# 第379次迭代，局部最优结果为：0.7089942321557319
# 当前最优结果:0.7347529653497712
# 第380次迭代，局部最优结果为：0.7174646602827178
# 当前最优结果:0.7347529653497712
# 第381次迭代，局部最优结果为：0.6930056377730797
# 当前最优结果:0.7347529653497712
# 第382次迭代，局部最优结果为：0.7393796992481203
# 当前最优结果:0.7393796992481203
# 第383次迭代，局部最优结果为：0.7146620639534883
# 当前最优结果:0.7393796992481203
# 第384次迭代，局部最优结果为：0.7393796992481203
# 当前最优结果:0.7393796992481203
# 第385次迭代，局部最优结果为：0.7393796992481203
# 当前最优结果:0.7393796992481203
# 第386次迭代，局部最优结果为：0.7032060067933973
# 当前最优结果:0.7393796992481203
# 第387次迭代，局部最优结果为：0.7372547794577033
# 当前最优结果:0.7393796992481203
# 第388次迭代，局部最优结果为：0.702996544739664
# 当前最优结果:0.7393796992481203
# 第389次迭代，局部最优结果为：0.7091220479538489
# 当前最优结果:0.7393796992481203
# 第390次迭代，局部最优结果为：0.7040451047073564
# 当前最优结果:0.7393796992481203
# 第391次迭代，局部最优结果为：0.7393796992481203
# 当前最优结果:0.7393796992481203
# 第392次迭代，局部最优结果为：0.7763486842105263
# 当前最优结果:0.7763486842105263
# 第393次迭代，局部最优结果为：0.7393796992481203
# 当前最优结果:0.7763486842105263
# 第394次迭代，局部最优结果为：0.7662662337662338
# 当前最优结果:0.7763486842105263
# 第395次迭代，局部最优结果为：0.733793489413301
# 当前最优结果:0.7763486842105263
# 第396次迭代，局部最优结果为：0.7169633635093262
# 当前最优结果:0.7763486842105263
# 第397次迭代，局部最优结果为：0.7147053479498516
# 当前最优结果:0.7763486842105263
# 第398次迭代，局部最优结果为：0.7081008100810081
# 当前最优结果:0.7763486842105263
# 第399次迭代，局部最优结果为：0.7763486842105263
# 当前最优结果:0.7763486842105263
# 第400次迭代，局部最优结果为：0.7500953470633105
# 当前最优结果:0.7763486842105263
# 第401次迭代，局部最优结果为：0.7763486842105263
# 当前最优结果:0.7763486842105263
# 第402次迭代，局部最优结果为：0.7285383546843649
# 当前最优结果:0.7763486842105263
# 第403次迭代，局部最优结果为：0.7040451047073564
# 当前最优结果:0.7763486842105263
# 第404次迭代，局部最优结果为：0.7763486842105263
# 当前最优结果:0.7763486842105263
# 第405次迭代，局部最优结果为：0.7429174011583984
# 当前最优结果:0.7763486842105263
# 第406次迭代，局部最优结果为：0.7506201895553718
# 当前最优结果:0.7763486842105263
# 第407次迭代，局部最优结果为：0.7763486842105263
# 当前最优结果:0.7763486842105263
# 第408次迭代，局部最优结果为：0.7763486842105263
# 当前最优结果:0.7763486842105263
# 第409次迭代，局部最优结果为：0.7393796992481203
# 当前最优结果:0.7763486842105263
# 第410次迭代，局部最优结果为：0.7613225806451613
# 当前最优结果:0.7763486842105263
# 第411次迭代，局部最优结果为：0.7151818181818183
# 当前最优结果:0.7763486842105263
# 第412次迭代，局部最优结果为：0.7841905901116427
# 当前最优结果:0.7841905901116427
# 第413次迭代，局部最优结果为：0.762996249838355
# 当前最优结果:0.7841905901116427
# 第414次迭代，局部最优结果为：0.7763486842105263
# 当前最优结果:0.7841905901116427
# 第415次迭代，局部最优结果为：0.762996249838355
# 当前最优结果:0.7841905901116427
# 第416次迭代，局部最优结果为：0.762996249838355
# 当前最优结果:0.7841905901116427
# 第417次迭代，局部最优结果为：0.762996249838355
# 当前最优结果:0.7841905901116427
# 第418次迭代，局部最优结果为：0.7690127077223851
# 当前最优结果:0.7841905901116427
# 第419次迭代，局部最优结果为：0.7734482532607984
# 当前最优结果:0.7841905901116427
# 第420次迭代，局部最优结果为：0.7930443548387097
# 当前最优结果:0.7930443548387097
# 第421次迭代，局部最优结果为：0.7651483222564436
# 当前最优结果:0.7930443548387097
# 第422次迭代，局部最优结果为：0.8027551020408162
# 当前最优结果:0.8027551020408163
# 第423次迭代，局部最优结果为：0.8027551020408162
# 当前最优结果:0.8027551020408163
# 第424次迭代，局部最优结果为：0.7973310810810812
# 当前最优结果:0.8027551020408163
# 第425次迭代，局部最优结果为：0.7973310810810812
# 当前最优结果:0.8027551020408163
# 第426次迭代，局部最优结果为：0.7714005556463474
# 当前最优结果:0.8027551020408163
# 第427次迭代，局部最优结果为：0.8027551020408162
# 当前最优结果:0.8027551020408163
# 第428次迭代，局部最优结果为：0.8194791666666666
# 当前最优结果:0.8194791666666666
# 第429次迭代，局部最优结果为：0.8194791666666666
# 当前最优结果:0.8194791666666666
# 第430次迭代，局部最优结果为：0.7861758827448367
# 当前最优结果:0.8194791666666666
# 第431次迭代，局部最优结果为：0.7959596640922735
# 当前最优结果:0.8194791666666666
# 第432次迭代，局部最优结果为：0.8194791666666666
# 当前最优结果:0.8194791666666666
# 第433次迭代，局部最优结果为：0.8179171720672327
# 当前最优结果:0.8194791666666666
# 第434次迭代，局部最优结果为：0.7973310810810812
# 当前最优结果:0.8194791666666666
# 第435次迭代，局部最优结果为：0.8194791666666666
# 当前最优结果:0.8194791666666666
# 第436次迭代，局部最优结果为：0.8194791666666666
# 当前最优结果:0.8194791666666666
# 第437次迭代，局部最优结果为：0.8030828909759086
# 当前最优结果:0.8194791666666666
# 第438次迭代，局部最优结果为：0.7749211977935382
# 当前最优结果:0.8194791666666666
# 第439次迭代，局部最优结果为：0.8154021558872305
# 当前最优结果:0.8194791666666666
# 第440次迭代，局部最优结果为：0.7763486842105263
# 当前最优结果:0.8194791666666666
# 第441次迭代，局部最优结果为：0.8154021558872305
# 当前最优结果:0.8194791666666666
# 第442次迭代，局部最优结果为：0.8194791666666666
# 当前最优结果:0.8194791666666666
# 第443次迭代，局部最优结果为：0.7959596640922735
# 当前最优结果:0.8194791666666666
# 第444次迭代，局部最优结果为：0.8207045241158675
# 当前最优结果:0.8207045241158675
# 第445次迭代，局部最优结果为：0.8194791666666666
# 当前最优结果:0.8207045241158675
# 第446次迭代，局部最优结果为：0.8207045241158675
# 当前最优结果:0.8207045241158675
# 第447次迭代，局部最优结果为：0.7959596640922735
# 当前最优结果:0.8207045241158675
# 第448次迭代，局部最优结果为：0.7962550607287449
# 当前最优结果:0.8207045241158675
# 第449次迭代，局部最优结果为：0.7973310810810812
# 当前最优结果:0.8207045241158675
# 第450次迭代，局部最优结果为：0.821104268865463
# 当前最优结果:0.821104268865463
# 第451次迭代，局部最优结果为：0.821104268865463
# 当前最优结果:0.821104268865463
# 第452次迭代，局部最优结果为：0.821104268865463
# 当前最优结果:0.821104268865463
# 第453次迭代，局部最优结果为：0.821104268865463
# 当前最优结果:0.821104268865463
# 第454次迭代，局部最优结果为：0.821104268865463
# 当前最优结果:0.821104268865463
# 第455次迭代，局部最优结果为：0.821104268865463
# 当前最优结果:0.821104268865463
# 第456次迭代，局部最优结果为：0.8081427201753184
# 当前最优结果:0.821104268865463
# 第457次迭代，局部最优结果为：0.8293565730751661
# 当前最优结果:0.8293565730751661
# 第458次迭代，局部最优结果为：0.8293565730751661
# 当前最优结果:0.8293565730751661
# 第459次迭代，局部最优结果为：0.8293565730751661
# 当前最优结果:0.8293565730751661
# 第460次迭代，局部最优结果为：0.821104268865463
# 当前最优结果:0.8293565730751661
# 第461次迭代，局部最优结果为：0.8050827221558929
# 当前最优结果:0.8293565730751661
# 第462次迭代，局部最优结果为：0.8081427201753184
# 当前最优结果:0.8293565730751661
# 第463次迭代，局部最优结果为：0.8081427201753184
# 当前最优结果:0.8293565730751661
# 第464次迭代，局部最优结果为：0.8293565730751661
# 当前最优结果:0.8293565730751661
# 第465次迭代，局部最优结果为：0.821104268865463
# 当前最优结果:0.8293565730751661
# 第466次迭代，局部最优结果为：0.8332509532551899
# 当前最优结果:0.8332509532551899
# 第467次迭代，局部最优结果为：0.8235971524288107
# 当前最优结果:0.8332509532551899
# 第468次迭代，局部最优结果为：0.8081427201753184
# 当前最优结果:0.8332509532551899
# 第469次迭代，局部最优结果为：0.8081427201753184
# 当前最优结果:0.8332509532551899
# 第470次迭代，局部最优结果为：0.8207045241158675
# 当前最优结果:0.8332509532551899
# 第471次迭代，局部最优结果为：0.8081427201753184
# 当前最优结果:0.8332509532551899
# 第472次迭代，局部最优结果为：0.827582579423522
# 当前最优结果:0.8332509532551899
# 第473次迭代，局部最优结果为：0.8289778714436249
# 当前最优结果:0.8332509532551899
# 第474次迭代，局部最优结果为：0.8332509532551899
# 当前最优结果:0.8332509532551899
# 第475次迭代，局部最优结果为：0.8205618524441972
# 当前最优结果:0.8332509532551899
# 第476次迭代，局部最优结果为：0.8293565730751661
# 当前最优结果:0.8332509532551899
# 第477次迭代，局部最优结果为：0.8332509532551899
# 当前最优结果:0.8332509532551899
# 第478次迭代，局部最优结果为：0.8332509532551899
# 当前最优结果:0.8332509532551899
# 第479次迭代，局部最优结果为：0.8207045241158675
# 当前最优结果:0.8332509532551899
# 第480次迭代，局部最优结果为：0.8177754677754677
# 当前最优结果:0.8332509532551899
# 第481次迭代，局部最优结果为：0.8081427201753184
# 当前最优结果:0.8332509532551899
# 第482次迭代，局部最优结果为：0.8292982887662954
# 当前最优结果:0.8332509532551899
# 第483次迭代，局部最优结果为：0.8235971524288107
# 当前最优结果:0.8332509532551899
# 第484次迭代，局部最优结果为：0.8293565730751661
# 当前最优结果:0.8332509532551899
# 第485次迭代，局部最优结果为：0.8293565730751661
# 当前最优结果:0.8332509532551899
# 第486次迭代，局部最优结果为：0.8351971123221742
# 当前最优结果:0.8351971123221743
# 第487次迭代，局部最优结果为：0.8292982887662954
# 当前最优结果:0.8351971123221743
# 第488次迭代，局部最优结果为：0.8351971123221742
# 当前最优结果:0.8351971123221743
# 第489次迭代，局部最优结果为：0.8304363124560169
# 当前最优结果:0.8351971123221743
# 第490次迭代，局部最优结果为：0.8394152795561247
# 当前最优结果:0.8394152795561246
# 第491次迭代，局部最优结果为：0.8351971123221742
# 当前最优结果:0.8394152795561246
# 第492次迭代，局部最优结果为：0.8293565730751661
# 当前最优结果:0.8394152795561246
# 第493次迭代，局部最优结果为：0.8293565730751661
# 当前最优结果:0.8394152795561246
# 第494次迭代，局部最优结果为：0.8293565730751661
# 当前最优结果:0.8394152795561246
# 第495次迭代，局部最优结果为：0.8351971123221742
# 当前最优结果:0.8394152795561246
# 第496次迭代，局部最优结果为：0.8453685794111325
# 当前最优结果:0.8453685794111326
# 第497次迭代，局部最优结果为：0.8394152795561247
# 当前最优结果:0.8453685794111326
# 第498次迭代，局部最优结果为：0.8453685794111325
# 当前最优结果:0.8453685794111326
# 第499次迭代，局部最优结果为：0.8411204960975087
# 当前最优结果:0.8453685794111326
# 第500次迭代，局部最优结果为：0.8293565730751661
# 当前最优结果:0.8453685794111326
# 第501次迭代，局部最优结果为：0.8351971123221742
# 当前最优结果:0.8453685794111326
# 第502次迭代，局部最优结果为：0.8362032312925171
# 当前最优结果:0.8453685794111326
# 第503次迭代，局部最优结果为：0.8411204960975087
# 当前最优结果:0.8453685794111326
# 第504次迭代，局部最优结果为：0.8453685794111325
# 当前最优结果:0.8453685794111326
# 第505次迭代，局部最优结果为：0.8362032312925171
# 当前最优结果:0.8453685794111326
# 第506次迭代，局部最优结果为：0.8262498249544882
# 当前最优结果:0.8453685794111326
# 第507次迭代，局部最优结果为：0.8362032312925171
# 当前最优结果:0.8453685794111326
# 第508次迭代，局部最优结果为：0.8411204960975087
# 当前最优结果:0.8453685794111326
# 第509次迭代，局部最优结果为：0.8362032312925171
# 当前最优结果:0.8453685794111326
# 第510次迭代，局部最优结果为：0.8411204960975087
# 当前最优结果:0.8453685794111326
# 第511次迭代，局部最优结果为：0.8453685794111325
# 当前最优结果:0.8453685794111326
# 第512次迭代，局部最优结果为：0.8453685794111325
# 当前最优结果:0.8453685794111326
# 第513次迭代，局部最优结果为：0.8362032312925171
# 当前最优结果:0.8453685794111326
# 第514次迭代，局部最优结果为：0.8453685794111325
# 当前最优结果:0.8453685794111326
# 第515次迭代，局部最优结果为：0.8453685794111325
# 当前最优结果:0.8453685794111326
# 第516次迭代，局部最优结果为：0.8453685794111325
# 当前最优结果:0.8453685794111326
# 第517次迭代，局部最优结果为：0.8453685794111325
# 当前最优结果:0.8453685794111326
# 第518次迭代，局部最优结果为：0.8394152795561247
# 当前最优结果:0.8453685794111326
# 第519次迭代，局部最优结果为：0.8453685794111325
# 当前最优结果:0.8453685794111326
# 第520次迭代，局部最优结果为：0.8453685794111325
# 当前最优结果:0.8453685794111326
# 第521次迭代，局部最优结果为：0.844823883161512
# 当前最优结果:0.8453685794111326
# 第522次迭代，局部最优结果为：0.8411204960975087
# 当前最优结果:0.8453685794111326
# 第523次迭代，局部最优结果为：0.8411204960975087
# 当前最优结果:0.8453685794111326
# 第524次迭代，局部最优结果为：0.8471284996410624
# 当前最优结果:0.8471284996410624
# 第525次迭代，局部最优结果为：0.8514069264069264
# 当前最优结果:0.8514069264069264
# 本次退火用时：6547.545493841171

# %%
def draw(history):
    plt.plot(history['T'], history['f'])
    plt.title('SA')
    plt.xlabel('T')
    plt.ylabel('f')
    plt.gca().invert_xaxis()
    plt.show()
    return

def wrXSLX(squ, use, tim, filename):
    data = {'square':squ,'utilization':use,'timecost':tim}
    df = pd.DataFrame(data)
    df.to_excel(filename,sheet_name='layout',header=0)
    return df

def drawP(m3):
    Lw,Pw,Lh,Ph = m.lcs_xy(m3.l,m3.x,m3.y,m3.w,m3.h)
    print(Pw)
    print(Ph)
    h,w = m3.h,m3.w
    for i in range(len(Pw)):
        x,y = [Pw[i], Pw[i], Pw[i]+w[i], Pw[i]+w[i], Pw[i]],[Ph[i], Ph[i]+h[i], Ph[i]+h[i], Ph[i], Ph[i]]
        plt.plot(x,y,color='r')
        plt.scatter(x,y,color='b')
    plt.show()
    return

# %%
print("本次测试的退火环境为：")
print(sa.iter,sa.T0,sa.alpha)
squ = []
use = []
for i in range(30):
    squ.append(mmm[i].s_cur)
    use.append(mmm[i].use)
print(use)
index = use.index(max(use))
history = {'f': fff[index], 'T': TTT[index]}
print('本次最优解为：'+str(max(use)))
draw(history)

drawP(mmm[index])

wrXSLX(squ,use,sss,'result_moreAlpha.xlsx')
# Out:
# 本次测试的退火环境为：
# 4000 400 0.98
# [0.8535006509474903, 0.8780133928571429, 0.8522678029755886, 0.8559770781952706, 0.8569716775599129, 0.8437365937365937, 0.8645054945054945, 0.8658375522782302, 0.8338102808691044, 0.8639358664616736, 0.8470068906115418, 0.8611617893891849, 0.848560025887175, 0.8723663783544023, 0.9008359097675483, 0.8566606170598912, 0.8528221435282214, 0.8492012089810017, 0.8428928571428571, 0.827756734006734, 0.880634328358209, 0.8515298022802713, 0.8358478538036549, 0.8565051714752313, 0.8654565456545654, 0.842471621332191, 0.8415703893881044, 0.8366775382870107, 0.8215329991645781, 0.8514069264069264]
# 本次最优解为：0.9008359097675483
# [ 140.  553.    0. 1008. 1344.    0.  665.    0. 1008.  196.    0.  826.
#   539. 1071.  826. 1162.  651.  357.  133. 1162.  140.  931.  406.    0.
#   693.  693. 1302.  483.  693.  483.  476.  196. 1071.]
# [455. 728. 581. 266. 525.   0.   0. 742. 406. 588. 140. 609.   0. 224.
#  406. 525. 630. 588. 140.   0. 322. 728.   0. 406. 399. 266. 406. 259.
#  140. 140. 469. 721. 140.]
#        square  utilization     timecost
# 0   1354948.0     0.853501  6639.351432
# 1   1317120.0     0.878013  6557.254933
# 2   1356908.0     0.852268  6580.187651
# 3   1351028.0     0.855977  6561.766212
# 4   1349460.0     0.856972  6536.899647
# 5   1370628.0     0.843737  6548.489363
# 6   1337700.0     0.864505  6546.844479
# 7   1335642.0     0.865838  6563.220412
# 8   1386945.0     0.833810  6545.350905
# 9   1338582.0     0.863936  6535.325302
# 10  1365336.0     0.847007  6541.471222
# 11  1342894.0     0.861162  6537.382163
# 12  1362837.0     0.848560  6571.792653
# 13  1325646.0     0.872366  6543.839211
# 14  1283751.0     0.900836  6538.338684
# 15  1349950.0     0.856661  6543.159775
# 16  1356026.0     0.852822  6583.031652
# 17  1361808.0     0.849201  6558.910082
# 18  1372000.0     0.842893  6573.957289
# 19  1397088.0     0.827757  6562.298477
# 20  1313200.0     0.880634  6555.772330
# 21  1358084.0     0.851530  6593.413551
# 22  1383564.0     0.835848  6565.115675
# 23  1350195.0     0.856505  6565.016110
# 24  1336230.0     0.865457  6544.029441
# 25  1372686.0     0.842472  6554.188625
# 26  1374156.0     0.841570  6572.277968
# 27  1382192.0     0.836678  6543.857268
# 28  1407672.0     0.821533  6560.634171
# 29  1358280.0     0.851407  6547.545494

# %%
# Out:
# 0.6977383592017739
# 0.6977383592017739

# %%
# Out:
# 0.35128899738032865
