# %%
# 导入必要的包
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import copy
import time
import pandas as pd

# %%
'''
产生初始解和初始目标函数X0和f0，初始化最优值记录器X*和f*

既然序列对可以表达模块的位置信息以及整体的最大长度和宽度
那么我们对模块进行乱序，随机生成一个序列对，一个正序列和一个负序列
目标函数就是该序列形成的矩形面积除以总面积，这样子就可以用求目标函数的最小值的方法求解该问题

while(不满足回火终止条件)
    t=t0
        while t>1e-3
            for i=0 i<L i++
                从四种新解中任选一种产生新解Xnew
                计算评价新解的目标函数fnew
                计算评价目标函数差df=fnew-f
                
                if df<0 or exp(-df/t)>random(0,1)
                    接受新解X=Xnew f=fnew
                    与最优值记录器比较，记录最优值
                else
                    还原原来的解
            下降温度 t=a*t
        以记录器的最优解作为下一个循环的初始解
    达不到要求，产生回火温度

'''

# %%
class module():
    def __init__(self, name='', typ='', w=0., h=0., pos=[], s=0.):
        self.name = name  #模块名称
        self.typ = typ    #模块类型
        self.w = w        #模块宽度
        self.h = h        #模块高度
        self.pos = pos    #模块位置:右下角、右上角、左上角、左下角(左下角一般为(0,0))
        self.s = s        #模块面积

# %%
def rdfile(filename,n):
    #filename是要读取的文件名，n为其中所包含的模块数
    
    #用于存储所有模块对象的列表
    modules = np.zeros(n-1,dtype=type(module('a','b',0.,0.,[],0.))) 
    t = 0
    s_total = 0.
    b1,b2 = 0,0

    #通过文件名打开数据流，按照行的顺序有规律地依次将模块名...读出，顺便创建模块对象放入数组中方便调用
    with open(filename,'r') as f:
        for line in f:
            line = line.split(' ')
            if 'MODULE' in line:
                #print(line[1].split(';')[0])
                name = line[1].split(';')[0]

            if 'TYPE' in line:
                typ = line[2]

            if 'DIMENSIONS' in line:
                #print(line[2:])
                w = 0.
                h = 0.
                pos = np.zeros(8)
                for i in range(10)[2:]:
                    if i != 9:
                        pos[i-2] = int(line[i])
                    else:
                        pos[i-2] = int(line[i].split(";")[0])
                # 用两个坐标值相减即可得到模块的宽高
                h = pos[3]-pos[1]
                w = pos[2]-pos[4]
                s = h*w
                if t == 33:
                    # 这里的s是parent模块的面积，其实实际上并没有使用到
                    s_total = s
                if t<n-1:
                    modules[t] = module(name,typ,w,h,pos,s)
                    t = t+1
                
    return modules,s_total

# %%
# 读取ami33和ami49并计算出它们模块的总面积（不包括parent）
modules,st = rdfile('ami33.yal',34)
modules1,st1 = rdfile('ami49.yal',50)
s = 0.
for i in range(33):
    s = s + modules[i].s
s1 = 0.
for i in range(49):
    s1 = s1 + modules1[i].s
print(s,s1)
# Out:
# 1156449.0 35445424.0

# %%
# m类，用于存储一组模块的布局
# x为正向序列，y为负向序列，modules则存储着从文件读取出来的各个模块的信息，比如宽w和高h
# m类中还存储着这组模块布局所代表的信息比如面积利用率use、总面积s_cur...其中的iuse是用于模拟退火算法，它是面积利用率的倒数
class m():
    def __init__(self, modules,s_total):
        self.modules = modules
        self.s_total = s_total
        self.l = len(modules)
        self.s_cur,self.iuse,self.use = 0.,0.,0.
        
        # 产生一个比较优的解，在此基础上进行模拟退火，这里随机产生可能没有对模块进行旋转
        # 可能在一定程度上会导致我们的初始解较差
        self.x,self.y,self.modules = self.xyInit()
        self.w,self.h = m.whSort(self.l, self.x, self.y, self.modules)
        self.s_cur,self.iuse,self.use = m.calSC(self.l, self.x, self.y, self.w, self.h, self.s_total) 
        
    # 计算当前模块布局的信息：总面积s_cur、面积利用率及其倒数
    def calSC(l,x,y,w,h,s_total):
        Lw,Pw,Lh,Ph = m.lcs_xy(l,x,y,w,h)
        s_cur = Lw*Lh
        iuse = s_cur/s_total
        use = s_total/s_cur
            
        return s_cur,iuse,use
    
    # 根据x和y序列还有模块序列（包含旋转信息），来生成新的模块宽高序列，用于LCS算法
    def whSort(l,x,y,modules):
        w = np.zeros(l)
        h = np.zeros(l)
        for i in range(l):
            w[i] = modules[i].w
            h[i] = modules[i].h
        return w,h
    
    # 初始化生成一组正向和反向序列--生成一个0到（总模块个数-1）长度的顺序序列，然后用shuffle打乱
    def xyInit(self):
        l = self.l
        tmp = np.zeros(l,dtype='int')
        for i in range(l):
            tmp[i] = i
            
        np.random.shuffle(tmp)
        x = copy.deepcopy(tmp)
        np.random.shuffle(tmp)
        y = copy.deepcopy(tmp)
        
        # 模块随机翻转
        md = copy.deepcopy(self.modules)
        for i in range(l):
            yes = random.randint(0,1)
            if yes:
                md[i].w,md[i].h = md[i].h,md[i].w 
            
        return x,y,md
    
    # lcs快速算法
    def lcs_xy(n,x,y,w,h):
        xr = x[::-1]
        Lw,Pw = m.lcs(n,x,y,w)
        Lh,Ph = m.lcs(n,xr,y,h)
        return Lw,Pw,Lh,Ph
    
    # lcs快速算法核心
    def lcs(n,x,y,w):
        # n个模块，x为正序列，y为负序列，w为每个模块的宽度/高度 
        class mdd():
            def __init__(self,x,y):
                self.x = x
                self.y = y

        match = np.zeros(n,dtype=type(mdd(3,4)))
        for i in range(len(x)):
            for j in range(len(y)):
                if x[i]==y[j]:
                    match[int(x[i]-1)] = mdd(i,j)
                    break
                    
        # 模块的位置P，总长度L
        P = np.zeros(n)
        L = np.zeros(n)

        for i in range(n):
            b = int(x[i]-1)
            p = int(match[b].y)
            P[b] = L[p]
            t = P[b] + w[b]
            for j in range(n)[p:n]:
                if t > L[j]:
                    L[j] = t
                else:
                    break

        return L[n-1],P
    
    def refresh(self):
        # 由于x,y,modules的改变，需要更新数据
        self.w,self.h = m.whSort(self.l, self.x, self.y, self.modules)
        self.s_cur,self.iuse,self.use = m.calSC(self.l, self.x, self.y, self.w, self.h, self.s_total) 
    
    def exchangeX(self,pos1,pos2):
        # 第1个随机模块与第2个随机模块交换正序列中的位置
        id1 = np.array(np.where(self.x==pos1))[0][0]
        id2 = np.array(np.where(self.x==pos2))[0][0] 
        x1 = copy.deepcopy(self.x)
        x1[id1],x1[id2] = x1[id2],x1[id1]
        self.x = x1
        return
    
    def exchangeY(self,pos1,pos2):
        # 第1个随机模块与第2个随机模块交换负序列中的位置
        id1 = np.array(np.where(self.y==pos1))[0][0]
        id2 = np.array(np.where(self.y==pos2))[0][0]
        y1 = copy.deepcopy(self.y)
        y1[id1],y1[id2] = y1[id2],y1[id1]
        self.y = y1
        return
    
    def exchangeXY(self,pos1,pos2):
        # 第1个随机模块与第2个随机模块交换正负序列中的位置
        self.exchangeX(pos1,pos2)
        self.exchangeY(pos1,pos2)
        return
    
    def exchangeWH(self,pos):
        # 旋转模块
        md = copy.deepcopy(self.modules)
        md[pos].w,md[pos].h = md[pos].h,md[pos].w 
        self.modules = md
        return

# %%
# SA类 进行模拟退火算法的框架
# 包含3个主要的方法：产生新解、Metropolis准则、运行
class SA:
    def __init__(self, m1, m2, m3, s_total, iter=4000, T0=400, Tf=0.01, alpha=0.95):
        self.iter = iter         #内循环迭代次数,即为L =100
        self.alpha = alpha       #降温系数，alpha=0.95
        self.T0 = T0             #初始温度T0为400
        self.Tf = Tf             #温度终值Tf为0.01
        self.T = T0              #当前温度
        
        # 生成初始解
        self.m1 = m1
        # 用于保存局部最优解&全局最优解
        self.m2 = m2
        self.m3 = m3
        
        # 模块的一些相关信息，模块个数&模块总面积
        self.l = self.m1.l
        self.s_total = self.m1.s_total
        
        # 存放解的序列对
        self.xi = np.zeros((self.iter,self.l),dtype='int')
        self.yi = np.zeros((self.iter,self.l),dtype='int')
        self.modulesi = np.zeros((self.iter,self.l),dtype=type(module()))
                                 
        # 存放f的历史，用于生成图像
        self.history = {'f': [], 'T': []}

    def generate_new(self):   #扰动产生新解的过程
        rand,rand1,rand2 = 0,0,0
        # 选择产生新解的方式
        rand = random.randint(1,4)
        
        while rand1 == rand2:
            rand1 = random.randint(0,self.l-1)
            rand2 = random.randint(0,self.l-1)
            
        if rand == 1:
            #正向序列中交换两个模块的顺序
            self.m1.exchangeX(rand1,rand2)
        elif rand == 2:
            #负向序列中交换两个模块的顺序
            self.m1.exchangeY(rand1,rand2)
        elif rand == 3:
            #正向序列和负向序列中同时交换两个模块的顺序
            self.m1.exchangeXY(rand1,rand2)
        else:
            #将某个模块旋转，即将模块中的宽和高对调
            self.m1.exchangeWH(rand1)
            
        self.m1.refresh()
            
        return 

    def Metrospolis(self, f, f_new):   #Metropolis准则
        if f_new <= f:
            if self.m1.iuse < self.m3.iuse:
                self.m3.x,self.m3.y,self.m3.modules = copy.deepcopy(self.m1.x),copy.deepcopy(self.m1.y),copy.deepcopy(self.m1.modules)
                self.m3.refresh()
            return 1
        else:
            p = math.exp((f - f_new) / self.T)
            if np.random.rand() < p:
                return 1
            else:
                return 0

    
    def run(self):
        count = 0   #迭代计数器
        count1 = 0  #回火计数器
        
        #外循环迭代，当前温度小于终止温度的阈值
        while self.T > self.Tf:  
            #用于存放一次迭代的中间结果
            t= []   
            #内循环迭代
            for i in range(self.iter): 
                #f为迭代一次后的值
                f = self.m2.iuse
                #产生新解
                self.generate_new()
                x_new,y_new,modules_new = copy.deepcopy(self.m1.x),copy.deepcopy(self.m1.y),copy.deepcopy(self.m1.modules)
                #产生新值
                f_new = self.m1.iuse
                #判断是否接受新值
                if self.Metrospolis(f, f_new):
                    self.xi[i] = x_new
                    self.yi[i] = y_new
                    self.modulesi[i] = modules_new
                    t.append(f_new)
                else:
                    t.append(self.m1.iuse)
                    if i>= 1:
                        self.m1.x = copy.deepcopy(self.xi[i-1])
                        self.m1.y = copy.deepcopy(self.yi[i-1])
                        self.m1.modules = copy.deepcopy(self.modulesi[i-1])
                        self.m1.refresh()
            
                    
            f_best = min(t)
            idx = t.index(f_best)
            
            # 将当前局部最优解作为下一次迭代的初始解
            self.m1.x = copy.deepcopy(self.m3.x)
            self.m1.y = copy.deepcopy(self.m3.y)
            self.m1.modules = copy.deepcopy(self.m3.modules)
            self.m1.refresh()
            
            # 保存局部最优解，但是好像没用
            self.m2.x = copy.deepcopy(self.xi[idx])
            self.m2.y = copy.deepcopy(self.yi[idx])
            self.m2.modules = copy.deepcopy(self.modulesi[idx])
            self.m2.refresh()
            
            # 迭代L次记录在该温度下最优解
            self.history['f'].append(f_best)
            self.history['T'].append(self.T)
            
            #温度按照一定的比例下降（冷却）+回火
            self.T = self.T * self.alpha  
            
            if self.T <= self.Tf:
                count1 += 1
                if self.m3.use < 0.9 and count1 < 2:
                    self.T = self.T0
                    
                    print("现在的结果好像不是很好，我的建议是回火！这是第" + str(count1) + "次回火")
                    
            
            print("第"+str(count)+"次迭代，局部最优结果为："+str(1/f_best))
            self.m3.refresh()
            print("当前最优结果:"+str(self.m3.use))
            
            
        return

# %%
mmm = []
TTT = []
fff = []
sss = []
for i in range(30):
    t1 = time.time()
    m1 = m(modules1,s1)
    m2 = m(modules1,s1)
    m3 = m(modules1,s1)
    sa = SA(m1,m2,m3,s)
    sa.run()
    t2 = time.time()
    t = t2-t1
    mmm.append(sa.m3)
    TTT.append(sa.history['T'])
    fff.append(sa.history['f'])
    sss.append(t)
    print("本次退火用时："+str(t))
# Out:
# 第0次迭代，局部最优结果为：0.47026456347287016
# 当前最优结果:0.47026456347287016
# 第0次迭代，局部最优结果为：0.5275526695021557
# 当前最优结果:0.5275526695021557
# 第0次迭代，局部最优结果为：0.5705487987632704
# 当前最优结果:0.5705487987632704
# 第0次迭代，局部最优结果为：0.5705487987632704
# 当前最优结果:0.5705487987632704
# 第0次迭代，局部最优结果为：0.5296664030694432
# 当前最优结果:0.5705487987632704
# 第0次迭代，局部最优结果为：0.5354818460153618
# 当前最优结果:0.5705487987632704
# 第0次迭代，局部最优结果为：0.5993967717344469
# 当前最优结果:0.5993967717344469
# 第0次迭代，局部最优结果为：0.5869309809878034
# 当前最优结果:0.5993967717344469
# 第0次迭代，局部最优结果为：0.6031752384764192
# 当前最优结果:0.6031752384764192
# 第0次迭代，局部最优结果为：0.6031752384764192
# 当前最优结果:0.6031752384764192
# 第0次迭代，局部最优结果为：0.6031752384764192
# 当前最优结果:0.6031752384764192
# 第0次迭代，局部最优结果为：0.5811817486486313
# 当前最优结果:0.6031752384764192
# 第0次迭代，局部最优结果为：0.6066351346818288
# 当前最优结果:0.6066351346818288
# 第0次迭代，局部最优结果为：0.5969630950023107
# 当前最优结果:0.6066351346818288
# 第0次迭代，局部最优结果为：0.49643275768830614
# 当前最优结果:0.6066351346818288
# 第0次迭代，局部最优结果为：0.5655439847390312
# 当前最优结果:0.6066351346818288
# 第0次迭代，局部最优结果为：0.6066351346818288
# 当前最优结果:0.6066351346818288
# 第0次迭代，局部最优结果为：0.5974324583253497
# 当前最优结果:0.6066351346818288
# 第0次迭代，局部最优结果为：0.5835183273102736
# 当前最优结果:0.6066351346818288
# 第0次迭代，局部最优结果为：0.5501928857410585
# 当前最优结果:0.6066351346818288
# 第0次迭代，局部最优结果为：0.6066351346818288
# 当前最优结果:0.6066351346818288
# 第0次迭代，局部最优结果为：0.6120035872011371
# 当前最优结果:0.6120035872011371
# 第0次迭代，局部最优结果为：0.6120035872011371
# 当前最优结果:0.6120035872011371
# 第0次迭代，局部最优结果为：0.6120035872011371
# 当前最优结果:0.6120035872011371
# 第0次迭代，局部最优结果为：0.6105799097858088
# 当前最优结果:0.6120035872011371
# 第0次迭代，局部最优结果为：0.6108356414240357
# 当前最优结果:0.6120035872011371
# 第0次迭代，局部最优结果为：0.6120035872011371
# 当前最优结果:0.6120035872011371
# 第0次迭代，局部最优结果为：0.6266185729185074
# 当前最优结果:0.6266185729185074
# 第0次迭代，局部最优结果为：0.5726191267783128
# 当前最优结果:0.6266185729185074
# 第0次迭代，局部最优结果为：0.6406773656428242
# 当前最优结果:0.6406773656428243
# 第0次迭代，局部最优结果为：0.6406773656428242
# 当前最优结果:0.6406773656428243
# 第0次迭代，局部最优结果为：0.5708459595959596
# 当前最优结果:0.6406773656428243
# 第0次迭代，局部最优结果为：0.6125321772117599
# 当前最优结果:0.6406773656428243
# 第0次迭代，局部最优结果为：0.6082776946233666
# 当前最优结果:0.6406773656428243
# 第0次迭代，局部最优结果为：0.5460001932273802
# 当前最优结果:0.6406773656428243
# 第0次迭代，局部最优结果为：0.550286639321316
# 当前最优结果:0.6406773656428243
# 第0次迭代，局部最优结果为：0.6462291625721381
# 当前最优结果:0.6462291625721381
# 第0次迭代，局部最优结果为：0.6280984846643025
# 当前最优结果:0.6462291625721381
# 第0次迭代，局部最优结果为：0.614544997332409
# 当前最优结果:0.6462291625721381
# 第0次迭代，局部最优结果为：0.6122729504172804
# 当前最优结果:0.6462291625721381
# 第0次迭代，局部最优结果为：0.6223638566158252
# 当前最优结果:0.6462291625721381
# 第0次迭代，局部最优结果为：0.6462291625721381
# 当前最优结果:0.6462291625721381
# 第0次迭代，局部最优结果为：0.6574328549200948
# 当前最优结果:0.6574328549200948
# 第0次迭代，局部最优结果为：0.6235354963279661
# 当前最优结果:0.6574328549200948
# 第0次迭代，局部最优结果为：0.6574328549200948
# 当前最优结果:0.6574328549200948
# 第0次迭代，局部最优结果为：0.6040697985142429
# 当前最优结果:0.6574328549200948
# 第0次迭代，局部最优结果为：0.5467595448003967
# 当前最优结果:0.6574328549200948
# 第0次迭代，局部最优结果为：0.6127812415288696
# 当前最优结果:0.6574328549200948
# 第0次迭代，局部最优结果为：0.6574328549200948
# 当前最优结果:0.6574328549200948
# 第0次迭代，局部最优结果为：0.6574328549200948
# 当前最优结果:0.6574328549200948
# 第0次迭代，局部最优结果为：0.6314473665833321
# 当前最优结果:0.6574328549200948
# 第0次迭代，局部最优结果为：0.6080179671319831
# 当前最优结果:0.6574328549200948
# 第0次迭代，局部最优结果为：0.6460190900777321
# 当前最优结果:0.6574328549200948
# 第0次迭代，局部最优结果为：0.6149336760890485
# 当前最优结果:0.6574328549200948
# 第0次迭代，局部最优结果为：0.6585964528934047
# 当前最优结果:0.6585964528934047
# 第0次迭代，局部最优结果为：0.5720594189695313
# 当前最优结果:0.6585964528934047
# 第0次迭代，局部最优结果为：0.6427266588477805
# 当前最优结果:0.6585964528934047
# 第0次迭代，局部最优结果为：0.6100114686635634
# 当前最优结果:0.6585964528934047
# 第0次迭代，局部最优结果为：0.6599543837241127
# 当前最优结果:0.6599543837241127
# 第0次迭代，局部最优结果为：0.6599543837241127
# 当前最优结果:0.6599543837241127
# 第0次迭代，局部最优结果为：0.6350751510043545
# 当前最优结果:0.6599543837241127
# 第0次迭代，局部最优结果为：0.5480254066765256
# 当前最优结果:0.6599543837241127
# 第0次迭代，局部最优结果为：0.5664864458491784
# 当前最优结果:0.6599543837241127
# 第0次迭代，局部最优结果为：0.6251521017699115
# 当前最优结果:0.6599543837241127
# 第0次迭代，局部最优结果为：0.5871596568808888
# 当前最优结果:0.6599543837241127
# 第0次迭代，局部最优结果为：0.6208426025102304
# 当前最优结果:0.6599543837241127
# 第0次迭代，局部最优结果为：0.6273815966584794
# 当前最优结果:0.6599543837241127
# 第0次迭代，局部最优结果为：0.6011001977696897
# 当前最优结果:0.6599543837241127
# 第0次迭代，局部最优结果为：0.6599543837241127
# 当前最优结果:0.6599543837241127
# 第0次迭代，局部最优结果为：0.6599543837241127
# 当前最优结果:0.6599543837241127
# 第0次迭代，局部最优结果为：0.6599543837241127
# 当前最优结果:0.6599543837241127
# 第0次迭代，局部最优结果为：0.564511245337204
# 当前最优结果:0.6599543837241127
# 第0次迭代，局部最优结果为：0.5457695047018916
# 当前最优结果:0.6599543837241127
# 第0次迭代，局部最优结果为：0.6204230063296567
# 当前最优结果:0.6599543837241127
# 第0次迭代，局部最优结果为：0.552472077620549
# 当前最优结果:0.6599543837241127
# 第0次迭代，局部最优结果为：0.5406203663844645
# 当前最优结果:0.6599543837241127
# 第0次迭代，局部最优结果为：0.6930747710113824
# 当前最优结果:0.6930747710113824
# 第0次迭代，局部最优结果为：0.6294780223605252
# 当前最优结果:0.6930747710113824
# 第0次迭代，局部最优结果为：0.6930747710113824
# 当前最优结果:0.6930747710113824
# 第0次迭代，局部最优结果为：0.6421173354353299
# 当前最优结果:0.6930747710113824
# 第0次迭代，局部最优结果为：0.6630005205927425
# 当前最优结果:0.6930747710113824
# 第0次迭代，局部最优结果为：0.5780385989810073
# 当前最优结果:0.6930747710113824
# 第0次迭代，局部最优结果为：0.6501765259971382
# 当前最优结果:0.6930747710113824
# 第0次迭代，局部最优结果为：0.6599543837241127
# 当前最优结果:0.6930747710113824
# 第0次迭代，局部最优结果为：0.6501765259971382
# 当前最优结果:0.6930747710113824
# 第0次迭代，局部最优结果为：0.6768924422086477
# 当前最优结果:0.6930747710113824
# 第0次迭代，局部最优结果为：0.5601868487243982
# 当前最优结果:0.6930747710113824
# 第0次迭代，局部最优结果为：0.6930747710113824
# 当前最优结果:0.6930747710113824
# 第0次迭代，局部最优结果为：0.5073033345395688
# 当前最优结果:0.6930747710113824
# 第0次迭代，局部最优结果为：0.584155409552235
# 当前最优结果:0.6930747710113824
# 第0次迭代，局部最优结果为：0.6930747710113824
# 当前最优结果:0.6930747710113824
# 第0次迭代，局部最优结果为：0.6995764105143034
# 当前最优结果:0.6995764105143034
# 第0次迭代，局部最优结果为：0.7098351840294541
# 当前最优结果:0.7098351840294541
# 第0次迭代，局部最优结果为：0.7098351840294541
# 当前最优结果:0.7098351840294541
# 第0次迭代，局部最优结果为：0.661559847819725
# 当前最优结果:0.7098351840294541
# 第0次迭代，局部最优结果为：0.5945393276896523
# 当前最优结果:0.7098351840294541
# 第0次迭代，局部最优结果为：0.6056477648729387
# 当前最优结果:0.7098351840294541
# 第0次迭代，局部最优结果为：0.7098351840294541
# 当前最优结果:0.7098351840294541
# 第0次迭代，局部最优结果为：0.7098351840294541
# 当前最优结果:0.7098351840294541
# 第0次迭代，局部最优结果为：0.5693632428177883
# 当前最优结果:0.7098351840294541
# 第0次迭代，局部最优结果为：0.6846339348923137
# 当前最优结果:0.7098351840294541
# 第0次迭代，局部最优结果为：0.6810757474757746
# 当前最优结果:0.7098351840294541
# 第0次迭代，局部最优结果为：0.7098351840294541
# 当前最优结果:0.7098351840294541
# 第0次迭代，局部最优结果为：0.6699712515930174
# 当前最优结果:0.7098351840294541
# 第0次迭代，局部最优结果为：0.5878696859173151
# 当前最优结果:0.7098351840294541
# 第0次迭代，局部最优结果为：0.650916027786776
# 当前最优结果:0.7098351840294541
# 第0次迭代，局部最优结果为：0.6930880521222574
# 当前最优结果:0.7098351840294541
# 第0次迭代，局部最优结果为：0.7080869858025512
# 当前最优结果:0.7098351840294541
# 第0次迭代，局部最优结果为：0.6925545522085124
# 当前最优结果:0.7098351840294541
# 第0次迭代，局部最优结果为：0.6157439564181137
# 当前最优结果:0.7098351840294541
# 第0次迭代，局部最优结果为：0.7333227903280092
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.7207754422045262
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.7108647798742138
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.7249099093682232
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.7333227903280092
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.7333227903280092
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.7333227903280092
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.7262986256696948
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.7333227903280092
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.6877662163806743
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.6002104208084275
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.7166878688082811
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.7302608997629653
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.6394789231927978
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.7173246492588524
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.7333227903280092
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.7333227903280092
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.6453551444558638
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.6717032150710168
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.7333227903280092
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.6262605274822695
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.7153271390316163
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.6765860173819349
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.7211145846624984
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.7333227903280092
# 当前最优结果:0.7333227903280091
# 第0次迭代，局部最优结果为：0.7550267201068804
# 当前最优结果:0.7550267201068804
# 第0次迭代，局部最优结果为：0.7301518087855298
# 当前最优结果:0.7550267201068804
# 第0次迭代，局部最优结果为：0.759775315830823
# 当前最优结果:0.759775315830823
# 第0次迭代，局部最优结果为：0.7390407068217948
# 当前最优结果:0.759775315830823
# 第0次迭代，局部最优结果为：0.756602976307521
# 当前最优结果:0.759775315830823
# 第0次迭代，局部最优结果为：0.7581222593924759
# 当前最优结果:0.759775315830823
# 第0次迭代，局部最优结果为：0.7290920819222706
# 当前最优结果:0.759775315830823
# 第0次迭代，局部最优结果为：0.6876903712548437
# 当前最优结果:0.759775315830823
# 第0次迭代，局部最优结果为：0.6636355296233096
# 当前最优结果:0.759775315830823
# 第0次迭代，局部最优结果为：0.7276926729358555
# 当前最优结果:0.759775315830823
# 第0次迭代，局部最优结果为：0.759775315830823
# 当前最优结果:0.759775315830823
# 第0次迭代，局部最优结果为：0.7152507514633761
# 当前最优结果:0.759775315830823
# 第0次迭代，局部最优结果为：0.7613714824607197
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.6981935548631943
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.6706868417148791
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.7538181939442444
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.7074941708526986
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.7405933133487312
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.759775315830823
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.7334447292430486
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.759775315830823
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.759775315830823
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.7108647798742138
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.7248256513026051
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.760423849970566
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.7389833278849297
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.7613714824607197
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.7613714824607197
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.7503900414937759
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.738138775510204
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.7613714824607197
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.750838675391105
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.7613714824607197
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.7131775608794243
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.7488364389233954
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.6945921032416654
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.7288511296862027
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.7490256338039836
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.7368155149934811
# 当前最优结果:0.7613714824607197
# 第0次迭代，局部最优结果为：0.7714068778419513
# 当前最优结果:0.7714068778419513
# 第0次迭代，局部最优结果为：0.7504772338694952
# 当前最优结果:0.7714068778419513
# 第0次迭代，局部最优结果为：0.7371158392434989
# 当前最优结果:0.7714068778419513
# 第0次迭代，局部最优结果为：0.7500694723831723
# 当前最优结果:0.7714068778419513
# 第0次迭代，局部最优结果为：0.7517000581927009
# 当前最优结果:0.7714068778419513
# 第0次迭代，局部最优结果为：0.7351979835759005
# 当前最优结果:0.7714068778419513
# 第0次迭代，局部最优结果为：0.7351979835759005
# 当前最优结果:0.7714068778419513
# 第0次迭代，局部最优结果为：0.7547809247155652
# 当前最优结果:0.7714068778419513
# 第0次迭代，局部最优结果为：0.7531400966183575
# 当前最优结果:0.7714068778419513
# 第0次迭代，局部最优结果为：0.7517000581927009
# 当前最优结果:0.7714068778419513
# 第0次迭代，局部最优结果为：0.7838992969163149
# 当前最优结果:0.7838992969163149
# 第0次迭代，局部最优结果为：0.7838992969163149
# 当前最优结果:0.7838992969163149
# 第0次迭代，局部最优结果为：0.7531400966183575
# 当前最优结果:0.7838992969163149
# 第0次迭代，局部最优结果为：0.7531150053304904
# 当前最优结果:0.7838992969163149
# 第0次迭代，局部最优结果为：0.7663530807695567
# 当前最优结果:0.7838992969163149
# 第0次迭代，局部最优结果为：0.7838992969163149
# 当前最优结果:0.7838992969163149
# 第0次迭代，局部最优结果为：0.7872709067955247
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.7872709067955247
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.7872709067955247
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.7574935075814694
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.7693525057432145
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.7693525057432145
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.7693525057432145
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.7727121236722242
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.7693525057432145
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.7872709067955247
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.7625722116803711
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.7809474456967656
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.7826305220883535
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.7809474456967656
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.7613009690754633
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.7825187685251292
# 当前最优结果:0.7872709067955248
# 现在的结果好像不是很好，我的建议是回火！这是第1次回火
# 第0次迭代，局部最优结果为：0.7840964273326396
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.6981531239383552
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.7872709067955247
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.7026506173894799
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.7117040535222353
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.5146136925646739
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.6183017932543549
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.6528192910259187
# 当前最优结果:0.7872709067955248
# 第0次迭代，局部最优结果为：0.7958281992606936
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.694365413043061
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7958281992606936
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7958281992606936
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6708858881139634
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.741771944216571
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6270487682252388
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6283232575915503
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6503963287442637
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.714798418972332
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6155595191090174
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7719666700816173
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.760423849970566
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7097488226059655
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7486318438853149
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7906716450538208
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6587883865797239
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7455824270059451
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7425577518456775
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.760423849970566
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6629373295404557
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7755952789405064
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7693525057432145
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7560367892976588
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7380664751208045
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7380664751208045
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6674688122831622
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7838992969163149
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7958281992606936
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7162308807337996
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6907188144526775
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6703139478853923
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7822242984186305
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7140617781656078
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6956715751896475
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.714798418972332
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7445816864295126
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7098351840294541
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6412225649753572
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.732161943319838
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7958281992606936
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.760423849970566
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6231036657007694
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7483282574152542
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.5349781090995148
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7958281992606936
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7771117213047832
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7663530807695567
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.741771944216571
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6651806732580038
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7674653493918638
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7083587935761849
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7517063073098953
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6458160729080364
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7075218503767576
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7307418781315661
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7078375501002004
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7910244073134459
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7426736316446547
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6876014706832898
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7207380985592731
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.672032701597919
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7321826934366561
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6908164395701784
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.646739907876291
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7958281992606936
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7958281992606936
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.5917631429113683
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7579316183435176
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7674653493918638
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7380664751208045
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7122197892216323
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7958281992606936
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7958281992606936
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.568120130686102
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6946508001136983
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6082633731568184
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7403750102349955
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7591438202341523
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6946508001136983
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.762720156555773
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6577556639424458
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6910276152738027
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7531400966183575
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6374659842364254
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7252791324435318
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7052262960449862
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7058153149637031
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6963895135701302
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6841858353510897
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.5587710028858691
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6498120746527154
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7336292017232847
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7425577518456775
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7355508374616655
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7805564427716823
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7958281992606936
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7618975396022919
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.760423849970566
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7336292017232847
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7872709067955247
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7690776715544517
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6924352244315026
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7527639027639028
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6784363745498199
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7548061271338538
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7958281992606936
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6508926000575871
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7277951722861212
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6629373295404557
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7093479352328355
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7122197892216323
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6549471244386499
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6816533610753029
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.6498167445203019
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7425577518456775
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7663530807695567
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7380664751208045
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7576839282721636
# 当前最优结果:0.7958281992606936
# 第0次迭代，局部最优结果为：0.7991798026400102
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7229277847734406
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.6814221981069513
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7959507933364143
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7080259963980894
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7589558502601981
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7725404758853432
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7991798026400102
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7991798026400102
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7991798026400102
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7991798026400102
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7895704262555612
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7680226953246103
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7367014559349514
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7366354378818737
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7351651076665406
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7531150053304904
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.6968027310487258
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.6934282219504059
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7991798026400102
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7991798026400102
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7547809247155652
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7476198153729128
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7626268802739391
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7576839282721636
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7562296405019675
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.719863068227052
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.75190008149146
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7352368407144048
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7209047385562292
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7524131274131274
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.7817373863125496
# 当前最优结果:0.7991798026400102
# 第0次迭代，局部最优结果为：0.8024351175183809
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7657170923379175
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7271455223880597
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7972244998721577
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7813118352040508
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7813118352040508
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.8024351175183809
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7813118352040508
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7597082892238409
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7746052958460762
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7615510300335203
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7558503546366072
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7721545470459892
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7591438202341523
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7641381874725349
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7937881873727087
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7425760462518889
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7650400829155827
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7680226953246103
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7675239792886852
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7635574470959788
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7516688141651773
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7618975396022919
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7431130834976989
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.748613249879953
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.8024351175183809
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7618975396022919
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.8024351175183809
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7920811160020147
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7462038687528884
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7635574470959788
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.752247249433248
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7675239792886852
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7532059692043699
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7689305197096803
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7725404758853432
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.8006906933498628
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7831456781569376
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7725404758853432
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7753558566283657
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7753558566283657
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7838992969163149
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7658662601109559
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7773021112715769
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7972244998721577
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7594020324179054
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7972244998721577
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7855814842487533
# 当前最优结果:0.8024351175183809
# 第0次迭代，局部最优结果为：0.7739555426213933
# 当前最优结果:0.8024351175183809
# 本次退火用时：8433.026911735535
# 第0次迭代，局部最优结果为：0.47977884605180776
# 当前最优结果:0.47977884605180776
# 第0次迭代，局部最优结果为：0.48947134799224834
# 当前最优结果:0.48947134799224834
# 第0次迭代，局部最优结果为：0.5232376130198915
# 当前最优结果:0.5232376130198915
# 第0次迭代，局部最优结果为：0.49687877788768003
# 当前最优结果:0.5232376130198915
# 第0次迭代，局部最优结果为：0.5272896384221315
# 当前最优结果:0.5272896384221315
# 第0次迭代，局部最优结果为：0.5117811196450099
# 当前最优结果:0.5272896384221315
# 第0次迭代，局部最优结果为：0.4906905440238774
# 当前最优结果:0.5272896384221315
# 第0次迭代，局部最优结果为：0.5321539339795311
# 当前最优结果:0.5321539339795311
# 第0次迭代，局部最优结果为：0.5321539339795311
# 当前最优结果:0.5321539339795311
# 第0次迭代，局部最优结果为：0.5321539339795311
# 当前最优结果:0.5321539339795311
# 第0次迭代，局部最优结果为：0.5321539339795311
# 当前最优结果:0.5321539339795311
# 第0次迭代，局部最优结果为：0.5684773041619515
# 当前最优结果:0.5684773041619514
# 第0次迭代，局部最优结果为：0.5684773041619515
# 当前最优结果:0.5684773041619514
# 第0次迭代，局部最优结果为：0.5684773041619515
# 当前最优结果:0.5684773041619514
# 第0次迭代，局部最优结果为：0.5361772274996739
# 当前最优结果:0.5684773041619514
# 第0次迭代，局部最优结果为：0.5684773041619515
# 当前最优结果:0.5684773041619514
# 第0次迭代，局部最优结果为：0.5011389269146996
# 当前最优结果:0.5684773041619514
# 第0次迭代，局部最优结果为：0.5225557392017939
# 当前最优结果:0.5684773041619514
# 第0次迭代，局部最优结果为：0.5684773041619515
# 当前最优结果:0.5684773041619514
# 第0次迭代，局部最优结果为：0.5684773041619515
# 当前最优结果:0.5684773041619514
# 第0次迭代，局部最优结果为：0.49826146852183495
# 当前最优结果:0.5684773041619514
# 第0次迭代，局部最优结果为：0.5826009638926832
# 当前最优结果:0.5826009638926832
# 第0次迭代，局部最优结果为：0.5874762857662621
# 当前最优结果:0.5874762857662621
# 第0次迭代，局部最优结果为：0.47757930429822426
# 当前最优结果:0.5874762857662621
# 第0次迭代，局部最优结果为：0.5732344364143527
# 当前最优结果:0.5874762857662621
# 第0次迭代，局部最优结果为：0.5841214470284237
# 当前最优结果:0.5874762857662621
# 第0次迭代，局部最优结果为：0.5549677165934255
# 当前最优结果:0.5874762857662621
# 第0次迭代，局部最优结果为：0.5911480125523012
# 当前最优结果:0.5911480125523012
# 第0次迭代，局部最优结果为：0.5911480125523012
# 当前最优结果:0.5911480125523012
# 第0次迭代，局部最优结果为：0.5911480125523012
# 当前最优结果:0.5911480125523012
# 第0次迭代，局部最优结果为：0.5911480125523012
# 当前最优结果:0.5911480125523012
# 第0次迭代，局部最优结果为：0.5680701622124217
# 当前最优结果:0.5911480125523012
# 第0次迭代，局部最优结果为：0.6024438344482052
# 当前最优结果:0.6024438344482052
# 第0次迭代，局部最优结果为：0.5759363057324841
# 当前最优结果:0.6024438344482052
# 第0次迭代，局部最优结果为：0.5967424732389162
# 当前最优结果:0.6024438344482052
# 第0次迭代，局部最优结果为：0.6247719860704217
# 当前最优结果:0.6247719860704217
# 第0次迭代，局部最优结果为：0.5070430433124734
# 当前最优结果:0.6247719860704217
# 第0次迭代，局部最优结果为：0.6247719860704217
# 当前最优结果:0.6247719860704217
# 第0次迭代，局部最优结果为：0.5858244250080985
# 当前最优结果:0.6247719860704217
# 第0次迭代，局部最优结果为：0.6153668163876411
# 当前最优结果:0.6247719860704217
# 第0次迭代，局部最优结果为：0.5419423667050249
# 当前最优结果:0.6247719860704217
# 第0次迭代，局部最优结果为：0.6247719860704217
# 当前最优结果:0.6247719860704217
# 第0次迭代，局部最优结果为：0.6247719860704217
# 当前最优结果:0.6247719860704217
# 第0次迭代，局部最优结果为：0.5806704341125096
# 当前最优结果:0.6247719860704217
# 第0次迭代，局部最优结果为：0.6081447355146787
# 当前最优结果:0.6247719860704217
# 第0次迭代，局部最优结果为：0.6247719860704217
# 当前最优结果:0.6247719860704217
# 第0次迭代，局部最优结果为：0.6247719860704217
# 当前最优结果:0.6247719860704217
# 第0次迭代，局部最优结果为：0.6247719860704217
# 当前最优结果:0.6247719860704217
# 第0次迭代，局部最优结果为：0.5986943164362519
# 当前最优结果:0.6247719860704217
# 第0次迭代，局部最优结果为：0.5983060940911799
# 当前最优结果:0.6247719860704217
# 第0次迭代，局部最优结果为：0.5991743477943954
# 当前最优结果:0.6247719860704217
# 第0次迭代，局部最优结果为：0.6220555861309852
# 当前最优结果:0.6247719860704217
# 第0次迭代，局部最优结果为：0.5602458533925662
# 当前最优结果:0.6247719860704217
# 第0次迭代，局部最优结果为：0.5902180795164522
# 当前最优结果:0.6247719860704217
# 第0次迭代，局部最优结果为：0.6247719860704217
# 当前最优结果:0.6247719860704217
# 第0次迭代，局部最优结果为：0.6459267937251765
# 当前最优结果:0.6459267937251765
# 第0次迭代，局部最优结果为：0.6011461546643974
# 当前最优结果:0.6459267937251765
# 第0次迭代，局部最优结果为：0.6338908907365085
# 当前最优结果:0.6459267937251765
# 第0次迭代，局部最优结果为：0.562640781531952
# 当前最优结果:0.6459267937251765
# 第0次迭代，局部最优结果为：0.5967857967857968
# 当前最优结果:0.6459267937251765
# 第0次迭代，局部最优结果为：0.6459267937251765
# 当前最优结果:0.6459267937251765
# 第0次迭代，局部最优结果为：0.6316679241065191
# 当前最优结果:0.6459267937251765
# 第0次迭代，局部最优结果为：0.6237892877838792
# 当前最优结果:0.6459267937251765
# 第0次迭代，局部最优结果为：0.5902180795164522
# 当前最优结果:0.6459267937251765
# 第0次迭代，局部最优结果为：0.6577963364420712
# 当前最优结果:0.6577963364420712
# 第0次迭代，局部最优结果为：0.5972982792218515
# 当前最优结果:0.6577963364420712
# 第0次迭代，局部最优结果为：0.5904030609912962
# 当前最优结果:0.6577963364420712
# 第0次迭代，局部最优结果为：0.6199274641948732
# 当前最优结果:0.6577963364420712
# 第0次迭代，局部最优结果为：0.6577963364420712
# 当前最优结果:0.6577963364420712
# 第0次迭代，局部最优结果为：0.6546389140271494
# 当前最优结果:0.6577963364420712
# 第0次迭代，局部最优结果为：0.5077705368198498
# 当前最优结果:0.6577963364420712
# 第0次迭代，局部最优结果为：0.6159872472614312
# 当前最优结果:0.6577963364420712
# 第0次迭代，局部最优结果为：0.5772231088413662
# 当前最优结果:0.6577963364420712
# 第0次迭代，局部最优结果为：0.5658589701869885
# 当前最优结果:0.6577963364420712
# 第0次迭代，局部最优结果为：0.5666603998245284
# 当前最优结果:0.6577963364420712
# 第0次迭代，局部最优结果为：0.6862863409876627
# 当前最优结果:0.6862863409876627
# 第0次迭代，局部最优结果为：0.6862863409876627
# 当前最优结果:0.6862863409876627
# 第0次迭代，局部最优结果为：0.6862863409876627
# 当前最优结果:0.6862863409876627
# 第0次迭代，局部最优结果为：0.6199869724707737
# 当前最优结果:0.6862863409876627
# 第0次迭代，局部最优结果为：0.6318025398710849
# 当前最优结果:0.6862863409876627
# 第0次迭代，局部最优结果为：0.5473950576925405
# 当前最优结果:0.6862863409876627
# 第0次迭代，局部最优结果为：0.5358308987798591
# 当前最优结果:0.6862863409876627
# 第0次迭代，局部最优结果为：0.6260675697663549
# 当前最优结果:0.6862863409876627
# 第0次迭代，局部最优结果为：0.6679446124980147
# 当前最优结果:0.6862863409876627
# 第0次迭代，局部最优结果为：0.6491496342242611
# 当前最优结果:0.6862863409876627
# 第0次迭代，局部最优结果为：0.6862863409876627
# 当前最优结果:0.6862863409876627
# 第0次迭代，局部最优结果为：0.689717772692601
# 当前最优结果:0.689717772692601
# 第0次迭代，局部最优结果为：0.6407931429138365
# 当前最优结果:0.689717772692601
# 第0次迭代，局部最优结果为：0.6579183841264875
# 当前最优结果:0.689717772692601
# 第0次迭代，局部最优结果为：0.6337376165628801
# 当前最优结果:0.689717772692601
# 第0次迭代，局部最优结果为：0.6784109239599355
# 当前最优结果:0.689717772692601
# 第0次迭代，局部最优结果为：0.5812228421566863
# 当前最优结果:0.689717772692601
# 第0次迭代，局部最优结果为：0.6638036089209943
# 当前最优结果:0.689717772692601
# 第0次迭代，局部最优结果为：0.5805101339856064
# 当前最优结果:0.689717772692601
# 第0次迭代，局部最优结果为：0.6550420168067227
# 当前最优结果:0.689717772692601
# 第0次迭代，局部最优结果为：0.5671508856440364
# 当前最优结果:0.689717772692601
# 第0次迭代，局部最优结果为：0.639985844466071
# 当前最优结果:0.689717772692601
# 第0次迭代，局部最优结果为：0.689717772692601
# 当前最优结果:0.689717772692601
# 第0次迭代，局部最优结果为：0.6773183520599251
# 当前最优结果:0.689717772692601
# 第0次迭代，局部最优结果为：0.6784109239599355
# 当前最优结果:0.689717772692601
# 第0次迭代，局部最优结果为：0.689717772692601
# 当前最优结果:0.689717772692601
# 第0次迭代，局部最优结果为：0.6933298573038791
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6933298573038791
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6527226856179686
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6342332484621481
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.5838725091369312
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6471078668169539
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6417003761266057
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.5661565818473252
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6731684074953657
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6792441491419493
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6485024958402662
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6499031491790142
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6444949714538236
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6933298573038791
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6077850147540212
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6933298573038791
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.5894331997001402
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6712843355605048
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6382579233429803
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6699216145331693
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.591169269292502
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6239334816884887
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6584357944636401
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6582800066976798
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6130886999444015
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6933298573038791
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6743481892488515
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6276842766553401
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6352000674384624
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6102914377505704
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6677744298712041
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6420512237898788
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6876093139267844
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6173203618364909
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6933298573038791
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6566594045025417
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6624662070582374
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6645793369053131
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6901494451144118
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6439877643606736
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6381182913317478
# 当前最优结果:0.6933298573038791
# 第0次迭代，局部最优结果为：0.6944854070660522
# 当前最优结果:0.6944854070660522
# 第0次迭代，局部最优结果为：0.6944854070660522
# 当前最优结果:0.6944854070660522
# 第0次迭代，局部最优结果为：0.6944854070660522
# 当前最优结果:0.6944854070660522
# 第0次迭代，局部最优结果为：0.6595331874544128
# 当前最优结果:0.6944854070660522
# 第0次迭代，局部最优结果为：0.6944854070660522
# 当前最优结果:0.6944854070660522
# 第0次迭代，局部最优结果为：0.6898861659596546
# 当前最优结果:0.6944854070660522
# 第0次迭代，局部最优结果为：0.6657610396303864
# 当前最优结果:0.6944854070660522
# 第0次迭代，局部最优结果为：0.7003214188901367
# 当前最优结果:0.7003214188901367
# 第0次迭代，局部最优结果为：0.7003214188901367
# 当前最优结果:0.7003214188901367
# 第0次迭代，局部最优结果为：0.6716657938621414
# 当前最优结果:0.7003214188901367
# 第0次迭代，局部最优结果为：0.6679988918644381
# 当前最优结果:0.7003214188901367
# 第0次迭代，局部最优结果为：0.6867319814688236
# 当前最优结果:0.7003214188901367
# 第0次迭代，局部最优结果为：0.700986491462682
# 当前最优结果:0.700986491462682
# 第0次迭代，局部最优结果为：0.6867319814688236
# 当前最优结果:0.700986491462682
# 第0次迭代，局部最优结果为：0.6855838745019543
# 当前最优结果:0.700986491462682
# 第0次迭代，局部最优结果为：0.6867319814688236
# 当前最优结果:0.700986491462682
# 第0次迭代，局部最优结果为：0.6879388918053241
# 当前最优结果:0.700986491462682
# 第0次迭代，局部最优结果为：0.6724050105781351
# 当前最优结果:0.700986491462682
# 第0次迭代，局部最优结果为：0.6867319814688236
# 当前最优结果:0.700986491462682
# 第0次迭代，局部最优结果为：0.6690714822173139
# 当前最优结果:0.700986491462682
# 第0次迭代，局部最优结果为：0.7022249834970683
# 当前最优结果:0.7022249834970683
# 第0次迭代，局部最优结果为：0.7022249834970683
# 当前最优结果:0.7022249834970683
# 第0次迭代，局部最优结果为：0.7022249834970683
# 当前最优结果:0.7022249834970683
# 第0次迭代，局部最优结果为：0.7047151430130153
# 当前最优结果:0.7047151430130153
# 第0次迭代，局部最优结果为：0.6817150310240578
# 当前最优结果:0.7047151430130153
# 第0次迭代，局部最优结果为：0.7047151430130153
# 当前最优结果:0.7047151430130153
# 第0次迭代，局部最优结果为：0.69158521101984
# 当前最优结果:0.7047151430130153
# 第0次迭代，局部最优结果为：0.6751941457586619
# 当前最优结果:0.7047151430130153
# 第0次迭代，局部最优结果为：0.7047151430130153
# 当前最优结果:0.7047151430130153
# 第0次迭代，局部最优结果为：0.688122127180299
# 当前最优结果:0.7047151430130153
# 第0次迭代，局部最优结果为：0.6900335775335775
# 当前最优结果:0.7047151430130153
# 第0次迭代，局部最优结果为：0.6972970888760363
# 当前最优结果:0.7047151430130153
# 第0次迭代，局部最优结果为：0.6913631219989601
# 当前最优结果:0.7047151430130153
# 第0次迭代，局部最优结果为：0.7047151430130153
# 当前最优结果:0.7047151430130153
# 第0次迭代，局部最优结果为：0.7013045434098065
# 当前最优结果:0.7047151430130153
# 第0次迭代，局部最优结果为：0.688122127180299
# 当前最优结果:0.7047151430130153
# 第0次迭代，局部最优结果为：0.707223026084236
# 当前最优结果:0.707223026084236
# 第0次迭代，局部最优结果为：0.7025905608478764
# 当前最优结果:0.707223026084236
# 第0次迭代，局部最优结果为：0.707223026084236
# 当前最优结果:0.707223026084236
# 第0次迭代，局部最优结果为：0.7058042962407893
# 当前最优结果:0.707223026084236
# 第0次迭代，局部最优结果为：0.6948776767222664
# 当前最优结果:0.707223026084236
# 第0次迭代，局部最优结果为：0.707223026084236
# 当前最优结果:0.707223026084236
# 第0次迭代，局部最优结果为：0.7104123946229209
# 当前最优结果:0.7104123946229209
# 第0次迭代，局部最优结果为：0.707223026084236
# 当前最优结果:0.7104123946229209
# 第0次迭代，局部最优结果为：0.7104123946229209
# 当前最优结果:0.7104123946229209
# 第0次迭代，局部最优结果为：0.7104123946229209
# 当前最优结果:0.7104123946229209
# 第0次迭代，局部最优结果为：0.707223026084236
# 当前最优结果:0.7104123946229209
# 第0次迭代，局部最优结果为：0.726689705055051
# 当前最优结果:0.726689705055051
# 第0次迭代，局部最优结果为：0.726689705055051
# 当前最优结果:0.726689705055051
# 第0次迭代，局部最优结果为：0.726689705055051
# 当前最优结果:0.726689705055051
# 第0次迭代，局部最优结果为：0.7226822250639386
# 当前最优结果:0.726689705055051
# 第0次迭代，局部最优结果为：0.726689705055051
# 当前最优结果:0.726689705055051
# 第0次迭代，局部最优结果为：0.7282729070268485
# 当前最优结果:0.7282729070268485
# 第0次迭代，局部最优结果为：0.7202845387596436
# 当前最优结果:0.7282729070268485
# 第0次迭代，局部最优结果为：0.7226822250639386
# 当前最优结果:0.7282729070268485
# 第0次迭代，局部最优结果为：0.7189701509151917
# 当前最优结果:0.7282729070268485
# 第0次迭代，局部最优结果为：0.7450111230122766
# 当前最优结果:0.7450111230122765
# 第0次迭代，局部最优结果为：0.7366714462621391
# 当前最优结果:0.7450111230122765
# 第0次迭代，局部最优结果为：0.7401628944460361
# 当前最优结果:0.7450111230122765
# 第0次迭代，局部最优结果为：0.7492521730483995
# 当前最优结果:0.7492521730483995
# 第0次迭代，局部最优结果为：0.7411608968815702
# 当前最优结果:0.7492521730483995
# 第0次迭代，局部最优结果为：0.7482601391888649
# 当前最优结果:0.7492521730483995
# 第0次迭代，局部最优结果为：0.7564289180009705
# 当前最优结果:0.7564289180009705
# 第0次迭代，局部最优结果为：0.7471040237957531
# 当前最优结果:0.7564289180009705
# 现在的结果好像不是很好，我的建议是回火！这是第1次回火
# 第0次迭代，局部最优结果为：0.7614163614163615
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7079068201657384
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7614163614163615
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6342488189639148
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6945654261243615
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7226533466533466
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7047920433996384
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6987330816754694
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6748212606534622
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6494433670904259
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7614163614163615
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6860286028602861
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7471040237957531
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.5669872960533742
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6771027949903589
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6846624466184087
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7174356329590987
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.542342180236917
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6952864282968089
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7614163614163615
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7570654107796965
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7034678595740543
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6833223756300679
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.522305208495792
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.5225044061136632
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.5646169937089246
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7174356329590987
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7614163614163615
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6038902709832534
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6876459180957452
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7059668572990064
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7614163614163615
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7202587202587203
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.749923284262907
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6541653101826732
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7213418160786582
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6959821428571429
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7547809247155652
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6561447811447811
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7614163614163615
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6257512897789989
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6753303010612952
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7614163614163615
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6806066764517706
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6846728151075978
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7387720086604844
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6887563507841837
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7614163614163615
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6885727775324023
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.616449189402926
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7266167105289592
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7202587202587203
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7200350374263418
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7614163614163615
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6591365516738651
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6285460068539334
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7614163614163615
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6649605459586265
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7110184984961372
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7591438202341523
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7319693198146237
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7457023276910707
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.723969655117196
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.5280116788321167
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6499895768188451
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6771027949903589
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6942774437764417
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.636138509377946
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.723969655117196
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7614163614163615
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7187644075610881
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6541653101826732
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.5400891766539939
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7110184984961372
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7614163614163615
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6860286028602861
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7355508374616655
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6345136345136345
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7614163614163615
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6755068804255256
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7457023276910707
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7614163614163615
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.5922127255460589
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6970713167896266
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7614163614163615
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.5382261904761905
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7614163614163615
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6278978525424023
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7614163614163615
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7293567251461989
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.555554190218727
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7319693198146237
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6771027949903589
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7187329849174334
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6887563507841837
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.697474583853998
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6564210526315789
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7614163614163615
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6701301396258856
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6852747252747252
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6368464052287582
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.669386002576213
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6820595600881031
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6689205184352252
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.749923284262907
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7614163614163615
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6700904105528382
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6997090413842201
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7614163614163615
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7371158392434989
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6558734994378559
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7380484022364608
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6326977574082496
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7099271402550091
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7041553748870822
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.6558734994378559
# 当前最优结果:0.7614163614163614
# 第0次迭代，局部最优结果为：0.7643448858833474
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7319693198146237
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.6900335775335775
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7226533466533466
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7643448858833474
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7184474504896411
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.6086666778856672
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7643448858833474
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7643448858833474
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.6846002422774077
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7346753062095022
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7068636647904941
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7346753062095022
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.732161943319838
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.6969477416371204
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7215288860517076
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.6624322344322344
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7275667846797553
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7496932311876099
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7643448858833474
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7003214188901367
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7429146554380199
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7040018685767674
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7025032242024954
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7226533466533466
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.723969655117196
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.6808090923122678
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.6792518028846154
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7643448858833474
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7124133828644814
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.6721026342391628
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7161429561429561
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7161429561429561
# 当前最优结果:0.7643448858833474
# 第0次迭代，局部最优结果为：0.7687801560141986
# 当前最优结果:0.7687801560141986
# 第0次迭代，局部最优结果为：0.6923450929346682
# 当前最优结果:0.7687801560141986
# 第0次迭代，局部最优结果为：0.7161429561429561
# 当前最优结果:0.7687801560141986
# 第0次迭代，局部最优结果为：0.7060853811855288
# 当前最优结果:0.7687801560141986
# 第0次迭代，局部最优结果为：0.707012893590736
# 当前最优结果:0.7687801560141986
# 第0次迭代，局部最优结果为：0.7687801560141986
# 当前最优结果:0.7687801560141986
# 第0次迭代，局部最优结果为：0.7306237879767291
# 当前最优结果:0.7687801560141986
# 第0次迭代，局部最优结果为：0.7333198167146507
# 当前最优结果:0.7687801560141986
# 第0次迭代，局部最优结果为：0.7333198167146507
# 当前最优结果:0.7687801560141986
# 第0次迭代，局部最优结果为：0.7161429561429561
# 当前最优结果:0.7687801560141986
# 第0次迭代，局部最优结果为：0.7687801560141986
# 当前最优结果:0.7687801560141986
# 第0次迭代，局部最优结果为：0.6997523603157405
# 当前最优结果:0.7687801560141986
# 第0次迭代，局部最优结果为：0.7457023276910707
# 当前最优结果:0.7687801560141986
# 第0次迭代，局部最优结果为：0.736035816035816
# 当前最优结果:0.7687801560141986
# 第0次迭代，局部最优结果为：0.7200350374263418
# 当前最优结果:0.7687801560141986
# 第0次迭代，局部最优结果为：0.736035816035816
# 当前最优结果:0.7687801560141986
# 第0次迭代，局部最优结果为：0.7654156914364558
# 当前最优结果:0.7687801560141986
# 第0次迭代，局部最优结果为：0.7213418160786582
# 当前最优结果:0.7687801560141986
# 第0次迭代，局部最优结果为：0.7110184984961372
# 当前最优结果:0.7687801560141986
# 第0次迭代，局部最优结果为：0.7687801560141986
# 当前最优结果:0.7687801560141986
# 第0次迭代，局部最优结果为：0.7773221577476898
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7306828282828283
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7469805865344898
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7227168822034304
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7434430138292799
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7773221577476898
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.736035816035816
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7428383651673856
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7637444781363762
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7669380831212893
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7428383651673856
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7366714462621391
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7684045039303166
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7539879091098604
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7428383651673856
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7654772486772486
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7539879091098604
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7637444781363762
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7486380420923647
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7385608102589235
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7455947227375799
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7773221577476898
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7511692627206645
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7480527645985778
# 当前最优结果:0.7773221577476896
# 第0次迭代，局部最优结果为：0.7773221577476898
# ...
# 第0次迭代，局部最优结果为：0.6519720239382796
# 当前最优结果:0.6837719298245614
# 第0次迭代，局部最优结果为：0.6374210466952402
# 当前最优结果:0.6837719298245614
# 第0次迭代，局部最优结果为：0.6461714367384858
# 当前最优结果:0.6837719298245614
# 第0次迭代，局部最优结果为：0.6400016987061521
# 当前最优结果:0.6837719298245614
# 第0次迭代，局部最优结果为：0.6437310229202189
# 当前最优结果:0.6837719298245614
# 第0次迭代，局部最优结果为：0.6837719298245614
# 当前最优结果:0.6837719298245614
# 第0次迭代，局部最优结果为：0.6691234691234691
# 当前最优结果:0.6837719298245614
# 第0次迭代，局部最优结果为：0.6628595724716301
# 当前最优结果:0.6837719298245614
# 第0次迭代，局部最优结果为：0.6837719298245614
# 当前最优结果:0.6837719298245614
# 第0次迭代，局部最优结果为：0.66852487135506
# 当前最优结果:0.6837719298245614
# 第0次迭代，局部最优结果为：0.6837719298245614
# 当前最优结果:0.6837719298245614
# 第0次迭代，局部最优结果为：0.6885098606563619
# 当前最优结果:0.6885098606563619
# 第0次迭代，局部最优结果为：0.6825744308231174
# 当前最优结果:0.6885098606563619
# 第0次迭代，局部最优结果为：0.6982933045022781
# 当前最优结果:0.6982933045022782
# 第0次迭代，局部最优结果为：0.6982933045022781
# 当前最优结果:0.6982933045022782
# 第0次迭代，局部最优结果为：0.6825332125603865
# 当前最优结果:0.6982933045022782
# 第0次迭代，局部最优结果为：0.6596294134811789
# 当前最优结果:0.6982933045022782
# 第0次迭代，局部最优结果为：0.6632923277803452
# 当前最优结果:0.6982933045022782
# 第0次迭代，局部最优结果为：0.6628595724716301
# 当前最优结果:0.6982933045022782
# 第0次迭代，局部最优结果为：0.6982933045022781
# 当前最优结果:0.6982933045022782
# 第0次迭代，局部最优结果为：0.7213562026326287
# 当前最优结果:0.7213562026326287
# 第0次迭代，局部最优结果为：0.7197914386355947
# 当前最优结果:0.7213562026326287
# 第0次迭代，局部最优结果为：0.7158509745554729
# 当前最优结果:0.7213562026326287
# 第0次迭代，局部最优结果为：0.7213562026326287
# 当前最优结果:0.7213562026326287
# 第0次迭代，局部最优结果为：0.6982933045022781
# 当前最优结果:0.7213562026326287
# 第0次迭代，局部最优结果为：0.6859115131516565
# 当前最优结果:0.7213562026326287
# 第0次迭代，局部最优结果为：0.7158509745554729
# 当前最优结果:0.7213562026326287
# 第0次迭代，局部最优结果为：0.7213562026326287
# 当前最优结果:0.7213562026326287
# 第0次迭代，局部最优结果为：0.716682188360711
# 当前最优结果:0.7213562026326287
# 第0次迭代，局部最优结果为：0.6822371027067811
# 当前最优结果:0.7213562026326287
# 第0次迭代，局部最优结果为：0.7240131315557691
# 当前最优结果:0.7240131315557691
# 第0次迭代，局部最优结果为：0.7240131315557691
# 当前最优结果:0.7240131315557691
# 第0次迭代，局部最优结果为：0.691863023027159
# 当前最优结果:0.7240131315557691
# 第0次迭代，局部最优结果为：0.7158509745554729
# 当前最优结果:0.7240131315557691
# 第0次迭代，局部最优结果为：0.7058153149637031
# 当前最优结果:0.7240131315557691
# 第0次迭代，局部最优结果为：0.6822371027067811
# 当前最优结果:0.7240131315557691
# 第0次迭代，局部最优结果为：0.6943120956750427
# 当前最优结果:0.7240131315557691
# 第0次迭代，局部最优结果为：0.7253489491416654
# 当前最优结果:0.7253489491416654
# 第0次迭代，局部最优结果为：0.7226822250639386
# 当前最优结果:0.7253489491416654
# 第0次迭代，局部最优结果为：0.7000503232299772
# 当前最优结果:0.7253489491416654
# 第0次迭代，局部最优结果为：0.7174071723262456
# 当前最优结果:0.7253489491416654
# 第0次迭代，局部最优结果为：0.7211145846624984
# 当前最优结果:0.7253489491416654
# 第0次迭代，局部最优结果为：0.7226822250639386
# 当前最优结果:0.7253489491416654
# 第0次迭代，局部最优结果为：0.7174071723262456
# 当前最优结果:0.7253489491416654
# 第0次迭代，局部最优结果为：0.7153695836201236
# 当前最优结果:0.7253489491416654
# 第0次迭代，局部最优结果为：0.7253489491416654
# 当前最优结果:0.7253489491416654
# 第0次迭代，局部最优结果为：0.7226822250639386
# 当前最优结果:0.7253489491416654
# 第0次迭代，局部最优结果为：0.7269292300766146
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.7253489491416654
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.7213562026326287
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.7237755240892974
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.7269292300766146
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.7253489491416654
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.7269292300766146
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.7253489491416654
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.7229277847734406
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.7269292300766146
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.7269292300766146
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.7216037412115843
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.7253489491416654
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.7269292300766146
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.7269292300766146
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.7269292300766146
# 当前最优结果:0.7269292300766145
# 现在的结果好像不是很好，我的建议是回火！这是第1次回火
# 第0次迭代，局部最优结果为：0.7216037412115843
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.716009692285764
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.7084087401383569
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.6951260762607626
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.7111834705803701
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.7269292300766146
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.6089577166947837
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.6070811135616719
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.7190959409594097
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.6633409872866124
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.6080179671319831
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.6686039633244601
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.6979806712569858
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.6700606168393283
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.6788642301570618
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.6089577166947837
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.6680112293144208
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.6864035587134584
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.5416566828005942
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.7269292300766146
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.5916431113902848
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.6778133843068909
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.6879388918053241
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.6948776767222664
# 当前最优结果:0.7269292300766145
# 第0次迭代，局部最优结果为：0.7350664975774721
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.7350664975774721
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6920854333857629
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.7203706137992296
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6202123573309921
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6127459451034605
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.7118048995528685
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.7242566961425093
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.5075496480572987
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6110998472622089
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.5021045500483102
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.7014459924907686
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6862629022465088
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.7350664975774721
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.7350664975774721
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.617585990219381
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6804760668420122
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6297498328504568
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.5897292079724512
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.5604489938855264
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.5496193414074491
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6857632568863001
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.686692867042585
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6761433314389974
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6577580563031934
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6843722563652327
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.7318537943537943
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6852799187564892
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.5841176736584389
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.7188758372587601
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6998146406776644
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.646351575456053
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.673444156463193
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6852098133939567
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.57686038462888
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.5269807966896873
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.7350664975774721
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.7350664975774721
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.7193934379276327
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6293860107053115
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6846624466184087
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.676968458250043
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6502840704782452
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.698573834577172
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.5503469263542301
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.7226822250639386
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6948776767222664
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.5722006011707009
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6642668762810106
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6330632034025869
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6900098821392734
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.5901602965747703
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.7133097724906126
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.5670512981311927
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6577556639424458
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.5304961043837416
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6751941457586619
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6822371027067811
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.7350664975774721
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.691384267188647
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.7350664975774721
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6073910371164006
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.7350664975774721
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.611767571352699
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.57686038462888
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6684532104191231
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.630645836239364
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.684020213023481
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6526213984641145
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6369518281493796
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.7111834705803701
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6689601089015151
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.6959821428571429
# 当前最优结果:0.7350664975774721
# 第0次迭代，局部最优结果为：0.7378195556208333
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.6404255243801813
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.6876014706832898
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.5544640667157223
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.7378195556208333
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.6562138272124591
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.6527344652344652
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.654738457973701
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.6652834492145826
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.639006671189507
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.6193924033291092
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.6236473111753306
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.686935448336638
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.7202845387596436
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.7216037412115843
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.6083615910436514
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.569193000125897
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.7378195556208333
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.6734968251308121
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.6031752384764192
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.6426170323149194
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.6767911140385018
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.6262106506089179
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.7255905022127533
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.707012893590736
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.7255905022127533
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.6654744031322676
# 当前最优结果:0.7378195556208335
# 第0次迭代，局部最优结果为：0.7405933133487312
# 当前最优结果:0.7405933133487314
# 第0次迭代，局部最优结果为：0.6639303336466166
# 当前最优结果:0.7405933133487314
# 第0次迭代，局部最优结果为：0.6240475927561837
# 当前最优结果:0.7405933133487314
# 第0次迭代，局部最优结果为：0.6389705466674204
# 当前最优结果:0.7405933133487314
# 第0次迭代，局部最优结果为：0.7296215605583798
# 当前最优结果:0.7405933133487314
# 第0次迭代，局部最优结果为：0.7023095235321302
# 当前最优结果:0.7405933133487314
# 第0次迭代，局部最优结果为：0.6713441435020194
# 当前最优结果:0.7405933133487314
# 第0次迭代，局部最优结果为：0.6864035587134584
# 当前最优结果:0.7405933133487314
# 第0次迭代，局部最优结果为：0.6652296102290952
# 当前最优结果:0.7405933133487314
# 第0次迭代，局部最优结果为：0.7201956161590416
# 当前最优结果:0.7405933133487314
# 第0次迭代，局部最优结果为：0.7405933133487312
# 当前最优结果:0.7405933133487314
# 第0次迭代，局部最优结果为：0.6758072773611065
# 当前最优结果:0.7405933133487314
# 第0次迭代，局部最优结果为：0.6876014706832898
# 当前最优结果:0.7405933133487314
# 第0次迭代，局部最优结果为：0.721724693900356
# 当前最优结果:0.7405933133487314
# 第0次迭代，局部最优结果为：0.6755573486342717
# 当前最优结果:0.7405933133487314
# 第0次迭代，局部最优结果为：0.6816713469910853
# 当前最优结果:0.7405933133487314
# 第0次迭代，局部最优结果为：0.7141435521577051
# 当前最优结果:0.7405933133487314
# 第0次迭代，局部最优结果为：0.7405933133487312
# 当前最优结果:0.7405933133487314
# 第0次迭代，局部最优结果为：0.7073530389614453
# 当前最优结果:0.7405933133487314
# 第0次迭代，局部最优结果为：0.6723475131425343
# 当前最优结果:0.7405933133487314
# 第0次迭代，局部最优结果为：0.698573834577172
# 当前最优结果:0.7405933133487314
# 第0次迭代，局部最优结果为：0.7443058813845331
# 当前最优结果:0.744305881384533
# 第0次迭代，局部最优结果为：0.6736247690565589
# 当前最优结果:0.744305881384533
# 第0次迭代，局部最优结果为：0.6773183520599251
# 当前最优结果:0.744305881384533
# 第0次迭代，局部最优结果为：0.6639303336466166
# 当前最优结果:0.744305881384533
# 第0次迭代，局部最优结果为：0.707223026084236
# 当前最优结果:0.744305881384533
# 第0次迭代，局部最优结果为：0.6786757034668589
# 当前最优结果:0.744305881384533
# 第0次迭代，局部最优结果为：0.7429146554380199
# 当前最优结果:0.744305881384533
# 第0次迭代，局部最优结果为：0.672212557800675
# 当前最优结果:0.744305881384533
# 第0次迭代，局部最优结果为：0.7084836731895556
# 当前最优结果:0.744305881384533
# 第0次迭代，局部最优结果为：0.7084836731895556
# 当前最优结果:0.744305881384533
# 第0次迭代，局部最优结果为：0.6977490720806229
# 当前最优结果:0.744305881384533
# 第0次迭代，局部最优结果为：0.7443058813845331
# 当前最优结果:0.744305881384533
# 第0次迭代，局部最优结果为：0.7429146554380199
# 当前最优结果:0.744305881384533
# 第0次迭代，局部最优结果为：0.7333198167146507
# 当前最优结果:0.744305881384533
# 第0次迭代，局部最优结果为：0.6985225670638676
# 当前最优结果:0.744305881384533
# 第0次迭代，局部最优结果为：0.726351134245871
# 当前最优结果:0.744305881384533
# 第0次迭代，局部最优结果为：0.7017644616393545
# 当前最优结果:0.744305881384533
# 第0次迭代，局部最优结果为：0.680788589024955
# 当前最优结果:0.744305881384533
# 第0次迭代，局部最优结果为：0.7147673421313698
# 当前最优结果:0.744305881384533
# 第0次迭代，局部最优结果为：0.7116116364265955
# 当前最优结果:0.744305881384533
# 第0次迭代，局部最优结果为：0.6866172584515384
# 当前最优结果:0.744305881384533
# 第0次迭代，局部最优结果为：0.7505987141653488
# 当前最优结果:0.7505987141653488
# 第0次迭代，局部最优结果为：0.7505987141653488
# 当前最优结果:0.7505987141653488
# 第0次迭代，局部最优结果为：0.7224512623841484
# 当前最优结果:0.7505987141653488
# 第0次迭代，局部最优结果为：0.7505987141653488
# 当前最优结果:0.7505987141653488
# 第0次迭代，局部最优结果为：0.7505987141653488
# 当前最优结果:0.7505987141653488
# 第0次迭代，局部最优结果为：0.7505987141653488
# 当前最优结果:0.7505987141653488
# 第0次迭代，局部最优结果为：0.7505987141653488
# 当前最优结果:0.7505987141653488
# 第0次迭代，局部最优结果为：0.7505987141653488
# 当前最优结果:0.7505987141653488
# 第0次迭代，局部最优结果为：0.7436998289248585
# 当前最优结果:0.7505987141653488
# 第0次迭代，局部最优结果为：0.7043089481555334
# 当前最优结果:0.7505987141653488
# 第0次迭代，局部最优结果为：0.6987438807169655
# 当前最优结果:0.7505987141653488
# 第0次迭代，局部最优结果为：0.7140476810941856
# 当前最优结果:0.7505987141653488
# 第0次迭代，局部最优结果为：0.7112897643245965
# 当前最优结果:0.7505987141653488
# 第0次迭代，局部最优结果为：0.7263423822892694
# 当前最优结果:0.7505987141653488
# 第0次迭代，局部最优结果为：0.7521127229172212
# 当前最优结果:0.7521127229172212
# 第0次迭代，局部最优结果为：0.729321428283366
# 当前最优结果:0.7521127229172212
# 第0次迭代，局部最优结果为：0.7521127229172212
# 当前最优结果:0.7521127229172212
# 第0次迭代，局部最优结果为：0.7263423822892694
# 当前最优结果:0.7521127229172212
# 第0次迭代，局部最优结果为：0.7280237033220077
# 当前最优结果:0.7521127229172212
# 第0次迭代，局部最优结果为：0.7247443172710077
# 当前最优结果:0.7521127229172212
# 第0次迭代，局部最优结果为：0.7521127229172212
# 当前最优结果:0.7521127229172212
# 第0次迭代，局部最优结果为：0.7436998289248585
# 当前最优结果:0.7521127229172212
# 第0次迭代，局部最优结果为：0.7521127229172212
# 当前最优结果:0.7521127229172212
# 第0次迭代，局部最优结果为：0.7135321109966897
# 当前最优结果:0.7521127229172212
# 第0次迭代，局部最优结果为：0.7521127229172212
# 当前最优结果:0.7521127229172212
# 第0次迭代，局部最优结果为：0.727426309692367
# 当前最优结果:0.7521127229172212
# 第0次迭代，局部最优结果为：0.7534978292209362
# 当前最优结果:0.7534978292209361
# 第0次迭代，局部最优结果为：0.750732699572419
# 当前最优结果:0.7534978292209361
# 第0次迭代，局部最优结果为：0.7190673484480989
# 当前最优结果:0.7534978292209361
# 第0次迭代，局部最优结果为：0.7558629913690414
# 当前最优结果:0.7558629913690414
# 第0次迭代，局部最优结果为：0.7434063404367272
# 当前最优结果:0.7558629913690414
# 第0次迭代，局部最优结果为：0.7645710903479475
# 当前最优结果:0.7645710903479475
# 第0次迭代，局部最优结果为：0.7501036948550761
# 当前最优结果:0.7645710903479475
# 第0次迭代，局部最优结果为：0.7645710903479475
# 当前最优结果:0.7645710903479475
# 第0次迭代，局部最优结果为：0.76177558361907
# 当前最优结果:0.7645710903479475
# 第0次迭代，局部最优结果为：0.7501036948550761
# 当前最优结果:0.7645710903479475
# 第0次迭代，局部最优结果为：0.76177558361907
# 当前最优结果:0.7645710903479475
# 第0次迭代，局部最优结果为：0.7714430751248811
# 当前最优结果:0.7714430751248811
# 第0次迭代，局部最优结果为：0.7771050426487335
# 当前最优结果:0.7771050426487335
# 第0次迭代，局部最优结果为：0.76177558361907
# 当前最优结果:0.7771050426487335
# 第0次迭代，局部最优结果为：0.7814063620729884
# 当前最优结果:0.7814063620729884
# 第0次迭代，局部最优结果为：0.7771050426487335
# 当前最优结果:0.7814063620729884
# 本次退火用时：8324.639991760254

# %%
def draw(history):
    plt.plot(history['T'], history['f'])
    plt.title('SA')
    plt.xlabel('T')
    plt.ylabel('f')
    plt.gca().invert_xaxis()
    plt.show()
    return

def wrXSLX(squ, use, tim, filename):
    data = {'square':squ,'utilization':use,'timecost':tim}
    df = pd.DataFrame(data)
    df.to_excel(filename,sheet_name='layout',header=0)
    return df

def drawP(m3):
    Lw,Pw,Lh,Ph = m.lcs_xy(m3.l,m3.x,m3.y,m3.w,m3.h)
    print(Pw)
    print(Ph)
    h,w = m3.h,m3.w
    for i in range(len(Pw)):
        x,y = [Pw[i], Pw[i], Pw[i]+w[i], Pw[i]+w[i], Pw[i]],[Ph[i], Ph[i]+h[i], Ph[i]+h[i], Ph[i], Ph[i]]
        plt.plot(x,y,color='r')
        plt.scatter(x,y,color='b')
    plt.show()
    return

# %%
print("本次测试的退火环境为：")
print(sa.iter,sa.T0,sa.alpha)
squ = []
use = []
for i in range(30):
    squ.append(mmm[i].s_cur)
    use.append(mmm[i].use)
print(use)
index = use.index(max(use))
history = {'f': fff[index], 'T': TTT[index]}
print('本次最优解为：'+str(max(use)))
draw(history)

drawP(mmm[index])

wrXSLX(squ,use,sss,'result_49.xlsx')
# Out:
# 本次测试的退火环境为：
# 4000 400 0.95
# [0.8024351175183809, 0.7851278778485437, 0.77767648273015, 0.7940112399016509, 0.7895704262555613, 0.7973615869278625, 0.769306686405132, 0.8157333273190644, 0.773776720464153, 0.8139673051994815, 0.8038368537088401, 0.7681694998768169, 0.7390558080230163, 0.8081257652536844, 0.7880530934888139, 0.8180173334057066, 0.7620452227850022, 0.8148108098366269, 0.8187283823183209, 0.7774591696795911, 0.7990420897289751, 0.7631901011993687, 0.7556261229265031, 0.7771417766776678, 0.7663530807695568, 0.7876961138745394, 0.7991162369368773, 0.7966064364940225, 0.7792850248207391, 0.7814063620729884]
# 本次最优解为：0.8187283823183209
# [4816. 5964. 1610.    0. 2156.  756. 3206. 4172. 4074. 5950. 3738. 1610.
#   896. 3766. 6216. 2156. 2618. 4872. 4536. 4074.    0.  392. 4284. 4074.
#  2618. 2856.    0. 3766. 4536.  392. 2618.  994. 4326. 4816. 2912.    0.
#  2856. 4172. 3416. 5362.    0. 1778.  364. 1610. 1694. 4536. 1162. 3010.
#  3738.]
# [   0. 3234. 2366. 1358.    0. 4802. 5768. 2100. 4172. 6132. 3346. 1960.
#   448. 1330. 5180.  532. 2282. 6132. 4788. 5180. 4802. 4802.    0. 6132.
#  1960. 5768. 4438.    0. 3794. 5754. 3584.    0. 5180. 3234. 1330.    0.
#  4550. 1134. 4550. 4788.  448.    0.  448. 1330. 5754. 4284.  532. 2282.
#  2254.]
#         square  utilization     timecost
# 0   44172324.0     0.802435  8433.026912
# 1   45146052.0     0.785128  8408.219698
# 2   45578624.0     0.777676  8423.520457
# 3   44640960.0     0.794011  8375.138575
# 4   44892036.0     0.789570  8429.689443
# 5   44453388.0     0.797362  8409.800045
# 6   46074504.0     0.769307  8359.771640
# 7   43452220.0     0.815733  8406.425535
# 8   45808336.0     0.773777  8396.352907
# 9   43546496.0     0.813967  8404.897773
# 10  44095296.0     0.803837  8442.198466
# 11  46142712.0     0.768169  8370.223751
# 12  47960416.0     0.739056  8327.985125
# 13  43861272.0     0.808126  8421.771753
# 14  44978472.0     0.788053  8385.988150
# 15  43330896.0     0.818017  8403.815346
# 16  46513544.0     0.762045  8349.534155
# 17  43501416.0     0.814811  8390.013057
# 18  43293264.0     0.818728  8363.018684
# 19  45591364.0     0.777459  8385.702754
# 20  44359896.0     0.799042  8350.202230
# 21  46443768.0     0.763190  8365.305372
# 22  46908680.0     0.755626  8385.268360
# 23  45609984.0     0.777142  8362.157295
# 24  46252080.0     0.766353  8353.464112
# 25  44998856.0     0.787696  8354.216699
# 26  44355780.0     0.799116  8340.607917
# 27  44495528.0     0.796606  8330.239300
# 28  45484544.0     0.779285  8299.075096
# 29  45361064.0     0.781406  8324.639992

# %%
# Out:
# 0.6610924369747899
# 0.6610924369747899
