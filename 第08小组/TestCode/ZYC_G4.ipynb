# %%
# 导入必要的包
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import copy
import time
import pandas as pd

# %%
'''
产生初始解和初始目标函数X0和f0，初始化最优值记录器X*和f*

既然序列对可以表达模块的位置信息以及整体的最大长度和宽度
那么我们对模块进行乱序，随机生成一个序列对，一个正序列和一个负序列
目标函数就是该序列形成的矩形面积除以总面积，这样子就可以用求目标函数的最小值的方法求解该问题

while(不满足回火终止条件)
    t=t0
        while t>1e-3
            for i=0 i<L i++
                从四种新解中任选一种产生新解Xnew
                计算评价新解的目标函数fnew
                计算评价目标函数差df=fnew-f
                
                if df<0 or exp(-df/t)>random(0,1)
                    接受新解X=Xnew f=fnew
                    与最优值记录器比较，记录最优值
                else
                    还原原来的解
            下降温度 t=a*t
        以记录器的最优解作为下一个循环的初始解
    达不到要求，产生回火温度

'''

# %%
'''
首先
    我们要确定初始温度T0和降温系数α还有终止温度Tf（决定了一共生成
    多少组新解、接受新解的程度）、迭代次数iter（生成一批新解中的新
    解的个数）。
评价函数设置
    整体面积利用率的倒数，一般模拟退火算法都是对最小值进行求解的，
    于是我们需要的面积利用率越大越好，所以我们取倒数即可。
    （面积利用率=sum(模块面积)/生成的矩形画布的面积，生成的矩形画
    布的面积我们可以通过求解LCS得到）

伪代码：
生成初始解x&y&h&w
while T(当前温度)>Tf
    while n(当前循环次数)<iter
        得到上一次的解或者是初始解x&y&h&w
            得到上一次解的评价函数的值f
        从四种方法中生成新解x_new&y_new&h_new&w_new
            得到评价函数值f_new
        Metropolis（f,f_new）  #Metropolis准则
            根据Metropolis准则的结果来决定是否接受新解或者是还原原来的解
    下降温度T=α*T
以记录器中的最优解作为布局问题的最终解


'''

# %%
class module():
    def __init__(self, name='', typ='', w=0., h=0., pos=[], s=0.):
        self.name = name  #模块名称
        self.typ = typ    #模块类型
        self.w = w        #模块宽度
        self.h = h        #模块高度
        self.pos = pos    #模块位置:右下角、右上角、左上角、左下角(左下角一般为(0,0))
        self.s = s        #模块面积

# %%
def rdfile(filename,n):
    #filename是要读取的文件名，n为其中所包含的模块数
    
    #用于存储所有模块对象的列表
    modules = np.zeros(n-1,dtype=type(module('a','b',0.,0.,[],0.))) 
    t = 0
    s_total = 0.
    b1,b2 = 0,0

    #通过文件名打开数据流，按照行的顺序有规律地依次将模块名...读出，顺便创建模块对象放入数组中方便调用
    with open(filename,'r') as f:
        for line in f:
            line = line.split(' ')
            if 'MODULE' in line:
                #print(line[1].split(';')[0])
                name = line[1].split(';')[0]

            if 'TYPE' in line:
                typ = line[2]

            if 'DIMENSIONS' in line:
                #print(line[2:])
                w = 0.
                h = 0.
                pos = np.zeros(8)
                for i in range(10)[2:]:
                    if i != 9:
                        pos[i-2] = int(line[i])
                    else:
                        pos[i-2] = int(line[i].split(";")[0])
                # 用两个坐标值相减即可得到模块的宽高
                h = pos[3]-pos[1]
                w = pos[2]-pos[4]
                s = h*w
                if t == n-1:
                    # 这里的s是parent模块的面积，其实实际上并没有使用到
                    s_total = s
                if t<n-1:
                    modules[t] = module(name,typ,w,h,pos,s)
                    t = t+1
                
    return modules,s_total

# %%
# 读取ami33和ami49并计算出它们模块的总面积（不包括parent）
modules,st = rdfile('ami33.yal',34)
modules1,st1 = rdfile('ami49.yal',50)
s = 0.
for i in range(33):
    s = s + modules[i].s
s1 = 0.
for i in range(49):
    s1 = s1 + modules1[i].s
print(s,s1)
# Out:
# 1156449.0 35445424.0

# %%
# m类，用于存储一组模块的布局
# x为正向序列，y为负向序列，modules则存储着从文件读取出来的各个模块的信息，比如宽w和高h
# m类中还存储着这组模块布局所代表的信息比如面积利用率use、总面积s_cur...其中的iuse是用于模拟退火算法，它是面积利用率的倒数
class m():
    def __init__(self, modules,s_total):
        self.modules = modules
        self.s_total = s_total
        self.l = len(modules)
        self.s_cur,self.iuse,self.use = 0.,0.,0.
        
        # 产生一个比较优的解，在此基础上进行模拟退火，这里随机产生可能没有对模块进行旋转
        # 可能在一定程度上会导致我们的初始解较差
        self.x,self.y,self.modules = self.xyInit()
        self.w,self.h = m.whSort(self.l, self.x, self.y, self.modules)
        self.s_cur,self.iuse,self.use = m.calSC(self.l, self.x, self.y, self.w, self.h, self.s_total) 
        
    # 计算当前模块布局的信息：总面积s_cur、面积利用率及其倒数
    def calSC(l,x,y,w,h,s_total):
        Lw,Pw,Lh,Ph = m.lcs_xy(l,x,y,w,h)
        s_cur = Lw*Lh
        iuse = s_cur/s_total
        use = s_total/s_cur
            
        return s_cur,iuse,use
    
    # 根据x和y序列还有模块序列（包含旋转信息），来生成新的模块宽高序列，用于LCS算法
    def whSort(l,x,y,modules):
        w = np.zeros(l)
        h = np.zeros(l)
        for i in range(l):
            w[i] = modules[i].w
            h[i] = modules[i].h
        return w,h
    
    # 初始化生成一组正向和反向序列--生成一个0到（总模块个数-1）长度的顺序序列，然后用shuffle打乱，随机翻转模块
    def xyInit(self):
        l = self.l
        tmp = np.zeros(l,dtype='int')
        for i in range(l):
            tmp[i] = i
            
        np.random.shuffle(tmp)
        x = copy.deepcopy(tmp)
        np.random.shuffle(tmp)
        y = copy.deepcopy(tmp)
        
        # 模块随机翻转
        md = copy.deepcopy(self.modules)
        for i in range(l):
            yes = random.randint(0,1)
            if yes:
                md[i].w,md[i].h = md[i].h,md[i].w 
            
        return x,y,md
    
    # lcs快速算法
    def lcs_xy(n,x,y,w,h):
        xr = x[::-1]
        Lw,Pw = m.lcs(n,x,y,w)
        Lh,Ph = m.lcs(n,xr,y,h)
        return Lw,Pw,Lh,Ph
    
    # lcs快速算法核心
    def lcs(n,x,y,w):
        # n个模块，x为正序列，y为负序列，w为每个模块的宽度/高度 
        class mdd():
            def __init__(self,x,y):
                self.x = x
                self.y = y

        match = np.zeros(n,dtype=type(mdd(3,4)))
        for i in range(len(x)):
            for j in range(len(y)):
                if x[i]==y[j]:
                    match[int(x[i]-1)] = mdd(i,j)
                    break
                    
        # 模块的位置P，总长度L
        P = np.zeros(n)
        L = np.zeros(n)

        for i in range(n):
            b = int(x[i]-1)
            p = int(match[b].y)
            P[b] = L[p]
            t = P[b] + w[b]
            for j in range(n)[p:n]:
                if t > L[j]:
                    L[j] = t
                else:
                    break

        return L[n-1],P
    
    def refresh(self):
        # 由于x,y,modules的改变，需要更新数据
        self.w,self.h = m.whSort(self.l, self.x, self.y, self.modules)
        self.s_cur,self.iuse,self.use = m.calSC(self.l, self.x, self.y, self.w, self.h, self.s_total) 
    
    def exchangeX(self,pos1,pos2):
        # 第1个随机模块与第2个随机模块交换正序列中的位置
        id1 = np.array(np.where(self.x==pos1))[0][0]
        id2 = np.array(np.where(self.x==pos2))[0][0] 
        x1 = copy.deepcopy(self.x)
        x1[id1],x1[id2] = x1[id2],x1[id1]
        self.x = x1
        return
    
    def exchangeY(self,pos1,pos2):
        # 第1个随机模块与第2个随机模块交换负序列中的位置
        id1 = np.array(np.where(self.y==pos1))[0][0]
        id2 = np.array(np.where(self.y==pos2))[0][0]
        y1 = copy.deepcopy(self.y)
        y1[id1],y1[id2] = y1[id2],y1[id1]
        self.y = y1
        return
    
    def exchangeXY(self,pos1,pos2):
        # 第1个随机模块与第2个随机模块交换正负序列中的位置
        self.exchangeX(pos1,pos2)
        self.exchangeY(pos1,pos2)
        return
    
    def exchangeWH(self,pos):
        # 旋转模块
        md = copy.deepcopy(self.modules)
        md[pos].w,md[pos].h = md[pos].h,md[pos].w 
        self.modules = md
        return

# %%
# SA类 进行模拟退火算法的框架
# 包含3个主要的方法：产生新解、Metropolis准则、运行
class SA:
    def __init__(self, m1, m2, m3, s_total, iter=4000, T0=800, Tf=0.01, alpha=0.95):
        self.iter = iter         #内循环迭代次数,即为L =100
        self.alpha = alpha       #降温系数，alpha=0.95
        self.T0 = T0             #初始温度T0为400
        self.Tf = Tf             #温度终值Tf为0.01
        self.T = T0              #当前温度
        
        # 生成初始解
        self.m1 = m1
        # 用于保存局部最优解&全局最优解
        self.m2 = m2
        self.m3 = m3
        
        # 模块的一些相关信息，模块个数&模块总面积
        self.l = self.m1.l
        self.s_total = self.m1.s_total
        
        # 存放解的序列对
        self.xi = np.zeros((self.iter,self.l),dtype='int')
        self.yi = np.zeros((self.iter,self.l),dtype='int')
        self.modulesi = np.zeros((self.iter,self.l),dtype=type(module()))
                                 
        # 存放f的历史，用于生成图像
        self.history = {'f': [], 'T': []}

    def generate_new(self):   #扰动产生新解的过程
        rand,rand1,rand2 = 0,0,0
        # 选择产生新解的方式
        rand = random.randint(1,4)
        
        while rand1 == rand2:
            rand1 = random.randint(0,self.l-1)
            rand2 = random.randint(0,self.l-1)
            
        if rand == 1:
            #正向序列中交换两个模块的顺序
            self.m1.exchangeX(rand1,rand2)
        elif rand == 2:
            #负向序列中交换两个模块的顺序
            self.m1.exchangeY(rand1,rand2)
        elif rand == 3:
            #正向序列和负向序列中同时交换两个模块的顺序
            self.m1.exchangeXY(rand1,rand2)
        else:
            #将某个模块旋转，即将模块中的宽和高对调
            self.m1.exchangeWH(rand1)
            
        self.m1.refresh()
            
        return 

    def Metrospolis(self, f, f_new):   #Metropolis准则
        if f_new <= f:
            if self.m1.iuse < self.m3.iuse:
                self.m3.x,self.m3.y,self.m3.modules = copy.deepcopy(self.m1.x),copy.deepcopy(self.m1.y),copy.deepcopy(self.m1.modules)
                self.m3.refresh()
            return 1
        else:
            p = math.exp((f - f_new) / self.T)
            if np.random.rand() < p:
                return 1
            else:
                return 0

    
    def run(self):
        count = 0   #迭代计数器
        count1 = 0  #回火计数器
        
        #外循环迭代，当前温度小于终止温度的阈值
        while self.T > self.Tf:  
            #用于存放一次迭代的中间结果
            t= []   
            #内循环迭代
            for i in range(self.iter): 
                #f为迭代一次后的值
                f = self.m2.iuse
                #产生新解
                self.generate_new()
                x_new,y_new,modules_new = copy.deepcopy(self.m1.x),copy.deepcopy(self.m1.y),copy.deepcopy(self.m1.modules)
                #产生新值
                f_new = self.m1.iuse
                #判断是否接受新值
                if self.Metrospolis(f, f_new):
                    self.xi[i] = x_new
                    self.yi[i] = y_new
                    self.modulesi[i] = modules_new
                    t.append(f_new)
                else:
                    t.append(self.m1.iuse)
                    if i>= 1:
                        self.m1.x = copy.deepcopy(self.xi[i-1])
                        self.m1.y = copy.deepcopy(self.yi[i-1])
                        self.m1.modules = copy.deepcopy(self.modulesi[i-1])
                        self.m1.refresh()
            
                    
            f_best = min(t)
            idx = t.index(f_best)
            
            # 将当前局部最优解作为下一次迭代的初始解
            self.m1.x = copy.deepcopy(self.m3.x)
            self.m1.y = copy.deepcopy(self.m3.y)
            self.m1.modules = copy.deepcopy(self.m3.modules)
            self.m1.refresh()
            
            # 保存局部最优解，但是好像没用
            self.m2.x = copy.deepcopy(self.xi[idx])
            self.m2.y = copy.deepcopy(self.yi[idx])
            self.m2.modules = copy.deepcopy(self.modulesi[idx])
            self.m2.refresh()
            
            # 迭代L次记录在该温度下最优解
            self.history['f'].append(f_best)
            self.history['T'].append(self.T)
            
            #温度按照一定的比例下降（冷却）+回火
            self.T = self.T * self.alpha  
            #if self.T <= self.Tf:
                #if self.m3.use < 0.9:
                    #self.T = self.T0/2
                    #count1 += 1
                    #print("现在的结果好像不是很好，我的建议是回火！这是第" + str(count1) + "次回火")
                    
            count += 1
            
            print("第"+str(count)+"次迭代，局部最优结果为："+str(1/f_best))
            self.m3.refresh()
            print("当前最优结果:"+str(self.m3.use))
            
            
        return

# %%
mmm = []
TTT = []
fff = []
sss = []
for i in range(30):
    t1 = time.time()
    m1 = m(modules,s)
    m2 = m(modules,s)
    m3 = m(modules,s)
    sa = SA(m1,m2,m3,s)
    sa.run()
    t2 = time.time()
    t = t2-t1
    mmm.append(sa.m3)
    TTT.append(sa.history['T'])
    fff.append(sa.history['f'])
    sss.append(t)
    print("本次退火用时："+str(t))
# Out:
# 第1次迭代，局部最优结果为：0.5310756075607561
# 当前最优结果:0.5310756075607561
# 第2次迭代，局部最优结果为：0.550807505601195
# 当前最优结果:0.550807505601195
# 第3次迭代，局部最优结果为：0.5617145849200305
# 当前最优结果:0.5617145849200305
# 第4次迭代，局部最优结果为：0.5305383837248511
# 当前最优结果:0.5617145849200305
# 第5次迭代，局部最优结果为：0.5319134550371873
# 当前最优结果:0.5617145849200305
# 第6次迭代，局部最优结果为：0.5457130965593785
# 当前最优结果:0.5617145849200305
# 第7次迭代，局部最优结果为：0.5084997737702799
# 当前最优结果:0.5617145849200305
# 第8次迭代，局部最优结果为：0.5267257348182204
# 当前最优结果:0.5617145849200305
# 第9次迭代，局部最优结果为：0.5434262030854248
# 当前最优结果:0.5617145849200305
# 第10次迭代，局部最优结果为：0.553858068149817
# 当前最优结果:0.5617145849200305
# 第11次迭代，局部最优结果为：0.57964927792514
# 当前最优结果:0.57964927792514
# 第12次迭代，局部最优结果为：0.5257752628764927
# 当前最优结果:0.57964927792514
# 第13次迭代，局部最优结果为：0.5119744891318495
# 当前最优结果:0.57964927792514
# 第14次迭代，局部最优结果为：0.5089932712215322
# 当前最优结果:0.57964927792514
# 第15次迭代，局部最优结果为：0.5308247677740042
# 当前最优结果:0.57964927792514
# 第16次迭代，局部最优结果为：0.5699072732541293
# 当前最优结果:0.57964927792514
# 第17次迭代，局部最优结果为：0.5396117703546196
# 当前最优结果:0.57964927792514
# 第18次迭代，局部最优结果为：0.57964927792514
# 当前最优结果:0.57964927792514
# 第19次迭代，局部最优结果为：0.57964927792514
# 当前最优结果:0.57964927792514
# 第20次迭代，局部最优结果为：0.57964927792514
# 当前最优结果:0.57964927792514
# 第21次迭代，局部最优结果为：0.5745690914402571
# 当前最优结果:0.57964927792514
# 第22次迭代，局部最优结果为：0.563457957312706
# 当前最优结果:0.57964927792514
# 第23次迭代，局部最优结果为：0.49684223822154855
# 当前最优结果:0.57964927792514
# 第24次迭代，局部最优结果为：0.5763369963369963
# 当前最优结果:0.57964927792514
# 第25次迭代，局部最优结果为：0.5723119452931762
# 当前最优结果:0.57964927792514
# 第26次迭代，局部最优结果为：0.5536242083040113
# 当前最优结果:0.57964927792514
# 第27次迭代，局部最优结果为：0.5319134550371873
# 当前最优结果:0.57964927792514
# 第28次迭代，局部最优结果为：0.57964927792514
# 当前最优结果:0.57964927792514
# 第29次迭代，局部最优结果为：0.507941632231405
# 当前最优结果:0.57964927792514
# 第30次迭代，局部最优结果为：0.593288084464555
# 当前最优结果:0.593288084464555
# 第31次迭代，局部最优结果为：0.593288084464555
# 当前最优结果:0.593288084464555
# 第32次迭代，局部最优结果为：0.5703893467385263
# 当前最优结果:0.593288084464555
# 第33次迭代，局部最优结果为：0.5195482763175274
# 当前最优结果:0.593288084464555
# 第34次迭代，局部最优结果为：0.593288084464555
# 当前最优结果:0.593288084464555
# 第35次迭代，局部最优结果为：0.5857781087118391
# 当前最优结果:0.593288084464555
# 第36次迭代，局部最优结果为：0.5575478384124735
# 当前最优结果:0.593288084464555
# 第37次迭代，局部最优结果为：0.5487328528249245
# 当前最优结果:0.593288084464555
# 第38次迭代，局部最优结果为：0.5988277681924287
# 当前最优结果:0.5988277681924287
# 第39次迭代，局部最优结果为：0.5542092286016203
# 当前最优结果:0.5988277681924287
# 第40次迭代，局部最优结果为：0.5694122756224668
# 当前最优结果:0.5988277681924287
# 第41次迭代，局部最优结果为：0.5172481809415271
# 当前最优结果:0.5988277681924287
# 第42次迭代，局部最优结果为：0.5988277681924287
# 当前最优结果:0.5988277681924287
# 第43次迭代，局部最优结果为：0.5652934131736527
# 当前最优结果:0.5988277681924287
# 第44次迭代，局部最优结果为：0.5988277681924287
# 当前最优结果:0.5988277681924287
# 第45次迭代，局部最优结果为：0.556627358490566
# 当前最优结果:0.5988277681924287
# 第46次迭代，局部最优结果为：0.592394578313253
# 当前最优结果:0.5988277681924287
# 第47次迭代，局部最优结果为：0.545650012715881
# 当前最优结果:0.5988277681924287
# 第48次迭代，局部最优结果为：0.5913111016460801
# 当前最优结果:0.5988277681924287
# 第49次迭代，局部最优结果为：0.5988277681924287
# 当前最优结果:0.5988277681924287
# 第50次迭代，局部最优结果为：0.5967986648460022
# 当前最优结果:0.5988277681924287
# 第51次迭代，局部最优结果为：0.6410528031290743
# 当前最优结果:0.6410528031290743
# 第52次迭代，局部最优结果为：0.6189614476789929
# 当前最优结果:0.6410528031290743
# 第53次迭代，局部最优结果为：0.6107919254658385
# 当前最优结果:0.6410528031290743
# 第54次迭代，局部最优结果为：0.581878698224852
# 当前最优结果:0.6410528031290743
# 第55次迭代，局部最优结果为：0.6410528031290743
# 当前最优结果:0.6410528031290743
# 第56次迭代，局部最优结果为：0.5736752552260573
# 当前最优结果:0.6410528031290743
# 第57次迭代，局部最优结果为：0.4873219079083213
# 当前最优结果:0.6410528031290743
# 第58次迭代，局部最优结果为：0.6097819346837536
# 当前最优结果:0.6410528031290743
# 第59次迭代，局部最优结果为：0.6356658047834518
# 当前最优结果:0.6410528031290743
# 第60次迭代，局部最优结果为：0.602435164386359
# 当前最优结果:0.6410528031290743
# 第61次迭代，局部最优结果为：0.6329382106844025
# 当前最优结果:0.6410528031290743
# 第62次迭代，局部最优结果为：0.5774368761009983
# 当前最优结果:0.6410528031290743
# 第63次迭代，局部最优结果为：0.6330061152236884
# 当前最优结果:0.6410528031290743
# 第64次迭代，局部最优结果为：0.5089932712215322
# 当前最优结果:0.6410528031290743
# 第65次迭代，局部最优结果为：0.6250264830508474
# 当前最优结果:0.6410528031290743
# 第66次迭代，局部最优结果为：0.5767595307917889
# 当前最优结果:0.6410528031290743
# 第67次迭代，局部最优结果为：0.5848201011002082
# 当前最优结果:0.6410528031290743
# 第68次迭代，局部最优结果为：0.5558931599773884
# 当前最优结果:0.6410528031290743
# 第69次迭代，局部最优结果为：0.6173101067168864
# 当前最优结果:0.6410528031290743
# 第70次迭代，局部最优结果为：0.6591537494763301
# 当前最优结果:0.6591537494763301
# 第71次迭代，局部最优结果为：0.5614072646827946
# 当前最优结果:0.6591537494763301
# 第72次迭代，局部最优结果为：0.5495505984259302
# 当前最优结果:0.6591537494763301
# 第73次迭代，局部最优结果为：0.6591537494763301
# 当前最优结果:0.6591537494763301
# 第74次迭代，局部最优结果为：0.5418790467006475
# 当前最优结果:0.6591537494763301
# 第75次迭代，局部最优结果为：0.609058064516129
# 当前最优结果:0.6591537494763301
# 第76次迭代，局部最优结果为：0.609058064516129
# 当前最优结果:0.6591537494763301
# 第77次迭代，局部最优结果为：0.5297643097643098
# 当前最优结果:0.6591537494763301
# 第78次迭代，局部最优结果为：0.6591537494763301
# 当前最优结果:0.6591537494763301
# 第79次迭代，局部最优结果为：0.6591537494763301
# 当前最优结果:0.6591537494763301
# 第80次迭代，局部最优结果为：0.6591537494763301
# 当前最优结果:0.6591537494763301
# 第81次迭代，局部最优结果为：0.5707755931219618
# 当前最优结果:0.6591537494763301
# 第82次迭代，局部最优结果为：0.6481298401713627
# 当前最优结果:0.6591537494763301
# 第83次迭代，局部最优结果为：0.5380371594665451
# 当前最优结果:0.6591537494763301
# 第84次迭代，局部最优结果为：0.6164555308867703
# 当前最优结果:0.6591537494763301
# 第85次迭代，局部最优结果为：0.6591537494763301
# 当前最优结果:0.6591537494763301
# 第86次迭代，局部最优结果为：0.6117894081965938
# 当前最优结果:0.6591537494763301
# 第87次迭代，局部最优结果为：0.6591537494763301
# 当前最优结果:0.6591537494763301
# 第88次迭代，局部最优结果为：0.6117894081965938
# 当前最优结果:0.6591537494763301
# 第89次迭代，局部最优结果为：0.570279086625589
# 当前最优结果:0.6591537494763301
# 第90次迭代，局部最优结果为：0.6280870768575687
# 当前最优结果:0.6591537494763301
# 第91次迭代，局部最优结果为：0.5904087656977035
# 当前最优结果:0.6591537494763301
# 第92次迭代，局部最优结果为：0.579905646469114
# 当前最优结果:0.6591537494763301
# 第93次迭代，局部最优结果为：0.6385551948051948
# 当前最优结果:0.6591537494763301
# 第94次迭代，局部最优结果为：0.6003510378510378
# 当前最优结果:0.6591537494763301
# 第95次迭代，局部最优结果为：0.6189614476789929
# 当前最优结果:0.6591537494763301
# 第96次迭代，局部最优结果为：0.6591537494763301
# 当前最优结果:0.6591537494763301
# 第97次迭代，局部最优结果为：0.6481298401713627
# 当前最优结果:0.6591537494763301
# 第98次迭代，局部最优结果为：0.6591537494763301
# 当前最优结果:0.6591537494763301
# 第99次迭代，局部最优结果为：0.5591196607519368
# 当前最优结果:0.6591537494763301
# 第100次迭代，局部最优结果为：0.5541181442524418
# 当前最优结果:0.6591537494763301
# 第101次迭代，局部最优结果为：0.6563125695216908
# 当前最优结果:0.6591537494763301
# 第102次迭代，局部最优结果为：0.5745830797321972
# 当前最优结果:0.6591537494763301
# 第103次迭代，局部最优结果为：0.546825764596849
# 当前最优结果:0.6591537494763301
# 第104次迭代，局部最优结果为：0.5557099128796797
# 当前最优结果:0.6591537494763301
# 第105次迭代，局部最优结果为：0.6210626036156943
# 当前最优结果:0.6591537494763301
# 第106次迭代，局部最优结果为：0.6507568864256762
# 当前最优结果:0.6591537494763301
# 第107次迭代，局部最优结果为：0.5519797927824683
# 当前最优结果:0.6591537494763301
# 第108次迭代，局部最优结果为：0.5788105456774985
# 当前最优结果:0.6591537494763301
# 第109次迭代，局部最优结果为：0.5994665989331979
# 当前最优结果:0.6591537494763301
# 第110次迭代，局部最优结果为：0.5924689343542111
# 当前最优结果:0.6591537494763301
# 第111次迭代，局部最优结果为：0.5821370430664496
# 当前最优结果:0.6591537494763301
# 第112次迭代，局部最优结果为：0.6385551948051948
# 当前最优结果:0.6591537494763301
# 第113次迭代，局部最优结果为：0.6534957773778208
# 当前最优结果:0.6591537494763301
# 第114次迭代，局部最优结果为：0.6677701383583736
# 当前最优结果:0.6677701383583736
# 第115次迭代，局部最优结果为：0.5808333128245515
# 当前最优结果:0.6677701383583736
# 第116次迭代，局部最优结果为：0.637004048582996
# 当前最优结果:0.6677701383583736
# 第117次迭代，局部最优结果为：0.6117894081965938
# 当前最优结果:0.6677701383583736
# 第118次迭代，局部最优结果为：0.5943339209267187
# 当前最优结果:0.6677701383583736
# 第119次迭代，局部最优结果为：0.5886270108492331
# 当前最优结果:0.6677701383583736
# 第120次迭代，局部最优结果为：0.6677701383583736
# 当前最优结果:0.6677701383583736
# 第121次迭代，局部最优结果为：0.6055264778325123
# 当前最优结果:0.6677701383583736
# 第122次迭代，局部最优结果为：0.6466381719546277
# 当前最优结果:0.6677701383583736
# 第123次迭代，局部最优结果为：0.6055264778325123
# 当前最优结果:0.6677701383583736
# 第124次迭代，局部最优结果为：0.5986454951298701
# 当前最优结果:0.6677701383583736
# 第125次迭代，局部最优结果为：0.6296118447378952
# 当前最优结果:0.6677701383583736
# 第126次迭代，局部最优结果为：0.5848780729579699
# 当前最优结果:0.6677701383583736
# 第127次迭代，局部最优结果为：0.6677701383583736
# 当前最优结果:0.6677701383583736
# 第128次迭代，局部最优结果为：0.6161497493734336
# 当前最优结果:0.6677701383583736
# 第129次迭代，局部最优结果为：0.6065847640588053
# 当前最优结果:0.6677701383583736
# 第130次迭代，局部最优结果为：0.5915037593984962
# 当前最优结果:0.6677701383583736
# 第131次迭代，局部最优结果为：0.6090266308835673
# 当前最优结果:0.6677701383583736
# 第132次迭代，局部最优结果为：0.6202954163162321
# 当前最优结果:0.6677701383583736
# 第133次迭代，局部最优结果为：0.6170196078431373
# 当前最优结果:0.6677701383583736
# 第134次迭代，局部最优结果为：0.6245633534455383
# 当前最优结果:0.6677701383583736
# 第135次迭代，局部最优结果为：0.6402354664568809
# 当前最优结果:0.6677701383583736
# 第136次迭代，局部最优结果为：0.6009778207837845
# 当前最优结果:0.6677701383583736
# 第137次迭代，局部最优结果为：0.6303685897435898
# 当前最优结果:0.6677701383583736
# 第138次迭代，局部最优结果为：0.6402180989583334
# 当前最优结果:0.6677701383583736
# 第139次迭代，局部最优结果为：0.613459139114161
# 当前最优结果:0.6677701383583736
# 第140次迭代，局部最优结果为：0.6677701383583736
# 当前最优结果:0.6677701383583736
# 第141次迭代，局部最优结果为：0.6143693869582194
# 当前最优结果:0.6677701383583736
# 第142次迭代，局部最优结果为：0.6677701383583736
# 当前最优结果:0.6677701383583736
# 第143次迭代，局部最优结果为：0.6144973572525841
# 当前最优结果:0.6677701383583736
# 第144次迭代，局部最优结果为：0.6336689488521949
# 当前最优结果:0.6677701383583736
# 第145次迭代，局部最优结果为：0.6536224659355268
# 当前最优结果:0.6677701383583736
# 第146次迭代，局部最优结果为：0.6811255411255411
# 当前最优结果:0.6811255411255411
# 第147次迭代，局部最优结果为：0.6811255411255411
# 当前最优结果:0.6811255411255411
# 第148次迭代，局部最优结果为：0.6501652892561983
# 当前最优结果:0.6811255411255411
# 第149次迭代，局部最优结果为：0.6677701383583736
# 当前最优结果:0.6811255411255411
# 第150次迭代，局部最优结果为：0.637004048582996
# 当前最优结果:0.6811255411255411
# 第151次迭代，局部最优结果为：0.6800656984785615
# 当前最优结果:0.6811255411255411
# 第152次迭代，局部最优结果为：0.6456122114016851
# 当前最优结果:0.6811255411255411
# 第153次迭代，局部最优结果为：0.6713984979517524
# 当前最优结果:0.6811255411255411
# 第154次迭代，局部最优结果为：0.6478096179183136
# 当前最优结果:0.6811255411255411
# 第155次迭代，局部最优结果为：0.6503086079576766
# 当前最优结果:0.6811255411255411
# 第156次迭代，局部最优结果为：0.6422040816326531
# 当前最优结果:0.6811255411255411
# 第157次迭代，局部最优结果为：0.6508825151682295
# 当前最优结果:0.6811255411255411
# 第158次迭代，局部最优结果为：0.6470104449379062
# 当前最优结果:0.6811255411255411
# 第159次迭代，局部最优结果为：0.6811255411255411
# 当前最优结果:0.6811255411255411
# 第160次迭代，局部最优结果为：0.6652666591498478
# 当前最优结果:0.6811255411255411
# 第161次迭代，局部最优结果为：0.668223902148985
# 当前最优结果:0.6811255411255411
# 第162次迭代，局部最优结果为：0.6600939754992448
# 当前最优结果:0.6811255411255411
# 第163次迭代，局部最优结果为：0.6811255411255411
# 当前最优结果:0.6811255411255411
# 第164次迭代，局部最优结果为：0.6869942364790126
# 当前最优结果:0.6869942364790126
# 第165次迭代，局部最优结果为：0.7226049416735557
# 当前最优结果:0.7226049416735556
# 第166次迭代，局部最优结果为：0.6726231190150478
# 当前最优结果:0.7226049416735556
# 第167次迭代，局部最优结果为：0.7226049416735557
# 当前最优结果:0.7226049416735556
# 第168次迭代，局部最优结果为：0.7226049416735557
# 当前最优结果:0.7226049416735556
# 第169次迭代，局部最优结果为：0.7005966693383204
# 当前最优结果:0.7226049416735556
# 第170次迭代，局部最优结果为：0.7226049416735557
# 当前最优结果:0.7226049416735556
# 第171次迭代，局部最优结果为：0.7226049416735557
# 当前最优结果:0.7226049416735556
# 第172次迭代，局部最优结果为：0.7226049416735557
# 当前最优结果:0.7226049416735556
# 第173次迭代，局部最优结果为：0.7092499098449333
# 当前最优结果:0.7226049416735556
# 第174次迭代，局部最优结果为：0.7114306384517995
# 当前最优结果:0.7226049416735556
# 第175次迭代，局部最优结果为：0.7188413742690059
# 当前最优结果:0.7226049416735556
# 第176次迭代，局部最优结果为：0.7281562384302109
# 当前最优结果:0.728156238430211
# 第177次迭代，局部最优结果为：0.7230698529411764
# 当前最优结果:0.728156238430211
# 第178次迭代，局部最优结果为：0.7424032714690154
# 当前最优结果:0.7424032714690154
# 第179次迭代，局部最优结果为：0.7207512597343105
# 当前最优结果:0.7424032714690154
# 第180次迭代，局部最优结果为：0.721654843444227
# 当前最优结果:0.7424032714690154
# 第181次迭代，局部最优结果为：0.7247351450944266
# 当前最优结果:0.7424032714690154
# 第182次迭代，局部最优结果为：0.7146620639534883
# 当前最优结果:0.7424032714690154
# 第183次迭代，局部最优结果为：0.7278867505551444
# 当前最优结果:0.7424032714690154
# 第184次迭代，局部最优结果为：0.7180103437785215
# 当前最优结果:0.7424032714690154
# 第185次迭代，局部最优结果为：0.7193233770192015
# 当前最优结果:0.7424032714690154
# 第186次迭代，局部最优结果为：0.7230698529411764
# 当前最优结果:0.7424032714690154
# 第187次迭代，局部最优结果为：0.725202802359882
# 当前最优结果:0.7424032714690154
# 第188次迭代，局部最优结果为：0.7424032714690154
# 当前最优结果:0.7424032714690154
# 第189次迭代，局部最优结果为：0.7424032714690154
# 当前最优结果:0.7424032714690154
# 第190次迭代，局部最优结果为：0.7292361883574341
# 当前最优结果:0.7424032714690154
# 第191次迭代，局部最优结果为：0.717661010764459
# 当前最优结果:0.7424032714690154
# 第192次迭代，局部最优结果为：0.7156155245603396
# 当前最优结果:0.7424032714690154
# 第193次迭代，局部最优结果为：0.7347758405977584
# 当前最优结果:0.7424032714690154
# 第194次迭代，局部最优结果为：0.7230698529411764
# 当前最优结果:0.7424032714690154
# 第195次迭代，局部最优结果为：0.7424032714690154
# 当前最优结果:0.7424032714690154
# 第196次迭代，局部最优结果为：0.7424032714690154
# 当前最优结果:0.7424032714690154
# 第197次迭代，局部最优结果为：0.7314510630384925
# 当前最优结果:0.7424032714690154
# 第198次迭代，局部最优结果为：0.7424032714690154
# 当前最优结果:0.7424032714690154
# 第199次迭代，局部最优结果为：0.7424032714690154
# 当前最优结果:0.7424032714690154
# 第200次迭代，局部最优结果为：0.7424032714690154
# 当前最优结果:0.7424032714690154
# 第201次迭代，局部最优结果为：0.7316778273809523
# 当前最优结果:0.7424032714690154
# 第202次迭代，局部最优结果为：0.7424032714690154
# 当前最优结果:0.7424032714690154
# 第203次迭代，局部最优结果为：0.7424032714690154
# 当前最优结果:0.7424032714690154
# 第204次迭代，局部最优结果为：0.7557398571840277
# 当前最优结果:0.7557398571840277
# 第205次迭代，局部最优结果为：0.7404932228915663
# 当前最优结果:0.7557398571840277
# 第206次迭代，局部最优结果为：0.7387316889946163
# 当前最优结果:0.7557398571840277
# 第207次迭代，局部最优结果为：0.7557398571840277
# 当前最优结果:0.7557398571840277
# 第208次迭代，局部最优结果为：0.7384543178973717
# 当前最优结果:0.7557398571840277
# 第209次迭代，局部最优结果为：0.7517199643266658
# 当前最优结果:0.7557398571840277
# 第210次迭代，局部最优结果为：0.7316778273809523
# 当前最优结果:0.7557398571840277
# 第211次迭代，局部最优结果为：0.7316778273809523
# 当前最优结果:0.7557398571840277
# 第212次迭代，局部最优结果为：0.7360591317365269
# 当前最优结果:0.7557398571840277
# 第213次迭代，局部最优结果为：0.7322453538518817
# 当前最优结果:0.7557398571840277
# 第214次迭代，局部最优结果为：0.7701670800156637
# 当前最优结果:0.7701670800156637
# 第215次迭代，局部最优结果为：0.7701670800156637
# 当前最优结果:0.7701670800156637
# 第216次迭代，局部最优结果为：0.7348673558350978
# 当前最优结果:0.7701670800156637
# 第217次迭代，局部最优结果为：0.7701670800156637
# 当前最优结果:0.7701670800156637
# 第218次迭代，局部最优结果为：0.779734372935113
# 当前最优结果:0.7797343729351129
# 第219次迭代，局部最优结果为：0.7701670800156637
# 当前最优结果:0.7797343729351129
# 第220次迭代，局部最优结果为：0.7295292262990325
# 当前最优结果:0.7797343729351129
# 第221次迭代，局部最优结果为：0.779734372935113
# 当前最优结果:0.7797343729351129
# 本次退火用时：2692.7735896110535
# 第1次迭代，局部最优结果为：0.47164268585131897
# 当前最优结果:0.47164268585131897
# 第2次迭代，局部最优结果为：0.533935116058097
# 当前最优结果:0.533935116058097
# 第3次迭代，局部最优结果为：0.55489984012038
# 当前最优结果:0.55489984012038
# 第4次迭代，局部最优结果为：0.55489984012038
# 当前最优结果:0.55489984012038
# 第5次迭代，局部最优结果为：0.549832261671792
# 当前最优结果:0.55489984012038
# 第6次迭代，局部最优结果为：0.526537715012382
# 当前最优结果:0.55489984012038
# 第7次迭代，局部最优结果为：0.557468820861678
# 当前最优结果:0.557468820861678
# 第8次迭代，局部最优结果为：0.5720622454915649
# 当前最优结果:0.5720622454915648
# 第9次迭代，局部最优结果为：0.4864781300243229
# 当前最优结果:0.5720622454915648
# 第10次迭代，局部最优结果为：0.5632159221076747
# 当前最优结果:0.5720622454915648
# 第11次迭代，局部最优结果为：0.5720622454915649
# 当前最优结果:0.5720622454915648
# 第12次迭代，局部最优结果为：0.5765622709727855
# 当前最优结果:0.5765622709727855
# 第13次迭代，局部最优结果为：0.5765622709727855
# 当前最优结果:0.5765622709727855
# 第14次迭代，局部最优结果为：0.5765622709727855
# 当前最优结果:0.5765622709727855
# 第15次迭代，局部最优结果为：0.5765622709727855
# 当前最优结果:0.5765622709727855
# 第16次迭代，局部最优结果为：0.5377551950419249
# 当前最优结果:0.5765622709727855
# 第17次迭代，局部最优结果为：0.5606204570288374
# 当前最优结果:0.5765622709727855
# 第18次迭代，局部最优结果为：0.5155307994757536
# 当前最优结果:0.5765622709727855
# 第19次迭代，局部最优结果为：0.5570214774604674
# 当前最优结果:0.5765622709727855
# 第20次迭代，局部最优结果为：0.581878698224852
# 当前最优结果:0.581878698224852
# 第21次迭代，局部最优结果为：0.615121976647206
# 当前最优结果:0.615121976647206
# 第22次迭代，局部最优结果为：0.5959848484848485
# 当前最优结果:0.615121976647206
# 第23次迭代，局部最优结果为：0.615121976647206
# 当前最优结果:0.615121976647206
# 第24次迭代，局部最优结果为：0.5638618119266054
# 当前最优结果:0.615121976647206
# 第25次迭代，局部最优结果为：0.594843230164331
# 当前最优结果:0.615121976647206
# 第26次迭代，局部最优结果为：0.5758588717548312
# 当前最优结果:0.615121976647206
# 第27次迭代，局部最优结果为：0.5182476943346509
# 当前最优结果:0.615121976647206
# 第28次迭代，局部最优结果为：0.5252954661799728
# 当前最优结果:0.615121976647206
# 第29次迭代，局部最优结果为：0.6067719045660221
# 当前最优结果:0.615121976647206
# 第30次迭代，局部最优结果为：0.5961353877241728
# 当前最优结果:0.615121976647206
# 第31次迭代，局部最优结果为：0.5143174686192469
# 当前最优结果:0.615121976647206
# 第32次迭代，局部最优结果为：0.5732015349492399
# 当前最优结果:0.615121976647206
# 第33次迭代，局部最优结果为：0.5851971237292338
# 当前最优结果:0.615121976647206
# 第34次迭代，局部最优结果为：0.6067719045660221
# 当前最优结果:0.615121976647206
# 第35次迭代，局部最优结果为：0.5154857592171938
# 当前最优结果:0.615121976647206
# 第36次迭代，局部最优结果为：0.5442407471463162
# 当前最优结果:0.615121976647206
# 第37次迭代，局部最优结果为：0.6272691029900332
# 当前最优结果:0.6272691029900332
# 第38次迭代，局部最优结果为：0.6082418432039586
# 当前最优结果:0.6272691029900332
# 第39次迭代，局部最优结果为：0.5595969176052163
# 当前最优结果:0.6272691029900332
# 第40次迭代，局部最优结果为：0.6243650793650793
# 当前最优结果:0.6272691029900332
# 第41次迭代，局部最优结果为：0.5089164420485175
# 当前最优结果:0.6272691029900332
# 第42次迭代，局部最优结果为：0.6047661755285074
# 当前最优结果:0.6272691029900332
# 第43次迭代，局部最优结果为：0.6272691029900332
# 当前最优结果:0.6272691029900332
# 第44次迭代，局部最优结果为：0.6272691029900332
# 当前最优结果:0.6272691029900332
# 第45次迭代，局部最优结果为：0.6272691029900332
# 当前最优结果:0.6272691029900332
# 第46次迭代，局部最优结果为：0.5828558727649906
# 当前最优结果:0.6272691029900332
# 第47次迭代，局部最优结果为：0.6272691029900332
# 当前最优结果:0.6272691029900332
# 第48次迭代，局部最优结果为：0.49866886409736305
# 当前最优结果:0.6272691029900332
# 第49次迭代，局部最优结果为：0.5380984952120383
# 当前最优结果:0.6272691029900332
# 第50次迭代，局部最优结果为：0.6272691029900332
# 当前最优结果:0.6272691029900332
# 第51次迭代，局部最优结果为：0.5516185579058082
# 当前最优结果:0.6272691029900332
# 第52次迭代，局部最优结果为：0.5082260217924975
# 当前最优结果:0.6272691029900332
# 第53次迭代，局部最优结果为：0.5901725431357839
# 当前最优结果:0.6272691029900332
# 第54次迭代，局部最优结果为：0.5777761457109283
# 当前最优结果:0.6272691029900332
# 第55次迭代，局部最优结果为：0.593347747385358
# 当前最优结果:0.6272691029900332
# 第56次迭代，局部最优结果为：0.6272691029900332
# 当前最优结果:0.6272691029900332
# 第57次迭代，局部最优结果为：0.6308740978348035
# 当前最优结果:0.6308740978348035
# 第58次迭代，局部最优结果为：0.6308740978348035
# 当前最优结果:0.6308740978348035
# 第59次迭代，局部最优结果为：0.521684350132626
# 当前最优结果:0.6308740978348035
# 第60次迭代，局部最优结果为：0.540390163483995
# 当前最优结果:0.6308740978348035
# 第61次迭代，局部最优结果为：0.503735166054811
# 当前最优结果:0.6308740978348035
# 第62次迭代，局部最优结果为：0.6308740978348035
# 当前最优结果:0.6308740978348035
# 第63次迭代，局部最优结果为：0.5961203303781163
# 当前最优结果:0.6308740978348035
# 第64次迭代，局部最优结果为：0.5118412491867274
# 当前最优结果:0.6308740978348035
# 第65次迭代，局部最优结果为：0.5862146050670641
# 当前最优结果:0.6308740978348035
# 第66次迭代，局部最优结果为：0.580504722550177
# 当前最优结果:0.6308740978348035
# 第67次迭代，局部最优结果为：0.6308740978348035
# 当前最优结果:0.6308740978348035
# 第68次迭代，局部最优结果为：0.6308740978348035
# 当前最优结果:0.6308740978348035
# 第69次迭代，局部最优结果为：0.6308740978348035
# 当前最优结果:0.6308740978348035
# 第70次迭代，局部最优结果为：0.649539011971928
# 当前最优结果:0.6495390119719279
# 第71次迭代，局部最优结果为：0.5041440594693896
# 当前最优结果:0.6495390119719279
# 第72次迭代，局部最优结果为：0.5443411675162028
# 当前最优结果:0.6495390119719279
# 第73次迭代，局部最优结果为：0.6132519163310381
# 当前最优结果:0.6495390119719279
# 第74次迭代，局部最优结果为：0.5866955030203594
# 当前最优结果:0.6495390119719279
# 第75次迭代，局部最优结果为：0.5658355310477103
# 当前最优结果:0.6495390119719279
# 第76次迭代，局部最优结果为：0.5736752552260573
# 当前最优结果:0.6495390119719279
# 第77次迭代，局部最优结果为：0.6272691029900332
# 当前最优结果:0.6495390119719279
# 第78次迭代，局部最优结果为：0.649539011971928
# 当前最优结果:0.6495390119719279
# 第79次迭代，局部最优结果为：0.5653882088014757
# 当前最优结果:0.6495390119719279
# 第80次迭代，局部最优结果为：0.649539011971928
# 当前最优结果:0.6495390119719279
# 第81次迭代，局部最优结果为：0.6152021479029273
# 当前最优结果:0.6495390119719279
# 第82次迭代，局部最优结果为：0.5153957023060797
# 当前最优结果:0.6495390119719279
# 第83次迭代，局部最优结果为：0.649539011971928
# 当前最优结果:0.6495390119719279
# 第84次迭代，局部最优结果为：0.5658355310477103
# 当前最优结果:0.6495390119719279
# 第85次迭代，局部最优结果为：0.5488604651162791
# 当前最优结果:0.6495390119719279
# 第86次迭代，局部最优结果为：0.6019434809222608
# 当前最优结果:0.6495390119719279
# 第87次迭代，局部最优结果为：0.649539011971928
# 当前最优结果:0.6495390119719279
# 第88次迭代，局部最优结果为：0.6587306017639835
# 当前最优结果:0.6587306017639835
# 第89次迭代，局部最优结果为：0.621930009486666
# 当前最优结果:0.6587306017639835
# 第90次迭代，局部最优结果为：0.6398015614834093
# 当前最优结果:0.6587306017639835
# 第91次迭代，局部最优结果为：0.6618525477439076
# 当前最优结果:0.6618525477439076
# 第92次迭代，局部最优结果为：0.6112190195012043
# 当前最优结果:0.6618525477439076
# 第93次迭代，局部最优结果为：0.6618525477439076
# 当前最优结果:0.6618525477439076
# 第94次迭代，局部最优结果为：0.5693573289587958
# 当前最优结果:0.6618525477439076
# 第95次迭代，局部最优结果为：0.5384176666514578
# 当前最优结果:0.6618525477439076
# 第96次迭代，局部最优结果为：0.6170196078431373
# 当前最优结果:0.6618525477439076
# 第97次迭代，局部最优结果为：0.6618525477439076
# 当前最优结果:0.6618525477439076
# 第98次迭代，局部最优结果为：0.5632159221076747
# 当前最优结果:0.6618525477439076
# 第99次迭代，局部最优结果为：0.5504734804310304
# 当前最优结果:0.6618525477439076
# 第100次迭代，局部最优结果为：0.6618525477439076
# 当前最优结果:0.6618525477439076
# 第101次迭代，局部最优结果为：0.5252954661799728
# 当前最优结果:0.6618525477439076
# 第102次迭代，局部最优结果为：0.5867684351847248
# 当前最优结果:0.6618525477439076
# 第103次迭代，局部最优结果为：0.649539011971928
# 当前最优结果:0.6618525477439076
# 第104次迭代，局部最优结果为：0.6428337963719561
# 当前最优结果:0.6618525477439076
# 第105次迭代，局部最优结果为：0.5637271294128887
# 当前最优结果:0.6618525477439076
# 第106次迭代，局部最优结果为：0.6618525477439076
# 当前最优结果:0.6618525477439076
# 第107次迭代，局部最优结果为：0.6618525477439076
# 当前最优结果:0.6618525477439076
# 第108次迭代，局部最优结果为：0.6428337963719561
# 当前最优结果:0.6618525477439076
# 第109次迭代，局部最优结果为：0.6262371640088095
# 当前最优结果:0.6618525477439076
# 第110次迭代，局部最优结果为：0.6618525477439076
# 当前最优结果:0.6618525477439076
# 第111次迭代，局部最优结果为：0.6618525477439076
# 当前最优结果:0.6618525477439076
# 第112次迭代，局部最优结果为：0.5847186779971757
# 当前最优结果:0.6618525477439076
# 第113次迭代，局部最优结果为：0.5820796132787451
# 当前最优结果:0.6618525477439076
# 第114次迭代，局部最优结果为：0.6556379698308192
# 当前最优结果:0.6618525477439076
# 第115次迭代，局部最优结果为：0.5953984712026035
# 当前最优结果:0.6618525477439076
# 第116次迭代，局部最优结果为：0.6098449612403101
# 当前最优结果:0.6618525477439076
# 第117次迭代，局部最优结果为：0.5624910624910625
# 当前最优结果:0.6618525477439076
# 第118次迭代，局部最优结果为：0.6556379698308192
# 当前最优结果:0.6618525477439076
# 第119次迭代，局部最优结果为：0.6618525477439076
# 当前最优结果:0.6618525477439076
# 第120次迭代，局部最优结果为：0.5412825099766067
# 当前最优结果:0.6618525477439076
# 第121次迭代，局部最优结果为：0.593347747385358
# 当前最优结果:0.6618525477439076
# 第122次迭代，局部最优结果为：0.6556379698308192
# 当前最优结果:0.6618525477439076
# 第123次迭代，局部最优结果为：0.5942590960594234
# 当前最优结果:0.6618525477439076
# 第124次迭代，局部最优结果为：0.6618525477439076
# 当前最优结果:0.6618525477439076
# 第125次迭代，局部最优结果为：0.6541297117516629
# 当前最优结果:0.6618525477439076
# 第126次迭代，局部最优结果为：0.6435524772993756
# 当前最优结果:0.6618525477439076
# 第127次迭代，局部最优结果为：0.6618525477439076
# 当前最优结果:0.6618525477439076
# 第128次迭代，局部最优结果为：0.5750730994152047
# 当前最优结果:0.6618525477439076
# 第129次迭代，局部最优结果为：0.6153785982478098
# 当前最优结果:0.6618525477439076
# 第130次迭代，局部最优结果为：0.5812195242082451
# 当前最优结果:0.6618525477439076
# 第131次迭代，局部最优结果为：0.6618525477439076
# 当前最优结果:0.6618525477439076
# 第132次迭代，局部最优结果为：0.6618525477439076
# 当前最优结果:0.6618525477439076
# 第133次迭代，局部最优结果为：0.628438290507256
# 当前最优结果:0.6618525477439076
# 第134次迭代，局部最优结果为：0.6738137383657854
# 当前最优结果:0.6738137383657854
# 第135次迭代，局部最优结果为：0.6738137383657854
# 当前最优结果:0.6738137383657854
# 第136次迭代，局部最优结果为：0.6753949175824175
# 当前最优结果:0.6753949175824175
# 第137次迭代，局部最优结果为：0.6596880590339893
# 当前最优结果:0.6753949175824175
# 第138次迭代，局部最优结果为：0.6319383082978552
# 当前最优结果:0.6753949175824175
# 第139次迭代，局部最优结果为：0.64738314680711
# 当前最优结果:0.6753949175824175
# 第140次迭代，局部最优结果为：0.6657921462423833
# 当前最优结果:0.6753949175824175
# 第141次迭代，局部最优结果为：0.6618896710323359
# 当前最优结果:0.6753949175824175
# 第142次迭代，局部最优结果为：0.6753949175824175
# 当前最优结果:0.6753949175824175
# 第143次迭代，局部最优结果为：0.6753949175824175
# 当前最优结果:0.6753949175824175
# 第144次迭代，局部最优结果为：0.6753949175824175
# 当前最优结果:0.6753949175824175
# 第145次迭代，局部最优结果为：0.6558748332592264
# 当前最优结果:0.6753949175824175
# 第146次迭代，局部最优结果为：0.6753949175824175
# 当前最优结果:0.6753949175824175
# 第147次迭代，局部最优结果为：0.6433244289374693
# 当前最优结果:0.6753949175824175
# 第148次迭代，局部最优结果为：0.6375547031174024
# 当前最优结果:0.6753949175824175
# 第149次迭代，局部最优结果为：0.6240679041726163
# 当前最优结果:0.6753949175824175
# 第150次迭代，局部最优结果为：0.621930009486666
# 当前最优结果:0.6753949175824175
# 第151次迭代，局部最优结果为：0.6268858903527412
# 当前最优结果:0.6753949175824175
# 第152次迭代，局部最优结果为：0.6835322057460612
# 当前最优结果:0.6835322057460612
# 第153次迭代，局部最优结果为：0.6794391985260249
# 当前最优结果:0.6835322057460612
# 第154次迭代，局部最优结果为：0.6794391985260249
# 当前最优结果:0.6835322057460612
# 第155次迭代，局部最优结果为：0.6876748251748251
# 当前最优结果:0.6876748251748251
# 第156次迭代，局部最优结果为：0.6713984979517524
# 当前最优结果:0.6876748251748251
# 第157次迭代，局部最优结果为：0.6634339686287739
# 当前最优结果:0.6876748251748251
# 第158次迭代，局部最优结果为：0.6876748251748251
# 当前最优结果:0.6876748251748251
# 第159次迭代，局部最优结果为：0.6876748251748251
# 当前最优结果:0.6876748251748251
# 第160次迭代，局部最优结果为：0.6876748251748251
# 当前最优结果:0.6876748251748251
# 第161次迭代，局部最优结果为：0.6632475269784173
# 当前最优结果:0.6876748251748251
# 第162次迭代，局部最优结果为：0.7046126287505597
# 当前最优结果:0.7046126287505597
# 第163次迭代，局部最优结果为：0.7046126287505597
# 当前最优结果:0.7046126287505597
# 第164次迭代，局部最优结果为：0.6723931623931624
# 当前最优结果:0.7046126287505597
# 第165次迭代，局部最优结果为：0.7232692838098741
# 当前最优结果:0.7232692838098741
# 第166次迭代，局部最优结果为：0.7232692838098741
# 当前最优结果:0.7232692838098741
# 第167次迭代，局部最优结果为：0.7232692838098741
# 当前最优结果:0.7232692838098741
# 第168次迭代，局部最优结果为：0.7303645478739864
# 当前最优结果:0.7303645478739865
# 第169次迭代，局部最优结果为：0.7303645478739864
# 当前最优结果:0.7303645478739865
# 第170次迭代，局部最优结果为：0.7303645478739864
# 当前最优结果:0.7303645478739865
# 第171次迭代，局部最优结果为：0.7195426829268293
# 当前最优结果:0.7303645478739865
# 第172次迭代，局部最优结果为：0.7179011406844107
# 当前最优结果:0.7303645478739865
# 第173次迭代，局部最优结果为：0.7259165846456693
# 当前最优结果:0.7303645478739865
# 第174次迭代，局部最优结果为：0.7303645478739864
# 当前最优结果:0.7303645478739865
# 第175次迭代，局部最优结果为：0.7303645478739864
# 当前最优结果:0.7303645478739865
# 第176次迭代，局部最优结果为：0.7303645478739864
# 当前最优结果:0.7303645478739865
# 第177次迭代，局部最优结果为：0.7303645478739864
# 当前最优结果:0.7303645478739865
# 第178次迭代，局部最优结果为：0.7187756966651438
# 当前最优结果:0.7303645478739865
# 第179次迭代，局部最优结果为：0.7303645478739864
# 当前最优结果:0.7303645478739865
# 第180次迭代，局部最优结果为：0.725559517953763
# 当前最优结果:0.7303645478739865
# 第181次迭代，局部最优结果为：0.7194988110481069
# 当前最优结果:0.7303645478739865
# 第182次迭代，局部最优结果为：0.7234022988505747
# 当前最优结果:0.7303645478739865
# 第183次迭代，局部最优结果为：0.7345471521942111
# 当前最优结果:0.7345471521942111
# 第184次迭代，局部最优结果为：0.7345471521942111
# 当前最优结果:0.7345471521942111
# 第185次迭代，局部最优结果为：0.7449810606060606
# 当前最优结果:0.7449810606060606
# 第186次迭代，局部最优结果为：0.7662662337662338
# 当前最优结果:0.7662662337662338
# 第187次迭代，局部最优结果为：0.7449810606060606
# 当前最优结果:0.7662662337662338
# 第188次迭代，局部最优结果为：0.7608317214700193
# 当前最优结果:0.7662662337662338
# 第189次迭代，局部最优结果为：0.7608317214700193
# 当前最优结果:0.7662662337662338
# 第190次迭代，局部最优结果为：0.7662662337662338
# 当前最优结果:0.7662662337662338
# 第191次迭代，局部最优结果为：0.7662662337662338
# 当前最优结果:0.7662662337662338
# 第192次迭代，局部最优结果为：0.7644791396734906
# 当前最优结果:0.7662662337662338
# 第193次迭代，局部最优结果为：0.7662662337662338
# 当前最优结果:0.7662662337662338
# 第194次迭代，局部最优结果为：0.7662662337662338
# 当前最优结果:0.7662662337662338
# 第195次迭代，局部最优结果为：0.7662662337662338
# 当前最优结果:0.7662662337662338
# 第196次迭代，局部最优结果为：0.7608317214700193
# 当前最优结果:0.7662662337662338
# 第197次迭代，局部最优结果为：0.7505963171453105
# 当前最优结果:0.7662662337662338
# 第198次迭代，局部最优结果为：0.7608317214700193
# 当前最优结果:0.7662662337662338
# 第199次迭代，局部最优结果为：0.7608317214700193
# 当前最优结果:0.7662662337662338
# 第200次迭代，局部最优结果为：0.7644791396734906
# 当前最优结果:0.7662662337662338
# 第201次迭代，局部最优结果为：0.7860711430855315
# 当前最优结果:0.7860711430855316
# 第202次迭代，局部最优结果为：0.7732961992136305
# 当前最优结果:0.7860711430855316
# 第203次迭代，局部最优结果为：0.7662662337662338
# 当前最优结果:0.7860711430855316
# 第204次迭代，局部最优结果为：0.7888034759358289
# 当前最优结果:0.7888034759358289
# 第205次迭代，局部最优结果为：0.7773715415019762
# 当前最优结果:0.7888034759358289
# 第206次迭代，局部最优结果为：0.7888034759358289
# 当前最优结果:0.7888034759358289
# 第207次迭代，局部最优结果为：0.7888034759358289
# 当前最优结果:0.7888034759358289
# 第208次迭代，局部最优结果为：0.8009026740871454
# 当前最优结果:0.8009026740871453
# 第209次迭代，局部最优结果为：0.7830457863304578
# 当前最优结果:0.8009026740871453
# 第210次迭代，局部最优结果为：0.7431513319478557
# 当前最优结果:0.8009026740871453
# 第211次迭代，局部最优结果为：0.7449810606060606
# 当前最优结果:0.8009026740871453
# 第212次迭代，局部最优结果为：0.7608317214700193
# 当前最优结果:0.8009026740871453
# 第213次迭代，局部最优结果为：0.7946464646464647
# 当前最优结果:0.8009026740871453
# 第214次迭代，局部最优结果为：0.7804563492063492
# 当前最优结果:0.8009026740871453
# 第215次迭代，局部最优结果为：0.7187756966651438
# 当前最优结果:0.8009026740871453
# 第216次迭代，局部最优结果为：0.7946464646464647
# 当前最优结果:0.8009026740871453
# 第217次迭代，局部最优结果为：0.7897272879370922
# 当前最优结果:0.8009026740871453
# 第218次迭代，局部最优结果为：0.78395615346288
# 当前最优结果:0.8009026740871453
# 第219次迭代，局部最优结果为：0.8009026740871454
# 当前最优结果:0.8009026740871453
# 第220次迭代，局部最优结果为：0.7788594812223615
# 当前最优结果:0.8009026740871453
# 第221次迭代，局部最优结果为：0.712590579710145
# 当前最优结果:0.8009026740871453
# 本次退火用时：2712.1031832695007
# 第1次迭代，局部最优结果为：0.5346366437114897
# 当前最优结果:0.5346366437114897
# 第2次迭代，局部最优结果为：0.5346366437114897
# 当前最优结果:0.5346366437114897
# 第3次迭代，局部最优结果为：0.5125526647265778
# 当前最优结果:0.5346366437114897
# 第4次迭代，局部最优结果为：0.5959848484848485
# 当前最优结果:0.5959848484848485
# 第5次迭代，局部最优结果为：0.47891639610389614
# 当前最优结果:0.5959848484848485
# 第6次迭代，局部最优结果为：0.5888473053892216
# 当前最优结果:0.5959848484848485
# 第7次迭代，局部最优结果为：0.5568900424728646
# 当前最优结果:0.5959848484848485
# 第8次迭代，局部最优结果为：0.6347084767641996
# 当前最优结果:0.6347084767641996
# 第9次迭代，局部最优结果为：0.5597429086424438
# 当前最优结果:0.6347084767641996
# 第10次迭代，局部最优结果为：0.568698795180723
# 当前最优结果:0.6347084767641996
# 第11次迭代，局部最优结果为：0.5971308572006881
# 当前最优结果:0.6347084767641996
# 第12次迭代，局部最优结果为：0.5123968736430743
# 当前最优结果:0.6347084767641996
# 第13次迭代，局部最优结果为：0.681223841824217
# 当前最优结果:0.681223841824217
# 第14次迭代，局部最优结果为：0.6893822111873814
# 当前最优结果:0.6893822111873813
# 第15次迭代，局部最优结果为：0.6794391985260249
# 当前最优结果:0.6893822111873813
# 第16次迭代，局部最优结果为：0.6893822111873814
# 当前最优结果:0.6893822111873813
# 第17次迭代，局部最优结果为：0.6256892895015908
# 当前最优结果:0.6893822111873813
# 第18次迭代，局部最优结果为：0.5599288256227758
# 当前最优结果:0.6893822111873813
# 第19次迭代，局部最优结果为：0.5873817819810851
# 当前最优结果:0.6893822111873813
# 第20次迭代，局部最优结果为：0.5511161965253129
# 当前最优结果:0.6893822111873813
# 第21次迭代，局部最优结果为：0.6346914078257362
# 当前最优结果:0.6893822111873813
# 第22次迭代，局部最优结果为：0.6893822111873814
# 当前最优结果:0.6893822111873813
# 第23次迭代，局部最优结果为：0.6893822111873814
# 当前最优结果:0.6893822111873813
# 第24次迭代，局部最优结果为：0.6893822111873814
# 当前最优结果:0.6893822111873813
# 第25次迭代，局部最优结果为：0.6681860649471986
# 当前最优结果:0.6893822111873813
# 第26次迭代，局部最优结果为：0.681223841824217
# 当前最优结果:0.6893822111873813
# 第27次迭代，局部最优结果为：0.6893822111873814
# 当前最优结果:0.6893822111873813
# 第28次迭代，局部最优结果为：0.6634899215653202
# 当前最优结果:0.6893822111873813
# 第29次迭代，局部最优结果为：0.5729371495156944
# 当前最优结果:0.6893822111873813
# 第30次迭代，局部最优结果为：0.6584365584198192
# 当前最优结果:0.6893822111873813
# 第31次迭代，局部最优结果为：0.6144493621452747
# 当前最优结果:0.6893822111873813
# 第32次迭代，局部最优结果为：0.5418044077134987
# 当前最优结果:0.6893822111873813
# 第33次迭代，局部最优结果为：0.6893822111873814
# 当前最优结果:0.6893822111873813
# 第34次迭代，局部最优结果为：0.5241871002132196
# 当前最优结果:0.6893822111873813
# 第35次迭代，局部最优结果为：0.603343814709717
# 当前最优结果:0.6893822111873813
# 第36次迭代，局部最优结果为：0.6893822111873814
# 当前最优结果:0.6893822111873813
# 第37次迭代，局部最优结果为：0.5111539461145282
# 当前最优结果:0.6893822111873813
# 第38次迭代，局部最优结果为：0.6893822111873814
# 当前最优结果:0.6893822111873813
# 第39次迭代，局部最优结果为：0.6365916815018612
# 当前最优结果:0.6893822111873813
# 第40次迭代，局部最优结果为：0.62952787409976
# 当前最优结果:0.6893822111873813
# 第41次迭代，局部最优结果为：0.5791940708746441
# 当前最优结果:0.6893822111873813
# 第42次迭代，局部最优结果为：0.6313804173354735
# 当前最优结果:0.6893822111873813
# 第43次迭代，局部最优结果为：0.6091523848854016
# 当前最优结果:0.6893822111873813
# 第44次迭代，局部最优结果为：0.6893822111873814
# 当前最优结果:0.6893822111873813
# 第45次迭代，局部最优结果为：0.6395934959349593
# 当前最优结果:0.6893822111873813
# 第46次迭代，局部最优结果为：0.6022506889864244
# 当前最优结果:0.6893822111873813
# 第47次迭代，局部最优结果为：0.7017632541405251
# 当前最优结果:0.7017632541405251
# 第48次迭代，局部最优结果为：0.5989797472209533
# 当前最优结果:0.7017632541405251
# 第49次迭代，局部最优结果为：0.5506019036954087
# 当前最优结果:0.7017632541405251
# 第50次迭代，局部最优结果为：0.5455617198335645
# 当前最优结果:0.7017632541405251
# 第51次迭代，局部最优结果为：0.7017632541405251
# 当前最优结果:0.7017632541405251
# 第52次迭代，局部最优结果为：0.6308403720731316
# 当前最优结果:0.7017632541405251
# 第53次迭代，局部最优结果为：0.6208175505050505
# 当前最优结果:0.7017632541405251
# 第54次迭代，局部最优结果为：0.5231413751828701
# 当前最优结果:0.7017632541405251
# 第55次迭代，局部最优结果为：0.5674544973672189
# 当前最优结果:0.7017632541405251
# 第56次迭代，局部最优结果为：0.6422040816326531
# 当前最优结果:0.7017632541405251
# 第57次迭代，局部最优结果为：0.7017632541405251
# 当前最优结果:0.7017632541405251
# 第58次迭代，局部最优结果为：0.6700451409590324
# 当前最优结果:0.7017632541405251
# 第59次迭代，局部最优结果为：0.7017632541405251
# 当前最优结果:0.7017632541405251
# 第60次迭代，局部最优结果为：0.6403744403744404
# 当前最优结果:0.7017632541405251
# 第61次迭代，局部最优结果为：0.6635458839406208
# 当前最优结果:0.7017632541405251
# 第62次迭代，局部最优结果为：0.6947805351938532
# 当前最优结果:0.7017632541405251
# 第63次迭代，局部最优结果为：0.6947805351938532
# 当前最优结果:0.7017632541405251
# 第64次迭代，局部最优结果为：0.7017632541405251
# 当前最优结果:0.7017632541405251
# 第65次迭代，局部最优结果为：0.6465318869165023
# 当前最优结果:0.7017632541405251
# 第66次迭代，局部最优结果为：0.5643472022955524
# 当前最优结果:0.7017632541405251
# 第67次迭代，局部最优结果为：0.6935554967821563
# 当前最优结果:0.7017632541405251
# 第68次迭代，局部最优结果为：0.5942590960594234
# 当前最优结果:0.7017632541405251
# 第69次迭代，局部最优结果为：0.7053075129998206
# 当前最优结果:0.7053075129998206
# 第70次迭代，局部最优结果为：0.7053075129998206
# 当前最优结果:0.7053075129998206
# 第71次迭代，局部最优结果为：0.5831727205337287
# 当前最优结果:0.7053075129998206
# 第72次迭代，局部最优结果为：0.6025582107843137
# 当前最优结果:0.7053075129998206
# 第73次迭代，局部最优结果为：0.5808047249907715
# 当前最优结果:0.7053075129998206
# 第74次迭代，局部最优结果为：0.5711485407289095
# 当前最优结果:0.7053075129998206
# 第75次迭代，局部最优结果为：0.6071777720607152
# 当前最优结果:0.7053075129998206
# 第76次迭代，局部最优结果为：0.7053075129998206
# 当前最优结果:0.7053075129998206
# 第77次迭代，局部最优结果为：0.7053075129998206
# 当前最优结果:0.7053075129998206
# 第78次迭代，局部最优结果为：0.6913410275938837
# 当前最优结果:0.7053075129998206
# 第79次迭代，局部最优结果为：0.7137543095626928
# 当前最优结果:0.7137543095626928
# 第80次迭代，局部最优结果为：0.7101676044895134
# 当前最优结果:0.7137543095626928
# 第81次迭代，局部最优结果为：0.6336179123711341
# 当前最优结果:0.7137543095626928
# 第82次迭代，局部最优结果为：0.5962106858658583
# 当前最优结果:0.7137543095626928
# 第83次迭代，局部最优结果为：0.7137543095626928
# 当前最优结果:0.7137543095626928
# 第84次迭代，局部最优结果为：0.7031012601662348
# 当前最优结果:0.7137543095626928
# 第85次迭代，局部最优结果为：0.7137543095626928
# 当前最优结果:0.7137543095626928
# 第86次迭代，局部最优结果为：0.608147804576376
# 当前最优结果:0.7137543095626928
# 第87次迭代，局部最优结果为：0.7137543095626928
# 当前最优结果:0.7137543095626928
# 第88次迭代，局部最优结果为：0.5853422619047619
# 当前最优结果:0.7137543095626928
# 第89次迭代，局部最优结果为：0.5254124090028718
# 当前最优结果:0.7137543095626928
# 第90次迭代，局部最优结果为：0.5604873183243089
# 当前最优结果:0.7137543095626928
# 第91次迭代，局部最优结果为：0.5652934131736527
# 当前最优结果:0.7137543095626928
# 第92次迭代，局部最优结果为：0.6091523848854016
# 当前最优结果:0.7137543095626928
# 第93次迭代，局部最优结果为：0.6214060031595576
# 当前最优结果:0.7137543095626928
# 第94次迭代，局部最优结果为：0.7137543095626928
# 当前最优结果:0.7137543095626928
# 第95次迭代，局部最优结果为：0.7137543095626928
# 当前最优结果:0.7137543095626928
# 第96次迭代，局部最优结果为：0.6811255411255411
# 当前最优结果:0.7137543095626928
# 第97次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第98次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第99次迭代，局部最优结果为：0.6548557158712541
# 当前最优结果:0.7284708932650164
# 第100次迭代，局部最优结果为：0.6834530290744817
# 当前最优结果:0.7284708932650164
# 第101次迭代，局部最优结果为：0.6208175505050505
# 当前最优结果:0.7284708932650164
# 第102次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第103次迭代，局部最优结果为：0.6572263993316625
# 当前最优结果:0.7284708932650164
# 第104次迭代，局部最优结果为：0.6114248704663212
# 当前最优结果:0.7284708932650164
# 第105次迭代，局部最优结果为：0.7247351450944266
# 当前最优结果:0.7284708932650164
# 第106次迭代，局部最优结果为：0.7210375168031284
# 当前最优结果:0.7284708932650164
# 第107次迭代，局部最优结果为：0.7053075129998206
# 当前最优结果:0.7284708932650164
# 第108次迭代，局部最优结果为：0.6729683490162532
# 当前最优结果:0.7284708932650164
# 第109次迭代，局部最优结果为：0.6423788786064235
# 当前最优结果:0.7284708932650164
# 第110次迭代，局部最优结果为：0.5963462704669497
# 当前最优结果:0.7284708932650164
# 第111次迭代，局部最优结果为：0.6575926441905823
# 当前最优结果:0.7284708932650164
# 第112次迭代，局部最优结果为：0.6083829556878818
# 当前最优结果:0.7284708932650164
# 第113次迭代，局部最优结果为：0.6246129416435093
# 当前最优结果:0.7284708932650164
# 第114次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第115次迭代，局部最优结果为：0.7032060067933973
# 当前最优结果:0.7284708932650164
# 第116次迭代，局部最优结果为：0.6470991445492432
# 当前最优结果:0.7284708932650164
# 第117次迭代，局部最优结果为：0.6603895013710895
# 当前最优结果:0.7284708932650164
# 第118次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第119次迭代，局部最优结果为：0.6455062633335157
# 当前最优结果:0.7284708932650164
# 第120次迭代，局部最优结果为：0.5992839368239297
# 当前最优结果:0.7284708932650164
# 第121次迭代，局部最优结果为：0.6482722628138219
# 当前最优结果:0.7284708932650164
# 第122次迭代，局部最优结果为：0.6281539444267007
# 当前最优结果:0.7284708932650164
# 第123次迭代，局部最优结果为：0.6144493621452747
# 当前最优结果:0.7284708932650164
# 第124次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第125次迭代，局部最优结果为：0.5937956020731646
# 当前最优结果:0.7284708932650164
# 第126次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第127次迭代，局部最优结果为：0.6572263993316625
# 当前最优结果:0.7284708932650164
# 第128次迭代，局部最优结果为：0.687314345622925
# 当前最优结果:0.7284708932650164
# 第129次迭代，局部最优结果为：0.6912195407685099
# 当前最优结果:0.7284708932650164
# 第130次迭代，局部最优结果为：0.6575926441905823
# 当前最优结果:0.7284708932650164
# 第131次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第132次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第133次迭代，局部最优结果为：0.7032060067933973
# 当前最优结果:0.7284708932650164
# 第134次迭代，局部最优结果为：0.6912195407685099
# 当前最优结果:0.7284708932650164
# 第135次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第136次迭代，局部最优结果为：0.6729683490162532
# 当前最优结果:0.7284708932650164
# 第137次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第138次迭代，局部最优结果为：0.6402875746066197
# 当前最优结果:0.7284708932650164
# 第139次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第140次迭代，局部最优结果为：0.672125078316341
# 当前最优结果:0.7284708932650164
# 第141次迭代，局部最优结果为：0.6470991445492432
# 当前最优结果:0.7284708932650164
# 第142次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第143次迭代，局部最优结果为：0.6402354664568809
# 当前最优结果:0.7284708932650164
# 第144次迭代，局部最优结果为：0.6431666439569423
# 当前最优结果:0.7284708932650164
# 第145次迭代，局部最优结果为：0.7198499359482706
# 当前最优结果:0.7284708932650164
# 第146次迭代，局部最优结果为：0.6482366512854317
# 当前最优结果:0.7284708932650164
# 第147次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第148次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第149次迭代，局部最优结果为：0.6537854234189313
# 当前最优结果:0.7284708932650164
# 第150次迭代，局部最优结果为：0.7137543095626928
# 当前最优结果:0.7284708932650164
# 第151次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第152次迭代，局部最优结果为：0.6579959852793577
# 当前最优结果:0.7284708932650164
# 第153次迭代，局部最优结果为：0.657317922294945
# 当前最优结果:0.7284708932650164
# 第154次迭代，局部最优结果为：0.6645922505068709
# 当前最优结果:0.7284708932650164
# 第155次迭代，局部最优结果为：0.6714749061113008
# 当前最优结果:0.7284708932650164
# 第156次迭代，局部最优结果为：0.6645922505068709
# 当前最优结果:0.7284708932650164
# 第157次迭代，局部最优结果为：0.693331374853114
# 当前最优结果:0.7284708932650164
# 第158次迭代，局部最优结果为：0.6951693667157585
# 当前最优结果:0.7284708932650164
# 第159次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第160次迭代，局部最优结果为：0.7150951399830324
# 当前最优结果:0.7284708932650164
# 第161次迭代，局部最优结果为：0.684563174382179
# 当前最优结果:0.7284708932650164
# 第162次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第163次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第164次迭代，局部最优结果为：0.7150951399830324
# 当前最优结果:0.7284708932650164
# 第165次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第166次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第167次迭代，局部最优结果为：0.7150951399830324
# 当前最优结果:0.7284708932650164
# 第168次迭代，局部最优结果为：0.7068495612327413
# 当前最优结果:0.7284708932650164
# 第169次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第170次迭代，局部最优结果为：0.7135600907029478
# 当前最优结果:0.7284708932650164
# 第171次迭代，局部最优结果为：0.7210375168031284
# 当前最优结果:0.7284708932650164
# 第172次迭代，局部最优结果为：0.7031012601662348
# 当前最优结果:0.7284708932650164
# 第173次迭代，局部最优结果为：0.7135600907029478
# 当前最优结果:0.7284708932650164
# 第174次迭代，局部最优结果为：0.7068495612327413
# 当前最优结果:0.7284708932650164
# 第175次迭代，局部最优结果为：0.7068495612327413
# 当前最优结果:0.7284708932650164
# 第176次迭代，局部最优结果为：0.7198499359482706
# 当前最优结果:0.7284708932650164
# 第177次迭代，局部最优结果为：0.7284708932650164
# 当前最优结果:0.7284708932650164
# 第178次迭代，局部最优结果为：0.7372547794577033
# 当前最优结果:0.7372547794577033
# 第179次迭代，局部最优结果为：0.7407488779385456
# 当前最优结果:0.7407488779385456
# 第180次迭代，局部最优结果为：0.7182288496652465
# 当前最优结果:0.7407488779385456
# 第181次迭代，局部最优结果为：0.7199816961561928
# 当前最优结果:0.7407488779385456
# 第182次迭代，局部最优结果为：0.7064475574712643
# 当前最优结果:0.7407488779385456
# 第183次迭代，局部最优结果为：0.7263187049916907
# 当前最优结果:0.7407488779385456
# 第184次迭代，局部最优结果为：0.7228926733643715
# 当前最优结果:0.7407488779385456
# 第185次迭代，局部最优结果为：0.7386854460093897
# 当前最优结果:0.7407488779385456
# 第186次迭代，局部最优结果为：0.7263187049916907
# 当前最优结果:0.7407488779385456
# 第187次迭代，局部最优结果为：0.7135600907029478
# 当前最优结果:0.7407488779385456
# 第188次迭代，局部最优结果为：0.7407488779385456
# 当前最优结果:0.7407488779385456
# 第189次迭代，局部最优结果为：0.7520553183353514
# 当前最优结果:0.7520553183353514
# 第190次迭代，局部最优结果为：0.7520553183353514
# 当前最优结果:0.7520553183353514
# 第191次迭代，局部最优结果为：0.7611261609907121
# 当前最优结果:0.7611261609907121
# 第192次迭代，局部最优结果为：0.7407488779385456
# 当前最优结果:0.7611261609907121
# 第193次迭代，局部最优结果为：0.7467961902351042
# 当前最优结果:0.7611261609907121
# 第194次迭代，局部最优结果为：0.7407488779385456
# 当前最优结果:0.7611261609907121
# 第195次迭代，局部最优结果为：0.7611261609907121
# 当前最优结果:0.7611261609907121
# 第196次迭代，局部最优结果为：0.7611261609907121
# 当前最优结果:0.7611261609907121
# 第197次迭代，局部最优结果为：0.7747176995798319
# 当前最优结果:0.7747176995798319
# 第198次迭代，局部最优结果为：0.7747176995798319
# 当前最优结果:0.7747176995798319
# 第199次迭代，局部最优结果为：0.760905309991295
# 当前最优结果:0.7747176995798319
# 第200次迭代，局部最优结果为：0.7989235300091397
# 当前最优结果:0.7989235300091398
# 第201次迭代，局部最优结果为：0.7747176995798319
# 当前最优结果:0.7989235300091398
# 第202次迭代，局部最优结果为：0.8062102889936463
# 当前最优结果:0.8062102889936462
# 第203次迭代，局部最优结果为：0.8010114037469455
# 当前最优结果:0.8062102889936462
# 第204次迭代，局部最优结果为：0.7747176995798319
# 当前最优结果:0.8062102889936462
# 第205次迭代，局部最优结果为：0.7870148059223689
# 当前最优结果:0.8062102889936462
# 第206次迭代，局部最优结果为：0.7747176995798319
# 当前最优结果:0.8062102889936462
# 第207次迭代，局部最优结果为：0.7747176995798319
# 当前最优结果:0.8062102889936462
# 第208次迭代，局部最优结果为：0.7747176995798319
# 当前最优结果:0.8062102889936462
# 第209次迭代，局部最优结果为：0.7989235300091397
# 当前最优结果:0.8062102889936462
# 第210次迭代，局部最优结果为：0.7747176995798319
# 当前最优结果:0.8062102889936462
# 第211次迭代，局部最优结果为：0.7747176995798319
# 当前最优结果:0.8062102889936462
# 第212次迭代，局部最优结果为：0.781852514410654
# 当前最优结果:0.8062102889936462
# 第213次迭代，局部最优结果为：0.7989235300091397
# 当前最优结果:0.8062102889936462
# 第214次迭代，局部最优结果为：0.8062102889936463
# 当前最优结果:0.8062102889936462
# 第215次迭代，局部最优结果为：0.8024275805793554
# 当前最优结果:0.8062102889936462
# 第216次迭代，局部最优结果为：0.7981939935064936
# 当前最优结果:0.8062102889936462
# 第217次迭代，局部最优结果为：0.8044789855813478
# 当前最优结果:0.8062102889936462
# 第218次迭代，局部最优结果为：0.7989235300091397
# 当前最优结果:0.8062102889936462
# 第219次迭代，局部最优结果为：0.7747176995798319
# 当前最优结果:0.8062102889936462
# 第220次迭代，局部最优结果为：0.776859776168532
# 当前最优结果:0.8062102889936462
# 第221次迭代，局部最优结果为：0.8024275805793554
# 当前最优结果:0.8062102889936462
# 本次退火用时：2716.588366508484
# 第1次迭代，局部最优结果为：0.4897285856573705
# 当前最优结果:0.48972858565737054
# 第2次迭代，局部最优结果为：0.575549919523972
# 当前最优结果:0.575549919523972
# 第3次迭代，局部最优结果为：0.6270857689446275
# 当前最优结果:0.6270857689446275
# 第4次迭代，局部最优结果为：0.5406872852233677
# 当前最优结果:0.6270857689446275
# 第5次迭代，局部最优结果为：0.6206869345676415
# 当前最优结果:0.6270857689446275
# 第6次迭代，局部最优结果为：0.5591196607519368
# 当前最优结果:0.6270857689446275
# 第7次迭代，局部最优结果为：0.55550063550346
# 当前最优结果:0.6270857689446275
# 第8次迭代，局部最优结果为：0.6270857689446275
# 当前最优结果:0.6270857689446275
# 第9次迭代，局部最优结果为：0.6270857689446275
# 当前最优结果:0.6270857689446275
# 第10次迭代，局部最优结果为：0.5388110131957445
# 当前最优结果:0.6270857689446275
# 第11次迭代，局部最优结果为：0.5816062495379383
# 当前最优结果:0.6270857689446275
# 第12次迭代，局部最优结果为：0.5351700680272109
# 当前最优结果:0.6270857689446275
# 第13次迭代，局部最优结果为：0.5905565008507656
# 当前最优结果:0.6270857689446275
# 第14次迭代，局部最优结果为：0.6270857689446275
# 当前最优结果:0.6270857689446275
# 第15次迭代，局部最优结果为：0.6270857689446275
# 当前最优结果:0.6270857689446275
# 第16次迭代，局部最优结果为：0.5160718971398582
# 当前最优结果:0.6270857689446275
# 第17次迭代，局部最优结果为：0.6270857689446275
# 当前最优结果:0.6270857689446275
# 第18次迭代，局部最优结果为：0.5589475179992421
# 当前最优结果:0.6270857689446275
# 第19次迭代，局部最优结果为：0.6647794490451242
# 当前最优结果:0.6647794490451242
# 第20次迭代，局部最优结果为：0.6391777705557361
# 当前最优结果:0.6647794490451242
# 第21次迭代，局部最优结果为：0.5472061210294459
# 当前最优结果:0.6647794490451242
# 第22次迭代，局部最优结果为：0.6647794490451242
# 当前最优结果:0.6647794490451242
# 第23次迭代，局部最优结果为：0.5813054187192118
# 当前最优结果:0.6647794490451242
# 第24次迭代，局部最优结果为：0.6579959852793577
# 当前最优结果:0.6647794490451242
# 第25次迭代，局部最优结果为：0.6647794490451242
# 当前最优结果:0.6647794490451242
# 第26次迭代，局部最优结果为：0.6611665172568355
# 当前最优结果:0.6647794490451242
# 第27次迭代，局部最优结果为：0.6022506889864244
# 当前最优结果:0.6647794490451242
# 第28次迭代，局部最优结果为：0.6238864363319147
# 当前最优结果:0.6647794490451242
# 第29次迭代，局部最优结果为：0.6021892222902633
# 当前最优结果:0.6647794490451242
# 第30次迭代，局部最优结果为：0.5919191412520065
# 当前最优结果:0.6647794490451242
# 第31次迭代，局部最优结果为：0.5607270135424092
# 当前最优结果:0.6647794490451242
# 第32次迭代，局部最优结果为：0.6647794490451242
# 当前最优结果:0.6647794490451242
# 第33次迭代，局部最优结果为：0.6141295862607338
# 当前最优结果:0.6647794490451242
# 第34次迭代，局部最优结果为：0.6647794490451242
# 当前最优结果:0.6647794490451242
# 第35次迭代，局部最优结果为：0.5762947769394183
# 当前最优结果:0.6647794490451242
# 第36次迭代，局部最优结果为：0.6647794490451242
# 当前最优结果:0.6647794490451242
# 第37次迭代，局部最优结果为：0.5487966515521451
# 当前最优结果:0.6647794490451242
# 第38次迭代，局部最优结果为：0.5706513854635137
# 当前最优结果:0.6647794490451242
# 第39次迭代，局部最优结果为：0.5253071581196581
# 当前最优结果:0.6647794490451242
# 第40次迭代，局部最优结果为：0.548528796541626
# 当前最优结果:0.6647794490451242
# 第41次迭代，局部最优结果为：0.5458266842433914
# 当前最优结果:0.6647794490451242
# 第42次迭代，局部最优结果为：0.708313325330132
# 当前最优结果:0.708313325330132
# 第43次迭代，局部最优结果为：0.5809333924088023
# 当前最优结果:0.708313325330132
# 第44次迭代，局部最优结果为：0.6279533844189017
# 当前最优结果:0.708313325330132
# 第45次迭代，局部最优结果为：0.6508825151682295
# 当前最优结果:0.708313325330132
# 第46次迭代，局部最优结果为：0.672029385802557
# 当前最优结果:0.708313325330132
# 第47次迭代，局部最优结果为：0.6145133572879238
# 当前最优结果:0.708313325330132
# 第48次迭代，局部最优结果为：0.6652666591498478
# 当前最优结果:0.708313325330132
# 第49次迭代，局部最优结果为：0.5873817819810851
# 当前最优结果:0.708313325330132
# 第50次迭代，局部最优结果为：0.708313325330132
# 当前最优结果:0.708313325330132
# 第51次迭代，局部最优结果为：0.7125045284385944
# 当前最优结果:0.7125045284385944
# 第52次迭代，局部最优结果为：0.5258221192407093
# 当前最优结果:0.7125045284385944
# 第53次迭代，局部最优结果为：0.5058513374485597
# 当前最优结果:0.7125045284385944
# 第54次迭代，局部最优结果为：0.681223841824217
# 当前最优结果:0.7125045284385944
# 第55次迭代，局部最优结果为：0.6618525477439076
# 当前最优结果:0.7125045284385944
# 第56次迭代，局部最优结果为：0.7125045284385944
# 当前最优结果:0.7125045284385944
# 第57次迭代，局部最优结果为：0.5135787961874918
# 当前最优结果:0.7125045284385944
# 第58次迭代，局部最优结果为：0.6920302603800141
# 当前最优结果:0.7125045284385944
# 第59次迭代，局部最优结果为：0.7125045284385944
# 当前最优结果:0.7125045284385944
# 第60次迭代，局部最优结果为：0.7114306384517995
# 当前最优结果:0.7125045284385944
# 第61次迭代，局部最优结果为：0.6123767514270888
# 当前最优结果:0.7125045284385944
# 第62次迭代，局部最优结果为：0.7125045284385944
# 当前最优结果:0.7125045284385944
# 第63次迭代，局部最优结果为：0.5382457580733443
# 当前最优结果:0.7125045284385944
# 第64次迭代，局部最优结果为：0.6229313484836487
# 当前最优结果:0.7125045284385944
# 第65次迭代，局部最优结果为：0.6913410275938837
# 当前最优结果:0.7125045284385944
# 第66次迭代，局部最优结果为：0.5788105456774985
# 当前最优结果:0.7125045284385944
# 第67次迭代，局部最优结果为：0.6650042265426881
# 当前最优结果:0.7125045284385944
# 第68次迭代，局部最优结果为：0.6618525477439076
# 当前最优结果:0.7125045284385944
# 第69次迭代，局部最优结果为：0.5509103641456583
# 当前最优结果:0.7125045284385944
# 第70次迭代，局部最优结果为：0.5520701754385965
# 当前最优结果:0.7125045284385944
# 第71次迭代，局部最优结果为：0.5313745356298548
# 当前最优结果:0.7125045284385944
# 第72次迭代，局部最优结果为：0.5235823941787204
# 当前最优结果:0.7125045284385944
# 第73次迭代，局部最优结果为：0.7017632541405251
# 当前最优结果:0.7125045284385944
# 第74次迭代，局部最优结果为：0.5770697833634897
# 当前最优结果:0.7125045284385944
# 第75次迭代，局部最优结果为：0.5629338103756709
# 当前最优结果:0.7125045284385944
# 第76次迭代，局部最优结果为：0.6328024453024453
# 当前最优结果:0.7125045284385944
# 第77次迭代，局部最优结果为：0.6650042265426881
# 当前最优结果:0.7125045284385944
# 第78次迭代，局部最优结果为：0.6764790185737216
# 当前最优结果:0.7125045284385944
# 第79次迭代，局部最优结果为：0.6239029290472666
# 当前最优结果:0.7125045284385944
# 第80次迭代，局部最优结果为：0.6595405767940979
# 当前最优结果:0.7125045284385944
# 第81次迭代，局部最优结果为：0.6237050739957717
# 当前最优结果:0.7125045284385944
# 第82次迭代，局部最优结果为：0.681223841824217
# 当前最优结果:0.7125045284385944
# 第83次迭代，局部最优结果为：0.6650042265426881
# 当前最优结果:0.7125045284385944
# 第84次迭代，局部最优结果为：0.6935554967821563
# 当前最优结果:0.7125045284385944
# 第85次迭代，局部最优结果为：0.5619285714285714
# 当前最优结果:0.7125045284385944
# 第86次迭代，局部最优结果为：0.6270857689446275
# 当前最优结果:0.7125045284385944
# 第87次迭代，局部最优结果为：0.7125045284385944
# 当前最优结果:0.7125045284385944
# 第88次迭代，局部最优结果为：0.5905565008507656
# 当前最优结果:0.7125045284385944
# 第89次迭代，局部最优结果为：0.596587462082912
# 当前最优结果:0.7125045284385944
# 第90次迭代，局部最优结果为：0.5318295513441648
# 当前最优结果:0.7125045284385944
# 第91次迭代，局部最优结果为：0.6098292033797577
# 当前最优结果:0.7125045284385944
# 第92次迭代，局部最优结果为：0.6197741596638655
# 当前最优结果:0.7125045284385944
# 第93次迭代，局部最优结果为：0.5361913849509269
# 当前最优结果:0.7125045284385944
# 第94次迭代，局部最优结果为：0.7125045284385944
# 当前最优结果:0.7125045284385944
# 第95次迭代，局部最优结果为：0.5789099293563579
# 当前最优结果:0.7125045284385944
# 第96次迭代，局部最优结果为：0.5794642637923838
# 当前最优结果:0.7125045284385944
# 第97次迭代，局部最优结果为：0.7125045284385944
# 当前最优结果:0.7125045284385944
# 第98次迭代，局部最优结果为：0.6241009096678655
# 当前最优结果:0.7125045284385944
# 第99次迭代，局部最优结果为：0.6595405767940979
# 当前最优结果:0.7125045284385944
# 第100次迭代，局部最优结果为：0.7114306384517995
# 当前最优结果:0.7125045284385944
# 第101次迭代，局部最优结果为：0.7125045284385944
# 当前最优结果:0.7125045284385944
# 第102次迭代，局部最优结果为：0.6676379066478076
# 当前最优结果:0.7125045284385944
# 第103次迭代，局部最优结果为：0.6400444757823941
# 当前最优结果:0.7125045284385944
# 第104次迭代，局部最优结果为：0.608147804576376
# 当前最优结果:0.7125045284385944
# 第105次迭代，局部最优结果为：0.5750730994152047
# 当前最优结果:0.7125045284385944
# 第106次迭代，局部最优结果为：0.7167456268221574
# 当前最优结果:0.7167456268221575
# 第107次迭代，局部最优结果为：0.6427287581699347
# 当前最优结果:0.7167456268221575
# 第108次迭代，局部最优结果为：0.6243650793650793
# 当前最优结果:0.7167456268221575
# 第109次迭代，局部最优结果为：0.6250595900206578
# 当前最优结果:0.7167456268221575
# 第110次迭代，局部最优结果为：0.7125045284385944
# 当前最优结果:0.7167456268221575
# 第111次迭代，局部最优结果为：0.5388356164383562
# 当前最优结果:0.7167456268221575
# 第112次迭代，局部最优结果为：0.7167456268221574
# 当前最优结果:0.7167456268221575
# 第113次迭代，局部最优结果为：0.6029276517473942
# 当前最优结果:0.7167456268221575
# 第114次迭代，局部最优结果为：0.6876748251748251
# 当前最优结果:0.7167456268221575
# 第115次迭代，局部最优结果为：0.6689625850340135
# 当前最优结果:0.7167456268221575
# 第116次迭代，局部最优结果为：0.7131073241479333
# 当前最优结果:0.7167456268221575
# 第117次迭代，局部最优结果为：0.64738314680711
# 当前最优结果:0.7167456268221575
# 第118次迭代，局部最优结果为：0.5780025470219436
# 当前最优结果:0.7167456268221575
# 第119次迭代，局部最优结果为：0.7241347569955817
# 当前最优结果:0.7241347569955817
# 第120次迭代，局部最优结果为：0.6647794490451242
# 当前最优结果:0.7241347569955817
# 第121次迭代，局部最优结果为：0.7059404163675521
# 当前最优结果:0.7241347569955817
# 第122次迭代，局部最优结果为：0.6753949175824175
# 当前最优结果:0.7241347569955817
# 第123次迭代，局部最优结果为：0.7131073241479333
# 当前最优结果:0.7241347569955817
# 第124次迭代，局部最优结果为：0.6470991445492432
# 当前最优结果:0.7241347569955817
# 第125次迭代，局部最优结果为：0.6416279259440503
# 当前最优结果:0.7241347569955817
# 第126次迭代，局部最优结果为：0.7241347569955817
# 当前最优结果:0.7241347569955817
# 第127次迭代，局部最优结果为：0.6289574672209786
# 当前最优结果:0.7241347569955817
# 第128次迭代，局部最优结果为：0.7241347569955817
# 当前最优结果:0.7241347569955817
# 第129次迭代，局部最优结果为：0.7114306384517995
# 当前最优结果:0.7241347569955817
# 第130次迭代，局部最优结果为：0.6704829545454546
# 当前最优结果:0.7241347569955817
# 第131次迭代，局部最优结果为：0.7241347569955817
# 当前最优结果:0.7241347569955817
# 第132次迭代，局部最优结果为：0.6739291833238149
# 当前最优结果:0.7241347569955817
# 第133次迭代，局部最优结果为：0.6064600678384212
# ...
# 当前最优结果:0.7552803379416283
# 第178次迭代，局部最优结果为：0.7593629343629344
# 当前最优结果:0.7593629343629343
# 第179次迭代，局部最优结果为：0.7350046714419184
# 当前最优结果:0.7593629343629343
# 第180次迭代，局部最优结果为：0.7463946869070209
# 当前最优结果:0.7593629343629343
# 第181次迭代，局部最优结果为：0.7463946869070209
# 当前最优结果:0.7593629343629343
# 第182次迭代，局部最优结果为：0.724801916344205
# 当前最优结果:0.7593629343629343
# 第183次迭代，局部最优结果为：0.7593629343629344
# 当前最优结果:0.7593629343629343
# 第184次迭代，局部最优结果为：0.7388935850474313
# 当前最优结果:0.7593629343629343
# 第185次迭代，局部最优结果为：0.7552803379416283
# 当前最优结果:0.7593629343629343
# 第186次迭代，局部最优结果为：0.7463946869070209
# 当前最优结果:0.7593629343629343
# 第187次迭代，局部最优结果为：0.724801916344205
# 当前最优结果:0.7593629343629343
# 第188次迭代，局部最优结果为：0.7424032714690154
# 当前最优结果:0.7593629343629343
# 第189次迭代，局部最优结果为：0.7634899068322981
# 当前最优结果:0.7634899068322981
# 第190次迭代，局部最优结果为：0.7589722150758941
# 当前最优结果:0.7634899068322981
# 第191次迭代，局部最优结果为：0.7634899068322981
# 当前最优结果:0.7634899068322981
# 第192次迭代，局部最优结果为：0.7634899068322981
# 当前最优结果:0.7634899068322981
# 第193次迭代，局部最优结果为：0.7500953470633105
# 当前最优结果:0.7634899068322981
# 第194次迭代，局部最优结果为：0.7593629343629344
# 当前最优结果:0.7634899068322981
# 第195次迭代，局部最优结果为：0.7291010194624653
# 当前最优结果:0.7634899068322981
# 第196次迭代，局部最优结果为：0.7676619828259174
# 当前最优结果:0.7676619828259172
# 第197次迭代，局部最优结果为：0.7676619828259174
# 当前最优结果:0.7676619828259172
# 第198次迭代，局部最优结果为：0.7816194734227521
# 当前最优结果:0.7816194734227521
# 第199次迭代，局部最优结果为：0.7816194734227521
# 当前最优结果:0.7816194734227521
# 第200次迭代，局部最优结果为：0.7625278666278957
# 当前最优结果:0.7816194734227521
# 第201次迭代，局部最优结果为：0.7463002782696686
# 当前最优结果:0.7816194734227521
# 第202次迭代，局部最优结果为：0.7212137880454712
# 当前最优结果:0.7816194734227521
# 第203次迭代，局部最优结果为：0.717661010764459
# 当前最优结果:0.7816194734227521
# 第204次迭代，局部最优结果为：0.7816194734227521
# 当前最优结果:0.7816194734227521
# 第205次迭代，局部最优结果为：0.7673125690877171
# 当前最优结果:0.7816194734227521
# 第206次迭代，局部最优结果为：0.7371626686656672
# 当前最优结果:0.7816194734227521
# 第207次迭代，局部最优结果为：0.7816194734227521
# 当前最优结果:0.7816194734227521
# 第208次迭代，局部最优结果为：0.7816194734227521
# 当前最优结果:0.7816194734227521
# 第209次迭代，局部最优结果为：0.7246683861459101
# 当前最优结果:0.7816194734227521
# 第210次迭代，局部最优结果为：0.7816194734227521
# 当前最优结果:0.7816194734227521
# 第211次迭代，局部最优结果为：0.7408651431441486
# 当前最优结果:0.7816194734227521
# 第212次迭代，局部最优结果为：0.7816194734227521
# 当前最优结果:0.7816194734227521
# 第213次迭代，局部最优结果为：0.6943512797881729
# 当前最优结果:0.7816194734227521
# 第214次迭代，局部最优结果为：0.7357837635615413
# 当前最优结果:0.7816194734227521
# 第215次迭代，局部最优结果为：0.7816194734227521
# 当前最优结果:0.7816194734227521
# 第216次迭代，局部最优结果为：0.7631196042293141
# 当前最优结果:0.7816194734227521
# 第217次迭代，局部最优结果为：0.7816194734227521
# 当前最优结果:0.7816194734227521
# 第218次迭代，局部最优结果为：0.7912098964095343
# 当前最优结果:0.7912098964095343
# 第219次迭代，局部最优结果为：0.7960939081157661
# 当前最优结果:0.7960939081157661
# 第220次迭代，局部最优结果为：0.7816194734227521
# 当前最优结果:0.7960939081157661
# 第221次迭代，局部最优结果为：0.6925176056338028
# 当前最优结果:0.7960939081157661
# 本次退火用时：2703.442693710327
# 第1次迭代，局部最优结果为：0.5119300681098434
# 当前最优结果:0.5119300681098434
# 第2次迭代，局部最优结果为：0.5114641123439667
# 当前最优结果:0.5119300681098434
# 第3次迭代，局部最优结果为：0.5445044296788483
# 当前最优结果:0.5445044296788483
# 第4次迭代，局部最优结果为：0.5065461881868132
# 当前最优结果:0.5445044296788483
# 第5次迭代，局部最优结果为：0.5322253292440916
# 当前最优结果:0.5445044296788483
# 第6次迭代，局部最优结果为：0.5197542283298097
# 当前最优结果:0.5445044296788483
# 第7次迭代，局部最优结果为：0.5492692236082666
# 当前最优结果:0.5492692236082666
# 第8次迭代，局部最优结果为：0.5060682734368299
# 当前最优结果:0.5492692236082666
# 第9次迭代，局部最优结果为：0.5492692236082666
# 当前最优结果:0.5492692236082666
# 第10次迭代，局部最优结果为：0.5227937267410951
# 当前最优结果:0.5492692236082666
# 第11次迭代，局部最优结果为：0.5556314153875129
# 当前最优结果:0.5556314153875129
# 第12次迭代，局部最优结果为：0.5066766852726492
# 当前最优结果:0.5556314153875129
# 第13次迭代，局部最优结果为：0.5057862929150058
# 当前最优结果:0.5556314153875129
# 第14次迭代，局部最优结果为：0.5539360653429095
# 当前最优结果:0.5556314153875129
# 第15次迭代，局部最优结果为：0.5369721514379323
# 当前最优结果:0.5556314153875129
# 第16次迭代，局部最优结果为：0.5531052261542067
# 当前最优结果:0.5556314153875129
# 第17次迭代，局部最优结果为：0.5923499736465627
# 当前最优结果:0.5923499736465627
# 第18次迭代，局部最优结果为：0.49162604674415694
# 当前最优结果:0.5923499736465627
# 第19次迭代，局部最优结果为：0.5923499736465627
# 当前最优结果:0.5923499736465627
# 第20次迭代，局部最优结果为：0.5750730994152047
# 当前最优结果:0.5923499736465627
# 第21次迭代，局部最优结果为：0.5923499736465627
# 当前最优结果:0.5923499736465627
# 第22次迭代，局部最优结果为：0.5433761569277524
# 当前最优结果:0.5923499736465627
# 第23次迭代，局部最优结果为：0.5628129918443269
# 当前最优结果:0.5923499736465627
# 第24次迭代，局部最优结果为：0.5309083547037386
# 当前最优结果:0.5923499736465627
# 第25次迭代，局部最优结果为：0.5106673013674917
# 当前最优结果:0.5923499736465627
# 第26次迭代，局部最优结果为：0.5331149762819065
# 当前最优结果:0.5923499736465627
# 第27次迭代，局部最优结果为：0.5958343852562484
# 当前最优结果:0.5958343852562484
# 第28次迭代，局部最优结果为：0.5443411675162028
# 当前最优结果:0.5958343852562484
# 第29次迭代，局部最优结果为：0.5948732167162373
# 当前最优结果:0.5958343852562484
# 第30次迭代，局部最优结果为：0.5128422425032594
# 当前最优结果:0.5958343852562484
# 第31次迭代，局部最优结果为：0.5958343852562484
# 当前最优结果:0.5958343852562484
# 第32次迭代，局部最优结果为：0.5627324749642346
# 当前最优结果:0.5958343852562484
# 第33次迭代，局部最优结果为：0.5873525459160818
# 当前最优结果:0.5958343852562484
# 第34次迭代，局部最优结果为：0.49446888749214335
# 当前最优结果:0.5958343852562484
# 第35次迭代，局部最优结果为：0.5494738312534923
# 当前最优结果:0.5958343852562484
# 第36次迭代，局部最优结果为：0.5627324749642346
# 当前最优结果:0.5958343852562484
# 第37次迭代，局部最优结果为：0.5857781087118391
# 当前最优结果:0.5958343852562484
# 第38次迭代，局部最优结果为：0.6000762776506483
# 当前最优结果:0.6000762776506484
# 第39次迭代，局部最优结果为：0.6416104828186168
# 当前最优结果:0.6416104828186168
# 第40次迭代，局部最优结果为：0.5888913840856351
# 当前最优结果:0.6416104828186168
# 第41次迭代，局部最优结果为：0.5227937267410951
# 当前最优结果:0.6416104828186168
# 第42次迭代，局部最优结果为：0.6179566401340595
# 当前最优结果:0.6416104828186168
# 第43次迭代，局部最优结果为：0.5562731279609683
# 当前最优结果:0.6416104828186168
# 第44次迭代，局部最优结果为：0.6732563115104836
# 当前最优结果:0.6732563115104835
# 第45次迭代，局部最优结果为：0.5901577855017379
# 当前最优结果:0.6732563115104835
# 第46次迭代，局部最优结果为：0.49225153822087814
# 当前最优结果:0.6732563115104835
# 第47次迭代，局部最优结果为：0.6256892895015908
# 当前最优结果:0.6732563115104835
# 第48次迭代，局部最优结果为：0.6302170952495394
# 当前最优结果:0.6732563115104835
# 第49次迭代，局部最优结果为：0.5987062404870624
# 当前最优结果:0.6732563115104835
# 第50次迭代，局部最优结果为：0.687314345622925
# 当前最优结果:0.687314345622925
# 第51次迭代，局部最优结果为：0.6369352836400929
# 当前最优结果:0.687314345622925
# 第52次迭代，局部最优结果为：0.5979326594208406
# 当前最优结果:0.687314345622925
# 第53次迭代，局部最优结果为：0.6369352836400929
# 当前最优结果:0.687314345622925
# 第54次迭代，局部最优结果为：0.687314345622925
# 当前最优结果:0.687314345622925
# 第55次迭代，局部最优结果为：0.6575926441905823
# 当前最优结果:0.687314345622925
# 第56次迭代，局部最优结果为：0.6568422810386574
# 当前最优结果:0.687314345622925
# 第57次迭代，局部最优结果为：0.687314345622925
# 当前最优结果:0.687314345622925
# 第58次迭代，局部最优结果为：0.687314345622925
# 当前最优结果:0.687314345622925
# 第59次迭代，局部最优结果为：0.6764790185737216
# 当前最优结果:0.687314345622925
# 第60次迭代，局部最优结果为：0.5307292720771773
# 当前最优结果:0.687314345622925
# 第61次迭代，局部最优结果为：0.687314345622925
# 当前最优结果:0.687314345622925
# 第62次迭代，局部最优结果为：0.707294413809638
# 当前最优结果:0.707294413809638
# 第63次迭代，局部最优结果为：0.647241114523914
# 当前最优结果:0.707294413809638
# 第64次迭代，局部最优结果为：0.6978415138971024
# 当前最优结果:0.707294413809638
# 第65次迭代，局部最优结果为：0.6868342936965252
# 当前最优结果:0.707294413809638
# 第66次迭代，局部最优结果为：0.6436753395516281
# 当前最优结果:0.707294413809638
# 第67次迭代，局部最优结果为：0.5886123304070231
# 当前最优结果:0.707294413809638
# 第68次迭代，局部最优结果为：0.6753562639500944
# 当前最优结果:0.707294413809638
# 第69次迭代，局部最优结果为：0.707294413809638
# 当前最优结果:0.707294413809638
# 第70次迭代，局部最优结果为：0.6206869345676415
# 当前最优结果:0.707294413809638
# 第71次迭代，局部最优结果为：0.6605743394536499
# 当前最优结果:0.707294413809638
# 第72次迭代，局部最优结果为：0.707294413809638
# 当前最优结果:0.707294413809638
# 第73次迭代，局部最优结果为：0.5532867591897974
# 当前最优结果:0.707294413809638
# 第74次迭代，局部最优结果为：0.5870165402313146
# 当前最优结果:0.707294413809638
# 第75次迭代，局部最优结果为：0.6273524720893141
# 当前最优结果:0.707294413809638
# 第76次迭代，局部最优结果为：0.687314345622925
# 当前最优结果:0.707294413809638
# 第77次迭代，局部最优结果为：0.5905565008507656
# 当前最优结果:0.707294413809638
# 第78次迭代，局部最优结果为：0.707294413809638
# 当前最优结果:0.707294413809638
# 第79次迭代，局部最优结果为：0.6860755813953489
# 当前最优结果:0.707294413809638
# 第80次迭代，局部最优结果为：0.5149908352971982
# 当前最优结果:0.707294413809638
# 第81次迭代，局部最优结果为：0.707294413809638
# 当前最优结果:0.707294413809638
# 第82次迭代，局部最优结果为：0.6402875746066197
# 当前最优结果:0.707294413809638
# 第83次迭代，局部最优结果为：0.5814199842333465
# 当前最优结果:0.707294413809638
# 第84次迭代，局部最优结果为：0.6565316568376544
# 当前最优结果:0.707294413809638
# 第85次迭代，局部最优结果为：0.6834530290744817
# 当前最优结果:0.707294413809638
# 第86次迭代，局部最优结果为：0.5967986648460022
# 当前最优结果:0.707294413809638
# 第87次迭代，局部最优结果为：0.548528796541626
# 当前最优结果:0.707294413809638
# 第88次迭代，局部最优结果为：0.707294413809638
# 当前最优结果:0.707294413809638
# 第89次迭代，局部最优结果为：0.6462486308871851
# 当前最优结果:0.707294413809638
# 第90次迭代，局部最优结果为：0.6051538461538462
# 当前最优结果:0.707294413809638
# 第91次迭代，局部最优结果为：0.6758591065292097
# 当前最优结果:0.707294413809638
# 第92次迭代，局部最优结果为：0.6759365333944324
# 当前最优结果:0.707294413809638
# 第93次迭代，局部最优结果为：0.614609375
# 当前最优结果:0.707294413809638
# 第94次迭代，局部最优结果为：0.6462486308871851
# 当前最优结果:0.707294413809638
# 第95次迭代，局部最优结果为：0.5442784004427841
# 当前最优结果:0.707294413809638
# 第96次迭代，局部最优结果为：0.5618081839605799
# 当前最优结果:0.707294413809638
# 第97次迭代，局部最优结果为：0.6787748058671269
# 当前最优结果:0.707294413809638
# 第98次迭代，局部最优结果为：0.5178951526189901
# 当前最优结果:0.707294413809638
# 第99次迭代，局部最优结果为：0.6759365333944324
# 当前最优结果:0.707294413809638
# 第100次迭代，局部最优结果为：0.5820796132787451
# 当前最优结果:0.707294413809638
# 第101次迭代，局部最优结果为：0.6023890349421884
# 当前最优结果:0.707294413809638
# 第102次迭代，局部最优结果为：0.707294413809638
# 当前最优结果:0.707294413809638
# 第103次迭代，局部最优结果为：0.6991645929612513
# 当前最优结果:0.707294413809638
# 第104次迭代，局部最优结果为：0.5635252262362408
# 当前最优结果:0.707294413809638
# 第105次迭代，局部最优结果为：0.6588777219430486
# 当前最优结果:0.707294413809638
# 第106次迭代，局部最优结果为：0.6153144227760976
# 当前最优结果:0.707294413809638
# 第107次迭代，局部最优结果为：0.707294413809638
# 当前最优结果:0.707294413809638
# 第108次迭代，局部最优结果为：0.6611665172568355
# 当前最优结果:0.707294413809638
# 第109次迭代，局部最优结果为：0.707294413809638
# 当前最优结果:0.707294413809638
# 第110次迭代，局部最优结果为：0.6912195407685099
# 当前最优结果:0.707294413809638
# 第111次迭代，局部最优结果为：0.636145552560647
# 当前最优结果:0.707294413809638
# 第112次迭代，局部最优结果为：0.5936163790935157
# 当前最优结果:0.707294413809638
# 第113次迭代，局部最优结果为：0.6442024238453979
# 当前最优结果:0.707294413809638
# 第114次迭代，局部最优结果为：0.5905565008507656
# 当前最优结果:0.707294413809638
# 第115次迭代，局部最优结果为：0.5813626958321017
# 当前最优结果:0.707294413809638
# 第116次迭代，局部最优结果为：0.570196419511488
# 当前最优结果:0.707294413809638
# 第117次迭代，局部最优结果为：0.6336179123711341
# 当前最优结果:0.707294413809638
# 第118次迭代，局部最优结果为：0.5770980046948356
# 当前最优结果:0.707294413809638
# 第119次迭代，局部最优结果为：0.7032060067933973
# 当前最优结果:0.707294413809638
# 第120次迭代，局部最优结果为：0.6991645929612513
# 当前最优结果:0.707294413809638
# 第121次迭代，局部最优结果为：0.6441496765741423
# 当前最优结果:0.707294413809638
# 第122次迭代，局部最优结果为：0.6023890349421884
# 当前最优结果:0.707294413809638
# 第123次迭代，局部最优结果为：0.5972517461281506
# 当前最优结果:0.707294413809638
# 第124次迭代，局部最优结果为：0.6369352836400929
# 当前最优结果:0.707294413809638
# 第125次迭代，局部最优结果为：0.6759365333944324
# 当前最优结果:0.707294413809638
# 第126次迭代，局部最优结果为：0.6600939754992448
# 当前最优结果:0.707294413809638
# 第127次迭代，局部最优结果为：0.6325649959796301
# 当前最优结果:0.707294413809638
# 第128次迭代，局部最优结果为：0.6806933548684818
# 当前最优结果:0.707294413809638
# 第129次迭代，局部最优结果为：0.6900877192982456
# 当前最优结果:0.707294413809638
# 第130次迭代，局部最优结果为：0.6834530290744817
# 当前最优结果:0.707294413809638
# 第131次迭代，局部最优结果为：0.6951693667157585
# 当前最优结果:0.707294413809638
# 第132次迭代，局部最优结果为：0.6860755813953489
# 当前最优结果:0.707294413809638
# 第133次迭代，局部最优结果为：0.6071777720607152
# 当前最优结果:0.707294413809638
# 第134次迭代，局部最优结果为：0.6643490499648136
# 当前最优结果:0.707294413809638
# 第135次迭代，局部最优结果为：0.6462486308871851
# 当前最优结果:0.707294413809638
# 第136次迭代，局部最优结果为：0.6462486308871851
# 当前最优结果:0.707294413809638
# 第137次迭代，局部最优结果为：0.6462486308871851
# 当前最优结果:0.707294413809638
# 第138次迭代，局部最优结果为：0.6895231973822601
# 当前最优结果:0.707294413809638
# 第139次迭代，局部最优结果为：0.6693420306296086
# 当前最优结果:0.707294413809638
# 第140次迭代，局部最优结果为：0.6951693667157585
# 当前最优结果:0.707294413809638
# 第141次迭代，局部最优结果为：0.6575926441905823
# 当前最优结果:0.707294413809638
# 第142次迭代，局部最优结果为：0.6796348557276969
# 当前最优结果:0.707294413809638
# 第143次迭代，局部最优结果为：0.707294413809638
# 当前最优结果:0.707294413809638
# 第144次迭代，局部最优结果为：0.6982544378698224
# 当前最优结果:0.707294413809638
# 第145次迭代，局部最优结果为：0.6770223752151463
# 当前最优结果:0.707294413809638
# 第146次迭代，局部最优结果为：0.6693420306296086
# 当前最优结果:0.707294413809638
# 第147次迭代，局部最优结果为：0.707294413809638
# 当前最优结果:0.707294413809638
# 第148次迭代，局部最优结果为：0.6991645929612513
# 当前最优结果:0.707294413809638
# 第149次迭代，局部最优结果为：0.659043310714585
# 当前最优结果:0.707294413809638
# 第150次迭代，局部最优结果为：0.707294413809638
# 当前最优结果:0.707294413809638
# 第151次迭代，局部最优结果为：0.707294413809638
# 当前最优结果:0.707294413809638
# 第152次迭代，局部最优结果为：0.707294413809638
# 当前最优结果:0.707294413809638
# 第153次迭代，局部最优结果为：0.7438071225969114
# 当前最优结果:0.7438071225969114
# 第154次迭代，局部最优结果为：0.7438071225969114
# 当前最优结果:0.7438071225969114
# 第155次迭代，局部最优结果为：0.707294413809638
# 当前最优结果:0.7438071225969114
# 第156次迭代，局部最优结果为：0.7210375168031284
# 当前最优结果:0.7438071225969114
# 第157次迭代，局部最优结果为：0.6761882932699196
# 当前最优结果:0.7438071225969114
# 第158次迭代，局部最优结果为：0.6441496765741423
# 当前最优结果:0.7438071225969114
# 第159次迭代，局部最优结果为：0.6647232784114914
# 当前最优结果:0.7438071225969114
# 第160次迭代，局部最优结果为：0.699620560858481
# 当前最优结果:0.7438071225969114
# 第161次迭代，局部最优结果为：0.699620560858481
# 当前最优结果:0.7438071225969114
# 第162次迭代，局部最优结果为：0.6666195910066659
# 当前最优结果:0.7438071225969114
# 第163次迭代，局部最优结果为：0.7438071225969114
# 当前最优结果:0.7438071225969114
# 第164次迭代，局部最优结果为：0.7438071225969114
# 当前最优结果:0.7438071225969114
# 第165次迭代，局部最优结果为：0.7060882572924458
# 当前最优结果:0.7438071225969114
# 第166次迭代，局部最优结果为：0.7081008100810081
# 当前最优结果:0.7438071225969114
# 第167次迭代，局部最优结果为：0.7438071225969114
# 当前最优结果:0.7438071225969114
# 第168次迭代，局部最优结果为：0.699620560858481
# 当前最优结果:0.7438071225969114
# 第169次迭代，局部最优结果为：0.7264081255771007
# 当前最优结果:0.7438071225969114
# 第170次迭代，局部最优结果为：0.7360591317365269
# 当前最优结果:0.7438071225969114
# 第171次迭代，局部最优结果为：0.7438071225969114
# 当前最优结果:0.7438071225969114
# 第172次迭代，局部最优结果为：0.7393796992481203
# 当前最优结果:0.7438071225969114
# 第173次迭代，局部最优结果为：0.7316778273809523
# 当前最优结果:0.7438071225969114
# 第174次迭代，局部最优结果为：0.7060882572924458
# 当前最优结果:0.7438071225969114
# 第175次迭代，局部最优结果为：0.7092499098449333
# 当前最优结果:0.7438071225969114
# 第176次迭代，局部最优结果为：0.7522470835723848
# 当前最优结果:0.7522470835723848
# 第177次迭代，局部最优结果为：0.7482878883956879
# 当前最优结果:0.7522470835723848
# 第178次迭代，局部最优结果为：0.7568061568061568
# 当前最优结果:0.7568061568061568
# 第179次迭代，局部最优结果为：0.7568061568061568
# 当前最优结果:0.7568061568061568
# 第180次迭代，局部最优结果为：0.7602925069261002
# 当前最优结果:0.7602925069261002
# 第181次迭代，局部最优结果为：0.7608317214700193
# 当前最优结果:0.7608317214700193
# 第182次迭代，局部最优结果为：0.7302515548129582
# 当前最优结果:0.7608317214700193
# 第183次迭代，局部最优结果为：0.7602925069261002
# 当前最优结果:0.7608317214700193
# 第184次迭代，局部最优结果为：0.7718799058084772
# 当前最优结果:0.7718799058084772
# 第185次迭代，局部最优结果为：0.7602925069261002
# 当前最优结果:0.7718799058084772
# 第186次迭代，局部最优结果为：0.7568061568061568
# 当前最优结果:0.7718799058084772
# 第187次迭代，局部最优结果为：0.7583381530749951
# 当前最优结果:0.7718799058084772
# 第188次迭代，局部最优结果为：0.7589722150758941
# 当前最优结果:0.7718799058084772
# 第189次迭代，局部最优结果为：0.7598029746957697
# 当前最优结果:0.7718799058084772
# 第190次迭代，局部最优结果为：0.7568061568061568
# 当前最优结果:0.7718799058084772
# 第191次迭代，局部最优结果为：0.7568061568061568
# 当前最优结果:0.7718799058084772
# 第192次迭代，局部最优结果为：0.7477426100180592
# 当前最优结果:0.7718799058084772
# 第193次迭代，局部最优结果为：0.7598029746957697
# 当前最优结果:0.7718799058084772
# 第194次迭代，局部最优结果为：0.7643801010493587
# 当前最优结果:0.7718799058084772
# 第195次迭代，局部最优结果为：0.7718799058084772
# 当前最优结果:0.7718799058084772
# 第196次迭代，局部最优结果为：0.7598029746957697
# 当前最优结果:0.7718799058084772
# 第197次迭代，局部最优结果为：0.7512414056531704
# 当前最优结果:0.7718799058084772
# 第198次迭代，局部最优结果为：0.7602925069261002
# 当前最优结果:0.7718799058084772
# 第199次迭代，局部最优结果为：0.7718799058084772
# 当前最优结果:0.7718799058084772
# 第200次迭代，局部最优结果为：0.7902561526870919
# 当前最优结果:0.7902561526870919
# 第201次迭代，局部最优结果为：0.7902561526870919
# 当前最优结果:0.7902561526870919
# 第202次迭代，局部最优结果为：0.8035750766087845
# 当前最优结果:0.8035750766087845
# 第203次迭代，局部最优结果为：0.8035750766087845
# 当前最优结果:0.8035750766087845
# 第204次迭代，局部最优结果为：0.7773715415019762
# 当前最优结果:0.8035750766087845
# 第205次迭代，局部最优结果为：0.8035750766087845
# 当前最优结果:0.8035750766087845
# 第206次迭代，局部最优结果为：0.7552803379416283
# 当前最优结果:0.8035750766087845
# 第207次迭代，局部最优结果为：0.8035750766087845
# 当前最优结果:0.8035750766087845
# 第208次迭代，局部最优结果为：0.7649003403014099
# 当前最优结果:0.8035750766087845
# 第209次迭代，局部最优结果为：0.8035750766087845
# 当前最优结果:0.8035750766087845
# 第210次迭代，局部最优结果为：0.7990858303707465
# 当前最优结果:0.8035750766087845
# 第211次迭代，局部最优结果为：0.7799405155320555
# 当前最优结果:0.8035750766087845
# 第212次迭代，局部最优结果为：0.8035750766087845
# 当前最优结果:0.8035750766087845
# 第213次迭代，局部最优结果为：0.7665648954137976
# 当前最优结果:0.8035750766087845
# 第214次迭代，局部最优结果为：0.7990858303707465
# 当前最优结果:0.8035750766087845
# 第215次迭代，局部最优结果为：0.8078107886089815
# 当前最优结果:0.8078107886089814
# 第216次迭代，局部最优结果为：0.7816194734227521
# 当前最优结果:0.8078107886089814
# 第217次迭代，局部最优结果为：0.8078107886089815
# 当前最优结果:0.8078107886089814
# 第218次迭代，局部最优结果为：0.7902561526870919
# 当前最优结果:0.8078107886089814
# 第219次迭代，局部最优结果为：0.8035750766087845
# 当前最优结果:0.8078107886089814
# 第220次迭代，局部最优结果为：0.8035750766087845
# 当前最优结果:0.8078107886089814
# 第221次迭代，局部最优结果为：0.8035750766087845
# 当前最优结果:0.8078107886089814
# 本次退火用时：2729.118388414383

# %%
def draw(history):
    plt.plot(history['T'], history['f'])
    plt.title('SA')
    plt.xlabel('T')
    plt.ylabel('f')
    plt.gca().invert_xaxis()
    plt.show()
    return

def wrXSLX(squ, use, tim, filename):
    data = {'square':squ,'utilization':use,'timecost':tim}
    df = pd.DataFrame(data)
    df.to_excel(filename,sheet_name='layout',header=0)
    return df

def drawP(m3):
    Lw,Pw,Lh,Ph = m.lcs_xy(m3.l,m3.x,m3.y,m3.w,m3.h)
    print(Pw)
    print(Ph)
    h,w = m3.h,m3.w
    for i in range(len(Pw)):
        x,y = [Pw[i], Pw[i], Pw[i]+w[i], Pw[i]+w[i], Pw[i]],[Ph[i], Ph[i]+h[i], Ph[i]+h[i], Ph[i], Ph[i]]
        plt.plot(x,y,color='r')
        plt.scatter(x,y,color='b')
    plt.show()
    return

# %%
print("本次测试的退火环境为：")
print(sa.iter,sa.T0,sa.alpha)
squ = []
use = []
for i in range(30):
    squ.append(mmm[i].s_cur)
    use.append(mmm[i].use)
print(use)
index = use.index(max(use))
history = {'f': fff[index], 'T': TTT[index]}
print('本次最优解为：'+str(max(use)))
draw(history)

drawP(mmm[index])

wrXSLX(squ,use,sss,'result_moreT0.xlsx')
# Out:
# 本次测试的退火环境为：
# 4000 800 0.95
# [0.7797343729351129, 0.8009026740871453, 0.8062102889936462, 0.8194791666666666, 0.775226645644462, 0.8123988847199752, 0.7701670800156637, 0.7821116118769883, 0.8259606635402814, 0.8008754962842309, 0.7790651614181026, 0.7651979379437798, 0.791130329847144, 0.7968465122560605, 0.8189104788341429, 0.7467489321309919, 0.789383905277945, 0.8252097902097902, 0.7841905901116427, 0.7824486954215429, 0.7758382642998027, 0.8242299364391982, 0.8437365937365937, 0.7763486842105263, 0.8034109477124183, 0.7573161340007701, 0.7950747877644523, 0.8445215773277034, 0.7960939081157661, 0.8078107886089814]
# 本次最优解为：0.8445215773277034
# [315.   0.   0. 350. 399.   0. 959. 833. 707. 133.   0. 378. 707. 714.
#  378. 896. 574. 560. 252.   0. 826.   0. 602. 896. 651. 399. 735. 497.
#  252. 896. 714. 133. 266.]
# [1113.  700.  938.  861.  861.    0.  119.    0.  308.  140.  819.  525.
#   182.  616.  322.  616.  861.  322.  140. 1099.  182.  140.    0.  819.
#  1113.  980.    0.  616.  322.  952.  987.  322.  819.]
#        square  utilization     timecost
# 0   1483132.0     0.779734  2692.773590
# 1   1443932.0     0.800903  2712.103183
# 2   1434426.0     0.806210  2716.588367
# 3   1411200.0     0.819479  2710.346862
# 4   1491756.0     0.775227  2729.876907
# 5   1423499.0     0.812399  2727.579881
# 6   1501556.0     0.770167  2736.795128
# 7   1478624.0     0.782112  2726.132235
# 8   1400126.0     0.825961  2714.484605
# 9   1443981.0     0.800875  2714.723424
# 10  1484406.0     0.779065  2708.814733
# 11  1511307.0     0.765198  2709.196028
# 12  1461768.0     0.791130  2712.582611
# 13  1451282.0     0.796847  2715.548618
# 14  1412180.0     0.818910  2727.559401
# 15  1548645.0     0.746749  2698.845977
# 16  1465002.0     0.789384  2712.221838
# 17  1401400.0     0.825210  2726.664907
# 18  1474704.0     0.784191  2698.052667
# 19  1477987.0     0.782449  2721.961425
# 20  1490580.0     0.775838  2696.173578
# 21  1403066.0     0.824230  2709.510313
# 22  1370628.0     0.843737  2723.012812
# 23  1489600.0     0.776349  2706.499739
# 24  1439424.0     0.803411  2706.839913
# 25  1527036.0     0.757316  2698.334060
# 26  1454516.0     0.795075  2701.434053
# 27  1369354.0     0.844522  2737.274898
# 28  1452654.0     0.796094  2703.442694
# 29  1431584.0     0.807811  2729.118388
